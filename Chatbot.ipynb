# %% [markdown]
# # Importing Libraries

# %%
import numpy as np
import tensorflow as tf
import re
import time

# %% [markdown]
# # DATA PREPROCESSING

# %% [markdown]
# #  IMPORTING THE DATASET

# %%
lines = open('E:\Data\cornell movie-dialogs corpus\movie_lines.txt', encoding='utf-8', errors='ignore').read().split('\n')
conversations = open('E:\Data\cornell movie-dialogs corpus\movie_conversations.txt', encoding='utf-8', errors='ignore').read().split('\n')

# %% [markdown]
# # DICTIONARY OF LINES

# %%
id2line = {}
for line in lines:
    _line = line.split(' +++$+++ ')
    if len(_line)==5:
        id2line[_line[0]] = _line[4]

# %%
conversations
# Out:
# ["u0 +++$+++ u2 +++$+++ m0 +++$+++ ['L194', 'L195', 'L196', 'L197']",
#  "u0 +++$+++ u2 +++$+++ m0 +++$+++ ['L198', 'L199']",
#  "u0 +++$+++ u2 +++$+++ m0 +++$+++ ['L200', 'L201', 'L202', 'L203']",
#  "u0 +++$+++ u2 +++$+++ m0 +++$+++ ['L204', 'L205', 'L206']",
#  "u0 +++$+++ u2 +++$+++ m0 +++$+++ ['L207', 'L208']",
#  "u0 +++$+++ u2 +++$+++ m0 +++$+++ ['L271', 'L272', 'L273', 'L274', 'L275']",
#  "u0 +++$+++ u2 +++$+++ m0 +++$+++ ['L276', 'L277']",
#  "u0 +++$+++ u2 +++$+++ m0 +++$+++ ['L280', 'L281']",
#  "u0 +++$+++ u2 +++$+++ m0 +++$+++ ['L363', 'L364']",
#  "u0 +++$+++ u2 +++$+++ m0 +++$+++ ['L365', 'L366']",
#  "u0 +++$+++ u2 +++$+++ m0 +++$+++ ['L367', 'L368']",
#  "u0 +++$+++ u2 +++$+++ m0 +++$+++ ['L401', 'L402', 'L403']",
#  "u0 +++$+++ u2 +++$+++ m0 +++$+++ ['L404', 'L405', 'L406', 'L407']",
#  "u0 +++$+++ u2 +++$+++ m0 +++$+++ ['L575', 'L576']",
#  "u0 +++$+++ u2 +++$+++ m0 +++$+++ ['L577', 'L578']",
#  "u0 +++$+++ u2 +++$+++ m0 +++$+++ ['L662', 'L663']",
#  "u0 +++$+++ u2 +++$+++ m0 +++$+++ ['L693', 'L694', 'L695']",
#  "u0 +++$+++ u2 +++$+++ m0 +++$+++ ['L696', 'L697', 'L698', 'L699']",
#  "u0 +++$+++ u2 +++$+++ m0 +++$+++ ['L860', 'L861']",
#  "u0 +++$+++ u2 +++$+++ m0 +++$+++ ['L862', 'L863', 'L864', 'L865']",
#  "u0 +++$+++ u2 +++$+++ m0 +++$+++ ['L866', 'L867', 'L868', 'L869']",
#  "u0 +++$+++ u2 +++$+++ m0 +++$+++ ['L870', 'L871', 'L872']",
#  "u0 +++$+++ u2 +++$+++ m0 +++$+++ ['L924', 'L925']",
#  "u0 +++$+++ u2 +++$+++ m0 +++$+++ ['L984', 'L985']",
#  "u0 +++$+++ u2 +++$+++ m0 +++$+++ ['L1044', 'L1045']",
#  "u0 +++$+++ u3 +++$+++ m0 +++$+++ ['L49', 'L50', 'L51']",
#  "u0 +++$+++ u3 +++$+++ m0 +++$+++ ['L571', 'L572', 'L573']",
#  "u0 +++$+++ u3 +++$+++ m0 +++$+++ ['L579', 'L580']",
#  "u0 +++$+++ u3 +++$+++ m0 +++$+++ ['L595', 'L596', 'L597']",
#  "u0 +++$+++ u3 +++$+++ m0 +++$+++ ['L598', 'L599', 'L600']",
#  "u0 +++$+++ u3 +++$+++ m0 +++$+++ ['L659', 'L660']",
#  "u0 +++$+++ u3 +++$+++ m0 +++$+++ ['L952', 'L953']",
#  "u0 +++$+++ u4 +++$+++ m0 +++$+++ ['L394', 'L395']",
#  "u0 +++$+++ u4 +++$+++ m0 +++$+++ ['L396', 'L397']",
#  "u0 +++$+++ u4 +++$+++ m0 +++$+++ ['L589', 'L590', 'L591']",
#  "u0 +++$+++ u4 +++$+++ m0 +++$+++ ['L592', 'L593']",
#  "u0 +++$+++ u4 +++$+++ m0 +++$+++ ['L756', 'L757', 'L758']",
#  "u0 +++$+++ u4 +++$+++ m0 +++$+++ ['L759', 'L760']",
#  "u0 +++$+++ u5 +++$+++ m0 +++$+++ ['L164', 'L165']",
#  "u0 +++$+++ u5 +++$+++ m0 +++$+++ ['L319', 'L320']",
#  "u0 +++$+++ u5 +++$+++ m0 +++$+++ ['L441', 'L442', 'L443', 'L444', 'L445']",
#  "u0 +++$+++ u5 +++$+++ m0 +++$+++ ['L525', 'L526', 'L527']",
#  "u0 +++$+++ u5 +++$+++ m0 +++$+++ ['L529', 'L530']",
#  "u0 +++$+++ u5 +++$+++ m0 +++$+++ ['L531', 'L532', 'L533']",
#  "u0 +++$+++ u5 +++$+++ m0 +++$+++ ['L542', 'L543']",
#  "u0 +++$+++ u5 +++$+++ m0 +++$+++ ['L601', 'L602']",
#  "u0 +++$+++ u5 +++$+++ m0 +++$+++ ['L655', 'L656']",
#  "u0 +++$+++ u5 +++$+++ m0 +++$+++ ['L889', 'L890', 'L891', 'L892']",
#  "u0 +++$+++ u5 +++$+++ m0 +++$+++ ['L893', 'L894', 'L895', 'L896', 'L897', 'L898', 'L899', 'L900']",
#  "u0 +++$+++ u5 +++$+++ m0 +++$+++ ['L901', 'L902', 'L903']",
#  "u0 +++$+++ u5 +++$+++ m0 +++$+++ ['L904', 'L905', 'L906', 'L907', 'L908']",
#  "u0 +++$+++ u5 +++$+++ m0 +++$+++ ['L909', 'L910', 'L911', 'L912', 'L913', 'L914']",
#  "u0 +++$+++ u5 +++$+++ m0 +++$+++ ['L982', 'L983']",
#  "u0 +++$+++ u5 +++$+++ m0 +++$+++ ['L1007', 'L1008', 'L1009', 'L1010', 'L1011']",
#  "u0 +++$+++ u5 +++$+++ m0 +++$+++ ['L1021', 'L1022']",
#  "u0 +++$+++ u5 +++$+++ m0 +++$+++ ['L1051', 'L1052']",
#  "u0 +++$+++ u11 +++$+++ m0 +++$+++ ['L179', 'L180', 'L181', 'L182', 'L183']",
#  "u0 +++$+++ u11 +++$+++ m0 +++$+++ ['L189', 'L190']",
#  "u0 +++$+++ u11 +++$+++ m0 +++$+++ ['L517', 'L518', 'L519', 'L520', 'L521']",
#  "u0 +++$+++ u11 +++$+++ m0 +++$+++ ['L523', 'L524']",
#  "u0 +++$+++ u11 +++$+++ m0 +++$+++ ['L536', 'L537']",
#  "u0 +++$+++ u11 +++$+++ m0 +++$+++ ['L538', 'L539', 'L540']",
#  "u0 +++$+++ u11 +++$+++ m0 +++$+++ ['L544', 'L545', 'L546']",
#  "u0 +++$+++ u11 +++$+++ m0 +++$+++ ['L878', 'L879', 'L880', 'L881', 'L882', 'L883', 'L884']",
#  "u0 +++$+++ u11 +++$+++ m0 +++$+++ ['L922', 'L923']",
#  "u1 +++$+++ u9 +++$+++ m0 +++$+++ ['L458', 'L459', 'L460', 'L461', 'L462', 'L463']",
#  "u2 +++$+++ u7 +++$+++ m0 +++$+++ ['L63', 'L64', 'L65']",
#  "u2 +++$+++ u7 +++$+++ m0 +++$+++ ['L66', 'L67', 'L68', 'L69', 'L70', 'L71', 'L72', 'L73', 'L74']",
#  "u2 +++$+++ u7 +++$+++ m0 +++$+++ ['L77', 'L78']",
#  "u2 +++$+++ u7 +++$+++ m0 +++$+++ ['L87', 'L88', 'L89', 'L90', 'L91', 'L92']",
#  "u2 +++$+++ u7 +++$+++ m0 +++$+++ ['L139', 'L140', 'L141', 'L142']",
#  "u2 +++$+++ u7 +++$+++ m0 +++$+++ ['L143', 'L144', 'L145', 'L146', 'L147']",
#  "u2 +++$+++ u7 +++$+++ m0 +++$+++ ['L157', 'L158', 'L159']",
#  "u2 +++$+++ u7 +++$+++ m0 +++$+++ ['L210', 'L211']",
#  "u2 +++$+++ u7 +++$+++ m0 +++$+++ ['L212', 'L213']",
#  "u2 +++$+++ u7 +++$+++ m0 +++$+++ ['L215', 'L216', 'L217', 'L218', 'L219', 'L220', 'L221', 'L222']",
#  "u2 +++$+++ u7 +++$+++ m0 +++$+++ ['L223', 'L224', 'L225']",
#  "u2 +++$+++ u7 +++$+++ m0 +++$+++ ['L244', 'L245']",
#  "u2 +++$+++ u7 +++$+++ m0 +++$+++ ['L388', 'L389', 'L390', 'L391']",
#  "u2 +++$+++ u7 +++$+++ m0 +++$+++ ['L416', 'L417', 'L418', 'L419']",
#  "u2 +++$+++ u7 +++$+++ m0 +++$+++ ['L424', 'L425']",
#  "u2 +++$+++ u7 +++$+++ m0 +++$+++ ['L432', 'L433']",
#  "u2 +++$+++ u7 +++$+++ m0 +++$+++ ['L499', 'L500']",
#  "u2 +++$+++ u7 +++$+++ m0 +++$+++ ['L583', 'L584', 'L585', 'L586']",
#  "u2 +++$+++ u7 +++$+++ m0 +++$+++ ['L778', 'L779']",
#  "u2 +++$+++ u9 +++$+++ m0 +++$+++ ['L385', 'L386']",
#  "u2 +++$+++ u9 +++$+++ m0 +++$+++ ['L411', 'L412']",
#  "u2 +++$+++ u9 +++$+++ m0 +++$+++ ['L426', 'L427']",
#  "u2 +++$+++ u9 +++$+++ m0 +++$+++ ['L430', 'L431']",
#  "u2 +++$+++ u9 +++$+++ m0 +++$+++ ['L619', 'L620']",
#  "u2 +++$+++ u9 +++$+++ m0 +++$+++ ['L621', 'L622']",
#  "u2 +++$+++ u9 +++$+++ m0 +++$+++ ['L623', 'L624', 'L625']",
#  "u2 +++$+++ u9 +++$+++ m0 +++$+++ ['L725', 'L726']",
#  "u2 +++$+++ u9 +++$+++ m0 +++$+++ ['L740', 'L741']",
#  "u2 +++$+++ u9 +++$+++ m0 +++$+++ ['L743', 'L744', 'L745']",
#  "u2 +++$+++ u9 +++$+++ m0 +++$+++ ['L780', 'L781']",
#  "u4 +++$+++ u5 +++$+++ m0 +++$+++ ['L148', 'L149', 'L150']",
#  "u4 +++$+++ u5 +++$+++ m0 +++$+++ ['L335', 'L336']",
#  "u4 +++$+++ u5 +++$+++ m0 +++$+++ ['L554', 'L555', 'L556']",
#  "u4 +++$+++ u5 +++$+++ m0 +++$+++ ['L557', 'L558']",
#  "u4 +++$+++ u9 +++$+++ m0 +++$+++ ['L285', 'L286']",
#  "u4 +++$+++ u9 +++$+++ m0 +++$+++ ['L287', 'L288', 'L289', 'L290', 'L291', 'L292']",
#  "u4 +++$+++ u9 +++$+++ m0 +++$+++ ['L294', 'L295', 'L296', 'L297']",
#  "u4 +++$+++ u9 +++$+++ m0 +++$+++ ['L298', 'L299']",
#  "u4 +++$+++ u9 +++$+++ m0 +++$+++ ['L300', 'L301']",
#  "u4 +++$+++ u9 +++$+++ m0 +++$+++ ['L349', 'L350', 'L351', 'L352']",
#  "u4 +++$+++ u9 +++$+++ m0 +++$+++ ['L354', 'L355', 'L356', 'L357', 'L358']",
#  "u4 +++$+++ u9 +++$+++ m0 +++$+++ ['L605', 'L606']",
#  "u4 +++$+++ u9 +++$+++ m0 +++$+++ ['L607', 'L608', 'L609']",
#  "u4 +++$+++ u9 +++$+++ m0 +++$+++ ['L747', 'L748']",
#  "u4 +++$+++ u7 +++$+++ m0 +++$+++ ['L231', 'L232', 'L233', 'L234', 'L235', 'L236']",
#  "u4 +++$+++ u7 +++$+++ m0 +++$+++ ['L238', 'L239', 'L240']",
#  "u4 +++$+++ u7 +++$+++ m0 +++$+++ ['L502', 'L503', 'L504', 'L505']",
#  "u4 +++$+++ u7 +++$+++ m0 +++$+++ ['L508', 'L509']",
#  "u5 +++$+++ u6 +++$+++ m0 +++$+++ ['L123', 'L124', 'L125', 'L126', 'L127', 'L128']",
#  "u5 +++$+++ u6 +++$+++ m0 +++$+++ ['L129', 'L130']",
#  "u5 +++$+++ u6 +++$+++ m0 +++$+++ ['L131', 'L132']",
#  "u5 +++$+++ u6 +++$+++ m0 +++$+++ ['L133', 'L134']",
#  "u5 +++$+++ u6 +++$+++ m0 +++$+++ ['L151', 'L152']",
#  "u5 +++$+++ u6 +++$+++ m0 +++$+++ ['L247', 'L248', 'L249', 'L250', 'L251']",
#  "u5 +++$+++ u6 +++$+++ m0 +++$+++ ['L252', 'L253', 'L254']",
#  "u5 +++$+++ u6 +++$+++ m0 +++$+++ ['L447', 'L448']",
#  "u5 +++$+++ u6 +++$+++ m0 +++$+++ ['L490', 'L491']",
#  "u5 +++$+++ u6 +++$+++ m0 +++$+++ ['L716', 'L717', 'L718', 'L719', 'L720', 'L721']",
#  "u5 +++$+++ u6 +++$+++ m0 +++$+++ ['L750', 'L751', 'L752', 'L753', 'L754', 'L755']",
#  "u5 +++$+++ u6 +++$+++ m0 +++$+++ ['L946', 'L947', 'L948', 'L949']",
#  "u5 +++$+++ u9 +++$+++ m0 +++$+++ ['L304', 'L305', 'L306', 'L307']",
#  "u5 +++$+++ u9 +++$+++ m0 +++$+++ ['L309', 'L310']",
#  "u5 +++$+++ u9 +++$+++ m0 +++$+++ ['L311', 'L312', 'L313']",
#  "u5 +++$+++ u9 +++$+++ m0 +++$+++ ['L322', 'L323', 'L324', 'L325', 'L326', 'L327', 'L328']",
#  "u5 +++$+++ u9 +++$+++ m0 +++$+++ ['L330', 'L331', 'L332']",
#  "u5 +++$+++ u9 +++$+++ m0 +++$+++ ['L333', 'L334']",
#  "u5 +++$+++ u9 +++$+++ m0 +++$+++ ['L473', 'L474']",
#  "u5 +++$+++ u9 +++$+++ m0 +++$+++ ['L475', 'L476', 'L477']",
#  "u5 +++$+++ u9 +++$+++ m0 +++$+++ ['L481', 'L482', 'L483']",
#  "u5 +++$+++ u9 +++$+++ m0 +++$+++ ['L564', 'L565', 'L566', 'L567']",
#  "u5 +++$+++ u9 +++$+++ m0 +++$+++ ['L610', 'L611']",
#  "u5 +++$+++ u9 +++$+++ m0 +++$+++ ['L612', 'L613', 'L614', 'L615', 'L616']",
#  "u5 +++$+++ u9 +++$+++ m0 +++$+++ ['L626', 'L627', 'L628', 'L629', 'L630', 'L631', 'L632', 'L633', 'L634', 'L635', 'L636']",
#  "u5 +++$+++ u9 +++$+++ m0 +++$+++ ['L639', 'L640', 'L641', 'L642', 'L643', 'L644', 'L645', 'L646']",
#  "u5 +++$+++ u9 +++$+++ m0 +++$+++ ['L650', 'L651']",
#  "u5 +++$+++ u9 +++$+++ m0 +++$+++ ['L668', 'L669']",
#  "u5 +++$+++ u9 +++$+++ m0 +++$+++ ['L670', 'L671', 'L672', 'L673', 'L674', 'L675', 'L676']",
#  "u5 +++$+++ u9 +++$+++ m0 +++$+++ ['L677', 'L678', 'L679']",
#  "u5 +++$+++ u9 +++$+++ m0 +++$+++ ['L680', 'L681', 'L682']",
#  "u5 +++$+++ u9 +++$+++ m0 +++$+++ ['L683', 'L684']",
#  "u5 +++$+++ u9 +++$+++ m0 +++$+++ ['L686', 'L687', 'L688', 'L689', 'L690']",
#  "u5 +++$+++ u9 +++$+++ m0 +++$+++ ['L764', 'L765', 'L766', 'L767', 'L768']",
#  "u5 +++$+++ u9 +++$+++ m0 +++$+++ ['L769', 'L770', 'L771', 'L772', 'L773', 'L774']",
#  "u5 +++$+++ u9 +++$+++ m0 +++$+++ ['L798', 'L799']",
#  "u5 +++$+++ u9 +++$+++ m0 +++$+++ ['L800', 'L801', 'L802']",
#  "u5 +++$+++ u9 +++$+++ m0 +++$+++ ['L803', 'L804', 'L805', 'L806']",
#  "u5 +++$+++ u9 +++$+++ m0 +++$+++ ['L808', 'L809', 'L810', 'L811', 'L812']",
#  "u5 +++$+++ u9 +++$+++ m0 +++$+++ ['L813', 'L814', 'L815', 'L816', 'L817', 'L818', 'L819', 'L820', 'L821', 'L822', 'L823']",
#  "u5 +++$+++ u9 +++$+++ m0 +++$+++ ['L824', 'L825']",
#  "u5 +++$+++ u9 +++$+++ m0 +++$+++ ['L828', 'L829', 'L830', 'L831', 'L832']",
#  "u5 +++$+++ u9 +++$+++ m0 +++$+++ ['L834', 'L835', 'L836', 'L837', 'L838', 'L839', 'L840', 'L841']",
#  "u5 +++$+++ u9 +++$+++ m0 +++$+++ ['L842', 'L843', 'L844', 'L845', 'L846', 'L847', 'L848']",
#  "u5 +++$+++ u9 +++$+++ m0 +++$+++ ['L852', 'L853', 'L854', 'L855', 'L856', 'L857']",
#  "u5 +++$+++ u9 +++$+++ m0 +++$+++ ['L936', 'L937', 'L938', 'L939', 'L940']",
#  "u5 +++$+++ u9 +++$+++ m0 +++$+++ ['L957', 'L958', 'L959']",
#  "u5 +++$+++ u9 +++$+++ m0 +++$+++ ['L960', 'L961']",
#  "u5 +++$+++ u9 +++$+++ m0 +++$+++ ['L973', 'L974', 'L975', 'L976', 'L977']",
#  "u5 +++$+++ u9 +++$+++ m0 +++$+++ ['L1031', 'L1032']",
#  "u5 +++$+++ u9 +++$+++ m0 +++$+++ ['L1033', 'L1034', 'L1035']",
#  "u5 +++$+++ u9 +++$+++ m0 +++$+++ ['L1040', 'L1041', 'L1042', 'L1043']",
#  "u5 +++$+++ u11 +++$+++ m0 +++$+++ ['L172', 'L173', 'L174']",
#  "u5 +++$+++ u11 +++$+++ m0 +++$+++ ['L184', 'L185']",
#  "u5 +++$+++ u11 +++$+++ m0 +++$+++ ['L338', 'L339', 'L340', 'L341', 'L342', 'L343', 'L344', 'L345', 'L346', 'L347']",
#  "u5 +++$+++ u11 +++$+++ m0 +++$+++ ['L986', 'L987', 'L988']",
#  "u5 +++$+++ u11 +++$+++ m0 +++$+++ ['L989', 'L990', 'L991', 'L992', 'L993', 'L994', 'L995', 'L996', 'L997']",
#  "u5 +++$+++ u11 +++$+++ m0 +++$+++ ['L998', 'L999', 'L1000']",
#  "u5 +++$+++ u8 +++$+++ m0 +++$+++ ['L103', 'L104', 'L105', 'L106', 'L107']",
#  "u5 +++$+++ u8 +++$+++ m0 +++$+++ ['L108', 'L109']",
#  "u5 +++$+++ u8 +++$+++ m0 +++$+++ ['L1017', 'L1018']",
#  "u6 +++$+++ u7 +++$+++ m0 +++$+++ ['L728', 'L729', 'L730', 'L731']",
#  "u6 +++$+++ u7 +++$+++ m0 +++$+++ ['L732', 'L733']",
#  "u6 +++$+++ u7 +++$+++ m0 +++$+++ ['L735', 'L736', 'L737', 'L738']",
#  "u7 +++$+++ u9 +++$+++ m0 +++$+++ ['L371', 'L372', 'L373']",
#  "u7 +++$+++ u9 +++$+++ m0 +++$+++ ['L375', 'L376', 'L377']",
#  "u7 +++$+++ u9 +++$+++ m0 +++$+++ ['L378', 'L379']",
#  "u7 +++$+++ u9 +++$+++ m0 +++$+++ ['L380', 'L381', 'L382']",
#  "u7 +++$+++ u9 +++$+++ m0 +++$+++ ['L383', 'L384']",
#  "u7 +++$+++ u9 +++$+++ m0 +++$+++ ['L414', 'L415']",
#  "u7 +++$+++ u9 +++$+++ m0 +++$+++ ['L420', 'L421']",
#  "u7 +++$+++ u9 +++$+++ m0 +++$+++ ['L428', 'L429']",
#  "u7 +++$+++ u9 +++$+++ m0 +++$+++ ['L436', 'L437']",
#  "u7 +++$+++ u9 +++$+++ m0 +++$+++ ['L723', 'L724']",
#  "u7 +++$+++ u9 +++$+++ m0 +++$+++ ['L775', 'L776', 'L777']",
#  "u8 +++$+++ u9 +++$+++ m0 +++$+++ ['L59', 'L60', 'L61', 'L62']",
#  "u8 +++$+++ u9 +++$+++ m0 +++$+++ ['L257', 'L258', 'L259']",
#  "u8 +++$+++ u9 +++$+++ m0 +++$+++ ['L261', 'L262', 'L263', 'L264']",
#  "u8 +++$+++ u9 +++$+++ m0 +++$+++ ['L511', 'L512']",
#  "u10 +++$+++ u11 +++$+++ m0 +++$+++ ['L161', 'L162']",
#  "u10 +++$+++ u11 +++$+++ m0 +++$+++ ['L170', 'L171']",
#  "u10 +++$+++ u11 +++$+++ m0 +++$+++ ['L191', 'L192', 'L193']",
#  "u10 +++$+++ u11 +++$+++ m0 +++$+++ ['L876', 'L877']",
#  "u10 +++$+++ u11 +++$+++ m0 +++$+++ ['L886', 'L887']",
#  "u10 +++$+++ u11 +++$+++ m0 +++$+++ ['L917', 'L918']",
#  "u10 +++$+++ u11 +++$+++ m0 +++$+++ ['L926', 'L927']",
#  "u10 +++$+++ u11 +++$+++ m0 +++$+++ ['L929', 'L930', 'L931', 'L932', 'L933']",
#  "u12 +++$+++ u23 +++$+++ m1 +++$+++ ['L2170', 'L2171', 'L2172']",
#  "u12 +++$+++ u23 +++$+++ m1 +++$+++ ['L2173', 'L2174', 'L2175']",
#  "u12 +++$+++ u23 +++$+++ m1 +++$+++ ['L2176', 'L2177']",
#  "u12 +++$+++ u23 +++$+++ m1 +++$+++ ['L2179', 'L2180', 'L2181']",
#  "u13 +++$+++ u16 +++$+++ m1 +++$+++ ['L1989', 'L1990', 'L1991', 'L1992', 'L1993']",
#  "u13 +++$+++ u16 +++$+++ m1 +++$+++ ['L2005', 'L2006']",
#  "u13 +++$+++ u16 +++$+++ m1 +++$+++ ['L2010', 'L2011', 'L2012']",
#  "u13 +++$+++ u16 +++$+++ m1 +++$+++ ['L2014', 'L2015', 'L2016']",
#  "u13 +++$+++ u16 +++$+++ m1 +++$+++ ['L2019', 'L2020']",
#  "u13 +++$+++ u16 +++$+++ m1 +++$+++ ['L2022', 'L2023']",
#  "u13 +++$+++ u16 +++$+++ m1 +++$+++ ['L2024', 'L2025']",
#  "u13 +++$+++ u24 +++$+++ m1 +++$+++ ['L2027', 'L2028', 'L2029']",
#  "u13 +++$+++ u24 +++$+++ m1 +++$+++ ['L2030', 'L2031']",
#  "u13 +++$+++ u24 +++$+++ m1 +++$+++ ['L2274', 'L2275']",
#  "u13 +++$+++ u24 +++$+++ m1 +++$+++ ['L2522', 'L2523', 'L2524']",
#  "u14 +++$+++ u16 +++$+++ m1 +++$+++ ['L1979', 'L1980', 'L1981', 'L1982', 'L1983', 'L1984']",
#  "u14 +++$+++ u16 +++$+++ m1 +++$+++ ['L1985', 'L1986']",
#  "u14 +++$+++ u16 +++$+++ m1 +++$+++ ['L2118', 'L2119']",
#  "u14 +++$+++ u16 +++$+++ m1 +++$+++ ['L2121', 'L2122', 'L2123']",
#  "u14 +++$+++ u16 +++$+++ m1 +++$+++ ['L2318', 'L2319', 'L2320']",
#  "u14 +++$+++ u16 +++$+++ m1 +++$+++ ['L2471', 'L2472']",
#  "u14 +++$+++ u16 +++$+++ m1 +++$+++ ['L2473', 'L2474']",
#  "u14 +++$+++ u16 +++$+++ m1 +++$+++ ['L2537', 'L2538']",
#  "u14 +++$+++ u16 +++$+++ m1 +++$+++ ['L2539', 'L2540']",
#  "u15 +++$+++ u16 +++$+++ m1 +++$+++ ['L2290', 'L2291', 'L2292', 'L2293']",
#  "u15 +++$+++ u16 +++$+++ m1 +++$+++ ['L2421', 'L2422']",
#  "u15 +++$+++ u16 +++$+++ m1 +++$+++ ['L2423', 'L2424', 'L2425', 'L2426']",
#  "u15 +++$+++ u16 +++$+++ m1 +++$+++ ['L2429', 'L2430', 'L2431', 'L2432']",
#  "u16 +++$+++ u17 +++$+++ m1 +++$+++ ['L2127', 'L2128', 'L2129']",
#  "u16 +++$+++ u17 +++$+++ m1 +++$+++ ['L2130', 'L2131']",
#  "u16 +++$+++ u17 +++$+++ m1 +++$+++ ['L2439', 'L2440']",
#  "u16 +++$+++ u17 +++$+++ m1 +++$+++ ['L2484', 'L2485']",
#  "u16 +++$+++ u17 +++$+++ m1 +++$+++ ['L2500', 'L2501']",
#  "u16 +++$+++ u17 +++$+++ m1 +++$+++ ['L2541', 'L2542']",
#  "u16 +++$+++ u17 +++$+++ m1 +++$+++ ['L2547', 'L2548', 'L2549']",
#  "u16 +++$+++ u17 +++$+++ m1 +++$+++ ['L2550', 'L2551', 'L2552']",
#  "u16 +++$+++ u24 +++$+++ m1 +++$+++ ['L2103', 'L2104', 'L2105']",
#  "u16 +++$+++ u24 +++$+++ m1 +++$+++ ['L2106', 'L2107', 'L2108']",
#  "u16 +++$+++ u24 +++$+++ m1 +++$+++ ['L2109', 'L2110']",
#  "u16 +++$+++ u24 +++$+++ m1 +++$+++ ['L2281', 'L2282']",
#  "u16 +++$+++ u24 +++$+++ m1 +++$+++ ['L2286', 'L2287']",
#  "u16 +++$+++ u24 +++$+++ m1 +++$+++ ['L2295', 'L2296', 'L2297']",
#  "u16 +++$+++ u24 +++$+++ m1 +++$+++ ['L2299', 'L2300', 'L2301']",
#  "u16 +++$+++ u24 +++$+++ m1 +++$+++ ['L2463', 'L2464']",
#  "u16 +++$+++ u24 +++$+++ m1 +++$+++ ['L2465', 'L2466']",
#  "u16 +++$+++ u24 +++$+++ m1 +++$+++ ['L2467', 'L2468', 'L2469']",
#  "u16 +++$+++ u25 +++$+++ m1 +++$+++ ['L2237', 'L2238', 'L2239']",
#  "u16 +++$+++ u25 +++$+++ m1 +++$+++ ['L2248', 'L2249', 'L2250', 'L2251']",
#  "u16 +++$+++ u25 +++$+++ m1 +++$+++ ['L2253', 'L2254', 'L2255']",
#  "u16 +++$+++ u25 +++$+++ m1 +++$+++ ['L2256', 'L2257', 'L2258', 'L2259', 'L2260']",
#  "u16 +++$+++ u25 +++$+++ m1 +++$+++ ['L2341', 'L2342', 'L2343']",
#  "u16 +++$+++ u25 +++$+++ m1 +++$+++ ['L2393', 'L2394']",
#  "u16 +++$+++ u25 +++$+++ m1 +++$+++ ['L2409', 'L2410']",
#  "u16 +++$+++ u19 +++$+++ m1 +++$+++ ['L1942', 'L1943']",
#  "u16 +++$+++ u19 +++$+++ m1 +++$+++ ['L1947', 'L1948', 'L1949', 'L1950']",
#  "u16 +++$+++ u19 +++$+++ m1 +++$+++ ['L1951', 'L1952']",
#  "u16 +++$+++ u19 +++$+++ m1 +++$+++ ['L1957', 'L1958', 'L1959', 'L1960', 'L1961', 'L1962']",
#  "u16 +++$+++ u19 +++$+++ m1 +++$+++ ['L1963', 'L1964', 'L1965', 'L1966', 'L1967', 'L1968', 'L1969']",
#  "u16 +++$+++ u19 +++$+++ m1 +++$+++ ['L2037', 'L2038', 'L2039', 'L2040']",
#  "u16 +++$+++ u19 +++$+++ m1 +++$+++ ['L2041', 'L2042']",
#  "u16 +++$+++ u19 +++$+++ m1 +++$+++ ['L2045', 'L2046']",
#  "u16 +++$+++ u19 +++$+++ m1 +++$+++ ['L2132', 'L2133']",
#  "u16 +++$+++ u19 +++$+++ m1 +++$+++ ['L2134', 'L2135', 'L2136', 'L2137', 'L2138', 'L2139']",
#  "u16 +++$+++ u19 +++$+++ m1 +++$+++ ['L2140', 'L2141', 'L2142', 'L2143']",
#  "u16 +++$+++ u19 +++$+++ m1 +++$+++ ['L2144', 'L2145']",
#  "u16 +++$+++ u19 +++$+++ m1 +++$+++ ['L2525', 'L2526']",
#  "u16 +++$+++ u19 +++$+++ m1 +++$+++ ['L2531', 'L2532', 'L2533', 'L2534', 'L2535']",
#  "u16 +++$+++ u18 +++$+++ m1 +++$+++ ['L2071', 'L2072']",
#  "u16 +++$+++ u18 +++$+++ m1 +++$+++ ['L2073', 'L2074', 'L2075']",
#  "u16 +++$+++ u18 +++$+++ m1 +++$+++ ['L2076', 'L2077']",
#  "u16 +++$+++ u18 +++$+++ m1 +++$+++ ['L2079', 'L2080', 'L2081', 'L2082']",
#  "u16 +++$+++ u18 +++$+++ m1 +++$+++ ['L2085', 'L2086']",
#  "u16 +++$+++ u18 +++$+++ m1 +++$+++ ['L2279', 'L2280']",
#  "u16 +++$+++ u18 +++$+++ m1 +++$+++ ['L2456', 'L2457', 'L2458', 'L2459']",
#  "u16 +++$+++ u21 +++$+++ m1 +++$+++ ['L2277', 'L2278']",
#  "u16 +++$+++ u21 +++$+++ m1 +++$+++ ['L2328', 'L2329']",
#  "u16 +++$+++ u21 +++$+++ m1 +++$+++ ['L2331', 'L2332', 'L2333']",
#  "u16 +++$+++ u21 +++$+++ m1 +++$+++ ['L2345', 'L2346']",
#  "u16 +++$+++ u21 +++$+++ m1 +++$+++ ['L2347', 'L2348']",
#  "u16 +++$+++ u21 +++$+++ m1 +++$+++ ['L2386', 'L2387', 'L2388', 'L2389']",
#  "u16 +++$+++ u20 +++$+++ m1 +++$+++ ['L2154', 'L2155']",
#  "u16 +++$+++ u20 +++$+++ m1 +++$+++ ['L2157', 'L2158', 'L2159', 'L2160']",
#  "u16 +++$+++ u20 +++$+++ m1 +++$+++ ['L2164', 'L2165']",
#  "u16 +++$+++ u20 +++$+++ m1 +++$+++ ['L2490', 'L2491', 'L2492']",
#  "u16 +++$+++ u22 +++$+++ m1 +++$+++ ['L2064', 'L2065']",
#  "u16 +++$+++ u22 +++$+++ m1 +++$+++ ['L2196', 'L2197', 'L2198', 'L2199', 'L2200', 'L2201', 'L2202', 'L2203', 'L2204', 'L2205', 'L2206', 'L2207', 'L2208', 'L2209', 'L2210', 'L2211']",
#  "u18 +++$+++ u24 +++$+++ m1 +++$+++ ['L1930', 'L1931']",
#  "u18 +++$+++ u24 +++$+++ m1 +++$+++ ['L2112', 'L2113']",
#  "u18 +++$+++ u24 +++$+++ m1 +++$+++ ['L2115', 'L2116']",
#  "u18 +++$+++ u24 +++$+++ m1 +++$+++ ['L2376', 'L2377']",
#  "u18 +++$+++ u24 +++$+++ m1 +++$+++ ['L2414', 'L2415']",
#  "u18 +++$+++ u24 +++$+++ m1 +++$+++ ['L2417', 'L2418', 'L2419']",
#  "u18 +++$+++ u24 +++$+++ m1 +++$+++ ['L2460', 'L2461', 'L2462']",
#  "u26 +++$+++ u30 +++$+++ m2 +++$+++ ['L3380', 'L3381', 'L3382']",
#  "u26 +++$+++ u30 +++$+++ m2 +++$+++ ['L3383', 'L3384', 'L3385']",
#  "u26 +++$+++ u30 +++$+++ m2 +++$+++ ['L3392', 'L3393', 'L3394', 'L3395', 'L3396']",
#  "u26 +++$+++ u30 +++$+++ m2 +++$+++ ['L3459', 'L3460', 'L3461']",
#  "u26 +++$+++ u30 +++$+++ m2 +++$+++ ['L3464', 'L3465', 'L3466', 'L3467', 'L3468', 'L3469', 'L3470', 'L3471', 'L3472', 'L3473', 'L3474', 'L3475', 'L3476', 'L3477', 'L3478', 'L3479', 'L3480', 'L3481']",
#  "u26 +++$+++ u30 +++$+++ m2 +++$+++ ['L3482', 'L3483', 'L3484', 'L3485', 'L3486', 'L3487', 'L3488', 'L3489']",
#  "u26 +++$+++ u30 +++$+++ m2 +++$+++ ['L3490', 'L3491', 'L3492', 'L3493']",
#  "u26 +++$+++ u30 +++$+++ m2 +++$+++ ['L3496', 'L3497']",
#  "u26 +++$+++ u30 +++$+++ m2 +++$+++ ['L3545', 'L3546']",
#  "u27 +++$+++ u34 +++$+++ m2 +++$+++ ['L3059', 'L3060', 'L3061']",
#  "u27 +++$+++ u34 +++$+++ m2 +++$+++ ['L3089', 'L3090', 'L3091', 'L3092']",
#  "u27 +++$+++ u34 +++$+++ m2 +++$+++ ['L3093', 'L3094', 'L3095']",
#  "u27 +++$+++ u34 +++$+++ m2 +++$+++ ['L3096', 'L3097']",
#  "u27 +++$+++ u34 +++$+++ m2 +++$+++ ['L3158', 'L3159', 'L3160']",
#  "u27 +++$+++ u34 +++$+++ m2 +++$+++ ['L3161', 'L3162', 'L3163', 'L3164', 'L3165', 'L3166']",
#  "u27 +++$+++ u34 +++$+++ m2 +++$+++ ['L3167', 'L3168', 'L3169', 'L3170']",
#  "u27 +++$+++ u34 +++$+++ m2 +++$+++ ['L3177', 'L3178', 'L3179', 'L3180', 'L3181']",
#  "u27 +++$+++ u34 +++$+++ m2 +++$+++ ['L3300', 'L3301', 'L3302']",
#  "u27 +++$+++ u34 +++$+++ m2 +++$+++ ['L3305', 'L3306', 'L3307', 'L3308']",
#  "u27 +++$+++ u34 +++$+++ m2 +++$+++ ['L3309', 'L3310', 'L3311']",
#  "u27 +++$+++ u34 +++$+++ m2 +++$+++ ['L3313', 'L3314']",
#  "u27 +++$+++ u34 +++$+++ m2 +++$+++ ['L3315', 'L3316', 'L3317', 'L3318']",
#  "u27 +++$+++ u34 +++$+++ m2 +++$+++ ['L3329', 'L3330']",
#  "u27 +++$+++ u34 +++$+++ m2 +++$+++ ['L3514', 'L3515', 'L3516', 'L3517']",
#  "u27 +++$+++ u29 +++$+++ m2 +++$+++ ['L3045', 'L3046', 'L3047', 'L3048']",
#  "u27 +++$+++ u29 +++$+++ m2 +++$+++ ['L3049', 'L3050', 'L3051']",
#  "u27 +++$+++ u29 +++$+++ m2 +++$+++ ['L3055', 'L3056']",
#  "u27 +++$+++ u29 +++$+++ m2 +++$+++ ['L3062', 'L3063', 'L3064', 'L3065']",
#  "u28 +++$+++ u29 +++$+++ m2 +++$+++ ['L3208', 'L3209', 'L3210', 'L3211', 'L3212', 'L3213', 'L3214']",
#  "u28 +++$+++ u34 +++$+++ m2 +++$+++ ['L2797', 'L2798', 'L2799', 'L2800']",
#  "u28 +++$+++ u34 +++$+++ m2 +++$+++ ['L3196', 'L3197']",
#  "u28 +++$+++ u34 +++$+++ m2 +++$+++ ['L3198', 'L3199', 'L3200', 'L3201', 'L3202', 'L3203']",
#  "u28 +++$+++ u34 +++$+++ m2 +++$+++ ['L3293', 'L3294']",
#  "u28 +++$+++ u34 +++$+++ m2 +++$+++ ['L3498', 'L3499', 'L3500', 'L3501', 'L3502', 'L3503', 'L3504', 'L3505', 'L3506']",
#  "u28 +++$+++ u35 +++$+++ m2 +++$+++ ['L2801', 'L2802', 'L2803', 'L2804', 'L2805']",
#  "u28 +++$+++ u35 +++$+++ m2 +++$+++ ['L3289', 'L3290', 'L3291', 'L3292']",
#  "u29 +++$+++ u36 +++$+++ m2 +++$+++ ['L2599', 'L2600', 'L2601']",
#  "u29 +++$+++ u36 +++$+++ m2 +++$+++ ['L2602', 'L2603']",
#  "u29 +++$+++ u36 +++$+++ m2 +++$+++ ['L2630', 'L2631', 'L2632', 'L2633']",
#  "u29 +++$+++ u36 +++$+++ m2 +++$+++ ['L2751', 'L2752']",
#  "u29 +++$+++ u36 +++$+++ m2 +++$+++ ['L2920', 'L2921', 'L2922', 'L2923']",
#  "u29 +++$+++ u36 +++$+++ m2 +++$+++ ['L2924', 'L2925']",
#  "u29 +++$+++ u36 +++$+++ m2 +++$+++ ['L2936', 'L2937', 'L2938']",
#  "u29 +++$+++ u36 +++$+++ m2 +++$+++ ['L3016', 'L3017']",
#  "u29 +++$+++ u36 +++$+++ m2 +++$+++ ['L3022', 'L3023']",
#  "u29 +++$+++ u36 +++$+++ m2 +++$+++ ['L3027', 'L3028']",
#  "u29 +++$+++ u44 +++$+++ m2 +++$+++ ['L2964', 'L2965', 'L2966', 'L2967']",
#  "u29 +++$+++ u44 +++$+++ m2 +++$+++ ['L2971', 'L2972', 'L2973']",
#  "u29 +++$+++ u44 +++$+++ m2 +++$+++ ['L2975', 'L2976', 'L2977', 'L2978']",
#  "u29 +++$+++ u44 +++$+++ m2 +++$+++ ['L2979', 'L2980', 'L2981']",
#  "u29 +++$+++ u44 +++$+++ m2 +++$+++ ['L2986', 'L2987', 'L2988', 'L2989', 'L2990']",
#  "u29 +++$+++ u34 +++$+++ m2 +++$+++ ['L2730', 'L2731']",
#  "u29 +++$+++ u34 +++$+++ m2 +++$+++ ['L2746', 'L2747', 'L2748']",
#  "u29 +++$+++ u34 +++$+++ m2 +++$+++ ['L2875', 'L2876', 'L2877', 'L2878', 'L2879', 'L2880', 'L2881', 'L2882']",
#  "u29 +++$+++ u34 +++$+++ m2 +++$+++ ['L2883', 'L2884', 'L2885', 'L2886']",
#  "u29 +++$+++ u34 +++$+++ m2 +++$+++ ['L2887', 'L2888', 'L2889', 'L2890', 'L2891']",
#  "u29 +++$+++ u34 +++$+++ m2 +++$+++ ['L2892', 'L2893']",
#  "u29 +++$+++ u34 +++$+++ m2 +++$+++ ['L2895', 'L2896', 'L2897']",
#  "u29 +++$+++ u34 +++$+++ m2 +++$+++ ['L2899', 'L2900', 'L2901', 'L2902', 'L2903', 'L2904', 'L2905', 'L2906']",
#  "u29 +++$+++ u34 +++$+++ m2 +++$+++ ['L2949', 'L2950', 'L2951', 'L2952', 'L2953']",
#  "u29 +++$+++ u34 +++$+++ m2 +++$+++ ['L2955', 'L2956', 'L2957', 'L2958']",
#  "u29 +++$+++ u34 +++$+++ m2 +++$+++ ['L2962', 'L2963']",
#  "u29 +++$+++ u34 +++$+++ m2 +++$+++ ['L2991', 'L2992']",
#  "u29 +++$+++ u34 +++$+++ m2 +++$+++ ['L2993', 'L2994', 'L2995', 'L2996', 'L2997', 'L2998', 'L2999']",
#  "u29 +++$+++ u34 +++$+++ m2 +++$+++ ['L3052', 'L3053', 'L3054']",
#  "u29 +++$+++ u34 +++$+++ m2 +++$+++ ['L3057', 'L3058']",
#  "u29 +++$+++ u34 +++$+++ m2 +++$+++ ['L3067', 'L3068']",
#  "u29 +++$+++ u34 +++$+++ m2 +++$+++ ['L3069', 'L3070', 'L3071', 'L3072', 'L3073', 'L3074', 'L3075', 'L3076', 'L3077', 'L3078', 'L3079']",
#  "u29 +++$+++ u34 +++$+++ m2 +++$+++ ['L3080', 'L3081', 'L3082']",
#  "u29 +++$+++ u34 +++$+++ m2 +++$+++ ['L3219', 'L3220', 'L3221', 'L3222']",
#  "u29 +++$+++ u34 +++$+++ m2 +++$+++ ['L3223', 'L3224', 'L3225', 'L3226', 'L3227', 'L3228']",
#  "u29 +++$+++ u34 +++$+++ m2 +++$+++ ['L3229', 'L3230']",
#  "u29 +++$+++ u30 +++$+++ m2 +++$+++ ['L3236', 'L3237', 'L3238', 'L3239', 'L3240', 'L3241', 'L3242']",
#  "u29 +++$+++ u30 +++$+++ m2 +++$+++ ['L3243', 'L3244']",
#  "u29 +++$+++ u30 +++$+++ m2 +++$+++ ['L3248', 'L3249']",
#  "u29 +++$+++ u41 +++$+++ m2 +++$+++ ['L2758', 'L2759', 'L2760', 'L2761', 'L2762', 'L2763', 'L2764', 'L2765']",
#  "u29 +++$+++ u41 +++$+++ m2 +++$+++ ['L3029', 'L3030']",
#  "u29 +++$+++ u41 +++$+++ m2 +++$+++ ['L3031', 'L3032', 'L3033', 'L3034', 'L3035', 'L3036', 'L3037']",
#  "u29 +++$+++ u41 +++$+++ m2 +++$+++ ['L3038', 'L3039', 'L3040', 'L3041', 'L3042', 'L3043', 'L3044']",
#  "u29 +++$+++ u41 +++$+++ m2 +++$+++ ['L3101', 'L3102']",
#  "u29 +++$+++ u41 +++$+++ m2 +++$+++ ['L3103', 'L3104', 'L3105', 'L3106', 'L3107', 'L3108', 'L3109', 'L3110', 'L3111', 'L3112', 'L3113', 'L3114', 'L3115', 'L3116', 'L3117']",
#  "u29 +++$+++ u41 +++$+++ m2 +++$+++ ['L3119', 'L3120', 'L3121']",
#  "u29 +++$+++ u41 +++$+++ m2 +++$+++ ['L3126', 'L3127', 'L3128', 'L3129', 'L3130']",
#  "u29 +++$+++ u41 +++$+++ m2 +++$+++ ['L3135', 'L3136', 'L3137', 'L3138', 'L3139', 'L3140', 'L3141', 'L3142', 'L3143', 'L3144', 'L3145', 'L3146', 'L3147']",
#  "u29 +++$+++ u41 +++$+++ m2 +++$+++ ['L3148', 'L3149', 'L3150', 'L3151', 'L3152', 'L3153', 'L3154', 'L3155', 'L3156', 'L3157']",
#  "u29 +++$+++ u31 +++$+++ m2 +++$+++ ['L2595', 'L2596']",
#  "u29 +++$+++ u31 +++$+++ m2 +++$+++ ['L2604', 'L2605', 'L2606', 'L2607']",
#  "u29 +++$+++ u31 +++$+++ m2 +++$+++ ['L2611', 'L2612']",
#  "u29 +++$+++ u31 +++$+++ m2 +++$+++ ['L2644', 'L2645']",
#  "u29 +++$+++ u31 +++$+++ m2 +++$+++ ['L2646', 'L2647', 'L2648']",
#  "u29 +++$+++ u31 +++$+++ m2 +++$+++ ['L2651', 'L2652']",
#  "u29 +++$+++ u31 +++$+++ m2 +++$+++ ['L2653', 'L2654', 'L2655', 'L2656']",
#  "u29 +++$+++ u31 +++$+++ m2 +++$+++ ['L2664', 'L2665']",
#  "u30 +++$+++ u45 +++$+++ m2 +++$+++ ['L2621', 'L2622', 'L2623', 'L2624', 'L2625', 'L2626']",
#  "u30 +++$+++ u45 +++$+++ m2 +++$+++ ['L2627', 'L2628']",
#  "u30 +++$+++ u31 +++$+++ m2 +++$+++ ['L3278', 'L3279', 'L3280', 'L3281', 'L3282', 'L3283', 'L3284', 'L3285', 'L3286']",
#  "u30 +++$+++ u34 +++$+++ m2 +++$+++ ['L3419', 'L3420', 'L3421']",
#  "u30 +++$+++ u34 +++$+++ m2 +++$+++ ['L3431', 'L3432']",
#  "u30 +++$+++ u34 +++$+++ m2 +++$+++ ['L3433', 'L3434']",
#  "u30 +++$+++ u34 +++$+++ m2 +++$+++ ['L3435', 'L3436']",
#  "u30 +++$+++ u34 +++$+++ m2 +++$+++ ['L3554', 'L3555', 'L3556']",
#  "u30 +++$+++ u32 +++$+++ m2 +++$+++ ['L2845', 'L2846', 'L2847']",
#  "u30 +++$+++ u32 +++$+++ m2 +++$+++ ['L2848', 'L2849']",
#  "u30 +++$+++ u32 +++$+++ m2 +++$+++ ['L2850', 'L2851', 'L2852', 'L2853', 'L2854']",
#  "u30 +++$+++ u32 +++$+++ m2 +++$+++ ['L2855', 'L2856']",
#  "u30 +++$+++ u32 +++$+++ m2 +++$+++ ['L2857', 'L2858']",
#  "u30 +++$+++ u33 +++$+++ m2 +++$+++ ['L2563', 'L2564']",
#  "u30 +++$+++ u33 +++$+++ m2 +++$+++ ['L2565', 'L2566', 'L2567', 'L2568', 'L2569']",
#  "u30 +++$+++ u33 +++$+++ m2 +++$+++ ['L2570', 'L2571', 'L2572', 'L2573', 'L2574']",
#  "u30 +++$+++ u33 +++$+++ m2 +++$+++ ['L2577', 'L2578', 'L2579', 'L2580', 'L2581']",
#  "u30 +++$+++ u48 +++$+++ m2 +++$+++ ['L2908', 'L2909']",
#  "u30 +++$+++ u48 +++$+++ m2 +++$+++ ['L2910', 'L2911', 'L2912', 'L2913', 'L2914', 'L2915']",
#  "u30 +++$+++ u42 +++$+++ m2 +++$+++ ['L2557', 'L2558']",
#  "u30 +++$+++ u42 +++$+++ m2 +++$+++ ['L2559', 'L2560']",
#  "u30 +++$+++ u42 +++$+++ m2 +++$+++ ['L2561', 'L2562']",
#  "u30 +++$+++ u42 +++$+++ m2 +++$+++ ['L2635', 'L2636', 'L2637', 'L2638']",
#  "u30 +++$+++ u42 +++$+++ m2 +++$+++ ['L2639', 'L2640']",
#  "u30 +++$+++ u42 +++$+++ m2 +++$+++ ['L2666', 'L2667', 'L2668']",
#  "u30 +++$+++ u42 +++$+++ m2 +++$+++ ['L2670', 'L2671']",
#  "u30 +++$+++ u42 +++$+++ m2 +++$+++ ['L2778', 'L2779']",
#  "u30 +++$+++ u42 +++$+++ m2 +++$+++ ['L2780', 'L2781', 'L2782', 'L2783']",
#  "u30 +++$+++ u42 +++$+++ m2 +++$+++ ['L2789', 'L2790']",
#  "u30 +++$+++ u42 +++$+++ m2 +++$+++ ['L2842', 'L2843', 'L2844']",
#  "u30 +++$+++ u42 +++$+++ m2 +++$+++ ['L3083', 'L3084', 'L3085']",
#  "u30 +++$+++ u42 +++$+++ m2 +++$+++ ['L3087', 'L3088']",
#  "u30 +++$+++ u42 +++$+++ m2 +++$+++ ['L3183', 'L3184', 'L3185', 'L3186', 'L3187', 'L3188']",
#  "u30 +++$+++ u42 +++$+++ m2 +++$+++ ['L3189', 'L3190']",
#  "u30 +++$+++ u42 +++$+++ m2 +++$+++ ['L3191', 'L3192', 'L3193']",
#  "u30 +++$+++ u42 +++$+++ m2 +++$+++ ['L3246', 'L3247']",
#  "u30 +++$+++ u42 +++$+++ m2 +++$+++ ['L3250', 'L3251']",
#  "u30 +++$+++ u42 +++$+++ m2 +++$+++ ['L3356', 'L3357']",
#  "u30 +++$+++ u42 +++$+++ m2 +++$+++ ['L3359', 'L3360']",
#  "u30 +++$+++ u42 +++$+++ m2 +++$+++ ['L3361', 'L3362']",
#  "u30 +++$+++ u42 +++$+++ m2 +++$+++ ['L3363', 'L3364']",
#  "u30 +++$+++ u42 +++$+++ m2 +++$+++ ['L3365', 'L3366']",
#  "u30 +++$+++ u42 +++$+++ m2 +++$+++ ['L3368', 'L3369', 'L3370']",
#  "u30 +++$+++ u42 +++$+++ m2 +++$+++ ['L3372', 'L3373', 'L3374', 'L3375']",
#  "u30 +++$+++ u42 +++$+++ m2 +++$+++ ['L3376', 'L3377', 'L3378']",
#  "u30 +++$+++ u42 +++$+++ m2 +++$+++ ['L3547', 'L3548']",
#  "u30 +++$+++ u39 +++$+++ m2 +++$+++ ['L2672', 'L2673']",
#  "u30 +++$+++ u39 +++$+++ m2 +++$+++ ['L2674', 'L2675', 'L2676']",
#  "u30 +++$+++ u39 +++$+++ m2 +++$+++ ['L2678', 'L2679']",
#  "u30 +++$+++ u39 +++$+++ m2 +++$+++ ['L2680', 'L2681', 'L2682']",
#  "u30 +++$+++ u39 +++$+++ m2 +++$+++ ['L2685', 'L2686', 'L2687', 'L2688', 'L2689', 'L2690', 'L2691', 'L2692']",
#  "u31 +++$+++ u37 +++$+++ m2 +++$+++ ['L3271', 'L3272', 'L3273', 'L3274', 'L3275']",
#  "u31 +++$+++ u37 +++$+++ m2 +++$+++ ['L3352', 'L3353']",
#  "u31 +++$+++ u36 +++$+++ m2 +++$+++ ['L2608', 'L2609', 'L2610']",
#  "u31 +++$+++ u36 +++$+++ m2 +++$+++ ['L2614', 'L2615']",
#  "u31 +++$+++ u36 +++$+++ m2 +++$+++ ['L3409', 'L3410']",
#  "u31 +++$+++ u36 +++$+++ m2 +++$+++ ['L3411', 'L3412', 'L3413']",
#  "u31 +++$+++ u41 +++$+++ m2 +++$+++ ['L3262', 'L3263', 'L3264', 'L3265', 'L3266', 'L3267', 'L3268', 'L3269']",
#  "u33 +++$+++ u42 +++$+++ m2 +++$+++ ['L2575', 'L2576']",
#  "u33 +++$+++ u42 +++$+++ m2 +++$+++ ['L2582', 'L2583', 'L2584', 'L2585', 'L2586', 'L2587', 'L2588', 'L2589', 'L2590', 'L2591']",
#  "u34 +++$+++ u36 +++$+++ m2 +++$+++ ['L2732', 'L2733']",
#  "u34 +++$+++ u36 +++$+++ m2 +++$+++ ['L2740', 'L2741', 'L2742', 'L2743']",
#  "u34 +++$+++ u36 +++$+++ m2 +++$+++ ['L2744', 'L2745']",
#  "u34 +++$+++ u36 +++$+++ m2 +++$+++ ['L3398', 'L3399', 'L3400', 'L3401', 'L3402', 'L3403']",
#  "u34 +++$+++ u40 +++$+++ m2 +++$+++ ['L2698', 'L2699', 'L2700']",
#  "u34 +++$+++ u40 +++$+++ m2 +++$+++ ['L2701', 'L2702', 'L2703']",
#  "u34 +++$+++ u40 +++$+++ m2 +++$+++ ['L2706', 'L2707']",
#  "u34 +++$+++ u40 +++$+++ m2 +++$+++ ['L2771', 'L2772', 'L2773']",
#  "u34 +++$+++ u38 +++$+++ m2 +++$+++ ['L2808', 'L2809', 'L2810', 'L2811', 'L2812', 'L2813']",
#  "u34 +++$+++ u35 +++$+++ m2 +++$+++ ['L2715', 'L2716', 'L2717', 'L2718', 'L2719', 'L2720', 'L2721']",
#  "u34 +++$+++ u35 +++$+++ m2 +++$+++ ['L2724', 'L2725']",
#  "u34 +++$+++ u35 +++$+++ m2 +++$+++ ['L2735', 'L2736', 'L2737']",
#  "u34 +++$+++ u35 +++$+++ m2 +++$+++ ['L2738', 'L2739']",
#  "u34 +++$+++ u35 +++$+++ m2 +++$+++ ['L2754', 'L2755', 'L2756', 'L2757']",
#  "u34 +++$+++ u35 +++$+++ m2 +++$+++ ['L2767', 'L2768']",
#  "u34 +++$+++ u35 +++$+++ m2 +++$+++ ['L2793', 'L2794', 'L2795']",
#  "u34 +++$+++ u35 +++$+++ m2 +++$+++ ['L2863', 'L2864', 'L2865']",
#  "u34 +++$+++ u35 +++$+++ m2 +++$+++ ['L2870', 'L2871', 'L2872']",
#  "u34 +++$+++ u35 +++$+++ m2 +++$+++ ['L3024', 'L3025', 'L3026']",
#  "u34 +++$+++ u35 +++$+++ m2 +++$+++ ['L3287', 'L3288']",
#  "u34 +++$+++ u35 +++$+++ m2 +++$+++ ['L3342', 'L3343', 'L3344']",
#  "u34 +++$+++ u47 +++$+++ m2 +++$+++ ['L2928', 'L2929', 'L2930']",
#  "u34 +++$+++ u47 +++$+++ m2 +++$+++ ['L3422', 'L3423', 'L3424']",
#  "u34 +++$+++ u47 +++$+++ m2 +++$+++ ['L3425', 'L3426', 'L3427']",
#  "u43 +++$+++ u46 +++$+++ m2 +++$+++ ['L2828', 'L2829', 'L2830', 'L2831', 'L2832', 'L2833', 'L2834', 'L2835', 'L2836', 'L2837', 'L2838', 'L2839', 'L2840']",
#  "u49 +++$+++ u55 +++$+++ m3 +++$+++ ['L3712', 'L3713']",
#  "u49 +++$+++ u55 +++$+++ m3 +++$+++ ['L3720', 'L3721']",
#  "u49 +++$+++ u55 +++$+++ m3 +++$+++ ['L3728', 'L3729']",
#  "u49 +++$+++ u55 +++$+++ m3 +++$+++ ['L3749', 'L3750']",
#  "u49 +++$+++ u55 +++$+++ m3 +++$+++ ['L3756', 'L3757']",
#  "u49 +++$+++ u55 +++$+++ m3 +++$+++ ['L3770', 'L3771']",
#  "u49 +++$+++ u55 +++$+++ m3 +++$+++ ['L3777', 'L3778']",
#  "u50 +++$+++ u60 +++$+++ m3 +++$+++ ['L3942', 'L3943', 'L3944', 'L3945']",
#  "u50 +++$+++ u60 +++$+++ m3 +++$+++ ['L3963', 'L3964', 'L3965', 'L3966', 'L3967', 'L3968', 'L3969']",
#  "u50 +++$+++ u60 +++$+++ m3 +++$+++ ['L3972', 'L3973', 'L3974', 'L3975', 'L3976']",
#  "u50 +++$+++ u60 +++$+++ m3 +++$+++ ['L3979', 'L3980', 'L3981', 'L3982', 'L3983', 'L3984']",
#  "u50 +++$+++ u60 +++$+++ m3 +++$+++ ['L3987', 'L3988', 'L3989', 'L3990', 'L3991', 'L3992']",
#  "u50 +++$+++ u60 +++$+++ m3 +++$+++ ['L3995', 'L3996', 'L3997', 'L3998', 'L3999', 'L4000', 'L4001']",
#  "u50 +++$+++ u60 +++$+++ m3 +++$+++ ['L4011', 'L4012', 'L4013', 'L4014', 'L4015', 'L4016', 'L4017']",
#  "u50 +++$+++ u60 +++$+++ m3 +++$+++ ['L4159', 'L4160', 'L4161', 'L4162', 'L4163']",
#  "u50 +++$+++ u60 +++$+++ m3 +++$+++ ['L4188', 'L4189', 'L4190', 'L4191', 'L4192', 'L4193']",
#  "u50 +++$+++ u60 +++$+++ m3 +++$+++ ['L4196', 'L4197', 'L4198', 'L4199']",
#  "u50 +++$+++ u60 +++$+++ m3 +++$+++ ['L4208', 'L4209']",
#  "u50 +++$+++ u60 +++$+++ m3 +++$+++ ['L4282', 'L4283']",
#  "u50 +++$+++ u60 +++$+++ m3 +++$+++ ['L4296', 'L4297', 'L4298', 'L4299', 'L4300']",
#  "u50 +++$+++ u56 +++$+++ m3 +++$+++ ['L4006', 'L4007']",
#  "u50 +++$+++ u56 +++$+++ m3 +++$+++ ['L4068', 'L4069', 'L4070']",
#  "u50 +++$+++ u56 +++$+++ m3 +++$+++ ['L4079', 'L4080']",
#  "u50 +++$+++ u56 +++$+++ m3 +++$+++ ['L4219', 'L4220', 'L4221', 'L4222', 'L4223', 'L4224']",
#  "u50 +++$+++ u56 +++$+++ m3 +++$+++ ['L4227', 'L4228', 'L4229', 'L4230']",
#  "u50 +++$+++ u56 +++$+++ m3 +++$+++ ['L4265', 'L4266', 'L4267', 'L4268', 'L4269', 'L4270', 'L4271']",
#  "u50 +++$+++ u56 +++$+++ m3 +++$+++ ['L4333', 'L4334', 'L4335']",
#  "u50 +++$+++ u56 +++$+++ m3 +++$+++ ['L4346', 'L4347', 'L4348', 'L4349', 'L4350']",
#  "u50 +++$+++ u56 +++$+++ m3 +++$+++ ['L4353', 'L4354', 'L4355', 'L4356', 'L4357']",
#  "u50 +++$+++ u56 +++$+++ m3 +++$+++ ['L4360', 'L4361', 'L4362', 'L4363']",
#  "u50 +++$+++ u56 +++$+++ m3 +++$+++ ['L4366', 'L4367', 'L4368']",
#  "u50 +++$+++ u51 +++$+++ m3 +++$+++ ['L3970', 'L3971']",
#  "u50 +++$+++ u51 +++$+++ m3 +++$+++ ['L3977', 'L3978']",
#  "u50 +++$+++ u51 +++$+++ m3 +++$+++ ['L3993', 'L3994']",
#  "u50 +++$+++ u51 +++$+++ m3 +++$+++ ['L4002', 'L4003']",
#  "u50 +++$+++ u51 +++$+++ m3 +++$+++ ['L4009', 'L4010']",
#  "u50 +++$+++ u51 +++$+++ m3 +++$+++ ['L4018', 'L4019']",
#  "u52 +++$+++ u55 +++$+++ m3 +++$+++ ['L3668', 'L3669']",
#  "u52 +++$+++ u55 +++$+++ m3 +++$+++ ['L3672', 'L3673', 'L3674', 'L3675', 'L3676', 'L3677']",
#  "u52 +++$+++ u55 +++$+++ m3 +++$+++ ['L3679', 'L3680', 'L3681', 'L3682', 'L3683', 'L3684', 'L3685']",
#  "u52 +++$+++ u55 +++$+++ m3 +++$+++ ['L3688', 'L3689', 'L3690', 'L3691', 'L3692', 'L3693']",
#  "u53 +++$+++ u59 +++$+++ m3 +++$+++ ['L3797', 'L3798', 'L3799']",
#  "u53 +++$+++ u59 +++$+++ m3 +++$+++ ['L3805', 'L3806', 'L3807', 'L3808', 'L3809', 'L3810']",
#  "u54 +++$+++ u55 +++$+++ m3 +++$+++ ['L3730', 'L3731', 'L3732', 'L3733', 'L3734', 'L3735']",
#  "u54 +++$+++ u55 +++$+++ m3 +++$+++ ['L3758', 'L3759']",
#  "u54 +++$+++ u55 +++$+++ m3 +++$+++ ['L3774', 'L3775', 'L3776']",
#  "u54 +++$+++ u55 +++$+++ m3 +++$+++ ['L3779', 'L3780']",
#  "u55 +++$+++ u58 +++$+++ m3 +++$+++ ['L3622', 'L3623']",
#  "u55 +++$+++ u58 +++$+++ m3 +++$+++ ['L3626', 'L3627', 'L3628', 'L3629', 'L3630', 'L3631']",
#  "u55 +++$+++ u58 +++$+++ m3 +++$+++ ['L3651', 'L3652', 'L3653']",
#  "u55 +++$+++ u61 +++$+++ m3 +++$+++ ['L3724', 'L3725', 'L3726']",
#  "u55 +++$+++ u61 +++$+++ m3 +++$+++ ['L3738', 'L3739', 'L3740']",
#  "u55 +++$+++ u61 +++$+++ m3 +++$+++ ['L3745', 'L3746', 'L3747', 'L3748']",
#  "u55 +++$+++ u61 +++$+++ m3 +++$+++ ['L3751', 'L3752', 'L3753', 'L3754']",
#  "u55 +++$+++ u61 +++$+++ m3 +++$+++ ['L3760', 'L3761', 'L3762', 'L3763']",
#  "u55 +++$+++ u61 +++$+++ m3 +++$+++ ['L3766', 'L3767', 'L3768']",
#  "u55 +++$+++ u61 +++$+++ m3 +++$+++ ['L3772', 'L3773']",
#  "u55 +++$+++ u57 +++$+++ m3 +++$+++ ['L3868', 'L3869']",
#  "u55 +++$+++ u57 +++$+++ m3 +++$+++ ['L3889', 'L3890', 'L3891', 'L3892', 'L3893']",
#  "u55 +++$+++ u57 +++$+++ m3 +++$+++ ['L3896', 'L3897']",
#  "u55 +++$+++ u57 +++$+++ m3 +++$+++ ['L3904', 'L3905', 'L3906', 'L3907']",
#  "u55 +++$+++ u59 +++$+++ m3 +++$+++ ['L3817', 'L3818', 'L3819', 'L3820', 'L3821']",
#  "u55 +++$+++ u59 +++$+++ m3 +++$+++ ['L3824', 'L3825', 'L3826', 'L3827', 'L3828', 'L3829']",
#  "u55 +++$+++ u59 +++$+++ m3 +++$+++ ['L3832', 'L3833', 'L3834']",
#  "u55 +++$+++ u59 +++$+++ m3 +++$+++ ['L3837', 'L3838', 'L3839']",
#  "u56 +++$+++ u60 +++$+++ m3 +++$+++ ['L4020', 'L4021', 'L4022', 'L4023', 'L4024', 'L4025']",
#  "u56 +++$+++ u60 +++$+++ m3 +++$+++ ['L4028', 'L4029', 'L4030', 'L4031', 'L4032', 'L4033']",
#  "u56 +++$+++ u60 +++$+++ m3 +++$+++ ['L4096', 'L4097']",
#  "u56 +++$+++ u60 +++$+++ m3 +++$+++ ['L4108', 'L4109', 'L4110', 'L4111', 'L4112', 'L4113']",
#  "u56 +++$+++ u60 +++$+++ m3 +++$+++ ['L4118', 'L4119']",
#  "u56 +++$+++ u60 +++$+++ m3 +++$+++ ['L4169', 'L4170']",
#  "u56 +++$+++ u60 +++$+++ m3 +++$+++ ['L4174', 'L4175']",
#  "u56 +++$+++ u60 +++$+++ m3 +++$+++ ['L4181', 'L4182', 'L4183']",
#  "u62 +++$+++ u75 +++$+++ m4 +++$+++ ['L5039', 'L5040']",
#  "u62 +++$+++ u75 +++$+++ m4 +++$+++ ['L5041', 'L5042']",
#  "u62 +++$+++ u75 +++$+++ m4 +++$+++ ['L5043', 'L5044']",
#  "u62 +++$+++ u75 +++$+++ m4 +++$+++ ['L5045', 'L5046', 'L5047', 'L5048']",
#  "u63 +++$+++ u71 +++$+++ m4 +++$+++ ['L4897', 'L4898', 'L4899', 'L4900']",
#  "u63 +++$+++ u71 +++$+++ m4 +++$+++ ['L4903', 'L4904', 'L4905', 'L4906']",
#  "u63 +++$+++ u71 +++$+++ m4 +++$+++ ['L4922', 'L4923']",
#  "u63 +++$+++ u71 +++$+++ m4 +++$+++ ['L4924', 'L4925']",
#  "u64 +++$+++ u69 +++$+++ m4 +++$+++ ['L4453', 'L4454']",
#  "u64 +++$+++ u69 +++$+++ m4 +++$+++ ['L4501', 'L4502', 'L4503', 'L4504', 'L4505']",
#  "u64 +++$+++ u69 +++$+++ m4 +++$+++ ['L4506', 'L4507', 'L4508', 'L4509', 'L4510', 'L4511']",
#  "u64 +++$+++ u69 +++$+++ m4 +++$+++ ['L4562', 'L4563']",
#  "u64 +++$+++ u69 +++$+++ m4 +++$+++ ['L4567', 'L4568']",
#  "u65 +++$+++ u71 +++$+++ m4 +++$+++ ['L5175', 'L5176', 'L5177', 'L5178', 'L5179', 'L5180']",
#  "u65 +++$+++ u71 +++$+++ m4 +++$+++ ['L5181', 'L5182']",
#  "u65 +++$+++ u71 +++$+++ m4 +++$+++ ['L5183', 'L5184', 'L5185', 'L5186', 'L5187', 'L5188']",
#  "u65 +++$+++ u71 +++$+++ m4 +++$+++ ['L5193', 'L5194']",
#  "u65 +++$+++ u71 +++$+++ m4 +++$+++ ['L5215', 'L5216']",
#  "u65 +++$+++ u71 +++$+++ m4 +++$+++ ['L5366', 'L5367', 'L5368']",
#  "u65 +++$+++ u71 +++$+++ m4 +++$+++ ['L5370', 'L5371']",
#  "u66 +++$+++ u67 +++$+++ m4 +++$+++ ['L4944', 'L4945']",
#  "u66 +++$+++ u67 +++$+++ m4 +++$+++ ['L4959', 'L4960']",
#  "u66 +++$+++ u67 +++$+++ m4 +++$+++ ['L5316', 'L5317', 'L5318']",
#  "u66 +++$+++ u67 +++$+++ m4 +++$+++ ['L5321', 'L5322', 'L5323', 'L5324', 'L5325']",
#  "u66 +++$+++ u67 +++$+++ m4 +++$+++ ['L5328', 'L5329']",
#  "u67 +++$+++ u69 +++$+++ m4 +++$+++ ['L4628', 'L4629']",
#  "u67 +++$+++ u69 +++$+++ m4 +++$+++ ['L5338', 'L5339', 'L5340']",
#  "u67 +++$+++ u69 +++$+++ m4 +++$+++ ['L5346', 'L5347', 'L5348']",
#  "u67 +++$+++ u71 +++$+++ m4 +++$+++ ['L4727', 'L4728', 'L4729']",
#  "u67 +++$+++ u71 +++$+++ m4 +++$+++ ['L4731', 'L4732']",
#  "u67 +++$+++ u71 +++$+++ m4 +++$+++ ['L4739', 'L4740', 'L4741']",
#  "u67 +++$+++ u71 +++$+++ m4 +++$+++ ['L4743', 'L4744', 'L4745', 'L4746', 'L4747', 'L4748', 'L4749', 'L4750', 'L4751']",
#  "u67 +++$+++ u71 +++$+++ m4 +++$+++ ['L4763', 'L4764']",
#  "u67 +++$+++ u71 +++$+++ m4 +++$+++ ['L4765', 'L4766']",
#  "u67 +++$+++ u71 +++$+++ m4 +++$+++ ['L4769', 'L4770']",
#  "u67 +++$+++ u71 +++$+++ m4 +++$+++ ['L4771', 'L4772', 'L4773', 'L4774', 'L4775']",
#  "u67 +++$+++ u71 +++$+++ m4 +++$+++ ['L4778', 'L4779']",
#  "u67 +++$+++ u71 +++$+++ m4 +++$+++ ['L4780', 'L4781', 'L4782', 'L4783', 'L4784', 'L4785']",
#  "u67 +++$+++ u71 +++$+++ m4 +++$+++ ['L4786', 'L4787', 'L4788']",
#  "u67 +++$+++ u71 +++$+++ m4 +++$+++ ['L4789', 'L4790', 'L4791', 'L4792']",
#  "u67 +++$+++ u71 +++$+++ m4 +++$+++ ['L4800', 'L4801', 'L4802', 'L4803']",
#  "u67 +++$+++ u71 +++$+++ m4 +++$+++ ['L4814', 'L4815', 'L4816']",
#  "u67 +++$+++ u71 +++$+++ m4 +++$+++ ['L4825', 'L4826', 'L4827', 'L4828']",
#  "u67 +++$+++ u71 +++$+++ m4 +++$+++ ['L4848', 'L4849', 'L4850', 'L4851', 'L4852', 'L4853', 'L4854', 'L4855']",
#  "u67 +++$+++ u71 +++$+++ m4 +++$+++ ['L4857', 'L4858']",
#  "u67 +++$+++ u71 +++$+++ m4 +++$+++ ['L4860', 'L4861']",
#  "u67 +++$+++ u71 +++$+++ m4 +++$+++ ['L4863', 'L4864']",
#  "u67 +++$+++ u71 +++$+++ m4 +++$+++ ['L4866', 'L4867']",
#  "u67 +++$+++ u71 +++$+++ m4 +++$+++ ['L4868', 'L4869']",
#  "u67 +++$+++ u71 +++$+++ m4 +++$+++ ['L4870', 'L4871']",
#  "u67 +++$+++ u71 +++$+++ m4 +++$+++ ['L4873', 'L4874', 'L4875', 'L4876', 'L4877', 'L4878', 'L4879']",
#  "u67 +++$+++ u71 +++$+++ m4 +++$+++ ['L4880', 'L4881']",
#  "u67 +++$+++ u71 +++$+++ m4 +++$+++ ['L4882', 'L4883', 'L4884', 'L4885', 'L4886']",
#  "u67 +++$+++ u71 +++$+++ m4 +++$+++ ['L4887', 'L4888', 'L4889', 'L4890', 'L4891']",
#  "u67 +++$+++ u71 +++$+++ m4 +++$+++ ['L4893', 'L4894']",
#  "u67 +++$+++ u71 +++$+++ m4 +++$+++ ['L4895', 'L4896']",
#  "u67 +++$+++ u71 +++$+++ m4 +++$+++ ['L4911', 'L4912']",
#  "u67 +++$+++ u71 +++$+++ m4 +++$+++ ['L4929', 'L4930']",
#  "u67 +++$+++ u71 +++$+++ m4 +++$+++ ['L4937', 'L4938', 'L4939']",
#  "u67 +++$+++ u71 +++$+++ m4 +++$+++ ['L4964', 'L4965']",
#  "u67 +++$+++ u71 +++$+++ m4 +++$+++ ['L4969', 'L4970', 'L4971', 'L4972', 'L4973']",
#  "u67 +++$+++ u71 +++$+++ m4 +++$+++ ['L4974', 'L4975']",
#  "u67 +++$+++ u71 +++$+++ m4 +++$+++ ['L4994', 'L4995', 'L4996', 'L4997']",
#  "u67 +++$+++ u71 +++$+++ m4 +++$+++ ['L5002', 'L5003', 'L5004', 'L5005']",
#  "u67 +++$+++ u71 +++$+++ m4 +++$+++ ['L5007', 'L5008', 'L5009', 'L5010']",
#  "u67 +++$+++ u71 +++$+++ m4 +++$+++ ['L5011', 'L5012', 'L5013', 'L5014']",
#  "u67 +++$+++ u71 +++$+++ m4 +++$+++ ['L5016', 'L5017']",
#  "u67 +++$+++ u71 +++$+++ m4 +++$+++ ['L5018', 'L5019', 'L5020']",
#  "u67 +++$+++ u71 +++$+++ m4 +++$+++ ['L5021', 'L5022']",
#  "u67 +++$+++ u71 +++$+++ m4 +++$+++ ['L5023', 'L5024', 'L5025']",
#  "u67 +++$+++ u71 +++$+++ m4 +++$+++ ['L5028', 'L5029', 'L5030']",
#  "u67 +++$+++ u71 +++$+++ m4 +++$+++ ['L5033', 'L5034', 'L5035']",
#  "u67 +++$+++ u71 +++$+++ m4 +++$+++ ['L5036', 'L5037', 'L5038']",
#  "u67 +++$+++ u71 +++$+++ m4 +++$+++ ['L5049', 'L5050', 'L5051']",
#  "u67 +++$+++ u71 +++$+++ m4 +++$+++ ['L5052', 'L5053', 'L5054', 'L5055', 'L5056']",
#  "u67 +++$+++ u71 +++$+++ m4 +++$+++ ['L5057', 'L5058', 'L5059']",
#  "u67 +++$+++ u71 +++$+++ m4 +++$+++ ['L5060', 'L5061', 'L5062', 'L5063', 'L5064']",
#  "u67 +++$+++ u71 +++$+++ m4 +++$+++ ['L5065', 'L5066']",
#  "u67 +++$+++ u71 +++$+++ m4 +++$+++ ['L5067', 'L5068']",
#  "u67 +++$+++ u71 +++$+++ m4 +++$+++ ['L5069', 'L5070', 'L5071', 'L5072']",
#  "u67 +++$+++ u71 +++$+++ m4 +++$+++ ['L5073', 'L5074']",
#  "u67 +++$+++ u71 +++$+++ m4 +++$+++ ['L5076', 'L5077']",
#  "u67 +++$+++ u71 +++$+++ m4 +++$+++ ['L5083', 'L5084', 'L5085']",
#  "u67 +++$+++ u71 +++$+++ m4 +++$+++ ['L5171', 'L5172']",
#  "u67 +++$+++ u71 +++$+++ m4 +++$+++ ['L5190', 'L5191', 'L5192']",
#  "u67 +++$+++ u71 +++$+++ m4 +++$+++ ['L5195', 'L5196']",
#  "u67 +++$+++ u71 +++$+++ m4 +++$+++ ['L5197', 'L5198', 'L5199', 'L5200']",
#  "u67 +++$+++ u71 +++$+++ m4 +++$+++ ['L5201', 'L5202']",
#  "u67 +++$+++ u71 +++$+++ m4 +++$+++ ['L5204', 'L5205']",
#  "u67 +++$+++ u71 +++$+++ m4 +++$+++ ['L5206', 'L5207']",
#  "u67 +++$+++ u71 +++$+++ m4 +++$+++ ['L5208', 'L5209', 'L5210']",
#  "u67 +++$+++ u71 +++$+++ m4 +++$+++ ['L5212', 'L5213']",
#  "u67 +++$+++ u71 +++$+++ m4 +++$+++ ['L5224', 'L5225', 'L5226', 'L5227']",
#  "u67 +++$+++ u71 +++$+++ m4 +++$+++ ['L5236', 'L5237']",
#  "u67 +++$+++ u71 +++$+++ m4 +++$+++ ['L5249', 'L5250', 'L5251', 'L5252']",
#  "u67 +++$+++ u71 +++$+++ m4 +++$+++ ['L5253', 'L5254', 'L5255']",
#  "u67 +++$+++ u71 +++$+++ m4 +++$+++ ['L5256', 'L5257']",
#  "u67 +++$+++ u71 +++$+++ m4 +++$+++ ['L5290', 'L5291']",
#  "u67 +++$+++ u71 +++$+++ m4 +++$+++ ['L5304', 'L5305']",
#  "u67 +++$+++ u71 +++$+++ m4 +++$+++ ['L5306', 'L5307']",
#  "u67 +++$+++ u71 +++$+++ m4 +++$+++ ['L5308', 'L5309', 'L5310', 'L5311', 'L5312', 'L5313', 'L5314']",
#  "u67 +++$+++ u71 +++$+++ m4 +++$+++ ['L5351', 'L5352', 'L5353']",
#  "u67 +++$+++ u71 +++$+++ m4 +++$+++ ['L5372', 'L5373']",
#  "u67 +++$+++ u71 +++$+++ m4 +++$+++ ['L5375', 'L5376']",
#  "u67 +++$+++ u71 +++$+++ m4 +++$+++ ['L5377', 'L5378', 'L5379', 'L5380', 'L5381', 'L5382']",
#  "u67 +++$+++ u71 +++$+++ m4 +++$+++ ['L5383', 'L5384']",
#  "u67 +++$+++ u70 +++$+++ m4 +++$+++ ['L4689', 'L4690']",
#  "u67 +++$+++ u70 +++$+++ m4 +++$+++ ['L4691', 'L4692']",
#  "u67 +++$+++ u70 +++$+++ m4 +++$+++ ['L4693', 'L4694', 'L4695', 'L4696', 'L4697', 'L4698', 'L4699', 'L4700', 'L4701', 'L4702', 'L4703']",
#  "u67 +++$+++ u70 +++$+++ m4 +++$+++ ['L5093', 'L5094', 'L5095', 'L5096']",
#  "u67 +++$+++ u70 +++$+++ m4 +++$+++ ['L5097', 'L5098', 'L5099']",
#  "u67 +++$+++ u70 +++$+++ m4 +++$+++ ['L5100', 'L5101']",
#  "u67 +++$+++ u70 +++$+++ m4 +++$+++ ['L5102', 'L5103', 'L5104']",
#  "u67 +++$+++ u70 +++$+++ m4 +++$+++ ['L5242', 'L5243']",
#  "u67 +++$+++ u70 +++$+++ m4 +++$+++ ['L5244', 'L5245']",
#  "u67 +++$+++ u77 +++$+++ m4 +++$+++ ['L4636', 'L4637', 'L4638', 'L4639']",
#  "u67 +++$+++ u77 +++$+++ m4 +++$+++ ['L4642', 'L4643', 'L4644']",
#  "u67 +++$+++ u73 +++$+++ m4 +++$+++ ['L4669', 'L4670', 'L4671']",
#  "u67 +++$+++ u73 +++$+++ m4 +++$+++ ['L4672', 'L4673']",
#  "u67 +++$+++ u73 +++$+++ m4 +++$+++ ['L4675', 'L4676']",
#  "u67 +++$+++ u73 +++$+++ m4 +++$+++ ['L4677', 'L4678', 'L4679', 'L4680']",
#  "u67 +++$+++ u73 +++$+++ m4 +++$+++ ['L4681', 'L4682']",
#  "u67 +++$+++ u73 +++$+++ m4 +++$+++ ['L4685', 'L4686', 'L4687']",
#  "u67 +++$+++ u73 +++$+++ m4 +++$+++ ['L5132', 'L5133', 'L5134', 'L5135', 'L5136', 'L5137', 'L5138']",
#  "u67 +++$+++ u73 +++$+++ m4 +++$+++ ['L5142', 'L5143']",
#  "u67 +++$+++ u73 +++$+++ m4 +++$+++ ['L5144', 'L5145']",
#  "u67 +++$+++ u73 +++$+++ m4 +++$+++ ['L5158', 'L5159']",
#  "u67 +++$+++ u73 +++$+++ m4 +++$+++ ['L5162', 'L5163']",
#  "u67 +++$+++ u75 +++$+++ m4 +++$+++ ['L4809', 'L4810', 'L4811', 'L4812', 'L4813']",
#  "u67 +++$+++ u75 +++$+++ m4 +++$+++ ['L4817', 'L4818', 'L4819']",
#  "u67 +++$+++ u75 +++$+++ m4 +++$+++ ['L4821', 'L4822', 'L4823']",
#  "u67 +++$+++ u68 +++$+++ m4 +++$+++ ['L4467', 'L4468']",
#  "u67 +++$+++ u68 +++$+++ m4 +++$+++ ['L4469', 'L4470', 'L4471']",
#  "u67 +++$+++ u68 +++$+++ m4 +++$+++ ['L4472', 'L4473', 'L4474']",
#  "u67 +++$+++ u68 +++$+++ m4 +++$+++ ['L4475', 'L4476']",
#  "u67 +++$+++ u68 +++$+++ m4 +++$+++ ['L4477', 'L4478', 'L4479', 'L4480', 'L4481', 'L4482', 'L4483', 'L4484', 'L4485', 'L4486', 'L4487', 'L4488']",
#  "u67 +++$+++ u68 +++$+++ m4 +++$+++ ['L4513', 'L4514']",
#  "u67 +++$+++ u68 +++$+++ m4 +++$+++ ['L4516', 'L4517']",
#  "u67 +++$+++ u68 +++$+++ m4 +++$+++ ['L4519', 'L4520', 'L4521', 'L4522']",
#  "u67 +++$+++ u68 +++$+++ m4 +++$+++ ['L4523', 'L4524', 'L4525']",
#  "u67 +++$+++ u68 +++$+++ m4 +++$+++ ['L4528', 'L4529', 'L4530', 'L4531', 'L4532']",
#  "u67 +++$+++ u68 +++$+++ m4 +++$+++ ['L4533', 'L4534', 'L4535']",
#  "u67 +++$+++ u68 +++$+++ m4 +++$+++ ['L4704', 'L4705', 'L4706']",
#  "u67 +++$+++ u68 +++$+++ m4 +++$+++ ['L4707', 'L4708', 'L4709']",
#  "u67 +++$+++ u68 +++$+++ m4 +++$+++ ['L4712', 'L4713', 'L4714', 'L4715', 'L4716', 'L4717', 'L4718']",
#  "u67 +++$+++ u68 +++$+++ m4 +++$+++ ['L4836', 'L4837']",
#  "u67 +++$+++ u68 +++$+++ m4 +++$+++ ['L4839', 'L4840']",
#  "u67 +++$+++ u68 +++$+++ m4 +++$+++ ['L5149', 'L5150', 'L5151', 'L5152', 'L5153']",
#  "u67 +++$+++ u68 +++$+++ m4 +++$+++ ['L5164', 'L5165']",
# ...
#  "u84 +++$+++ u88 +++$+++ m5 +++$+++ ['L6029', 'L6030', 'L6031', 'L6032']",
#  "u84 +++$+++ u98 +++$+++ m5 +++$+++ ['L5543', 'L5544']",
#  "u84 +++$+++ u98 +++$+++ m5 +++$+++ ['L5545', 'L5546', 'L5547', 'L5548']",
#  "u84 +++$+++ u98 +++$+++ m5 +++$+++ ['L5834', 'L5835']",
#  "u84 +++$+++ u98 +++$+++ m5 +++$+++ ['L6208', 'L6209']",
#  "u84 +++$+++ u98 +++$+++ m5 +++$+++ ['L6211', 'L6212']",
#  "u84 +++$+++ u86 +++$+++ m5 +++$+++ ['L5922', 'L5923']",
#  "u84 +++$+++ u86 +++$+++ m5 +++$+++ ['L5924', 'L5925']",
#  "u84 +++$+++ u86 +++$+++ m5 +++$+++ ['L5933', 'L5934']",
#  "u84 +++$+++ u86 +++$+++ m5 +++$+++ ['L6020', 'L6021', 'L6022', 'L6023', 'L6024', 'L6025', 'L6026']",
#  "u84 +++$+++ u86 +++$+++ m5 +++$+++ ['L6132', 'L6133']",
#  "u84 +++$+++ u86 +++$+++ m5 +++$+++ ['L6156', 'L6157', 'L6158']",
#  "u84 +++$+++ u86 +++$+++ m5 +++$+++ ['L6183', 'L6184']",
#  "u84 +++$+++ u86 +++$+++ m5 +++$+++ ['L6190', 'L6191']",
#  "u84 +++$+++ u86 +++$+++ m5 +++$+++ ['L6206', 'L6207']",
#  "u84 +++$+++ u86 +++$+++ m5 +++$+++ ['L6213', 'L6214']",
#  "u84 +++$+++ u86 +++$+++ m5 +++$+++ ['L6215', 'L6216']",
#  "u84 +++$+++ u86 +++$+++ m5 +++$+++ ['L6278', 'L6279', 'L6280']",
#  "u84 +++$+++ u86 +++$+++ m5 +++$+++ ['L6282', 'L6283']",
#  "u84 +++$+++ u90 +++$+++ m5 +++$+++ ['L5794', 'L5795', 'L5796', 'L5797', 'L5798', 'L5799', 'L5800']",
#  "u84 +++$+++ u90 +++$+++ m5 +++$+++ ['L5801', 'L5802', 'L5803']",
#  "u84 +++$+++ u90 +++$+++ m5 +++$+++ ['L5804', 'L5805', 'L5806']",
#  "u84 +++$+++ u90 +++$+++ m5 +++$+++ ['L5809', 'L5810', 'L5811', 'L5812', 'L5813']",
#  "u84 +++$+++ u90 +++$+++ m5 +++$+++ ['L5815', 'L5816']",
#  "u84 +++$+++ u90 +++$+++ m5 +++$+++ ['L5817', 'L5818', 'L5819']",
#  "u84 +++$+++ u90 +++$+++ m5 +++$+++ ['L5820', 'L5821', 'L5822']",
#  "u84 +++$+++ u85 +++$+++ m5 +++$+++ ['L5824', 'L5825']",
#  "u84 +++$+++ u85 +++$+++ m5 +++$+++ ['L5858', 'L5859']",
#  "u84 +++$+++ u85 +++$+++ m5 +++$+++ ['L5869', 'L5870', 'L5871']",
#  "u84 +++$+++ u85 +++$+++ m5 +++$+++ ['L5900', 'L5901']",
#  "u84 +++$+++ u85 +++$+++ m5 +++$+++ ['L5943', 'L5944']",
#  "u84 +++$+++ u85 +++$+++ m5 +++$+++ ['L5946', 'L5947']",
#  "u84 +++$+++ u85 +++$+++ m5 +++$+++ ['L5949', 'L5950']",
#  "u84 +++$+++ u85 +++$+++ m5 +++$+++ ['L5954', 'L5955', 'L5956', 'L5957']",
#  "u84 +++$+++ u85 +++$+++ m5 +++$+++ ['L5958', 'L5959', 'L5960', 'L5961', 'L5962', 'L5963', 'L5964', 'L5965']",
#  "u84 +++$+++ u85 +++$+++ m5 +++$+++ ['L6051', 'L6052', 'L6053', 'L6054', 'L6055', 'L6056']",
#  "u84 +++$+++ u85 +++$+++ m5 +++$+++ ['L6057', 'L6058', 'L6059']",
#  "u84 +++$+++ u85 +++$+++ m5 +++$+++ ['L6062', 'L6063', 'L6064']",
#  "u84 +++$+++ u85 +++$+++ m5 +++$+++ ['L6066', 'L6067']",
#  "u84 +++$+++ u85 +++$+++ m5 +++$+++ ['L6237', 'L6238', 'L6239', 'L6240', 'L6241']",
#  "u84 +++$+++ u85 +++$+++ m5 +++$+++ ['L6267', 'L6268', 'L6269', 'L6270']",
#  "u84 +++$+++ u85 +++$+++ m5 +++$+++ ['L6289', 'L6290', 'L6291', 'L6292', 'L6293']",
#  "u84 +++$+++ u85 +++$+++ m5 +++$+++ ['L6297', 'L6298', 'L6299', 'L6300', 'L6301']",
#  "u84 +++$+++ u85 +++$+++ m5 +++$+++ ['L6302', 'L6303', 'L6304', 'L6305']",
#  "u84 +++$+++ u85 +++$+++ m5 +++$+++ ['L6308', 'L6309']",
#  "u84 +++$+++ u97 +++$+++ m5 +++$+++ ['L5722', 'L5723', 'L5724', 'L5725', 'L5726']",
#  "u84 +++$+++ u97 +++$+++ m5 +++$+++ ['L5728', 'L5729']",
#  "u84 +++$+++ u89 +++$+++ m5 +++$+++ ['L5531', 'L5532', 'L5533']",
#  "u84 +++$+++ u89 +++$+++ m5 +++$+++ ['L5534', 'L5535', 'L5536']",
#  "u84 +++$+++ u89 +++$+++ m5 +++$+++ ['L5537', 'L5538']",
#  "u84 +++$+++ u89 +++$+++ m5 +++$+++ ['L5539', 'L5540']",
#  "u87 +++$+++ u90 +++$+++ m5 +++$+++ ['L5560', 'L5561', 'L5562', 'L5563', 'L5564', 'L5565', 'L5566', 'L5567']",
#  "u87 +++$+++ u90 +++$+++ m5 +++$+++ ['L5568', 'L5569', 'L5570']",
#  "u87 +++$+++ u90 +++$+++ m5 +++$+++ ['L5573', 'L5574']",
#  "u87 +++$+++ u90 +++$+++ m5 +++$+++ ['L5585', 'L5586']",
#  "u87 +++$+++ u90 +++$+++ m5 +++$+++ ['L6313', 'L6314']",
#  "u90 +++$+++ u91 +++$+++ m5 +++$+++ ['L5767', 'L5768', 'L5769', 'L5770']",
#  "u90 +++$+++ u91 +++$+++ m5 +++$+++ ['L5773', 'L5774']",
#  "u90 +++$+++ u91 +++$+++ m5 +++$+++ ['L6254', 'L6255']",
#  "u91 +++$+++ u96 +++$+++ m5 +++$+++ ['L5441', 'L5442']",
#  "u91 +++$+++ u96 +++$+++ m5 +++$+++ ['L5443', 'L5444', 'L5445', 'L5446', 'L5447']",
#  "u91 +++$+++ u96 +++$+++ m5 +++$+++ ['L5448', 'L5449', 'L5450', 'L5451', 'L5452', 'L5453']",
#  "u91 +++$+++ u96 +++$+++ m5 +++$+++ ['L5479', 'L5480']",
#  "u92 +++$+++ u93 +++$+++ m5 +++$+++ ['L5396', 'L5397', 'L5398']",
#  "u92 +++$+++ u93 +++$+++ m5 +++$+++ ['L5399', 'L5400']",
#  "u92 +++$+++ u93 +++$+++ m5 +++$+++ ['L5404', 'L5405']",
#  "u92 +++$+++ u93 +++$+++ m5 +++$+++ ['L5406', 'L5407']",
#  "u94 +++$+++ u99 +++$+++ m5 +++$+++ ['L6219', 'L6220', 'L6221', 'L6222', 'L6223', 'L6224', 'L6225']",
#  "u95 +++$+++ u99 +++$+++ m5 +++$+++ ['L6002', 'L6003']",
#  "u95 +++$+++ u99 +++$+++ m5 +++$+++ ['L6004', 'L6005']",
#  "u95 +++$+++ u99 +++$+++ m5 +++$+++ ['L6006', 'L6007', 'L6008', 'L6009']",
#  "u95 +++$+++ u99 +++$+++ m5 +++$+++ ['L6011', 'L6012']",
#  "u100 +++$+++ u114 +++$+++ m6 +++$+++ ['L6335', 'L6336']",
#  "u100 +++$+++ u114 +++$+++ m6 +++$+++ ['L6337', 'L6338', 'L6339', 'L6340', 'L6341', 'L6342', 'L6343', 'L6344']",
#  "u100 +++$+++ u114 +++$+++ m6 +++$+++ ['L6347', 'L6348', 'L6349', 'L6350']",
#  "u100 +++$+++ u114 +++$+++ m6 +++$+++ ['L6351', 'L6352']",
#  "u100 +++$+++ u114 +++$+++ m6 +++$+++ ['L6361', 'L6362', 'L6363', 'L6364', 'L6365']",
#  "u100 +++$+++ u114 +++$+++ m6 +++$+++ ['L6429', 'L6430', 'L6431', 'L6432', 'L6433', 'L6434', 'L6435']",
#  "u100 +++$+++ u114 +++$+++ m6 +++$+++ ['L6957', 'L6958', 'L6959']",
#  "u100 +++$+++ u114 +++$+++ m6 +++$+++ ['L6960', 'L6961', 'L6962', 'L6963', 'L6964']",
#  "u100 +++$+++ u114 +++$+++ m6 +++$+++ ['L6971', 'L6972', 'L6973', 'L6974', 'L6975', 'L6976']",
#  "u100 +++$+++ u114 +++$+++ m6 +++$+++ ['L6977', 'L6978', 'L6979']",
#  "u100 +++$+++ u114 +++$+++ m6 +++$+++ ['L6980', 'L6981', 'L6982', 'L6983', 'L6984', 'L6985']",
#  "u100 +++$+++ u114 +++$+++ m6 +++$+++ ['L6986', 'L6987', 'L6988', 'L6989', 'L6990', 'L6991', 'L6992', 'L6993']",
#  "u100 +++$+++ u114 +++$+++ m6 +++$+++ ['L6996', 'L6997', 'L6998', 'L6999', 'L7000']",
#  "u100 +++$+++ u114 +++$+++ m6 +++$+++ ['L7001', 'L7002']",
#  "u101 +++$+++ u114 +++$+++ m6 +++$+++ ['L6605', 'L6606']",
#  "u101 +++$+++ u114 +++$+++ m6 +++$+++ ['L6607', 'L6608', 'L6609', 'L6610', 'L6611', 'L6612']",
#  "u102 +++$+++ u105 +++$+++ m6 +++$+++ ['L6707', 'L6708', 'L6709', 'L6710', 'L6711', 'L6712', 'L6713', 'L6714', 'L6715', 'L6716', 'L6717']",
#  "u102 +++$+++ u105 +++$+++ m6 +++$+++ ['L6909', 'L6910']",
#  "u103 +++$+++ u114 +++$+++ m6 +++$+++ ['L6779', 'L6780']",
#  "u103 +++$+++ u114 +++$+++ m6 +++$+++ ['L6781', 'L6782', 'L6783', 'L6784']",
#  "u103 +++$+++ u114 +++$+++ m6 +++$+++ ['L6789', 'L6790']",
#  "u103 +++$+++ u114 +++$+++ m6 +++$+++ ['L6791', 'L6792', 'L6793', 'L6794', 'L6795', 'L6796', 'L6797', 'L6798', 'L6799']",
#  "u103 +++$+++ u114 +++$+++ m6 +++$+++ ['L6800', 'L6801', 'L6802']",
#  "u103 +++$+++ u114 +++$+++ m6 +++$+++ ['L6803', 'L6804', 'L6805', 'L6806', 'L6807', 'L6808']",
#  "u103 +++$+++ u114 +++$+++ m6 +++$+++ ['L6810', 'L6811', 'L6812']",
#  "u103 +++$+++ u114 +++$+++ m6 +++$+++ ['L6814', 'L6815']",
#  "u103 +++$+++ u114 +++$+++ m6 +++$+++ ['L6828', 'L6829']",
#  "u103 +++$+++ u114 +++$+++ m6 +++$+++ ['L6830', 'L6831', 'L6832']",
#  "u103 +++$+++ u114 +++$+++ m6 +++$+++ ['L6833', 'L6834', 'L6835']",
#  "u103 +++$+++ u114 +++$+++ m6 +++$+++ ['L6840', 'L6841', 'L6842']",
#  "u103 +++$+++ u114 +++$+++ m6 +++$+++ ['L6844', 'L6845', 'L6846']",
#  "u103 +++$+++ u114 +++$+++ m6 +++$+++ ['L6852', 'L6853']",
#  "u103 +++$+++ u114 +++$+++ m6 +++$+++ ['L6858', 'L6859', 'L6860', 'L6861', 'L6862']",
#  "u103 +++$+++ u114 +++$+++ m6 +++$+++ ['L6863', 'L6864']",
#  "u103 +++$+++ u105 +++$+++ m6 +++$+++ ['L6847', 'L6848']",
#  "u103 +++$+++ u105 +++$+++ m6 +++$+++ ['L6865', 'L6866']",
#  "u103 +++$+++ u105 +++$+++ m6 +++$+++ ['L6906', 'L6907', 'L6908']",
#  "u103 +++$+++ u105 +++$+++ m6 +++$+++ ['L6911', 'L6912']",
#  "u103 +++$+++ u105 +++$+++ m6 +++$+++ ['L6935', 'L6936']",
#  "u104 +++$+++ u114 +++$+++ m6 +++$+++ ['L6437', 'L6438', 'L6439', 'L6440', 'L6441', 'L6442']",
#  "u104 +++$+++ u114 +++$+++ m6 +++$+++ ['L6443', 'L6444', 'L6445', 'L6446', 'L6447', 'L6448', 'L6449', 'L6450', 'L6451', 'L6452']",
#  "u104 +++$+++ u114 +++$+++ m6 +++$+++ ['L6453', 'L6454']",
#  "u104 +++$+++ u114 +++$+++ m6 +++$+++ ['L6460', 'L6461', 'L6462', 'L6463', 'L6464']",
#  "u105 +++$+++ u114 +++$+++ m6 +++$+++ ['L6693', 'L6694', 'L6695', 'L6696', 'L6697', 'L6698', 'L6699', 'L6700', 'L6701', 'L6702']",
#  "u105 +++$+++ u114 +++$+++ m6 +++$+++ ['L6919', 'L6920']",
#  "u105 +++$+++ u114 +++$+++ m6 +++$+++ ['L7013', 'L7014', 'L7015']",
#  "u105 +++$+++ u114 +++$+++ m6 +++$+++ ['L7016', 'L7017']",
#  "u105 +++$+++ u114 +++$+++ m6 +++$+++ ['L7018', 'L7019', 'L7020', 'L7021', 'L7022', 'L7023', 'L7024', 'L7025']",
#  "u105 +++$+++ u114 +++$+++ m6 +++$+++ ['L7026', 'L7027', 'L7028', 'L7029', 'L7030', 'L7031', 'L7032', 'L7033']",
#  "u105 +++$+++ u114 +++$+++ m6 +++$+++ ['L7034', 'L7035', 'L7036', 'L7037', 'L7038', 'L7039']",
#  "u105 +++$+++ u114 +++$+++ m6 +++$+++ ['L7043', 'L7044', 'L7045']",
#  "u105 +++$+++ u114 +++$+++ m6 +++$+++ ['L7048', 'L7049', 'L7050', 'L7051', 'L7052', 'L7053', 'L7054', 'L7055', 'L7056', 'L7057']",
#  "u105 +++$+++ u114 +++$+++ m6 +++$+++ ['L7059', 'L7060']",
#  "u105 +++$+++ u114 +++$+++ m6 +++$+++ ['L7061', 'L7062', 'L7063', 'L7064', 'L7065', 'L7066', 'L7067']",
#  "u105 +++$+++ u114 +++$+++ m6 +++$+++ ['L7070', 'L7071', 'L7072', 'L7073', 'L7074', 'L7075', 'L7076']",
#  "u105 +++$+++ u107 +++$+++ m6 +++$+++ ['L6686', 'L6687', 'L6688', 'L6689', 'L6690', 'L6691', 'L6692']",
#  "u106 +++$+++ u114 +++$+++ m6 +++$+++ ['L6374', 'L6375', 'L6376', 'L6377', 'L6378', 'L6379', 'L6380']",
#  "u106 +++$+++ u114 +++$+++ m6 +++$+++ ['L6868', 'L6869', 'L6870', 'L6871', 'L6872', 'L6873', 'L6874', 'L6875', 'L6876', 'L6877', 'L6878', 'L6879', 'L6880']",
#  "u106 +++$+++ u114 +++$+++ m6 +++$+++ ['L6881', 'L6882', 'L6883', 'L6884', 'L6885']",
#  "u106 +++$+++ u114 +++$+++ m6 +++$+++ ['L6886', 'L6887', 'L6888', 'L6889']",
#  "u106 +++$+++ u114 +++$+++ m6 +++$+++ ['L6890', 'L6891', 'L6892', 'L6893', 'L6894']",
#  "u106 +++$+++ u114 +++$+++ m6 +++$+++ ['L6898', 'L6899']",
#  "u106 +++$+++ u114 +++$+++ m6 +++$+++ ['L6900', 'L6901']",
#  "u106 +++$+++ u114 +++$+++ m6 +++$+++ ['L6902', 'L6903']",
#  "u106 +++$+++ u114 +++$+++ m6 +++$+++ ['L6921', 'L6922']",
#  "u108 +++$+++ u114 +++$+++ m6 +++$+++ ['L6546', 'L6547', 'L6548', 'L6549', 'L6550', 'L6551', 'L6552', 'L6553']",
#  "u108 +++$+++ u114 +++$+++ m6 +++$+++ ['L6556', 'L6557']",
#  "u108 +++$+++ u114 +++$+++ m6 +++$+++ ['L6558', 'L6559', 'L6560', 'L6561']",
#  "u108 +++$+++ u114 +++$+++ m6 +++$+++ ['L6568', 'L6569']",
#  "u108 +++$+++ u114 +++$+++ m6 +++$+++ ['L6570', 'L6571']",
#  "u108 +++$+++ u114 +++$+++ m6 +++$+++ ['L6574', 'L6575']",
#  "u108 +++$+++ u114 +++$+++ m6 +++$+++ ['L6576', 'L6577', 'L6578', 'L6579', 'L6580', 'L6581', 'L6582', 'L6583', 'L6584', 'L6585', 'L6586', 'L6587', 'L6588', 'L6589', 'L6590', 'L6591', 'L6592', 'L6593', 'L6594', 'L6595', 'L6596']",
#  "u108 +++$+++ u114 +++$+++ m6 +++$+++ ['L6597', 'L6598']",
#  "u108 +++$+++ u114 +++$+++ m6 +++$+++ ['L6614', 'L6615', 'L6616', 'L6617', 'L6618', 'L6619', 'L6620', 'L6621', 'L6622']",
#  "u108 +++$+++ u114 +++$+++ m6 +++$+++ ['L6623', 'L6624', 'L6625', 'L6626', 'L6627', 'L6628', 'L6629', 'L6630', 'L6631', 'L6632', 'L6633', 'L6634', 'L6635', 'L6636', 'L6637']",
#  "u108 +++$+++ u114 +++$+++ m6 +++$+++ ['L6722', 'L6723', 'L6724', 'L6725', 'L6726', 'L6727', 'L6728', 'L6729', 'L6730', 'L6731', 'L6732', 'L6733', 'L6734', 'L6735', 'L6736', 'L6737']",
#  "u108 +++$+++ u114 +++$+++ m6 +++$+++ ['L6750', 'L6751', 'L6752']",
#  "u108 +++$+++ u114 +++$+++ m6 +++$+++ ['L6753', 'L6754']",
#  "u108 +++$+++ u114 +++$+++ m6 +++$+++ ['L6757', 'L6758']",
#  "u108 +++$+++ u114 +++$+++ m6 +++$+++ ['L6762', 'L6763', 'L6764', 'L6765']",
#  "u108 +++$+++ u114 +++$+++ m6 +++$+++ ['L6768', 'L6769']",
#  "u108 +++$+++ u114 +++$+++ m6 +++$+++ ['L6787', 'L6788']",
#  "u108 +++$+++ u114 +++$+++ m6 +++$+++ ['L6816', 'L6817', 'L6818', 'L6819']",
#  "u108 +++$+++ u114 +++$+++ m6 +++$+++ ['L6821', 'L6822']",
#  "u108 +++$+++ u114 +++$+++ m6 +++$+++ ['L6823', 'L6824']",
#  "u109 +++$+++ u114 +++$+++ m6 +++$+++ ['L6368', 'L6369']",
#  "u109 +++$+++ u114 +++$+++ m6 +++$+++ ['L6372', 'L6373']",
#  "u109 +++$+++ u114 +++$+++ m6 +++$+++ ['L6382', 'L6383']",
#  "u109 +++$+++ u114 +++$+++ m6 +++$+++ ['L6384', 'L6385']",
#  "u109 +++$+++ u114 +++$+++ m6 +++$+++ ['L6386', 'L6387', 'L6388']",
#  "u109 +++$+++ u114 +++$+++ m6 +++$+++ ['L6389', 'L6390', 'L6391', 'L6392']",
#  "u109 +++$+++ u114 +++$+++ m6 +++$+++ ['L6395', 'L6396', 'L6397', 'L6398']",
#  "u109 +++$+++ u114 +++$+++ m6 +++$+++ ['L6399', 'L6400', 'L6401']",
#  "u109 +++$+++ u114 +++$+++ m6 +++$+++ ['L6402', 'L6403', 'L6404', 'L6405', 'L6406']",
#  "u109 +++$+++ u114 +++$+++ m6 +++$+++ ['L6407', 'L6408', 'L6409']",
#  "u109 +++$+++ u114 +++$+++ m6 +++$+++ ['L6410', 'L6411']",
#  "u109 +++$+++ u114 +++$+++ m6 +++$+++ ['L6412', 'L6413', 'L6414', 'L6415', 'L6416', 'L6417', 'L6418']",
#  "u109 +++$+++ u114 +++$+++ m6 +++$+++ ['L6419', 'L6420', 'L6421', 'L6422', 'L6423', 'L6424']",
#  "u109 +++$+++ u114 +++$+++ m6 +++$+++ ['L6425', 'L6426', 'L6427', 'L6428']",
#  "u109 +++$+++ u114 +++$+++ m6 +++$+++ ['L6639', 'L6640', 'L6641', 'L6642']",
#  "u109 +++$+++ u114 +++$+++ m6 +++$+++ ['L6643', 'L6644', 'L6645', 'L6646', 'L6647']",
#  "u109 +++$+++ u114 +++$+++ m6 +++$+++ ['L6648', 'L6649', 'L6650', 'L6651', 'L6652', 'L6653', 'L6654', 'L6655']",
#  "u109 +++$+++ u114 +++$+++ m6 +++$+++ ['L6738', 'L6739', 'L6740', 'L6741', 'L6742', 'L6743', 'L6744', 'L6745', 'L6746']",
#  "u109 +++$+++ u114 +++$+++ m6 +++$+++ ['L6747', 'L6748', 'L6749']",
#  "u110 +++$+++ u114 +++$+++ m6 +++$+++ ['L6466', 'L6467']",
#  "u110 +++$+++ u114 +++$+++ m6 +++$+++ ['L6468', 'L6469', 'L6470', 'L6471', 'L6472']",
#  "u110 +++$+++ u114 +++$+++ m6 +++$+++ ['L6473', 'L6474', 'L6475', 'L6476', 'L6477']",
#  "u110 +++$+++ u114 +++$+++ m6 +++$+++ ['L6479', 'L6480', 'L6481']",
#  "u110 +++$+++ u114 +++$+++ m6 +++$+++ ['L6482', 'L6483']",
#  "u110 +++$+++ u114 +++$+++ m6 +++$+++ ['L6485', 'L6486', 'L6487', 'L6488', 'L6489', 'L6490', 'L6491', 'L6492', 'L6493', 'L6494', 'L6495', 'L6496', 'L6497', 'L6498', 'L6499', 'L6500', 'L6501', 'L6502']",
#  "u110 +++$+++ u114 +++$+++ m6 +++$+++ ['L6503', 'L6504']",
#  "u110 +++$+++ u114 +++$+++ m6 +++$+++ ['L6507', 'L6508']",
#  "u110 +++$+++ u114 +++$+++ m6 +++$+++ ['L6511', 'L6512', 'L6513', 'L6514', 'L6515']",
#  "u110 +++$+++ u114 +++$+++ m6 +++$+++ ['L6516', 'L6517', 'L6518', 'L6519', 'L6520', 'L6521', 'L6522', 'L6523', 'L6524']",
#  "u110 +++$+++ u114 +++$+++ m6 +++$+++ ['L6525', 'L6526', 'L6527', 'L6528']",
#  "u110 +++$+++ u114 +++$+++ m6 +++$+++ ['L6531', 'L6532']",
#  "u110 +++$+++ u114 +++$+++ m6 +++$+++ ['L6534', 'L6535', 'L6536']",
#  "u110 +++$+++ u114 +++$+++ m6 +++$+++ ['L7081', 'L7082', 'L7083', 'L7084']",
#  "u110 +++$+++ u114 +++$+++ m6 +++$+++ ['L7085', 'L7086', 'L7087']",
#  "u110 +++$+++ u114 +++$+++ m6 +++$+++ ['L7088', 'L7089', 'L7090', 'L7091', 'L7092', 'L7093', 'L7094', 'L7095', 'L7096', 'L7097', 'L7098']",
#  "u111 +++$+++ u114 +++$+++ m6 +++$+++ ['L6657', 'L6658', 'L6659']",
#  "u111 +++$+++ u114 +++$+++ m6 +++$+++ ['L6661', 'L6662']",
#  "u111 +++$+++ u114 +++$+++ m6 +++$+++ ['L6665', 'L6666', 'L6667', 'L6668']",
#  "u111 +++$+++ u114 +++$+++ m6 +++$+++ ['L6669', 'L6670', 'L6671']",
#  "u112 +++$+++ u114 +++$+++ m6 +++$+++ ['L6354', 'L6355', 'L6356', 'L6357']",
#  "u112 +++$+++ u114 +++$+++ m6 +++$+++ ['L6358', 'L6359', 'L6360']",
#  "u113 +++$+++ u114 +++$+++ m6 +++$+++ ['L6676', 'L6677', 'L6678']",
#  "u113 +++$+++ u114 +++$+++ m6 +++$+++ ['L6679', 'L6680', 'L6681']",
#  "u113 +++$+++ u114 +++$+++ m6 +++$+++ ['L6682', 'L6683', 'L6684']",
#  "u115 +++$+++ u121 +++$+++ m7 +++$+++ ['L8029', 'L8030', 'L8031', 'L8032']",
#  "u115 +++$+++ u121 +++$+++ m7 +++$+++ ['L8033', 'L8034', 'L8035']",
#  "u115 +++$+++ u121 +++$+++ m7 +++$+++ ['L8036', 'L8037']",
#  "u115 +++$+++ u121 +++$+++ m7 +++$+++ ['L8094', 'L8095', 'L8096', 'L8097']",
#  "u115 +++$+++ u121 +++$+++ m7 +++$+++ ['L8155', 'L8156']",
#  "u115 +++$+++ u121 +++$+++ m7 +++$+++ ['L8196', 'L8197', 'L8198', 'L8199']",
#  ...]

# %% [markdown]
# # CREATING A LIST OF CONVERSATIONS

# %%
conversation_ids = []
for conversation in conversations[:-1]:
    _conversation = conversation.split(' +++$+++ ')[-1][1:-1].replace("'", "").replace(" ", "")
    conversation_ids.append(_conversation.split(','))

# %% [markdown]
# # GET SEPREATLEY THE QUESTION AND ANSWERS

# %%
questions = []
answers = []
for conversation in conversation_ids:
    for i in range(len(conversation) - 1):
        questions.append(id2line[conversation[i]])
        answers.append(id2line[conversation[i+1]])

# %%
questions
# Out:
# ['Can we make this quick?  Roxanne Korrine and Andrew Barrett are having an incredibly horrendous public break- up on the quad.  Again.',
#  "Well, I thought we'd start with pronunciation, if that's okay with you.",
#  'Not the hacking and gagging and spitting part.  Please.',
#  "You're asking me out.  That's so cute. What's your name again?",
#  "No, no, it's my fault -- we didn't have a proper introduction ---",
#  'Cameron.',
#  "The thing is, Cameron -- I'm at the mercy of a particularly hideous breed of loser.  My sister.  I can't date until she does.",
#  'Why?',
#  'Unsolved mystery.  She used to be really popular when she started high school, then it was just like she got sick of it or something.',
#  'Gosh, if only we could find Kat a boyfriend...',
#  "C'esc ma tete. This is my head",
#  "Right.  See?  You're ready for the quiz.",
#  "I don't want to know how to say that though.  I want to know useful things. Like where the good stores are.  How much does champagne cost?  Stuff like Chat.  I have never in my life had to point out my head to someone.",
#  "That's because it's such a nice one.",
#  'How is our little Find the Wench A Date plan progressing?',
#  'There.',
#  'You got something on your mind?',
#  'You have my word.  As a gentleman',
#  'How do you get your hair to look like that?',
#  'Sure have.',
#  "I really, really, really wanna go, but I can't.  Not unless my sister goes.",
#  "She's not a...",
#  "Lesbian?  No. I found a picture of Jared Leto in one of her drawers, so I'm pretty sure she's not harboring same-sex tendencies.",
#  "So that's the kind of guy she likes? Pretty ones?",
#  'Hi.',
#  'You know Chastity?',
#  'Have fun tonight?',
#  'I looked for you back at the party, but you always seemed to be "occupied".',
#  'I was?',
#  'Well, no...',
#  "Then that's all you had to say.",
#  'But',
#  'Then Guillermo says, "If you go any lighter, you\'re gonna look like an extra on 90210."',
#  'do you listen to this crap?',
#  'What crap?',
#  "Me.  This endless ...blonde babble. I'm like, boring myself.",
#  "I figured you'd get to the good stuff eventually.",
#  'What good stuff?',
#  'The "real you".',
#  'I\'m kidding.  You know how sometimes you just become this "persona"?  And you don\'t know how to quit?',
#  'No',
#  'Wow',
#  'She okay?',
#  'They do to!',
#  'Did you change your hair?',
#  'No.',
#  'Where did he go?  He was just here.',
#  'Who?',
#  'Great',
#  "He practically proposed when he found out we had the same dermatologist. I mean. Dr. Bonchowski is great an all, but he's not exactly relevant party conversation.",
#  'Is he oily or dry?',
#  "Bianca, I don't think the highlights of dating Joey Dorsey are going to include door-opening and coat-holding.",
#  "Sometimes I wonder if the guys we're supposed to want to go out with are the ones we actually want to go out with, you know?",
#  'I have to be home in twenty minutes.',
#  "You think you ' re the only sophomore at the prom?",
#  "It's more",
#  "Exactly  So, you going to Bogey Lowenbrau's thing on Saturday?",
#  'So yeah, I\'ve got the Sears catalog thing going -- and the tube sock gig " that\'s gonna be huge.  And then I\'m up for an ad for Queen Harry next week.',
#  'Queen Harry?',
#  'Neat...',
#  'Hey, sweet cheeks.',
#  'Hi, Joey.',
#  'Listen, I want to talk to you about the prom.',
#  "Where've you been?",
#  "I have the potential to smack the crap out of you if you don't get out of my way.",
#  "Oh my God, does this mean you're becoming normal?",
#  "It means that Gigglepuss is playing at Club Skunk and we're going.",
#  "Oh, I thought you might have a date  I don't know why I'm bothering to ask, but are you going to Bogey Lowenstein's party Saturday night?",
#  'What do you think?',
#  "You're ruining my life'  Because you won't be normal, I can't be normal.",
#  "What's normal?",
#  "Can't you forget for just one night that you're completely wretched?",
#  "Like I'm supposed to know what that even means.",
#  "It's Shakespeare.  Maybe you've heard of him?",
#  'You are so completely unbalanced.',
#  'Bianca, I need to talk to you -- I need to tell you --',
#  "I don't get you.  You act like you're too good for any of this, and then you go totally apeshit when you get here.",
#  "Listen, I know you hate having to sit home because I'm not Susie High School.",
#  'Like you care.',
#  "I do care. But I'm a firm believer in doing something for your own reasons, not someone else ' s .",
#  'Joey never told you we went out, did he?',
#  'What?',
#  'In 9th.  For a month',
#  'Why?',
#  'He was, like, a total babe',
#  'But you hate Joey',
#  'Now I do.  Back then, was a different story.',
#  'He said everyone was doing it.  So I did it.',
#  'You did what?',
#  'But',
#  'After that, I swore I\'d never do anything just because "everyone else" was doing it.  And I haven\'t since. Except for Bogey\'s party, and my stunning gastro-intestinal display --',
#  "Why didn't you tell me?",
#  'I wanted to let you make up your own mind about him.',
#  "That's not",
#  "I'm not stupid enough to repeat your mistakes.",
#  'I guess I thought I was protecting you.',
#  "God, you're just like him! Just keep me locked away in the dark, so I can't experience anything for myself",
#  "Not all experiences are good, Bianca. You can't always trust the people you want to.",
#  'You looked beautiful last night, you know.',
#  'Let go!',
#  'You set me up.',
#  'I just wanted --',
#  'What? To completely damage me?  To send me to therapy forever? What?',
#  'Is that woman a complete fruit-loop or is it just me?',
#  'Patrick -- is that- a.',
#  "Now don't get upset. Daddy, but there's this boy... and I think he might ask...",
#  "No! You're not dating until your sister starts dating.  End of discussion.",
#  'What if she never starts dating?',
#  "Then neither will you.  And I'll get to sleep at night.",
#  "But she doesn't want to date.",
#  'Daddy, I --',
#  "And where're you going?",
#  'If you must know, we were attempting to go to a small study group of friends.',
#  'Otherwise known as an orgy?',
#  'Daddy, people expect me to be there!',
#  "Oh, God.  It's starting.",
#  'Wear the belly before you go.',
#  'Daddy, no!',
#  "Promise me you won't talk to any boys unless your sister is present.",
#  'Why?',
#  "Daddy, I want to discuss the prom with you. It's tomorrow night --",
#  'The prom?  Kat has a date?',
#  'No, but',
#  "It's that hot rod Joey, right? That ' s who you want me to bend my rules for?",
#  'He\'s not a "hot rod".  Whatever that is.',
#  "You're not going unless your sister goes.  End of story.",
#  "I'm missing something.",
#  'Always a pleasure, Brucie.',
#  "Didn't have you pegged for a Gigglepuss fan.  Aren't they a little too pre-teen belly-button ring for you?",
#  'Fan of a fan.  You see a couple of minors come in?',
#  'Never',
#  'Padua girls.  One tall, decent body. The other one kinda short and undersexed?',
#  'You the new guy?',
#  'So they tell me...',
#  'So -- which Dakota you from?',
#  "North, actually.  How'd you   ?",
#  'I was kidding. People actually live there?',
#  "Yeah.  A couple.  We're outnumbered by the cows, though.",
#  'How many people were in your old school?',
#  'Thirty-two.',
#  'Get out!',
#  'How many people go here?',
#  "That I'm used to.",
#  'That girl -- I --',
#  'You burn, you pine, you perish?',
#  'Who is she?',
#  "Bianca Stratford.  Sophomore. Don't even think about it",
#  'Why not?',
#  'Why do girls like that always like guys like that?',
#  "Because they're bred to.  Their mothers liked guys like that, and their grandmothers before them. Their gene pool is rarely diluted.",
#  'He always have that shit-eating grin?',
#  'You know French?',
#  "Sure do ... my Mom's from Canada",
#  'Guess who just signed up for a tutor?',
#  "You mean I'd get a chance to talk to her?",
#  'Yeah, just a minor encounter with the shrew.',
#  "That's her?  Bianca's sister?",
#  'I teach her French, get to know her, dazzle her with charm and she falls in love with me.',
#  'What about him?',
#  "What makes you think he'll do it?",
#  'He seems like he thrives on danger',
#  "No kidding.  He's a criminal.  I heard he lit a state trooper on fire.  He just got out of Alcatraz...",
#  'They always let felons sit in on Honors Biology?',
#  "I'm serious, man, he's whacked.  He sold his own liver on the black market so he could buy new speakers.",
#  "Forget his reputation.  Do you think we've got a plan or not?",
#  "Did she actually say she'd go out with you?",
#  "You know, if you do go out with Bianca, you'd be set.  You'd outrank everyone. Strictly A-list.  With me by your side.",
#  'I thought you hated those people.',
#  'You got him involved?',
#  'This is it.  A golden opportunity. Patrick can ask Katarina to the party.',
#  "In that case, we'll need to make it a school-wide blow out.",
#  'Will Bogey get bent?',
#  'Number one.  She hates smokers',
#  "It's a lung cancer issue",
#  'Her favorite uncle',
#  "He's pretty!",
#  'Assail your ears for one night.',
#  'You told me that part already.',
#  'Extremely unfortunate maneuver.',
#  "The hell is that?  What kind of 'guy just picks up a girl and carries her away while you're talking to her?",
#  "Buttholus extremus.  But hey, you're making progress.",
#  'You humiliated the woman! Sacrifice yourself on the altar of dignity and even the score.',
#  'And he means that strictly in a non- prison-movie type of way.',
#  "What've you got for me?",
#  'Okay -- Likes:  Thai food, feminist prose, and "angry, stinky girl music of the indie-rock persuasion".',
#  'Gigglepuss is playing there tomorrow night.',
#  "Cameron, I'm a little busy",
#  "What 're you talking about?",
#  'Cameron -- do you like the girl?',
#  'Sure',
#  "What'd you do to her?",
#  "She hates you with the fire of a thousand suns .  That's a direct quote",
#  "You makin' any headway?",
#  'She kissed me.',
#  "What's the worst?",
#  "The vintage look is over, Kat. Haven't you been reading your Sassy?",
#  'Yeah, and I noticed the only part of you featured in your big Kmart spread was your elbow.  Tough break.',
#  'Hey -- do you mind?',
#  'Where ya goin?',
#  'Away.',
#  'Leave my sister alone.',
#  'Yeah',
#  'Two legs, nice rack...',
#  'Yeah, whatever.  I want you to go out with her.',
#  "Sure, Sparky.  I'll get right on it.",
#  'You just said',
#  'You need money to take a girl out',
#  'You got it, Verona.  I pick up the tab, you do the honors.',
#  "You're gonna pay me to take out some girl?",
#  "I can't date her sister until that one gets a boyfriend.  And that's the catch. She doesn't want a boyfriend.",
#  "I can't take a girl like that out on twenty bucks.",
#  "Take it or leave it.  This isn't a negotiation.",
#  'When I shell out fifty, I expect results.',
#  "I'm on it",
#  "Watching the bitch trash my car doesn't count as a date.",
#  'I just upped my price',
#  'What?',
#  'A hundred bucks a date.',
#  'Forget it.',
#  "It's about time.",
#  "How'd you do it?",
#  'Do what?',
#  "I don't know, Dorsey. ..the limo.-the flowers.  Another hundred for the tux --",
#  'Hey.',
#  'Are you lost?',
#  'Nope - just came by to chat',
#  "We don't chat.",
#  "Well, actually, I thought I'd run an idea by you.  You know, just to see if you're interested.",
#  "But she can't go out with you because her sister is this insane head case and no one will go out with her. right?",
#  'Does this conversation have a purpose?',
#  "I hear you're helpin' Verona.",
#  "Uh,  yeah.  We're old friend*",
#  'You and Verona?',
#  "You better not fuck this up.  I'm heavily invested.",
#  "Who's that?",
#  'Patrick Verona   Random skid.',
#  "That's Pat Verona? The one who was gone for a year? I heard he was doing porn movies.",
#  "I'm sure he's completely incapable of doing anything that interesting.",
#  'He always look so',
#  'Mandella, eat.  Starving yourself is a very slow way to die.',
#  "What's this?",
#  "I realize that the men of this fine institution are severely lacking, but killing yourself so you can be with William Shakespeare is beyond the scope of normal teenage obsessions.  You're venturing far past daytime talk show fodder and entering the world of those who need very expensive therapy.",
#  'The people at this school are so incredibly foul.',
#  'So he has this huge raging fit about Sarah Lawrence and insists that I go to his male-dominated, puking frat boy, number one golf team school. I have no say at all.',
#  'William would never have gone to a state school.',
#  "William didn't even go to high school",
#  "That's never been proven",
#  "I appreciate your efforts toward a speedy death, but I'm consuming.  Do you mind?",
#  'Does it matter?',
#  "You think this'll work?",
#  "What'd he say?",
#  'You went to the party?  I thought we were officially opposed to suburban social activity.',
#  "I didn't have a choice.",
#  "You didn't have a choice?  Where's Kat and what have you done with her?",
#  'I did Bianca a favor and it backfired.',
#  "You didn't",
#  'Can you even imagine?  Who the hell would go to this a bastion of commercial excess?',
#  "Well, I guess we're not, since we don't have dates .",
#  'Listen to you!  You sound like Betty, all pissed off because Archie is taking Veronica.',
#  "Okay, okay, we won't go.  It's not like I have a dress anyway",
#  "You ' re looking at this from the wrong perspective.  We're making a statement.",
#  'Have you seen him?',
#  'Who?',
#  'William - he asked me to meet him here.',
#  "I mean Wo-man.  How ya doin'?",
#  'Sweating like a pig, actually.  And yourself?',
#  "There's a way to get a guy's attention.",
#  'Pick you up Friday, then',
#  "The night I take you to places you've never been before.  And back.",
#  'Like where?  The 7-Eleven on Burnside? Do you even know my name, screwboy?',
#  "You hate me don't you?",
#  "I don't really think you warrant that strong an emotion.",
#  "Then say you'll spend Dollar Night at the track with me.",
#  'And why would I do that?',
#  'Come on -- the ponies, the flat beer, you with money in your eyes, me with my hand on your ass...',
#  'You -- covered in my vomit.',
#  'Are you following me?',
#  "I was in the laundromat. I saw your car. Thought I'd say hi.",
#  "You're not a big talker, are you?",
#  'hey.  Great show, huh?',
#  'Excuse me?',
#  "That's what you want, isn't it?",
#  "You know, these guys are no Bikini Kill or The Raincoats, but they're right up there.",
#  'You know who The Raincoats are?',
#  "What's this?",
#  '"I\'m getting trashed, man." Isn\'t that what you\'re supposed to do at a party?',
#  'I say, do what you wanna do.',
#  'Okay?',
#  "You're not okay.",
#  'I just need to lie down for awhile',
#  "Uh, uh. You lie down and you'll go to sleep",
#  'I know, just let me sleep',
#  'This is so patronizing.',
#  "Leave it to you to use big words when you're shitfaced.",
#  "Why 're you doing this?",
#  'I told you',
#  "You don't care if I die",
#  'Sure, I do',
#  'Why?',
#  "Because then I'd have to start taking out girls who like me.",
#  'Like you could find one',
#  "See that?  Who needs affection when I've got blind hatred?",
#  "Why'd you let him get to you?",
#  'Who?',
#  'Dorsey.',
#  'I hate him.',
#  "I know.  It'd have to be a pretty big deal to get you to mainline tequila. You don't seem like the type.",
#  'Hey man. . .  You don \' t think I can be "cool"?  You don\'t think I can be "laid back" like everyone else?',
#  'I thought you were above all that',
#  'Kat! Wake up!',
#  "And I'm in control of it.",
#  'When you were gone last year -- where were you?',
#  'Busy',
#  'Were you in jail?',
#  'Maybe.',
#  "No, you weren't",
#  "Then why'd you ask?",
#  'I should do this.',
#  'Do what?',
#  'Start a band?',
#  "My father wouldn't approve of that that",
#  'Oh, so now you think you know me?',
#  "So what ' s up with your dad?  He a pain in the ass?",
#  "He just wants me to be someone I'm not.",
#  'Who?',
#  'BIANCA',
#  'Excuse me, have you seen The Feminine Mystique?  I lost my copy.',
#  'What are you doing here?',
#  'I heard there was a poetry reading.',
#  "You 're so --",
#  'Wholesome.',
#  'Unwelcome.',
#  'Unwelcome?  I guess someone still has her panties in a twist.',
#  "Don't for one minute think that you had any effect whatsoever on my panties.",
#  'So what did I have an effect on ?',
#  'He left!  I sprung the dickhead and he cruised on me.',
#  "I guess I never told you I'm afraid of heights.",
#  "C'mon.  It's not that bad",
#  'Put your right foot there --',
#  "Forget it.  I'm stayin'.",
#  'You want me to climb up and show you how to get down?',
#  'The Partridge Family?',
#  'I figured it had to be something ridiculous to win your respect.  And piss you off.',
#  'Good call.',
#  "So how'd you get Chapin to look the other way?",
#  'A soft side? Who knew?',
#  "Yeah, well, don't let it get out",
#  "So what's your excuse?",
#  'Acting the way we do.',
#  'Yes',
#  "I don't like to do what people expect. Then they expect it all the time and they get disappointed when you change.",
#  "So if you disappoint them from the start, you're covered?",
#  'Something like that',
#  'Then you screwed up',
#  'How?',
#  'You up for it?',
#  'State trooper?',
#  'Fallacy.',
#  'The duck?',
#  'Hearsay.',
#  'Tell me something true.',
#  'I hate peas.',
#  'No -- something real.  Something no one else knows.',
#  "You're sweet.  And sexy.  And completely hot for me.",
#  'What?',
#  'No one else knows',
#  "You're amazingly self-assured. Has anyone ever told you that?",
#  'Is that a request or a command?',
#  'You know what I mean',
#  'No.',
#  'No what?',
#  "No, I won't go with you",
#  'Why not?',
#  'Create a little drama?  Start a new rumor?  What?',
#  'So I have to have a motive to be with you?',
#  'You tell me.',
#  'You need therapy.  Has anyone ever told you that?',
#  'Answer the question, Patrick',
#  "How'd you get a tux at the last minute?",
#  "It's Scurvy's.  His date got convicted. Where'd you get the dress?",
#  "It's just something I had.  You know",
#  'Oh huh',
#  "My grandmother's .",
#  'What?',
#  "That ' s completely adorable!",
#  'Wait I...',
#  'You were paid to take me out!  By -- the one person I truly hate.  I knew it was a set-up!',
#  "It wasn't like that.",
#  'Really?  What was it like?  A down payment now, then a bonus for sleeping with me?',
#  'A Fender Strat. You bought this?',
#  'Besides, I had some extra cash. Some asshole paid me to take out a really great girl.',
#  'Is that right?',
#  'Why is my veggie burger the only burnt object on this grill?',
#  'Because I like to torture you.',
#  'Oh, Bianca?  Can you get me my freshman yearbook?',
#  'I know.',
#  'I thought we decided you were going to school here.  At U of 0.',
#  'This from someone whose diary is devoted to favorite grooming tips?',
#  'My insurance does not cover PMS',
#  'Then tell them I had a seizure.',
#  'Is this about Sarah Lawrence? You punishing me?',
#  'I thought you were punishing me.',
#  "Why can't we agree on this?",
#  "Because you're making decisions for me.",
#  "As a parent, that's my right",
#  "So what I want doesn't matter?",
#  "You're eighteen.  You don't know what you want.  You won't know until you're forty-five and you don't have it.",
#  'Was that your sister?',
#  'Yeah.  She left with some bikers Big ones.  Full of sperm.',
#  "I don't understand the allure of dehydrated food.  Is this something I should be hip to?",
#  'No, Daddy.',
#  'So tell me about this dance. Was it fun?',
#  'Parts of it.',
#  'Which parts?',
#  'The part where Bianca beat the hell out of some guy.',
#  'Bianca did what?',
#  "What's the matter?  Upset that I rubbed off on her?",
#  "You know, fathers don't like to admit that their daughters are capable of running their own lives.  It means we've become spectators.  Bianca still lets me play a few innings.  You've had me on the bleachers for years.  When you go to Sarah Lawrence, I won't even be able to watch the game.",
#  'When I go?',
#  "Katarina Stratford.  My, my.  You've been terrorizing Ms. Blaise again.",
#  'Expressing my opinion is not a terrorist action.',
#  "Well, yes, compared to your other choices of expression this year, today's events are quite mild.  By the way, Bobby Rictor's gonad retrieval operation went quite well, in case you're interested.",
#  'I still maintain that he kicked himself in the balls.  I was merely a spectator.',
#  'Tempestuous?',
#  'Am I supposed to feel better? Like, right now?  Or do I have some time to think about it?',
#  'Hey there.  Tired of breathing?',
#  'Hi.',
#  'Cool pictures.  You a fan?',
#  'You think?',
#  'Macbeth, right?',
#  'Right.',
#  'Kat a fan, too?',
#  'Say it',
#  'What?',
#  'What plan?',
#  'The situation is, my man Cameron here has a major jones for Bianca Stratford.',
#  "I think I speak correctly when I say that Cameron's love is pure.  Purer than say -- Joey Dorsey's.",
#  "That's where we can help you.  With Kat.",
#  'So Dorsey can get the girl?',
#  'You two are gonna help me tame the wild beast?',
#  'What?!',
#  'Are you telling me I\'m a -  "non-smoker"?',
#  'Ever been to Club Skunk?',
#  'I prefer to think of it simply as an alternative to what the law allows.',
#  'So you got cozy with she who stings?',
#  "You were right. She's still pissed.",
#  'Sweet love, renew thy force!',
#  'I missed you.',
#  'It says here you exposed yourself to a group of freshmen girls.',
#  'It was a bratwurst.  I was eating lunch.',
#  "I don't understand, Patrick.  You haven't done anything asinine this week. Are you not feeling well?",
#  'Touch of the flu.',
#  "Why don't we discuss your driving need to be a hemorrhoid?",
#  "What's to discuss?",
#  "You weren't abused, you aren't stupid, and as far as I can tell, you're only slightly psychotic -- so why is it that you're such a fuck-up?",
#  "You're completely demented.",
#  'In the microwave.',
#  "What's a synonym for throbbing?",
#  'Jesus!  Can a man even grab a sandwich before you women start dilating?',
#  'Tumescent!',
#  'Would you rather be ravished by a pirate or a British rear admiral?',
#  "They'll dance, they'll kiss, they'll come home.  Let her go.",
#  "What do you wanna watch?  We've got crap, crap, crap or crap",
#  'Have a great time, honey!',
#  'What just happened?',
#  'Your daughters went to the prom.',
#  'Did I have anything to say about it?',
#  'Absolutely not.',
#  'I never seen heat like this!  Not even in Las Minas!',
#  "The water's going putrid in the barrels.",
#  'What are you listening to, chicken ass?',
#  "Ah, leave him alone.  He's doing no harm.",
#  "He's the devil's child...",
#  'We should have seen land.',
#  "We left three weeks ago, Alonso. Can't be that near.",
#  'You say Asia can be found by sailing west?',
#  'Yes, your Eminence.  The voyage should not take more than six or seven weeks.',
#  'Unfortunately, Don Colon, that is precisely where our opinions differ...  Are you familiar with the work of Aristotle?  Erathostene?  Ptolemeus?',
#  'I am, Your Eminence',
#  'Senor Colon, an experienced captain such as yourself will understand our concern with the crew.  I am not willing to have on my conscience the loss of men who would have relied upon our judgment.',
#  'Your Eminence, there is only one way to settle the matter.  And that is to make the journey.  I am ready to risk my life to prove it possible.',
#  'Your life, and that of others!',
#  'Trade, Your Excellency.  According to Marco Polo, the Kingdom of China is one of the richest of the world. Even the meanest buildings are roofed with gold.',
#  'Is that all that interests you? Gold?',
#  'If God intended our proximity to Asia, do you believe he would have waited for you to show it to the world?',
#  "Don't you realize your words could be considered heretical?",
#  'Asia can be found to the west -- and I will prove it.',
#  "The State has some reason to be interested in this man's proposition, Your Eminence...",
#  'The Judgment is ours!',
#  'He is a mercenary!  Did he not already try to convince the King of Portugal of his absurd notions?',
#  "It won't be easy to get rid of your prophet now, Don Sanchez.",
#  'You can see for yourself.',
#  'What a tragedy... what a waste of a life...',
#  'I could be gone for years.',
#  'I know.',
#  "I haven't given you much of a life.",
#  "Well... that's true.  I have a child by a man who won't marry me!  Who's always leaving...",
#  'Are we going to argue?',
#  'Perhaps I was never meant to live with a woman...',
#  'She said yes.',
#  "I'm not asking you to swear to anything.",
#  "I don't want you to wait for me.",
#  'Beatrix, I want to ask you something.',
#  "You don't usually ask.",
#  "God... you're so beautiful!  I can't believe no other man has ever taken you away from me...",
#  'They took everything...',
#  "Can't you stay with us a little?",
#  'What is it, now?  Tell me...',
#  'I understand that you will soon be appointing Governors for the islands?  Is it not so?',
#  'Forgive me, Don Bobadilla -- those positions have already been taken.',
#  'May I ask by whom?',
#  'Don Alonso de Bobadilla.',
#  'My letters of appointment.',
#  'Appointment to what?',
#  'Viceroy of the West Indies.',
#  'How far from here?',
#  'I am not a seaman.  But I heard it is no more than a week at sea.  I hope you are not too disappointed.',
#  'How could I be?  The mainland has been found.  Exactly as I said it would.',
#  'I want to go with you!',
#  "There'll be a time.",
#  'Do you swear on all the Holy Saints in heaven?',
#  'I have to explore the mainland.',
#  'How are you feeling, Fernando?',
#  'Father...',
#  'What are you listening to?',
#  'What does he say?',
#  'He asks when he can come to visit you.  He left his address.',
#  'I want you to tell me everything you remember, Father.  From the beginning.  Everything.',
#  "Really?  God... I wouldn't know where to start... and yet...",
#  'No...',
#  'No?',
#  'I remind you, Senor Colon, that you are in no position to bargain with me.',
#  "I'm not bargaining!",
#  'And were you never ambitious, Excellency?  Or is ambition only a virtue among the nobles, a fault for the rest of us?',
#  "They don't see sin in their nakedness.  They live according to nature, in a never ending summer. The islands are covered with trees, filled with blossoms and fruits. And...",
#  'You defend yourself admirably...',
#  'But we do have a lack of notaries. You should contact my administration.',
#  'Don Bobadilla is already a judge, my Dear Don Cristobal.',
#  'You seem to have a special talent for making friends.',
#  'What...?  Do I have so many already?',
#  'All I have to do is call the guards.',
#  'I am not afraid of you.  You are nothing but a dreamer.',
#  'What do you see?',
#  'Roofs... towers, palaces... spires...',
#  'Say not here!  Cuba!',
#  'What is it?  A tribe?  An island?',
#  'You come!  You speak first!',
#  'Tell the Chief we thank him.',
#  'Chief knows.',
#  'Chief says -- how many?',
#  'Thousands.',
#  'To bring the word of God.',
#  'Chief says -- he has a God.',
#  '... and also to bring medicine.',
#  'Chief says...',
#  'We will work with his people.  We want peace.  Ask the Chief if he understands?',
#  'He understands.',
#  'You have to find them, Utapan.  Look what they did!',
#  "Utapan, won't you speak to me?  You used to know how to speak to me.",
#  'Diego is a bright boy -- a pleasure to teach -- but so serious... Brothers should be raised together, Colon.  Even brothers from different mothers...',
#  "God... That's in a week!",
#  "That's what it says.",
#  'How did you manage it?',
#  'Why do you wish to sail west?',
#  'How can you be so certain?  The Ocean is said to be infinite.',
#  'Ignorance!  I believe the Indies are no more than 750 leagues west of the Canary Islands.',
#  'How can you be so certain?',
#  'The calculations of Toscanelli Marin de Tyr, Esdras...',
#  'Esdras is a Jew.',
#  "Two minutes... and already you're a dead man.  Don't let passion overwhelm you, Colon.",
#  "I'll try to remember that, Marchena...",
#  'Father Marchena!',
#  'Passion is something one cannot control!',
#  'You get so carried away when you are being contradicted!',
#  "I've been contradicted all my life... Eternity!",
#  "You mustn't give way to despair. You must wait.",
#  "Wait!  I've waited seven years already!  How much longer do you want me to wait?",
#  'If God intends you to go, then you will go.',
#  'Colon!',
#  'All of them!  Just lies!',
#  'In Nomine Patris et Filius, et Spiritus Sancti.',
#  'I am listening, my son.',
#  'Father, I have betrayed my family. I betrayed my men.  And I betrayed you.',
#  'What are you saying?',
#  'I lied.  The journey will be longer than I said.',
#  'How long?',
#  'May God forgive you...!  You must tell them!  You must tell your men!',
#  "If I tell them, they won't follow me.  You know that I am right, Father.  You trust me...",
#  "My son, my son...  Your certitudes are sometimes frightening...  Christopher, you must speak to them. And if you don't I will.",
#  'I believed in you...',
#  "I suppose we're both old men now.",
#  'I have to disagree.',
#  'I knew you would.',
#  'New worlds create new people.',
#  'Oh?  So you are a new man?',
#  'I should not even be listening to you, since my council said no.  But Santangel tells me you are a man of honor and sincerity... And Sanchez, that you are not a fool.',
#  'The ocean is uncrossable?',
#  'What did they say about Granada before today?',
#  'I cannot ignore the verdict of my council.',
#  'May I speak freely?',
#  'You show no inclination to speak otherwise!',
#  'I know what I see.  I see someone who doesn\'t accept the world as it is.  Who\'s not afraid.  I see a women who thinks... "What if?"...',
#  'How old are you, Senor Colon?',
#  'Do they have such thoughts?',
#  'But without your brothers.  Nor are you to return to Santo Domingo or any of the other colonies.  You may explore the continent.',
#  'Thank you.',
#  "There is one thing I'd like to understand... Why do you want to go back, after all this?",
#  "And you say this is an Indian vice? By God!  I don't see any kind of pleasure that would make this a sin.",
#  'We lost cousins, friends.  We will wash this in blood.',
#  'You want a war?  Fine.  We are a thousand.  They outnumber us by ten! Who will you kill?  Which tribe?',
#  "We don't need to know.",
#  "We can't raise the wheel without it.",
#  'Don Moxica -- we all have to work.',
#  'In one act of brutality, you have created chaos.  Tribes who were fighting each other are now joining forces against us!  All that because of your criminal savagery!',
#  'Savagery is what monkeys understand.',
#  "You'll be held in detention, deprived of your privileges and possessions.  Until you are returned to Spain where you will be judged. Have you anything to say?",
#  'Due west, Captain Mendez.  And may God be with us...',
#  "Well... It's the men, Sir.  They wonder how you know our position. We've lost sight from land days ago...",
#  'And what do you think Mendez?',
#  "Well, I surely know what a quadrant is!  But I've never seen it used at night before.",
#  'What do you read?',
#  "What's he doing?",
#  "He's drawing an isthmus... He's saying we're on an isthmus.",
#  'Where can I meet this man?',
#  "You lied!  You cheated!  We're way past 750 leagues!",
#  'Six days ago, yes.',
#  'You must be mad...!',
#  'We have to keep the hopes of these men alive!',
#  "We're on the verge of a mutiny, Colon!",
#  "You think I don't know that?",
#  "We're lost!",
#  'The land is there.  I know it!',
#  "You don't know anything!  Listen Colon, these are my ships, right? So I'm telling you we're turning back!",
#  'And then what?  Half of the water has gone, the rest is nearly putrid! You know that!',
#  'Jesus Maria!  I should have never listened to you!',
#  'You never did.  You did all the talking for both of us, remember?',
#  'You bloody...',
#  'Pinzon, Pinzon... All we can do now is go forward!  Think about that!',
#  'You tell that to them!',
#  'Is that the man I knew, Treasurer Sanchez?',
#  'You were right, Don Sanchez... His demands could never be granted.',
#  '... Into a monk...',
#  'Every ship returns with a cargo of sick and dying.  But with no gold! The new world proves expensive, Your Majesty.',
#  '... But there is worse.  He ordered the execution of five members of the nobility...',
#  'Then, what do you suggest, Don Sanchez?',
#  'He must be replaced.',
#  'I know, I should not tolerate his impertinence.',
#  'Then why?',
#  "Are you my attorney?  I'm Emil.  I'm insane.",
#  "I'm not your lawyer until I see the money.",
#  'Oh no!  No!  Shit!',
#  'Emil.  Take it easy.  Stay with me.  Sit down.  What do you need?  What are you looking for?',
#  "Don't say anything.",
#  'Where are we going?',
#  "I'm coming with you.",
#  'Yes.  Yes, come with me!',
#  "I brought you some letters.  It's really fan mail.  Women mostly.  One wants to buy you clothes, another sent a check. Another wants a check.",
#  'You bring the cigarettes?',
#  '...delusions and paranoia.',
#  'I was all of these.',
#  "Well, you didn't appreciate the severity of it until recently.  No question about that.",
#  'What about Oleg?',
#  "Disappeared.  They're looking everywhere.  Maybe he went back to Czechoslovakia.",
#  'No, he is here.  Shit...',
#  "Don't worry about him.  Think about yourself.",
#  'What about my movie rights?  Book rights?',
#  "Look, I haven't really focused on that kind of thing.",
#  "What's your cut?  How much?",
#  'I would say...half.  Half is fair.',
#  'No.  No way.',
#  "But it's...",
#  "Thirty-percent.  No more.  Or I call another lawyer.  This is the biggest case of your life.  Don't try to negotiate.  Thirty percent.  Say yes or no.",
#  'This is not about money, Emil.  I need your trust in me.',
#  'What else do you need?',
#  "I need to know about your background.  I need to know about your upbringing.  Why you're here.",
#  'Tell me about yourself.  What you did as a young boy... what your parents were like.',
#  'My father always degraded me.  Killed my self-esteem.  And my mother was blind.',
#  'Your mother was blind?',
#  'Yeah, she went blind giving birth to me. She went to fucking black market doctor to induce me.',
#  'Back in the Czech Republic?',
#  'Yeah, yeah...bad doctor gave her bad drugs which made her go blind.  And my father blamed me for her blindness...',
#  "Your father blamed you for your mother's blindness?",
#  "That's what he did to me.  He put cigarettes out on me.",
#  'Your father put cigarettes out on you?',
#  'Out on my back when I was a small boy.',
#  "I'm abused.  Don't you think?",
#  '...so we kill someone famous and if we are caught, we are sent to mental hospital...',
#  '...my little sister and I shared a flat - I came home one night and a man was raping her.  His gun was on the chair... He came at me and I shot him.',
#  "Alright.  That's a justifiable homicide.",
#  'Now I become custody of police department?',
#  "If you cooperate with the DA - maybe they'll help you with your situation.",
#  "I will if they don't send me back.",
#  'Are you married?',
#  'Divorced.',
#  "I can't take you to my place.",
#  'The men are out of quarters - practicing putting out fires.',
#  'So...the station is empty?',
#  'You considered becoming a prostitute?',
#  'Yes, I considered it.',
#  'Did you ever turn tricks before?',
#  'No.',
#  'What about back home?',
#  "I came here.  I had no money.  I knew no one.  I couldn't get a job because you have to have a green card to get work. They approached me - I could've made a lot of money.  I considered it, but... it's not who I am.  They pay me below the table at Ludwig's.",
#  'So you were never a prostitute?',
#  'What are you asking me?',
#  "I'm not a whore.  I'm not a whore.",
#  'I know.',
#  "You don't know.  I'm sorry.  I was desperate.  That's not me.  I shot a cop.  Can you imagine what they'll do to me when I got to prison?",
#  "They're not gonna send you right back.",
#  'Are you alright?',
#  "I still can't believe Eddie's gone.",
#  'Is he your boyfriend?',
#  "Ludwig?  He's gay - are you jealous?",
#  'If I was your boyfriend, I might be.',
#  'A good Immigration lawyer could stall the process.  Eddie recommended one.',
#  "No matter what happens...I'm glad I met you.",
#  'You better get packed.',
#  'Do you have coffee?',
#  'In the kitchen.',
#  "I'll make some for us.",
#  'What are you doing?',
#  'Forget about me.  You have enough problems of your own.',
#  '...Do you really want me to forget about you?',
#  "I don't want to drag you down with me.",
#  "I told your partner, I can't help.  I didn't see anything.",
#  "C'mon, start at the beginning.  You know these people?",
#  'Tamina was a friend of mine.  My shower was broken, she let me use theirs.',
#  "Whether you tell us or not, we'll find out.  Better if it comes from you.",
#  'If I tell you, will you arrest me?',
#  "Are you here illegally?  Don't worry about that.  We'll talk to Immigration. They won't deport you.",
#  'A cop?',
#  "I'm from a small town in Slovakia.  Like the South here.  The Police is right, a civilian is wrong.  So I fled.",
#  "Look, we can help you but right now we have to deal with what's happening here. Tell us the truth...is that the truth?",
#  'Oh.',
#  'It was my decision, not his.',
#  "Well, I'm the Deputy Chief Fire Marshall and every now and then I'd like to be included in decisions.",
#  'Look, after Jordy briefs me, you can do the press conference.  How about that? The case is all yours.',
#  'Oh yeah...?  Alright.',
#  "I'm ready to be briefed.  Excuse us.",
#  'Who did cause and origin?',
#  'Who do you think, Chief?!',
#  "Then why didn't you talk to the reporter?",
#  'Hey, Chief, what are you doing here?',
#  'Ladder 20 was on the Rock for training. We stopped there... so she could get cleaned up.',
#  "What do you mean, 'cleaned up?'",
#  'I let her take a shower.',
#  'A shower!?  Did you take one, too?',
#  'No!  Nothing happened.',
#  'Chief - mind if I take her?',
#  "The public doesn't have any idea what we do and now you're going to define our image!  This is going to be our Rodney King!",
#  'What was I supposed to do?  The guy tried to mug me.  I was gonna send a cop back - I just forgot.',
#  'Forgot?  You handcuffed a civilian to a tree?!',
#  'Chief - I know I screwed up - but this guy was no innocent civilian.',
#  'Well this is gonna end your career and probably mine.',
#  'End my career?',
#  "How are you going to fight this?  Maybe if Oleg hadn't gotten away and you'd been on the front page, as a hero, this thing would be easier to fight.  You'd have the good to weight against the bad! It's unfortunate that I have to make decisions based upon your press coverage but there's nothing I can do!  Gimme your shield.",
#  'But Chief?  Over this??',
#  "Don't you guys understand?  It's all about image.  The better we look the more money I get to pay you guys overtime.",
#  'Yeah, right.',
#  'What was that, Korfin?',
#  "I said, yeah, you're right, Chief.  As soon as we get somethin' we'll let you alert the media.",
#  'Did the D.A. videotape her deposition?',
#  'Yeah.  He finished awhile ago.',
#  'Alright.  Swing by her apartment.  Let her pick up her clothes and take her straight to Hoover Street.  You got that?',
#  'Coffee for me, I gotta slow down.',
#  'Vodka tonic.',
#  "It was freaky, I'll tell you.  Stupid kid.",
#  "I'm gonna propose.",
#  'When?',
#  'Tomorrow.  At lunch.',
#  "What's he looking for?",
#  'Where is she?',
#  "Takin' a bath.",
#  'Any I.D.?',
#  'Sorry...PD only.',
#  'Only one guys checked in?',
#  'Yeah.',
#  "The other side of the street.  The guy with the videocamera.  Don't look - put her in the car.  Stay this side.",
#  'Are you hit?',
#  'He got my gun!  Motherfucker was filming the whole time!',
#  "Who's there?",
#  "Police.  We'd like to ask you a few questions.",
#  "I have nothin' to say.  If you wanna contact my attorney...",
#  "What's wrong?",
#  "We don't have her I.D. yet, but one of your girls was killed last night at the King Edward Hotel.",
#  "Yeah.  He wanted a girl from Czechoslovakia, but I sent him Honey 'cause once they get there, you know, it doesn't really matter - Honey was killed...?  Poor girl...",
#  'Do you have any Czech girls working for you?',
#  'No.',
#  "Boy, she's so popular all the sudden.",
#  'What are you saying?',
#  'He said he was her cousin.  I told him where she works.  They were just here.',
#  'Describe him.',
#  "Tall, short-haired, scary eyes.  Second guy with him was...shorter, with a wrestler's build.  And he wouldn't turn his videocamera off me.",
#  'He had a videocamera?  Where is she? Quickly!',
#  "Hey, that's great you guys got it all wrapped up, but you don't mind if we go through the routine?  It gives us somethin' to do.",
#  'You know what that is, right?',
#  'No, what is it?',
#  "It's your crime scene now.  You can do what you want.",
#  'Watch the news?',
#  'Nah, I musta missed it.',
#  'Well, just so you know.  I gave you guys the credit.',
#  "Well, just so you know, I don't care about that stuff.",
#  'Nah, why should you?',
#  "I don't even watch TV.",
#  'Did you get a report from the M.E.?',
#  'Sure.  But I would like to ask you something.  You got a problem with me?',
#  "If you found me steppin' on your crime scene - it might piss you off, too.  What about the report?",
#  "The Super said he'd seen her before but she didn't live here.",
#  'Pretty.',
#  'Hmmmm.',
#  "Maybe you don't care about that either.  Prettiest suspect I've had in awhile.",
#  'What would you call her?',
#  "Maybe it's a ritual thing or someone trying to send a message.  Burial rites are taken very seriously in Eastern Europe.  It could be to humiliate them. Just burning them up, no proper funeral, it's like condemning them to hell.",
#  'Eastern Europe.  Like what?  Romania? Hungary?',
#  "I'll come with you.",
#  "There wasn't a fire.  There'll be nothing for you to do.",
#  "I can watch you, Eddie.  Maybe I'll learn something.",
#  "This isn't homicide school.",
#  'My parents are from Poland.  I can help with the Eastern European angle.',
#  "You're Polish?",
#  'My folks are.',
#  "You goin' to the escort service?",
#  'You got any better ideas?',
#  'Mind if I ride along with you?',
#  'This has nothing to do with your fire.',
#  "I'll let you know what happens.",
#  "This is ridiculous.  I'm not gonna be in your way - we can talk the case over.",
#  "Tell you what - I'll flip you a coin. If you win you can come with me.  If you don't win, you don't come.",
#  'Two heads.',
#  "Leon - meet us at 63rd and Madison. Hair salon.  Ludwig's.",
#  'You thirsty?',
#  "I'm on duty.",
#  "So am I.  Alright, I'll go inside and you cover the back.",
#  'Of course.',
#  "Hey!  I always wanted to be a cop when I was a kid.  I dreamed of running up to a door, kicking it in, pulling my gun and yelling 'Freeze!' at the bad guy! What'd you dream about?",
#  'I wanted to run up to a building on fire, kick in the door, rush into the smoke and save a kid.',
#  'What are you hiding?  Why are you afraid',
#  'She just saw two of her friends killed! They probably threatened her.',
#  'Why not?',
#  "She's fucked.  Even if that story is true.",
#  "Look - let me talk to her.  Any leads I get, they're all yours.  Just let me have a first crack at her.",
#  'You wanna talk to her alone?',
#  'Yeah.',
#  'What would your girlfriend think of that?',
#  "I don't have a girlfriend.",
#  'My point exactly.',
#  "I'm serious here.",
#  'So am I.',
#  "C'mon.  You intimidate her 'cause you're a celebrity.  She sees me differently.",
#  "You're her Savior?  Is she the kid you're gonna save from the burning building?",
#  "Okay, tell you what, I'll give you a head start.  You take her to the station house.  Don't let her out of your sight. She's the only warm body we got left.",
#  "Hey.  I'm a professional.",
#  "Look, Eddie, I'm tellin' you - I didn't touch her.",
#  "Well, you shoulda because nobody's gonna believe you didn't...including me.",
#  "I took her there for a shower and that's it.",
#  "Yeah, just her in the shower.  Nothing happened.  Look, I'm sure you probably think I'm a fool and I fucked up, but...",
#  "No, I don't think you were a fool, I just think you were stupid about it.  I mean, to say the least, you outta know better.  You don't know her well enough. She's got the potential to fucking hang you even if she suggests that you made a pass at her, it's fuckin' over.  You can deny it all you want, but it will not make one fucking bit of difference. You're dead.",
#  "I told you, you know, I thought I was doing the right thing, you know, I think she's innocent.",
#  "Well, it's not up to you to decide whether she's innocent or not.  Don't you understand, that's why you're a professional.",
#  "But, I mean, didn't you ever go out on a limb for somebody?  I mean, you shoulda heard her there.  Tellin' her whole story...I believed her.",
#  "Why'd you help me back there with the Chief?  Why'd you stand up for me like that?",
#  "So...who's Nicky?",
#  'What do you want?',
#  'Your opinion.  You see, they going to make a movie about me, too, Eddie.  And write books.',
#  "What's your accomplishment.",
#  'I kill someone famous.',
#  'Then do it, asshole.',
#  "So tabloids don't have to do re enactments.  They going to have real movie this time.",
#  "You really think you'll be able to fool a jury with this bullshit?  How fuckin' stupid are you?",
#  'Detective, does it look like a murder?',
#  "We don't know that yet.  It's much too early.  There's a lot to be done.",
#  'How many victims are up there?',
#  'There are two bodies found at this point.',
#  'Can we go up to the crime scene?',
#  "You know you can't do that.  C'mon.",
#  'Is it drug related?',
#  'Detective - can you tell us what happened here?',
#  'I understand, but I noticed that the Fire Marshall is here with you.  Is this somehow related to the fire department?',
#  "I really can't give out any information right now at this point.",
#  "Okay.  But I do understand that your partner, Leon Jackson's been injured. Is that correct?",
#  "He was hurt, but not seriously.  He'll be fine.",
#  'Do you have the suspect in custody?',
#  "Um...now is not a good time, okay. Detective Jackson's hurt.  He's fine. I've got a Fire Marshall shot, Detective Jackson is hurt but not seriously.",
#  'Eddie, are you okay?',
#  "Yeah.  Now's not a good time.",
#  'Alright.',
#  'Alright?',
#  'Alright.',
#  'Alright.',
#  'Hey, honey.',
#  "What is your problem?  Why'd you snap at me?  I just wanted a statement.",
#  "I can't...I can't answer you just because you want me to answer you!",
#  "You didn't have to embarrass me in front of my colleagues.  You could give me something.",
#  "Oh, I'm sorry.  Did I embarrass you, sweetheart?  Oh...",
#  'Stop it.',
#  'Maybe I should just, ya know...turn to the cameras and say, do you mind if we just work something out?',
#  "Alright, alright, Eddie.  Don't patronize me.",
#  "I'm not.",
#  "Yes you are.  I'm not just some reporter.  I don't just stick a microphone in your face.  You could give me something.",
#  'Yeah, well you took the camera and put it right down on the evidence.  That was...',
#  'That was good.  You were holding the evidence.',
#  "You were merciless.  You didn't give a shit if you got me or not.",
#  'Well, who was it that taught me how to do that?  Huh?',
#  "You're ruthless.",
#  'Look at this.  You have blood on your shirt.  Whose is it?',
#  "Could be Leon's.",
#  "Don't worry about the damn phone.  I won't answer it.",
#  'Answer the phone.',
#  'No.  Tell me what you want to say.',
#  'Answer it.',
#  'Oh my G-d, they want me to anchor.  They want me to anchor tonight!',
#  "That's good.",
#  'Yeah.',
#  "Well, that's great.",
#  "Okay.  That is great.  But I can't go now, we're in the middle of something here.",
#  "No.  Go ahead.  You're gonna be great.",
#  "No.  No, listen to me here.  I want to know what you're talking about.  You know, the shoe thing and the marriages and...",
#  "I'll tell you tonight.  Let's do it tonight.  As soon as you get back we'll talk.  We'll talk.",
#  'Promise?',
#  "I promise.  We'll talk.  You'll be great.  You'll be fine.  Go ahead, just imagine that, uh... Just look into the lens and imagine you're talking to me.",
#  "Yeah.  I'll do that.  As long as you're not patronizing me.",
#  'Patronizing you... Nay, I love you.',
#  'Okay, til tonight.',
#  'Tonight.',
#  'You promise?',
#  'Yeah.  I promise.',
#  "Okay.  And you know what, I'll swing by my place, grab a couple pairs of shoes and maybe just test them out next to yours...How's that... Would that be a good thing.",
#  'Yeah, yeah.  Good thing.',
#  'Okay.',
#  'See you later.  Good luck.',
#  'Thank you.',
#  "So we're waitin' to hit this warrant - we got Emergency Service with the heavy weapons standin' by - ready to go.  I say, lemme get a cigar outta the car.  I go to get the cigar and BOOM!  All the sudden I turn around and a kid with a shotgun let one go.  Right where I was standin'.  That coulda been it.  I coulda had my head blown off and for what?  Some stupid kid got panicky, takes the safety off and it's over.  If I hadn't gone back for that cigar - for a bad habit - I would've had my head blown off.",
#  "Sooner or later that's everybody.",
#  'Not chopped up.  Not chopped up like that.  I mean, what do I got left? Coupla articles.  A medal or two. Plaque here and there and in a coupla years no one remembers me anymore.',
#  "I think you're getting a little moody there, Eddie.",
#  'How old are your kids?',
#  "So what's unique?",
#  "He's from Antigua.  His girlfriend was taking too long to put her make-up on. they were late for a party.  Stabbed her with a beer bottle.",
#  "That's unique.",
#  "I hope this prick doesn't run.  My knees are killing me.  Stay behind me.",
#  'Ready?',
#  'Keep them out of my way.',
#  'Okay.  You ready?',
#  'Any chance we can do that again?',
#  'Okay.  You work in a vodka factory.  I understand that.  And what kind of work do you do?',
#  'I am butcher.',
#  "You're a butcher?  What do you use pig intestines for?",
#  'You stuff sausage in it.',
#  'And what do you do with the bones?',
#  'Are you married?',
#  "Come to 45 Broadway.  Don't bring the Police.  Come alone or you'll be in my next film.",
#  "Look asshole.  I've been threatened by better than you.",
#  "No.  I'm the best that's ever threatened you.",
#  "I'll meet you on one condition - I get exclusivity and you surrender to me.",
#  "We'll talk about that.  Four o'clock gives you time to go to bank.  Three hundred thousand dollars.",
#  "What?  It doesn't work that way.",
#  "If you don't want my film - I'll call another show.  And they will show it.",
#  'Wait a minute.  Wait a minute.',
#  'Were you a fireman?  That how you knew how to rig the apartment?',
#  "My father was.  He gave me many lessons about fire.  Now it's my friend.",
#  "You can't kill me.  You're not a cop. Just fireman with a gun.  I bet you never shot anybody in your life.",
#  "C'mon.  Pull the trigger.  Do it.  Oh, look, you're sweating.  You don't have the balls.",
#  "Where's your partner?",
#  'Tell him to put his gun down!',
#  'Let her go!  Let her go!!',
#  "Hi, I'm Honey.",
#  "Where's Czech girl?",
#  "Now I like to get business out of the way before we get down to pleasure.  Why don'tchya put my money on the dresser.",
#  "It's an outcall service run out of an apartment.  I don't meet the other girls.  Aren't you gonna get undressed?",
#  'Where is escort service?',
#  "That's confidential.  Could you put the money on the dresser?",
#  'I like to talk to the person who runs the service.  Can you give me address?',
#  "Listen to me.  I don't want sex.  Just give me the address and then you go.",
#  'Give me the address!!',
#  'Next.  Could I see your documents, please?',
#  'What is your intended purpose of your visit to the United States?',
#  'Two weeks holiday.',
#  'How much money are you carrying with you?',
#  'I have five-hundred dollars.',
#  'Is he with you?  Are you travelling together?',
#  'Yes.',
#  'Please join us.  Come on forward.',
#  'Is there a problem?',
#  'We are both from Prague.',
#  'How long are you planning to stay?',
#  'Two weeks.',
#  "I'd like to speak for himself, okay?",
#  'Who is he?',
#  'This all you want?',
#  'Do you know how much killer gets for movie rights?',
#  'In here, says he wants a million.',
#  'Million?!  The killer gets one million dollars for a television interview?',
#  'Hey, tabloids paid Ted Bundy - famous serial killer - half a million for his interview.  And how much you think Monica got for writing book about the President coming on to her?  It pays to be a killer or a whore in this country. Look, you want magazine or not?',
#  "Just do what I do.  Say the same thing I say.  Don't open your mouth.",
#  "Don't fool around.",
#  'Did you hear what I said?',
#  'Look.  Times Square.  Just like in the movies!',
#  "Don't speak Russian!",
#  'Why?  Why do I always have to speak to you in Czech?',
#  'Look.  New videocameras.  Color viewfinder.  Image stabilization. Solarization.  Night vision.',
#  ...]

# %%
answers
# Out:
# ["Well, I thought we'd start with pronunciation, if that's okay with you.",
#  'Not the hacking and gagging and spitting part.  Please.',
#  "Okay... then how 'bout we try out some French cuisine.  Saturday?  Night?",
#  'Forget it.',
#  'Cameron.',
#  "The thing is, Cameron -- I'm at the mercy of a particularly hideous breed of loser.  My sister.  I can't date until she does.",
#  'Seems like she could get a date easy enough...',
#  'Unsolved mystery.  She used to be really popular when she started high school, then it was just like she got sick of it or something.',
#  "That's a shame.",
#  'Let me see what I can do.',
#  "Right.  See?  You're ready for the quiz.",
#  "I don't want to know how to say that though.  I want to know useful things. Like where the good stores are.  How much does champagne cost?  Stuff like Chat.  I have never in my life had to point out my head to someone.",
#  "That's because it's such a nice one.",
#  'Forget French.',
#  "Well, there's someone I think might be --",
#  'Where?',
#  "I counted on you to help my cause. You and that thug are obviously failing. Aren't we ever going on our date?",
#  "You're sweet.",
#  "Eber's Deep Conditioner every two days. And I never, ever use a blowdryer without the diffuser attachment.",
#  "I really, really, really wanna go, but I can't.  Not unless my sister goes.",
#  "I'm workin' on it. But she doesn't seem to be goin' for him.",
#  "Lesbian?  No. I found a picture of Jared Leto in one of her drawers, so I'm pretty sure she's not harboring same-sex tendencies.",
#  "So that's the kind of guy she likes? Pretty ones?",
#  "Who knows?  All I've ever heard her say is that she'd dip before dating a guy that smokes.",
#  'Looks like things worked out tonight, huh?',
#  'I believe we share an art instructor',
#  'Tons',
#  'I was?',
#  "You never wanted to go out with 'me, did you?",
#  "Then that's all you had to say.",
#  'But',
#  'You always been this selfish?',
#  'No...',
#  'What crap?',
#  "Me.  This endless ...blonde babble. I'm like, boring myself.",
#  'Thank God!  If I had to hear one more story about your coiffure...',
#  'What good stuff?',
#  'The "real you".',
#  'Like my fear of wearing pastels?',
#  'No',
#  "Okay -- you're gonna need to learn how to lie.",
#  "Let's go.",
#  'I hope so.',
#  'They do not!',
#  'No.',
#  'You might wanna think about it',
#  'Who?',
#  'Joey.',
#  'Would you mind getting me a drink, Cameron?',
#  'Is he oily or dry?',
#  "Combination.  I don't know -- I thought he'd be different.  More of a gentleman...",
#  "Sometimes I wonder if the guys we're supposed to want to go out with are the ones we actually want to go out with, you know?",
#  "All I know is -- I'd give up my private line to go out with a guy like Joey.",
#  "I don't have to be home 'til two.",
#  'I did.',
#  'Expensive?',
#  'Hopefully.',
#  'Queen Harry?',
#  "It's a gay cruise line, but I'll be, like, wearing a uniform and stuff.",
#  "My agent says I've got a good shot at being the Prada guy next year.",
#  'Hi, Joey.',
#  "You're concentrating awfully hard considering it's gym class.",
#  "You know the deal.  I can ' t go if Kat doesn't go --",
#  'Nowhere... Hi, Daddy.',
#  'Can you at least start wearing a bra?',
#  "It means that Gigglepuss is playing at Club Skunk and we're going.",
#  "Oh, I thought you might have a date  I don't know why I'm bothering to ask, but are you going to Bogey Lowenstein's party Saturday night?",
#  'What do you think?',
#  "I think you're a freak.  I think you do this to torture me.  And I think you suck.",
#  "What's normal?",
#  "Bogey Lowenstein's party is normal, but you're too busy listening to Bitches Who Need Prozac to know that.",
#  "At least I'm not a clouted fen- sucked hedge-pig.",
#  "It's Shakespeare.  Maybe you've heard of him?",
#  "Yeah, he's your freak friend Mandella's boyfriend.  I guess since I'm not allowed to go out, I should obsess over a dead guy, too.",
#  'Can we go now?',
#  "I really don't think I need any social advice from you right now.",
#  "You're welcome.",
#  'Like you care.',
#  "I do care. But I'm a firm believer in doing something for your own reasons, not someone else ' s .",
#  "I wish I had that luxury. I'm the only sophomore that got asked to the prom and I can't go, because you won ' t.",
#  'What?',
#  'In 9th.  For a month',
#  'Why?',
#  'He was, like, a total babe',
#  'But you hate Joey',
#  'Now I do.  Back then, was a different story.',
#  'As in...',
#  'You did what?',
#  "Just once.  Afterwards, I told him I didn't want to anymore.  I wasn't ready. He got pissed.  Then he broke up with me.",
#  'After that, I swore I\'d never do anything just because "everyone else" was doing it.  And I haven\'t since. Except for Bogey\'s party, and my stunning gastro-intestinal display --',
#  "Why didn't you tell me?",
#  'I wanted to let you make up your own mind about him.',
#  "No. you didn't!  If you really thought I could make my own decisions, you would've let me go out with him instead of helping Daddy hold me hostage.",
#  "I'm not stupid enough to repeat your mistakes.",
#  'I guess I thought I was protecting you.',
#  "God, you're just like him! Just keep me locked away in the dark, so I can't experience anything for myself",
#  "Not all experiences are good, Bianca. You can't always trust the people you want to.",
#  "I guess I'll never know, will I?",
#  'So did you',
#  'You set me up.',
#  'I just wanted --',
#  'What? To completely damage me?  To send me to therapy forever? What?',
#  'No! I just wanted',
#  "It's just you.",
#  'Perm?',
#  "No! You're not dating until your sister starts dating.  End of discussion.",
#  'What if she never starts dating?',
#  "Then neither will you.  And I'll get to sleep at night.",
#  "But it's not fair -- she's a mutant, Daddy!",
#  'Exactly my point',
#  "And where're you going?",
#  'If you must know, we were attempting to go to a small study group of friends.',
#  'Otherwise known as an orgy?',
#  'It\'s just a party. Daddy, but I knew you\'d forbid me to go since "Gloria Steinem" over there isn\'t going --',
#  "If Kat's not going, you're not going.",
#  "It's just a party. Daddy.",
#  'Daddy, no!',
#  'Just for a minute',
#  'Why?',
#  "Because she'll scare them away.",
#  'The prom?  Kat has a date?',
#  'No, but',
#  "It's that hot rod Joey, right? That ' s who you want me to bend my rules for?",
#  'He\'s not a "hot rod".  Whatever that is.',
#  "You're not going unless your sister goes.  End of story.",
#  "Fine.  I see that I'm a prisoner in my own house.  I'm not a daughter. I'm a possession!",
#  "I have a date, Daddy.  And he ' s not a captain of oppression like some men we know.",
#  "Didn't have you pegged for a Gigglepuss fan.  Aren't they a little too pre-teen belly-button ring for you?",
#  'Fan of a fan.  You see a couple of minors come in?',
#  'Never',
#  'Padua girls.  One tall, decent body. The other one kinda short and undersexed?',
#  "Just sent 'em through.",
#  'So they tell me...',
#  "C'mon.  I'm supposed to give you the tour.",
#  "North, actually.  How'd you   ?",
#  'I was kidding. People actually live there?',
#  "Yeah.  A couple.  We're outnumbered by the cows, though.",
#  'How many people were in your old school?',
#  'Thirty-two.',
#  'Get out!',
#  'How many people go here?',
#  'Couple thousand. Most of them evil',
#  'Yeah, but these guys have never seen a horse.  They just jack off to Clint Eastwood.',
#  'You burn, you pine, you perish?',
#  'Who is she?',
#  "Bianca Stratford.  Sophomore. Don't even think about it",
#  'Why not?',
#  "I could start with your haircut, but it doesn't matter.  She's not allowed to date until her older sister does.  And that's an impossibility.",
#  "Because they're bred to.  Their mothers liked guys like that, and their grandmothers before them. Their gene pool is rarely diluted.",
#  'He always have that shit-eating grin?',
#  "Joey Dorsey?  Perma-shit-grin.  I wish I could say he's a moron, but he's number twelve in the class.  And a model.  Mostly regional stuff, but he's rumored to have a big tube sock ad coming out.",
#  "Sure do ... my Mom's from Canada",
#  'Guess who just signed up for a tutor?',
#  "You mean I'd get a chance to talk to her?",
#  'You could consecrate with her, my friend.',
#  "That's her?  Bianca's sister?",
#  'The mewling, rampalian wretch herself.',
#  "Unlikely, but even so, she still can't go out with you.  So what's the point?",
#  'You wanna go out with him?',
#  'He seems like he thrives on danger',
#  "No kidding.  He's a criminal.  I heard he lit a state trooper on fire.  He just got out of Alcatraz...",
#  'They always let felons sit in on Honors Biology?',
#  "I'm serious, man, he's whacked.  He sold his own liver on the black market so he could buy new speakers.",
#  "Forget his reputation.  Do you think we've got a plan or not?",
#  "Did she actually say she'd go out with you?",
#  "That's what I just said",
#  'I thought you hated those people.',
#  "Hey -- I've gotta have a few clients when I get to Wall Street.",
#  "Like we had a choice?  Besides -- when you let the enemy think he's orchestrating the battle, you're in a position of power. We let him pretend he's calling the shots, and while he's busy setting up the plan, you have time to woo Bianca.",
#  "In that case, we'll need to make it a school-wide blow out.",
#  'Will Bogey get bent?',
#  "Are you kidding?  He'll piss himself with joy.  He's the ultimate kiss ass.",
#  "It's a lung cancer issue",
#  'Her favorite uncle',
#  'Dead at forty-one.',
#  "Okay!  I wasn't sure",
#  "It's her favorite band.",
#  "Hell, I've just been going over the whole thing in my head and -",
#  "The hell is that?  What kind of 'guy just picks up a girl and carries her away while you're talking to her?",
#  "Buttholus extremus.  But hey, you're making progress.",
#  "No, I ' m not.",
#  "Best case scenario, you're back on the payroll for awhile.",
#  "Yeah -- we'll see.",
#  "I've retrieved certain pieces of information on Miss Katarina Stratford I think you'll find helpful.",
#  "So what does that give me?  I'm supposed to buy her some noodles and a book and sit around listening to chicks who can't play their instruments?",
#  "Don't make me do it, man",
#  "It's off. The whole thing.",
#  "She's partial to Joey, not me",
#  'Sure',
#  'Then, go get her',
#  "I don ' t know.  I decided not to nail her when she was too drunk to remember it.",
#  "She just needs time to cool off I'll give it a day.",
#  'She kissed me.',
#  'Where?',
#  'You get the girl.',
#  'Yeah, and I noticed the only part of you featured in your big Kmart spread was your elbow.  Tough break.',
#  "They're running the rest of me next month.",
#  'Not at all',
#  'Away.',
#  'Your sister here?',
#  'And why would I do that?',
#  'What do you think?',
#  'Yeah, whatever.  I want you to go out with her.',
#  "Sure, Sparky.  I'll get right on it.",
#  'You just said',
#  'You need money to take a girl out',
#  "But you'd go out with her if you had the cake?",
#  "You're gonna pay me to take out some girl?",
#  "I can't date her sister until that one gets a boyfriend.  And that's the catch. She doesn't want a boyfriend.",
#  'How much?',
#  'Fine, thirty.',
#  "Fifty, and you've got your man.",
#  "I'm on it",
#  "Watching the bitch trash my car doesn't count as a date.",
#  'I got her under control. She just acts crazed in public to keep up the image.',
#  'What?',
#  'A hundred bucks a date.',
#  'Forget it.',
#  'Forget her sister, then.',
#  "A deal's a deal.",
#  'Do what?',
#  'Get her to act like a human',
#  "Enough with the Barbie n' Ken shit. I know.",
#  'Are you lost?',
#  'Nope - just came by to chat',
#  "We don't chat.",
#  "Well, actually, I thought I'd run an idea by you.  You know, just to see if you're interested.",
#  "We're not.",
#  'Does this conversation have a purpose?',
#  "So what you need to do is recruit a guy who'll go out with her.  Someone who's up for the job.",
#  "Uh,  yeah.  We're old friend*",
#  'You and Verona?',
#  'What?  We took bathes together when we were kids.',
#  "Hey -- it's all for the higher good right?",
#  'Patrick Verona   Random skid.',
#  "That's Pat Verona? The one who was gone for a year? I heard he was doing porn movies.",
#  "I'm sure he's completely incapable of doing anything that interesting.",
#  'He always look so',
#  'Block E?',
#  'Just a little.',
#  'An attempted slit.',
#  "But imagine the things he'd say during sex.",
#  "You could always go with me.  I'm sure William has some friends.",
#  'William would never have gone to a state school.',
#  "William didn't even go to high school",
#  "That's never been proven",
#  'Neither has his heterosexuality.',
#  'Does it matter?',
#  'If I was Bianca, it would be, "Any school you want, precious.  Don\'t forget your tiara."',
#  'No fear.',
#  'Who cares?',
#  "I didn't have a choice.",
#  "You didn't have a choice?  Where's Kat and what have you done with her?",
#  'I did Bianca a favor and it backfired.',
#  "You didn't",
#  'I got drunk.  I puked.  I got rejected. It was big fun.',
#  "Well, I guess we're not, since we don't have dates .",
#  'Listen to you!  You sound like Betty, all pissed off because Archie is taking Veronica.',
#  "Okay, okay, we won't go.  It's not like I have a dress anyway",
#  "You ' re looking at this from the wrong perspective.  We're making a statement.",
#  'Oh, good.  Something new and different for us.',
#  'Who?',
#  'William - he asked me to meet him here.',
#  "Oh, honey -- tell me we haven't' progressed to full-on hallucinations.",
#  'Sweating like a pig, actually.  And yourself?',
#  "There's a way to get a guy's attention.",
#  'My mission in life.',
#  'Oh, right.  Friday.',
#  'Like where?  The 7-Eleven on Burnside? Do you even know my name, screwboy?',
#  'I know a lot more than that',
#  "I don't really think you warrant that strong an emotion.",
#  "Then say you'll spend Dollar Night at the track with me.",
#  'And why would I do that?',
#  'Come on -- the ponies, the flat beer, you with money in your eyes, me with my hand on your ass...',
#  'You -- covered in my vomit.',
#  'Seven-thirty?',
#  "I was in the laundromat. I saw your car. Thought I'd say hi.",
#  'Hi',
#  "Depends on the topic. My fenders don't really whip me into a verbal frenzy.",
#  '',
#  "That's what you want, isn't it?",
#  "Do you mind?  You're sort of ruining it for me.",
#  'You know who The Raincoats are?',
#  "Why, don't you?",
#  '"I\'m getting trashed, man." Isn\'t that what you\'re supposed to do at a party?',
#  'I say, do what you wanna do.',
#  "Funny, you're the only one",
#  "I'm fine. I'm",
#  'I just need to lie down for awhile',
#  "Uh, uh. You lie down and you'll go to sleep",
#  'I know, just let me sleep',
#  'What if you have a concussion? My dog went to sleep with a concussion and woke up a vegetable. Not that I could tell the difference...',
#  "Leave it to you to use big words when you're shitfaced.",
#  "Why 're you doing this?",
#  'I told you',
#  "You don't care if I die",
#  'Sure, I do',
#  'Why?',
#  "Because then I'd have to start taking out girls who like me.",
#  'Like you could find one',
#  "See that?  Who needs affection when I've got blind hatred?",
#  'Just let me sit down.',
#  'Who?',
#  'Dorsey.',
#  'I hate him.',
#  "I know.  It'd have to be a pretty big deal to get you to mainline tequila. You don't seem like the type.",
#  'Hey man. . .  You don \' t think I can be "cool"?  You don\'t think I can be "laid back" like everyone else?',
#  'I thought you were above all that',
#  'You know what they say',
#  'What?',
#  "But it's Gigglepuss - I know you like them.  I saw you there.",
#  'Busy',
#  'Were you in jail?',
#  'Maybe.',
#  "No, you weren't",
#  "Then why'd you ask?",
#  "Why'd you lie?",
#  'Do what?',
#  'This.',
#  "My father wouldn't approve of that that",
#  "You don't strike me as the type that would ask permission.",
#  "I'm gettin' there",
#  "He just wants me to be someone I'm not.",
#  'Who?',
#  'BIANCA',
#  "No offense, but you're sister is without.  I know everyone likes her and all, but ...",
#  'What are you doing here?',
#  'I heard there was a poetry reading.',
#  "You 're so --",
#  'Pleasant?',
#  'Unwelcome.',
#  'Unwelcome?  I guess someone still has her panties in a twist.',
#  "Don't for one minute think that you had any effect whatsoever on my panties.",
#  'So what did I have an effect on ?',
#  'Other than my upchuck reflex? Nothing.',
#  'Look up, sunshine',
#  "C'mon.  It's not that bad",
#  "Try lookin' at it from this angle",
#  "Forget it.  I'm stayin'.",
#  'You want me to climb up and show you how to get down?',
#  'Maybe.',
#  'I figured it had to be something ridiculous to win your respect.  And piss you off.',
#  'Good call.',
#  "So how'd you get Chapin to look the other way?",
#  'I dazzled him with my wit',
#  "Yeah, well, don't let it get out",
#  "So what's your excuse?",
#  'Acting the way we do.',
#  'Yes',
#  "I don't like to do what people expect. Then they expect it all the time and they get disappointed when you change.",
#  "So if you disappoint them from the start, you're covered?",
#  'Something like that',
#  'Then you screwed up',
#  'How?',
#  'You never disappointed me.',
#  'For. . . ?',
#  'Fallacy.',
#  'The duck?',
#  'Hearsay.',
#  "I know the porn career's a lie.",
#  'I hate peas.',
#  'No -- something real.  Something no one else knows.',
#  "You're sweet.  And sexy.  And completely hot for me.",
#  'What?',
#  'No one else knows',
#  "You're amazingly self-assured. Has anyone ever told you that?",
#  'Go to the prom with me',
#  'You know what I mean',
#  'No.',
#  'No what?',
#  "No, I won't go with you",
#  'Why not?',
#  "Because I don't want to. It's a stupid tradition.",
#  'So I have to have a motive to be with you?',
#  'You tell me.',
#  'You need therapy.  Has anyone ever told you that?',
#  'Answer the question, Patrick',
#  "Nothing!  There's nothing in it for me. Just the pleasure of your company.",
#  "It's Scurvy's.  His date got convicted. Where'd you get the dress?",
#  "It's just something I had.  You know",
#  'Oh huh',
#  "Look, I'm  -- sorry -- that I questioned your motives.  I was wrong.",
#  'What?',
#  "That's where I was last year.  She'd never lived alone -- my grandfather died -- I stayed with her.  I wasn't in jail, I don't know Marilyn Manson, and I've never slept with a Spice Girl.  I spent a year sitting next to my grandma on the couch watching Wheel of Fortune.  End of story.",
#  'It gets worse -- you still have your freshman yearbook?',
#  'You were paid to take me out!  By -- the one person I truly hate.  I knew it was a set-up!',
#  "It wasn't like that.",
#  'Really?  What was it like?  A down payment now, then a bonus for sleeping with me?',
#  "I didn't care about the money.",
#  'I thought you could use it. When you start your band.',
#  'Is that right?',
#  'Yeah, but then I fucked up. I fell for her.',
#  'Because I like to torture you.',
#  'Oh, Bianca?  Can you get me my freshman yearbook?',
#  "Don ' t you even dare. . .",
#  'I thought we decided you were going to school here.  At U of 0.',
#  'You decided.',
#  'Enough!',
#  'Then tell them I had a seizure.',
#  'Is this about Sarah Lawrence? You punishing me?',
#  'I thought you were punishing me.',
#  "Why can't we agree on this?",
#  "Because you're making decisions for me.",
#  "As a parent, that's my right",
#  "So what I want doesn't matter?",
#  "You're eighteen.  You don't know what you want.  You won't know until you're forty-five and you don't have it.",
#  'I want to go to an East Coast school! I want you to trust me to make my own choices.  I want --',
#  'Yeah.  She left with some bikers Big ones.  Full of sperm.',
#  'Funny.',
#  'No, Daddy.',
#  'So tell me about this dance. Was it fun?',
#  'Parts of it.',
#  'Which parts?',
#  'The part where Bianca beat the hell out of some guy.',
#  'Bianca did what?',
#  "What's the matter?  Upset that I rubbed off on her?",
#  'No -- impressed.',
#  'When I go?',
#  "Oh, Christ.  Don't tell me you've changed your mind.  I already sent 'em a check.",
#  'Expressing my opinion is not a terrorist action.',
#  "Well, yes, compared to your other choices of expression this year, today's events are quite mild.  By the way, Bobby Rictor's gonad retrieval operation went quite well, in case you're interested.",
#  'I still maintain that he kicked himself in the balls.  I was merely a spectator.',
#  'The point is Kat -- people perceive you as somewhat ...',
#  'No ... I believe "heinous bitch" is the term used most often.',
#  'Just smack her now.',
#  'Hi.',
#  'Cool pictures.  You a fan?',
#  'Yeah.  I guess.',
#  'Oh yeah.',
#  'Right.',
#  'Kat a fan, too?',
#  'Yeah...',
#  'What?',
#  "Whatever the hell it is you're standin' there waitin' to say.",
#  'The situation is, my man Cameron here has a major jones for Bianca Stratford.',
#  'What is it with this chick?  She have three tits?',
#  "Dorsey can plow whoever he wants. I'm just in this for the cash.",
#  'So Dorsey can get the girl?',
#  "Patrick, Pat, you're not looking at the big picture.  Joey's just a pawn. We set this whole thing up so Cameron can get the girl.",
#  "We're your guys.",
#  'Good enough.',
#  'Just for now.',
#  'Yeah.',
#  "I'm likin' you guys better",
#  "No - I've got a sweet-payin' job that I'm about to lose.",
#  'Sweet love, renew thy force!',
#  "Man -- don't say shit like that to  me. People can hear you.",
#  'It says here you exposed yourself to a group of freshmen girls.',
#  'It was a bratwurst.  I was eating lunch.',
#  'With the teeth of your zipper?',
#  'Touch of the flu.',
#  "I'm at a loss, then.  What should we talk about? Your year of absence?",
#  "What's to discuss?",
#  "You weren't abused, you aren't stupid, and as far as I can tell, you're only slightly psychotic -- so why is it that you're such a fuck-up?",
#  "Well, you know -- there's the prestige of the job title... and the benefits package is pretty good...",
#  'See you next week!',
#  'Make anyone cry today?',
#  'Sarah Lawrence is on the other side of the country.',
#  'Tumescent!',
#  "You're not helping.",
#  'Pirate -- no question.',
#  "Kissing?  Is that what you think happens?  Kissing isn't what keeps me up to my elbows in placenta all day.",
#  'Dr. Ruth?',
#  'But -- who -- what --?',
#  'Your daughters went to the prom.',
#  'Did I have anything to say about it?',
#  'Absolutely not.',
#  "That ' s what I thought",
#  "The water's going putrid in the barrels.",
#  "You'll be drinking your own piss... For the glory of Spain... and Admiral Colon...!  Bastard!",
#  "Ah, leave him alone.  He's doing no harm.",
#  "With a face like that?  I don't want you looking at me.  You hear?",
#  "We'll all go crazy...",
#  "We left three weeks ago, Alonso. Can't be that near.",
#  "Can't be that far, I say.  Also, I don't like the smell of the sea around here.  Smells like a cunt. Bad sign...",
#  'Yes, your Eminence.  The voyage should not take more than six or seven weeks.',
#  'Unfortunately, Don Colon, that is precisely where our opinions differ...  Are you familiar with the work of Aristotle?  Erathostene?  Ptolemeus?',
#  'I am, Your Eminence',
#  'Then you cannot ignore that according to their calculations, the circumference of the Earth is approximately...  22,000 leagues or more.  Which makes the ocean... uncrossable.',
#  'Excellency, you are right.',
#  'Your life, and that of others!',
#  'If they agree to follow me, yes.',
#  'Is that all that interests you? Gold?',
#  'No.  The Portuguese have already discovered black-skinned people.  I, too, will find other populations -- and bring them to the word of God.',
#  "Did He not choose a carpenter's son to reveal Himself to the world?",
#  'Blind faith is what I consider heresy!',
#  'IF-GOD-WILLS-IT!',
#  'The Judgment is ours!',
#  'Naturally.  But I would really deplore the loss of such a potential opportunity for Spain for a... dispute over a point of geography.',
#  'Indeed.  The world is full of mercenaries -- and states often make use of them, when it benefits them.  My only concern is the welfare and prosperity of Spain.',
#  'On the contrary, Your Eminence.  It seems to me the man is preparing his own cross.',
#  'What a tragedy... what a waste of a life...',
#  'A waste...?  Let me tell you something, Arojaz.  If your name, or mine, is ever remembered -- it will only be because of his.',
#  'I know.',
#  "I haven't given you much of a life.",
#  "Well... that's true.  I have a child by a man who won't marry me!  Who's always leaving...",
#  'Are we going to argue?',
#  "I'd love to argue with you sometimes.  But you're never here!",
#  'I find that hard to believe.',
#  'Thank God...',
#  "I don't want you to wait for me.",
#  "That's something you can't decide.",
#  "You don't usually ask.",
#  'I can arrange for the Queen to take Fernando and Diego into her service.',
#  "They tried... but I didn't let them.",
#  "Not everything... Do you think I care?  I'm a free man again.  Riches don't make a man rich, they only make him busier...",
#  'I am busy inside.',
#  "I can't keep my eyes off you.  I would like to catch up with all the moments I didn't spend with you.",
#  'Forgive me, Don Bobadilla -- those positions have already been taken.',
#  'May I ask by whom?',
#  'Bartolome and Giacomo Colon.',
#  'Yes... I remember...',
#  'Appointment to what?',
#  'Viceroy of the West Indies.',
#  'Congratulations.  Then I am free to search for the mainland.',
#  'I am not a seaman.  But I heard it is no more than a week at sea.  I hope you are not too disappointed.',
#  'How could I be?  The mainland has been found.  Exactly as I said it would.',
#  'I am afraid this is not the worst news.',
#  "There'll be a time.",
#  'You promise?  Do you swear on St. Christopher...?',
#  'Yes... Yes, I do... On all of them!',
#  'This time with me!',
#  'Not bad.',
#  'There must be a passage to that other ocean.',
#  "I am not listening, Father.  But I can't help hearing.",
#  'He asks when he can come to visit you.  He left his address.',
#  'He never had one... except aboard my ships!',
#  "Really?  God... I wouldn't know where to start... and yet...",
#  'Tell me the first thing that comes to your mind.',
#  'No?',
#  'NO...!  I have waited too long, fought too hard.  Now you expect me to take all the risks while you take the profit!  No... I will not be your servant!',
#  "I'm not bargaining!",
#  'Then you are too ambitious.',
#  "If you won't accept our proposal, we'll simply find someone who will.",
#  'Forgive me, Don Colon.  But what about gold?',
#  '... for a commoner?',
#  'Don Bobadilla is already a judge, my Dear Don Cristobal.',
#  'Good!  We are also in need of judges.  Except there are no thieves!',
#  'What...?  Do I have so many already?',
#  'To rise so high, in so short a time, is a dangerous occupation.  A little hypocrisy goes a long way.',
#  'Call them.',
#  'Look out of that window.',
#  'Roofs... towers, palaces... spires...',
#  'All of them created by people like me.',
#  'What is it?  A tribe?  An island?',
#  'Island.  Far.',
#  'Tell the Chief we thank him.',
#  'Chief knows.',
#  'Tell him his country is very beautiful.  Tell him we are leaving men here -- to build a fort.',
#  'Thousands.',
#  'Why?',
#  'Chief says -- he has a God.',
#  '... and also to bring medicine.',
#  'Chief says...',
#  'He has medicine.  Tell him we admire his people.',
#  'He understands.',
#  'Ask him if he will help.',
#  'You did the same to your God!',
#  'You never learned how to speak my language.',
#  'Father, I am doing what I think is the best for him.  And he has the teacher I would have chosen for myself.',
#  "That's what it says.",
#  'How did you manage it?',
#  'With some difficulty.  I had to promise them you were not a total fool.',
#  'To open a new route to Asia.  At the moment there are only two ways of reaching it...',
#  'Ignorance!  I believe the Indies are no more than 750 leagues west of the Canary Islands.',
#  'How can you be so certain?',
#  'The calculations of Toscanelli Marin de Tyr, Esdras...',
#  'Esdras is a Jew.',
#  'So was Christ!',
#  "I'll try to remember that, Marchena...",
#  'Father Marchena!',
#  'Passion is something one cannot control!',
#  'You get so carried away when you are being contradicted!',
#  "I've been contradicted all my life... Eternity!",
#  'Only God knows the meaning of such words, my son.',
#  "Wait!  I've waited seven years already!  How much longer do you want me to wait?",
#  'If God intends you to go, then you will go.',
#  'Damn God!',
#  'Damn all of you!  You all set up theories based on what?  You never leave the safety of your studies! Go out!  Find out what the world is about and then tell me something I can listen to!',
#  "Colon!  Don't!",
#  'Forgive me, Father.  For I have sinned.',
#  'Father, I have betrayed my family. I betrayed my men.  And I betrayed you.',
#  'What are you saying?',
#  'I lied.  The journey will be longer than I said.',
#  'How long?',
#  'I am not sure... It could be twice the distance.',
#  "If I tell them, they won't follow me.  You know that I am right, Father.  You trust me...",
#  "My son, my son...  Your certitudes are sometimes frightening...  Christopher, you must speak to them. And if you don't I will.",
#  'You are bound by an oath, Father.',
#  'Give me absolution.',
#  "You'll always be older than me, Father.",
#  'I knew you would.',
#  'New worlds create new people.',
#  'Oh?  So you are a new man?',
#  "I don't know... I have the impression that I didn't change that much.  I still can't accept the world as it is!",
#  'No more than the woman who said she would take Granada from the Moors.',
#  'What did they say about Granada before today?',
#  'That she was impregnable.',
#  'Surely you can do anything you want.',
#  'You show no inclination to speak otherwise!',
#  'I know what I see.  I see someone who doesn\'t accept the world as it is.  Who\'s not afraid.  I see a women who thinks... "What if?"...',
#  'A woman?',
#  'Thirty seven, Your Majesty... And you?',
#  'They come and go as naked as the day God created them...',
#  'Thank you.',
#  "There is one thing I'd like to understand... Why do you want to go back, after all this?",
#  'Your Majesty -- some men are content to read about things.  I must see them with my own eyes.  I cannot be other than I am.',
#  'The Indians have no such word, Don Moxica.',
#  "If you want to keep your head on your shoulders, you'll do as I say.",
#  "We don't need to know.",
#  'We came here to stay!  To build! Not to start a crusade.  In this forest, there is enough danger to sweep us away in days!  So we will be brave and swallow our grief.  And in the name of those who died, we will accomplish what we came for.',
#  "My horse doesn't work.",
#  'You did not hear me, Don Colon.  Not my horse.',
#  'Savagery is what monkeys understand.',
#  "You'll be held in detention, deprived of your privileges and possessions.  Until you are returned to Spain where you will be judged. Have you anything to say?",
#  'You will regret this.',
#  'God be with us admiral.',
#  'And what do you think Mendez?',
#  "Well, I surely know what a quadrant is!  But I've never seen it used at night before.",
#  'Come over here.',
#  'Twenty eight.',
#  "He's drawing an isthmus... He's saying we're on an isthmus.",
#  "We can't be.",
#  'Immediately.',
#  'Six days ago, yes.',
#  'You must be mad...!',
#  'We have to keep the hopes of these men alive!',
#  "We're on the verge of a mutiny, Colon!",
#  "You think I don't know that?",
#  "We're lost!",
#  'The land is there.  I know it!',
#  "You don't know anything!  Listen Colon, these are my ships, right? So I'm telling you we're turning back!",
#  'And then what?  Half of the water has gone, the rest is nearly putrid! You know that!',
#  'Jesus Maria!  I should have never listened to you!',
#  'You never did.  You did all the talking for both of us, remember?',
#  'You bloody...',
#  'Pinzon, Pinzon... All we can do now is go forward!  Think about that!',
#  'You tell that to them!',
#  "You're right.  Let the men decide.",
#  'Yes, Your Majesty.',
#  'Never, Your Majesty.  Although...',
#  "Yes.  It would be a pity, wouldn't it?  Call him back!",
#  "We weren't expecting immediate profits, were we?  We must have faith.  We must give time for time.",
#  'Is this true, Brother Buyl?',
#  'He must be replaced.',
#  'And who would you think of, for such a task?',
#  'Then why?',
#  'Because he is not afraid of me.',
#  "I'm not your lawyer until I see the money.",
#  'Here.  I have your money.',
#  'Emil.  Take it easy.  Stay with me.  Sit down.  What do you need?  What are you looking for?',
#  'He has the camera!  He took the movie!',
#  'Where are we going?',
#  "I'm coming with you.",
#  'Yes.  Yes, come with me!',
#  "I'm invoking rights - this man is represented by counsel.  I'm coming with him.",
#  'You bring the cigarettes?',
#  'Oh, sure.',
#  'I was all of these.',
#  "Well, you didn't appreciate the severity of it until recently.  No question about that.",
#  'What about Oleg?',
#  "Disappeared.  They're looking everywhere.  Maybe he went back to Czechoslovakia.",
#  'No, he is here.  Shit...',
#  "Don't worry about him.  Think about yourself.",
#  'What about my movie rights?  Book rights?',
#  "Look, I haven't really focused on that kind of thing.",
#  "What's your cut?  How much?",
#  'I would say...half.  Half is fair.',
#  'No.  No way.',
#  "But it's...",
#  "Thirty-percent.  No more.  Or I call another lawyer.  This is the biggest case of your life.  Don't try to negotiate.  Thirty percent.  Say yes or no.",
#  'This is not about money, Emil.  I need your trust in me.',
#  'What else do you need?',
#  "I need to know about your background.  I need to know about your upbringing.  Why you're here.",
#  'Give me another one, please.',
#  'My father always degraded me.  Killed my self-esteem.  And my mother was blind.',
#  'Your mother was blind?',
#  'Yeah, she went blind giving birth to me. She went to fucking black market doctor to induce me.',
#  'Back in the Czech Republic?',
#  'Yeah, yeah...bad doctor gave her bad drugs which made her go blind.  And my father blamed me for her blindness...',
#  "Your father blamed you for your mother's blindness?",
#  'Yeah, he hated me from day when I was born.  Put it out.  Can you put the cigarette out?',
#  'Your father put cigarettes out on you?',
#  'Out on my back when I was a small boy.',
#  'Can I see your back?',
#  "I don't think it's abuse, I think it's torture.",
#  "Officers, there's your killer, do your duty, arrest him!",
#  "Alright.  That's a justifiable homicide.",
#  'Yes, but he was a cop.',
#  "If you cooperate with the DA - maybe they'll help you with your situation.",
#  "I will if they don't send me back.",
#  "They won't until this is over.",
#  'Divorced.',
#  "Do you live alone?  I've been in these clothes since...the killings.  Could we stop at your place? I could take a shower...before I go into custody?",
#  'Somewhere else?',
#  'So...the station is empty?',
#  'Yeah.  This way.',
#  'Yes, I considered it.',
#  'Did you ever turn tricks before?',
#  'No.',
#  'What about back home?',
#  'No.',
#  'So you were never a prostitute?',
#  'What are you asking me?',
#  "I'm just trying to find out who you are.",
#  'I know.',
#  "You don't know.  I'm sorry.  I was desperate.  That's not me.  I shot a cop.  Can you imagine what they'll do to me when I got to prison?",
#  "They're not gonna send you right back.",
#  "I'm sorry.  I didn't mean to...I'm glad. Actually I'm glad it's over.  All this time.  Hiding.  Never being able to look anyone in the eyes. Always afraid that someone would find out who I was.  Never trusting anyone...",
#  "I still can't believe Eddie's gone.",
#  "I'm sorry.",
#  "Ludwig?  He's gay - are you jealous?",
#  'If I was your boyfriend, I might be.',
#  "If you were my boyfriend, I'd suggest you find another girlfriend that isn't going to jail ten-thousand miles away.",
#  "No matter what happens...I'm glad I met you.",
#  "I'm glad I met you.",
#  'Right.',
#  'In the kitchen.',
#  "I'll make some for us.",
#  "I'll get my clothes.",
#  'Pouring it out!',
#  '...Do you really want me to forget about you?',
#  "I don't want to drag you down with me.",
#  'Daphne, I...',
#  "C'mon, start at the beginning.  You know these people?",
#  'Tamina was a friend of mine.  My shower was broken, she let me use theirs.',
#  'Go on.',
#  'If I tell you, will you arrest me?',
#  'Arrest you for what?  Why would we arrest you?',
#  "No, no, don't talk to Immigration!",
#  "I'm from a small town in Slovakia.  Like the South here.  The Police is right, a civilian is wrong.  So I fled.",
#  "Look, we can help you but right now we have to deal with what's happening here. Tell us the truth...is that the truth?",
#  "You're a cop - you'll never believe me.",
#  'It was my decision, not his.',
#  "Well, I'm the Deputy Chief Fire Marshall and every now and then I'd like to be included in decisions.",
#  'Look, after Jordy briefs me, you can do the press conference.  How about that? The case is all yours.',
#  'Oh yeah...?  Alright.',
#  "I'm ready to be briefed.  Excuse us.",
#  "Yeah, sure.  Beep me when you're ready for the press conference.",
#  'Who do you think, Chief?!',
#  "Then why didn't you talk to the reporter?",
#  "'Cause we got more important things to do, like finding out who did it.",
#  "I came to see how the investigation was going.  I called and you're not here.  I wait up at the station and you don't even show up!!!  I beep you - you don't return my call.  Where the hell have you been?!",
#  "What do you mean, 'cleaned up?'",
#  'I let her take a shower.',
#  'A shower!?  Did you take one, too?',
#  'No!  Nothing happened.',
#  "Oh really.  That's nice.  You took a homicide witness to take a shower after your partner was shot?  Are you out of your fucking mind??  Are you having that much trouble gettin' dates?!",
#  'Okay.  But not water sports.',
#  'What was I supposed to do?  The guy tried to mug me.  I was gonna send a cop back - I just forgot.',
#  'Forgot?  You handcuffed a civilian to a tree?!',
#  'Chief - I know I screwed up - but this guy was no innocent civilian.',
#  'Well this is gonna end your career and probably mine.',
#  'End my career?',
#  "How are you going to fight this?  Maybe if Oleg hadn't gotten away and you'd been on the front page, as a hero, this thing would be easier to fight.  You'd have the good to weight against the bad! It's unfortunate that I have to make decisions based upon your press coverage but there's nothing I can do!  Gimme your shield.",
#  'But Chief?  Over this??',
#  "There's nothing to talk about.  Get a good lawyer.  You're suspended until your trial.",
#  'Yeah, right.',
#  'What was that, Korfin?',
#  "I said, yeah, you're right, Chief.  As soon as we get somethin' we'll let you alert the media.",
#  "You do that, wiseguy.  Now let's solve this thing before Eddie Flemming does.",
#  'Yeah.  He finished awhile ago.',
#  'Alright.  Swing by her apartment.  Let her pick up her clothes and take her straight to Hoover Street.  You got that?',
#  'Yeah.',
#  'Vodka tonic.',
#  'Maybe you could just put in a shot of Martell?',
#  "What's the kid gonna say - sorry? Meanwhile I'm not here anymore. Like last week - we were at the morgue and this guy was all chopped up - spleen here - liver there - his heart in a pan. Six hours ago this guy was walkin' his dog or buyin' a quart of milk.  Who knows?  But some kid's robbed him for $3 or some shit and shot him and now you can't tell if he's a piece of beef or a human being and I'm thinkin' that's me. Sooner or later.  That's me.",
#  'When?',
#  'Tomorrow.  At lunch.',
#  'You ready?',
#  'A timer.',
#  "Takin' a bath.",
#  'Any I.D.?',
#  "Still unknown but we're running prints. Kid over there caught the case.",
#  "It's okay.",
#  'Yeah.',
#  "C'mere.  You wanna go to homicide school?  Here - make yourself useful.",
#  'Stay with her.',
#  "No.  I'm okay.",
#  "I know.  Relax.  Take it easy.  Don't worry, we'll get those fuckers.",
#  "Police.  We'd like to ask you a few questions.",
#  "I have nothin' to say.  If you wanna contact my attorney...",
#  "Homicide, Miss Hearn.  It's Detective Eddie Flemming.  Open up.",
#  "We don't have her I.D. yet, but one of your girls was killed last night at the King Edward Hotel.",
#  "Oh my G-d.  Honey!  Honey's dead?",
#  'Do you have any Czech girls working for you?',
#  'No.',
#  'Did you tell him you did?',
#  'What are you saying?',
#  'Daphne.  Another guy came in asking me about her, too.',
#  'Describe him.',
#  "Tall, short-haired, scary eyes.  Second guy with him was...shorter, with a wrestler's build.  And he wouldn't turn his videocamera off me.",
#  'He had a videocamera?  Where is she? Quickly!',
#  "She washes hair up at Ludwig's - a salon on 63rd and Madison.",
#  "No, we don't mind.  You mind Leon?",
#  'No, what is it?',
#  "Why don't you explain it, Bobby.  Hey Camello!  You mind punching a hole in the floor?",
#  'Watch the news?',
#  'Nah, I musta missed it.',
#  'Well, just so you know.  I gave you guys the credit.',
#  "Well, just so you know, I don't care about that stuff.",
#  'Nah, why should you?',
#  "I don't even watch TV.",
#  'Good.  Good.  Commendable.',
#  'Sure.  But I would like to ask you something.  You got a problem with me?',
#  "If you found me steppin' on your crime scene - it might piss you off, too.  What about the report?",
#  "You were right, they were both dead before the fire.  The male was stabbed so hard the killer broke off the tip of the knife in his spine.  That's usually an indicator of something personal.",
#  'Pretty.',
#  'Hmmmm.',
#  "Maybe you don't care about that either.  Prettiest suspect I've had in awhile.",
#  "Who says she's a suspect?",
#  "Look, I'm not even sure she has anything to do with this.  I saw her outside after the fire - thought it was a lead. Maybe she saw something.  Maybe she was visiting somebody here.  Who knows?",
#  'Eastern Europe.  Like what?  Romania? Hungary?',
#  'Or Czechoslovakia.  The Slavs have been fighting the Germans and the Russians for a thousand years.  These are very intense people and they take things personally.',
#  "There wasn't a fire.  There'll be nothing for you to do.",
#  "I can watch you, Eddie.  Maybe I'll learn something.",
#  "This isn't homicide school.",
#  'My parents are from Poland.  I can help with the Eastern European angle.',
#  "You're Polish?",
#  'My folks are.',
#  'Stay here.',
#  'You got any better ideas?',
#  'Mind if I ride along with you?',
#  'This has nothing to do with your fire.',
#  'But what if it does?  You might need my help.',
#  "This is ridiculous.  I'm not gonna be in your way - we can talk the case over.",
#  "Tell you what - I'll flip you a coin. If you win you can come with me.  If you don't win, you don't come.",
#  "I'll call it... tails.",
#  'Better than one.',
#  "I'm on my way with Eddie.  Ludwig's. 63rd and Madison.  The suspects might be there already.",
#  "I'm on duty.",
#  "So am I.  Alright, I'll go inside and you cover the back.",
#  'Of course.',
#  "Hey!  I always wanted to be a cop when I was a kid.  I dreamed of running up to a door, kicking it in, pulling my gun and yelling 'Freeze!' at the bad guy! What'd you dream about?",
#  'I wanted to run up to a building on fire, kick in the door, rush into the smoke and save a kid.',
#  "Then I guess we're doin' this the right way, aren't we?  If we pull up to a burning building I'll gladly let you go first.",
#  'She just saw two of her friends killed! They probably threatened her.',
#  'Is that all there is?',
#  'Something back home?',
#  'Raw deal.',
#  'You wanna talk to her alone?',
#  'Yeah.',
#  'What would your girlfriend think of that?',
#  "I don't have a girlfriend.",
#  'My point exactly.',
#  "I'm serious here.",
#  'So am I.',
#  "C'mon.  You intimidate her 'cause you're a celebrity.  She sees me differently.",
#  "You're her Savior?  Is she the kid you're gonna save from the burning building?",
#  "You know what I'm saying here.",
#  "Hey.  I'm a professional.",
#  'Women like that have a way of turning professionals into amateurs.',
#  "Well, you shoulda because nobody's gonna believe you didn't...including me.",
#  "I took her there for a shower and that's it.",
#  'Just a shower?',
#  "No, I don't think you were a fool, I just think you were stupid about it.  I mean, to say the least, you outta know better.  You don't know her well enough. She's got the potential to fucking hang you even if she suggests that you made a pass at her, it's fuckin' over.  You can deny it all you want, but it will not make one fucking bit of difference. You're dead.",
#  "I told you, you know, I thought I was doing the right thing, you know, I think she's innocent.",
#  "Well, it's not up to you to decide whether she's innocent or not.  Don't you understand, that's why you're a professional.",
#  "But, I mean, didn't you ever go out on a limb for somebody?  I mean, you shoulda heard her there.  Tellin' her whole story...I believed her.",
#  "How you go out on a limb for somebody is by giving her a number of an Immigration lawyer.  Here, here's a number of an Immigration lawyer.  That's how you help her. But you can't get involved in her like that.  You're gonna jeopardize your career, your life and you're gonna jeopardize my case.  And lemme give you another piece of advice.  Maybe you don't watch TV but I'll let you in on a little secret - the whole fuckin' world watches television.  And when you get out there, they know your face.  And the little fame, the little fuckin' itty bitty fame that I get in this city makes it a lot easier for my job.  And I get more done because of it.",
#  "You know, I don't know.  I like you. You remind me of a puppy I used to have. He pissed on the rug all the time, but I still kept him.",
#  'What do you want?',
#  'Your opinion.  You see, they going to make a movie about me, too, Eddie.  And write books.',
#  "What's your accomplishment.",
#  'I kill someone famous.',
#  'Then do it, asshole.',
#  'Good - be tough to the end.  Actor who plays you will want to die like hero.',
#  "If you kill me and film it you're putting a noose around your neck.",
#  "Smarter than Americans.  You're fed cry baby talk shows all day long.  Not only will Americans believe me, they'll cry for me.  So...Detective Eddie Flemming, would you like to say goodbye to your Nicolette? Maybe you can propose to her now?",
#  "We don't know that yet.  It's much too early.  There's a lot to be done.",
#  'How many victims are up there?',
#  'There are two bodies found at this point.',
#  'Can we go up to the crime scene?',
#  "You know you can't do that.  C'mon.",
#  'Is it drug related?',
#  "We don't know.  When I have more I'll let you know.",
#  "I can't talk right now.  We have some things to take care of.",
#  "I really can't give out any information right now at this point.",
#  "Okay.  But I do understand that your partner, Leon Jackson's been injured. Is that correct?",
#  "He was hurt, but not seriously.  He'll be fine.",
#  'Do you have the suspect in custody?',
#  "Um...now is not a good time, okay. Detective Jackson's hurt.  He's fine. I've got a Fire Marshall shot, Detective Jackson is hurt but not seriously.",
#  'Alright, cut, cut, cut.',
#  "Yeah.  Now's not a good time.",
#  'Alright.',
#  'Alright?',
#  'Alright.',
#  'Alright.',
#  'Okay.',
#  'Hey.',
#  "I can't...I can't answer you just because you want me to answer you!",
#  "You didn't have to embarrass me in front of my colleagues.  You could give me something.",
#  "Oh, I'm sorry.  Did I embarrass you, sweetheart?  Oh...",
#  'Stop it.',
#  'Maybe I should just, ya know...turn to the cameras and say, do you mind if we just work something out?',
#  "Alright, alright, Eddie.  Don't patronize me.",
#  "I'm not.",
#  "Yes you are.  I'm not just some reporter.  I don't just stick a microphone in your face.  You could give me something.",
#  'Yeah, well you took the camera and put it right down on the evidence.  That was...',
#  'That was good.  You were holding the evidence.',
#  "You were merciless.  You didn't give a shit if you got me or not.",
#  'Well, who was it that taught me how to do that?  Huh?',
#  "You're ruthless.",
#  "You're not so bad yourself.",
#  "Could be Leon's.",
#  'Jesus.  And last week you came over with blood on your shoes.  What am I going to do with you?',
#  'Answer the phone.',
#  'No.  Tell me what you want to say.',
#  'Answer it.',
#  "Okay.  Okay.  Hold that thought just for a second.  They only call me when it's an emergency.  Just hold that thought.  Can you call back?",
#  "That's good.",
#  'Yeah.',
#  "Well, that's great.",
#  "Okay.  That is great.  But I can't go now, we're in the middle of something here.",
#  "No.  Go ahead.  You're gonna be great.",
#  "No.  No, listen to me here.  I want to know what you're talking about.  You know, the shoe thing and the marriages and...",
#  "I'll tell you tonight.  Let's do it tonight.  As soon as you get back we'll talk.  We'll talk.",
#  'Promise?',
#  "I promise.  We'll talk.  You'll be great.  You'll be fine.  Go ahead, just imagine that, uh... Just look into the lens and imagine you're talking to me.",
#  "Yeah.  I'll do that.  As long as you're not patronizing me.",
#  'Patronizing you... Nay, I love you.',
#  'I love you.',
#  'Tonight.',
#  'You promise?',
#  'Yeah.  I promise.',
#  "Okay.  And you know what, I'll swing by my place, grab a couple pairs of shoes and maybe just test them out next to yours...How's that... Would that be a good thing.",
#  'Yeah, yeah.  Good thing.',
#  'Okay.',
#  'See you later.  Good luck.',
#  'Thank you.',
#  "Don't be late.",
#  'Jesus Christ.',
#  'Not chopped up.  Not chopped up like that.  I mean, what do I got left? Coupla articles.  A medal or two. Plaque here and there and in a coupla years no one remembers me anymore.',
#  "I think you're getting a little moody there, Eddie.",
#  "I'm not moody.",
#  "My kids?  Let's see...Susan's 15. Aundrea's 9.  Don't tell me you're thinking about having a kid!  How old are you?  Never mind. Let me just tell you this: Every stupid cliche you hear about kids - they change your life, they make you a better person, they make you whole...  It's all true!  Before I had kids when friends talked about their kids, I wanted to vomit.  Now -- I get it.  Am I right, Leon?",
#  'Not what.  Who.',
#  "That's unique.",
#  'Yeah.  And he still went to the party.',
#  "You're worried for my safety.  I'm touched.",
#  'Keep them out of my way.',
#  'Okay.  You ready?',
#  'Yeah, yeah.  Jesus.',
#  "Again?  I didn't wanna do it the first time.",
#  'I am butcher.',
#  "You're a butcher?  What do you use pig intestines for?",
#  'You stuff sausage in it.',
#  'And what do you do with the bones?',
#  'Dog food.',
#  'No.  Are you proposing?',
#  "Look asshole.  I've been threatened by better than you.",
#  "No.  I'm the best that's ever threatened you.",
#  "I'll meet you on one condition - I get exclusivity and you surrender to me.",
#  "We'll talk about that.  Four o'clock gives you time to go to bank.  Three hundred thousand dollars.",
#  "What?  It doesn't work that way.",
#  "If you don't want my film - I'll call another show.  And they will show it.",
#  'Wait a minute.  Wait a minute.',
#  "Come alone.  Bring cash.  And we'll talk about surrendering.",
#  "My father was.  He gave me many lessons about fire.  Now it's my friend.",
#  'Tommy, take a walk.',
#  "You'll be my first.",
#  'Get down on your knees.',
#  "The Sheraton!  On Broadway!  Room 210. Go get Oleg.  He'll kill you.",
#  'Let her go!  Let her go!!',
#  "If he doesn't lower his gun I'll fucking kill her.",
#  "Where's Czech girl?",
#  "Baby, I'm anybody you want me to be. I'm a little schoolgirl, I'm mommy, I'm a Czech girl.",
#  'I ordered a Czech girl.  Daphne, you know her?',
#  'Where is escort service?',
#  "That's confidential.  Could you put the money on the dresser?",
#  'I like to talk to the person who runs the service.  Can you give me address?',
#  "Look.  Do we have a problem here? There's no reason to have a problem. I'm gonna make you feel real good.  You wanna Czech girl? After I'm done with you, you won't miss her.  Now why don't you pay me?",
#  "Look, man, I don't give a shit if you want sex or not, but you're payin' for my time.",
#  "Alright, alright - don't hurt me! Please, it's in my book, in my purse!",
#  'Yes sir.',
#  'Two weeks holiday.',
#  'How much money are you carrying with you?',
#  'I have five-hundred dollars.',
#  'Can you show me?  Sir, no cameras in the FIS area!',
#  'Yes.',
#  'Please join us.  Come on forward.',
#  'Is there a problem?',
#  "No, you're travelling together.  I want to talk to you together.  Hi, how are you?  Can I take a look at your documents?  Are you related?",
#  'How long are you planning to stay?',
#  'Two weeks.',
#  "I'd like to speak for himself, okay?",
#  "He doesn't speak English.",
#  "New York's finest.  This is his case.",
#  'Do you know how much killer gets for movie rights?',
#  'In here, says he wants a million.',
#  'Million?!  The killer gets one million dollars for a television interview?',
#  'Hey, tabloids paid Ted Bundy - famous serial killer - half a million for his interview.  And how much you think Monica got for writing book about the President coming on to her?  It pays to be a killer or a whore in this country. Look, you want magazine or not?',
#  'Yes.  Both.',
#  'Okay.',
#  'Okay.',
#  'I want to document my trip to America.',
#  "Don't speak Russian!",
#  'Why?  Why do I always have to speak to you in Czech?',
#  "Because I don't like your ugly language. I heard enough of it in school!  Now speak Czech or English.  And don't fool around anymore.  You almost got us thrown out!",
#  'We have no money.  Come on.',
#  ...]

# %% [markdown]
# # FIRST CLEAN SECTION

# %%
def clean_text(text):
    text = text.lower()
    text = re.sub(r"i'm", "i am", text)
    text = re.sub(r"he's", "he is", text)
    text = re.sub(r"she's", "she is", text)
    text = re.sub(r"that's", "that is", text)
    text = re.sub(r"what's", "what is", text)
    text = re.sub(r"where's", "where is", text)
    text = re.sub(r"\'ll", " will", text)
    text = re.sub(r"\'ve", " have", text)
    text = re.sub(r"\'re", " are", text)
    text = re.sub(r"\'d", " would", text)
    text = re.sub(r"won't", "will not", text)
    text = re.sub(r"can't", "cannot", text)
    text = re.sub(r"[-()\"#/@;:<>{}+=~|.?,]", "", text)
    return text

# %% [markdown]
# # Cleaning of Questions and answers

# %%
 ## CLEANING OF QUESTIONS
clean_questions = []
for question in questions:
    clean_questions.append(clean_text(question))
    
 ## CLEANING OF ANSWERS
clean_answers = []
for answer in answers:
    clean_answers.append(clean_text(answer))

# %%
clean_questions
# Out:
# ['can we make this quick  roxanne korrine and andrew barrett are having an incredibly horrendous public break up on the quad  again',
#  'well i thought we would start with pronunciation if that is okay with you',
#  'not the hacking and gagging and spitting part  please',
#  'you are asking me out  that is so cute what is your name again',
#  "no no it's my fault  we didn't have a proper introduction ",
#  'cameron',
#  'the thing is cameron  i am at the mercy of a particularly hideous breed of loser  my sister  i cannot date until she does',
#  'why',
#  'unsolved mystery  she used to be really popular when she started high school then it was just like she got sick of it or something',
#  'gosh if only we could find kat a boyfriend',
#  "c'esc ma tete this is my head",
#  'right  see  you are ready for the quiz',
#  "i don't want to know how to say that though  i want to know useful things like where the good stores are  how much does champagne cost  stuff like chat  i have never in my life had to point out my head to someone",
#  "that is because it's such a nice one",
#  'how is our little find the wench a date plan progressing',
#  'there',
#  'you got something on your mind',
#  'you have my word  as a gentleman',
#  'how do you get your hair to look like that',
#  'sure have',
#  'i really really really wanna go but i cannot  not unless my sister goes',
#  'she is not a',
#  'lesbian  no i found a picture of jared leto in one of her drawers so i am pretty sure she is not harboring samesex tendencies',
#  'so that is the kind of guy she likes pretty ones',
#  'hi',
#  'you know chastity',
#  'have fun tonight',
#  'i looked for you back at the party but you always seemed to be occupied',
#  'i was',
#  'well no',
#  'then that is all you had to say',
#  'but',
#  'then guillermo says if you go any lighter you are gonna look like an extra on 90210',
#  'do you listen to this crap',
#  'what crap',
#  'me  this endless blonde babble i am like boring myself',
#  'i figured you would get to the good stuff eventually',
#  'what good stuff',
#  'the real you',
#  "i am kidding  you know how sometimes you just become this persona  and you don't know how to quit",
#  'no',
#  'wow',
#  'she okay',
#  'they do to!',
#  'did you change your hair',
#  'no',
#  'where did he go  he was just here',
#  'who',
#  'great',
#  'he practically proposed when he found out we had the same dermatologist i mean dr bonchowski is great an all but he is not exactly relevant party conversation',
#  'is he oily or dry',
#  "bianca i don't think the highlights of dating joey dorsey are going to include dooropening and coatholding",
#  'sometimes i wonder if the guys we are supposed to want to go out with are the ones we actually want to go out with you know',
#  'i have to be home in twenty minutes',
#  "you think you ' re the only sophomore at the prom",
#  "it's more",
#  "exactly  so you going to bogey lowenbrau's thing on saturday",
#  'so yeah i have got the sears catalog thing going  and the tube sock gig  that is gonna be huge  and then i am up for an ad for queen harry next week',
#  'queen harry',
#  'neat',
#  'hey sweet cheeks',
#  'hi joey',
#  'listen i want to talk to you about the prom',
#  'where have you been',
#  "i have the potential to smack the crap out of you if you don't get out of my way",
#  'oh my god does this mean you are becoming normal',
#  'it means that gigglepuss is playing at club skunk and we are going',
#  "oh i thought you might have a date  i don't know why i am bothering to ask but are you going to bogey lowenstein's party saturday night",
#  'what do you think',
#  "you are ruining my life'  because you will not be normal i cannot be normal",
#  'what is normal',
#  'cannot you forget for just one night that you are completely wretched',
#  'like i am supposed to know what that even means',
#  "it's shakespeare  maybe you have heard of him",
#  'you are so completely unbalanced',
#  'bianca i need to talk to you  i need to tell you ',
#  "i don't get you  you act like you are too good for any of this and then you go totally apeshit when you get here",
#  'listen i know you hate having to sit home because i am not susie high school',
#  'like you care',
#  "i do care but i am a firm believer in doing something for your own reasons not someone else ' s ",
#  'joey never told you we went out did he',
#  'what',
#  'in 9th  for a month',
#  'why',
#  'he was like a total babe',
#  'but you hate joey',
#  'now i do  back then was a different story',
#  'he said everyone was doing it  so i did it',
#  'you did what',
#  'but',
#  "after that i swore i would never do anything just because everyone else was doing it  and i haven't since except for bogey's party and my stunning gastrointestinal display ",
#  "why didn't you tell me",
#  'i wanted to let you make up your own mind about him',
#  'that is not',
#  'i am not stupid enough to repeat your mistakes',
#  'i guess i thought i was protecting you',
#  'god you are just like him! just keep me locked away in the dark so i cannot experience anything for myself',
#  'not all experiences are good bianca you cannot always trust the people you want to',
#  'you looked beautiful last night you know',
#  'let go!',
#  'you set me up',
#  'i just wanted ',
#  'what to completely damage me  to send me to therapy forever what',
#  'is that woman a complete fruitloop or is it just me',
#  'patrick  is that a',
#  "now don't get upset daddy but there's this boy and i think he might ask",
#  'no! you are not dating until your sister starts dating  end of discussion',
#  'what if she never starts dating',
#  'then neither will you  and i will get to sleep at night',
#  "but she doesn't want to date",
#  'daddy i ',
#  'and where are you going',
#  'if you must know we were attempting to go to a small study group of friends',
#  'otherwise known as an orgy',
#  'daddy people expect me to be there!',
#  "oh god  it's starting",
#  'wear the belly before you go',
#  'daddy no!',
#  'promise me you will not talk to any boys unless your sister is present',
#  'why',
#  "daddy i want to discuss the prom with you it's tomorrow night ",
#  'the prom  kat has a date',
#  'no but',
#  "it's that hot rod joey right that ' s who you want me to bend my rules for",
#  'he is not a hot rod  whatever that is',
#  'you are not going unless your sister goes  end of story',
#  'i am missing something',
#  'always a pleasure brucie',
#  "didn't have you pegged for a gigglepuss fan  aren't they a little too preteen bellybutton ring for you",
#  'fan of a fan  you see a couple of minors come in',
#  'never',
#  'padua girls  one tall decent body the other one kinda short and undersexed',
#  'you the new guy',
#  'so they tell me',
#  'so  which dakota you from',
#  'north actually  how would you   ',
#  'i was kidding people actually live there',
#  'yeah  a couple  we are outnumbered by the cows though',
#  'how many people were in your old school',
#  'thirtytwo',
#  'get out!',
#  'how many people go here',
#  'that i am used to',
#  'that girl  i ',
#  'you burn you pine you perish',
#  'who is she',
#  "bianca stratford  sophomore don't even think about it",
#  'why not',
#  'why do girls like that always like guys like that',
#  'because they are bred to  their mothers liked guys like that and their grandmothers before them their gene pool is rarely diluted',
#  'he always have that shiteating grin',
#  'you know french',
#  "sure do  my mom's from canada",
#  'guess who just signed up for a tutor',
#  'you mean i would get a chance to talk to her',
#  'yeah just a minor encounter with the shrew',
#  "that is her  bianca's sister",
#  'i teach her french get to know her dazzle her with charm and she falls in love with me',
#  'what about him',
#  'what makes you think he will do it',
#  'he seems like he thrives on danger',
#  'no kidding  he is a criminal  i heard he lit a state trooper on fire  he just got out of alcatraz',
#  'they always let felons sit in on honors biology',
#  'i am serious man he is whacked  he sold his own liver on the black market so he could buy new speakers',
#  'forget his reputation  do you think we have got a plan or not',
#  'did she actually say she would go out with you',
#  'you know if you do go out with bianca you would be set  you would outrank everyone strictly alist  with me by your side',
#  'i thought you hated those people',
#  'you got him involved',
#  'this is it  a golden opportunity patrick can ask katarina to the party',
#  'in that case we will need to make it a schoolwide blow out',
#  'will bogey get bent',
#  'number one  she hates smokers',
#  "it's a lung cancer issue",
#  'her favorite uncle',
#  'he is pretty!',
#  'assail your ears for one night',
#  'you told me that part already',
#  'extremely unfortunate maneuver',
#  "the hell is that  what kind of 'guy just picks up a girl and carries her away while you are talking to her",
#  'buttholus extremus  but hey you are making progress',
#  'you humiliated the woman! sacrifice yourself on the altar of dignity and even the score',
#  'and he means that strictly in a non prisonmovie type of way',
#  'what have you got for me',
#  'okay  likes  thai food feminist prose and angry stinky girl music of the indierock persuasion',
#  'gigglepuss is playing there tomorrow night',
#  'cameron i am a little busy',
#  'what  are you talking about',
#  'cameron  do you like the girl',
#  'sure',
#  'what would you do to her',
#  'she hates you with the fire of a thousand suns   that is a direct quote',
#  "you makin' any headway",
#  'she kissed me',
#  'what is the worst',
#  "the vintage look is over kat haven't you been reading your sassy",
#  'yeah and i noticed the only part of you featured in your big kmart spread was your elbow  tough break',
#  'hey  do you mind',
#  'where ya goin',
#  'away',
#  'leave my sister alone',
#  'yeah',
#  'two legs nice rack',
#  'yeah whatever  i want you to go out with her',
#  'sure sparky  i will get right on it',
#  'you just said',
#  'you need money to take a girl out',
#  'you got it verona  i pick up the tab you do the honors',
#  'you are gonna pay me to take out some girl',
#  "i cannot date her sister until that one gets a boyfriend  and that is the catch she doesn't want a boyfriend",
#  'i cannot take a girl like that out on twenty bucks',
#  "take it or leave it  this isn't a negotiation",
#  'when i shell out fifty i expect results',
#  'i am on it',
#  "watching the bitch trash my car doesn't count as a date",
#  'i just upped my price',
#  'what',
#  'a hundred bucks a date',
#  'forget it',
#  "it's about time",
#  'how would you do it',
#  'do what',
#  "i don't know dorsey the limothe flowers  another hundred for the tux ",
#  'hey',
#  'are you lost',
#  'nope  just came by to chat',
#  "we don't chat",
#  'well actually i thought i would run an idea by you  you know just to see if you are interested',
#  'but she cannot go out with you because her sister is this insane head case and no one will go out with her right',
#  'does this conversation have a purpose',
#  "i hear you are helpin' verona",
#  'uh  yeah  we are old friend*',
#  'you and verona',
#  'you better not fuck this up  i am heavily invested',
#  "who's that",
#  'patrick verona   random skid',
#  'that is pat verona the one who was gone for a year i heard he was doing porn movies',
#  'i am sure he is completely incapable of doing anything that interesting',
#  'he always look so',
#  'mandella eat  starving yourself is a very slow way to die',
#  'what is this',
#  'i realize that the men of this fine institution are severely lacking but killing yourself so you can be with william shakespeare is beyond the scope of normal teenage obsessions  you are venturing far past daytime talk show fodder and entering the world of those who need very expensive therapy',
#  'the people at this school are so incredibly foul',
#  'so he has this huge raging fit about sarah lawrence and insists that i go to his maledominated puking frat boy number one golf team school i have no say at all',
#  'william would never have gone to a state school',
#  "william didn't even go to high school",
#  'that is never been proven',
#  'i appreciate your efforts toward a speedy death but i am consuming  do you mind',
#  'does it matter',
#  'you think this will work',
#  'what would he say',
#  'you went to the party  i thought we were officially opposed to suburban social activity',
#  "i didn't have a choice",
#  "you didn't have a choice  where is kat and what have you done with her",
#  'i did bianca a favor and it backfired',
#  "you didn't",
#  'can you even imagine  who the hell would go to this a bastion of commercial excess',
#  "well i guess we are not since we don't have dates ",
#  'listen to you!  you sound like betty all pissed off because archie is taking veronica',
#  "okay okay we will not go  it's not like i have a dress anyway",
#  "you ' re looking at this from the wrong perspective  we are making a statement",
#  'have you seen him',
#  'who',
#  'william  he asked me to meet him here',
#  "i mean woman  how ya doin'",
#  'sweating like a pig actually  and yourself',
#  "there's a way to get a guy's attention",
#  'pick you up friday then',
#  'the night i take you to places you have never been before  and back',
#  'like where  the 7eleven on burnside do you even know my name screwboy',
#  "you hate me don't you",
#  "i don't really think you warrant that strong an emotion",
#  'then say you will spend dollar night at the track with me',
#  'and why would i do that',
#  'come on  the ponies the flat beer you with money in your eyes me with my hand on your ass',
#  'you  covered in my vomit',
#  'are you following me',
#  'i was in the laundromat i saw your car thought i would say hi',
#  'you are not a big talker are you',
#  'hey  great show huh',
#  'excuse me',
#  "that is what you want isn't it",
#  'you know these guys are no bikini kill or the raincoats but they are right up there',
#  'you know who the raincoats are',
#  'what is this',
#  "i am getting trashed man isn't that what you are supposed to do at a party",
#  'i say do what you wanna do',
#  'okay',
#  'you are not okay',
#  'i just need to lie down for awhile',
#  'uh uh you lie down and you will go to sleep',
#  'i know just let me sleep',
#  'this is so patronizing',
#  'leave it to you to use big words when you are shitfaced',
#  'why  are you doing this',
#  'i told you',
#  "you don't care if i die",
#  'sure i do',
#  'why',
#  'because then i would have to start taking out girls who like me',
#  'like you could find one',
#  'see that  who needs affection when i have got blind hatred',
#  'why would you let him get to you',
#  'who',
#  'dorsey',
#  'i hate him',
#  "i know  it would have to be a pretty big deal to get you to mainline tequila you don't seem like the type",
#  "hey man    you don ' t think i can be cool  you don't think i can be laid back like everyone else",
#  'i thought you were above all that',
#  'kat! wake up!',
#  'and i am in control of it',
#  'when you were gone last year  where were you',
#  'busy',
#  'were you in jail',
#  'maybe',
#  "no you weren't",
#  'then why would you ask',
#  'i should do this',
#  'do what',
#  'start a band',
#  "my father wouldn't approve of that that",
#  'oh so now you think you know me',
#  "so what ' s up with your dad  he a pain in the ass",
#  'he just wants me to be someone i am not',
#  'who',
#  'bianca',
#  'excuse me have you seen the feminine mystique  i lost my copy',
#  'what are you doing here',
#  'i heard there was a poetry reading',
#  'you  are so ',
#  'wholesome',
#  'unwelcome',
#  'unwelcome  i guess someone still has her panties in a twist',
#  "don't for one minute think that you had any effect whatsoever on my panties",
#  'so what did i have an effect on ',
#  'he left!  i sprung the dickhead and he cruised on me',
#  'i guess i never told you i am afraid of heights',
#  "c'mon  it's not that bad",
#  'put your right foot there ',
#  "forget it  i am stayin'",
#  'you want me to climb up and show you how to get down',
#  'the partridge family',
#  'i figured it had to be something ridiculous to win your respect  and piss you off',
#  'good call',
#  'so how would you get chapin to look the other way',
#  'a soft side who knew',
#  "yeah well don't let it get out",
#  'so what is your excuse',
#  'acting the way we do',
#  'yes',
#  "i don't like to do what people expect then they expect it all the time and they get disappointed when you change",
#  'so if you disappoint them from the start you are covered',
#  'something like that',
#  'then you screwed up',
#  'how',
#  'you up for it',
#  'state trooper',
#  'fallacy',
#  'the duck',
#  'hearsay',
#  'tell me something true',
#  'i hate peas',
#  'no  something real  something no one else knows',
#  'you are sweet  and sexy  and completely hot for me',
#  'what',
#  'no one else knows',
#  'you are amazingly selfassured has anyone ever told you that',
#  'is that a request or a command',
#  'you know what i mean',
#  'no',
#  'no what',
#  'no i will not go with you',
#  'why not',
#  'create a little drama  start a new rumor  what',
#  'so i have to have a motive to be with you',
#  'you tell me',
#  'you need therapy  has anyone ever told you that',
#  'answer the question patrick',
#  'how would you get a tux at the last minute',
#  "it's scurvy's  his date got convicted where would you get the dress",
#  "it's just something i had  you know",
#  'oh huh',
#  "my grandmother's ",
#  'what',
#  "that ' s completely adorable!",
#  'wait i',
#  'you were paid to take me out!  by  the one person i truly hate  i knew it was a setup!',
#  "it wasn't like that",
#  'really  what was it like  a down payment now then a bonus for sleeping with me',
#  'a fender strat you bought this',
#  'besides i had some extra cash some asshole paid me to take out a really great girl',
#  'is that right',
#  'why is my veggie burger the only burnt object on this grill',
#  'because i like to torture you',
#  'oh bianca  can you get me my freshman yearbook',
#  'i know',
#  'i thought we decided you were going to school here  at u of 0',
#  'this from someone whose diary is devoted to favorite grooming tips',
#  'my insurance does not cover pms',
#  'then tell them i had a seizure',
#  'is this about sarah lawrence you punishing me',
#  'i thought you were punishing me',
#  'why cannot we agree on this',
#  'because you are making decisions for me',
#  'as a parent that is my right',
#  "so what i want doesn't matter",
#  "you are eighteen  you don't know what you want  you will not know until you are fortyfive and you don't have it",
#  'was that your sister',
#  'yeah  she left with some bikers big ones  full of sperm',
#  "i don't understand the allure of dehydrated food  is this something i should be hip to",
#  'no daddy',
#  'so tell me about this dance was it fun',
#  'parts of it',
#  'which parts',
#  'the part where bianca beat the hell out of some guy',
#  'bianca did what',
#  'what is the matter  upset that i rubbed off on her',
#  "you know fathers don't like to admit that their daughters are capable of running their own lives  it means we have become spectators  bianca still lets me play a few innings  you have had me on the bleachers for years  when you go to sarah lawrence i will not even be able to watch the game",
#  'when i go',
#  'katarina stratford  my my  you have been terrorizing ms blaise again',
#  'expressing my opinion is not a terrorist action',
#  "well yes compared to your other choices of expression this year today's events are quite mild  by the way bobby rictor's gonad retrieval operation went quite well in case you are interested",
#  'i still maintain that he kicked himself in the balls  i was merely a spectator',
#  'tempestuous',
#  'am i supposed to feel better like right now  or do i have some time to think about it',
#  'hey there  tired of breathing',
#  'hi',
#  'cool pictures  you a fan',
#  'you think',
#  'macbeth right',
#  'right',
#  'kat a fan too',
#  'say it',
#  'what',
#  'what plan',
#  'the situation is my man cameron here has a major jones for bianca stratford',
#  "i think i speak correctly when i say that cameron's love is pure  purer than say  joey dorsey's",
#  'that is where we can help you  with kat',
#  'so dorsey can get the girl',
#  'you two are gonna help me tame the wild beast',
#  'what!',
#  'are you telling me i am a   nonsmoker',
#  'ever been to club skunk',
#  'i prefer to think of it simply as an alternative to what the law allows',
#  'so you got cozy with she who stings',
#  'you were right she is still pissed',
#  'sweet love renew thy force!',
#  'i missed you',
#  'it says here you exposed yourself to a group of freshmen girls',
#  'it was a bratwurst  i was eating lunch',
#  "i don't understand patrick  you haven't done anything asinine this week are you not feeling well",
#  'touch of the flu',
#  "why don't we discuss your driving need to be a hemorrhoid",
#  'what is to discuss',
#  "you weren't abused you aren't stupid and as far as i can tell you are only slightly psychotic  so why is it that you are such a fuckup",
#  'you are completely demented',
#  'in the microwave',
#  'what is a synonym for throbbing',
#  'jesus!  can a man even grab a sandwich before you women start dilating',
#  'tumescent!',
#  'would you rather be ravished by a pirate or a british rear admiral',
#  'they will dance they will kiss they will come home  let her go',
#  'what do you wanna watch  we have got crap crap crap or crap',
#  'have a great time honey!',
#  'what just happened',
#  'your daughters went to the prom',
#  'did i have anything to say about it',
#  'absolutely not',
#  'i never seen heat like this!  not even in las minas!',
#  "the water's going putrid in the barrels",
#  'what are you listening to chicken ass',
#  'ah leave him alone  he is doing no harm',
#  "he is the devil's child",
#  'we should have seen land',
#  'we left three weeks ago alonso cannot be that near',
#  'you say asia can be found by sailing west',
#  'yes your eminence  the voyage should not take more than six or seven weeks',
#  'unfortunately don colon that is precisely where our opinions differ  are you familiar with the work of aristotle  erathostene  ptolemeus',
#  'i am your eminence',
#  'senor colon an experienced captain such as yourself will understand our concern with the crew  i am not willing to have on my conscience the loss of men who would have relied upon our judgment',
#  'your eminence there is only one way to settle the matter  and that is to make the journey  i am ready to risk my life to prove it possible',
#  'your life and that of others!',
#  'trade your excellency  according to marco polo the kingdom of china is one of the richest of the world even the meanest buildings are roofed with gold',
#  'is that all that interests you gold',
#  'if god intended our proximity to asia do you believe he would have waited for you to show it to the world',
#  "don't you realize your words could be considered heretical",
#  'asia can be found to the west  and i will prove it',
#  "the state has some reason to be interested in this man's proposition your eminence",
#  'the judgment is ours!',
#  'he is a mercenary!  did he not already try to convince the king of portugal of his absurd notions',
#  'it will not be easy to get rid of your prophet now don sanchez',
#  'you can see for yourself',
#  'what a tragedy what a waste of a life',
#  'i could be gone for years',
#  'i know',
#  "i haven't given you much of a life",
#  "well that is true  i have a child by a man who will not marry me!  who's always leaving",
#  'are we going to argue',
#  'perhaps i was never meant to live with a woman',
#  'she said yes',
#  'i am not asking you to swear to anything',
#  "i don't want you to wait for me",
#  'beatrix i want to ask you something',
#  "you don't usually ask",
#  'god you are so beautiful!  i cannot believe no other man has ever taken you away from me',
#  'they took everything',
#  'cannot you stay with us a little',
#  'what is it now  tell me',
#  'i understand that you will soon be appointing governors for the islands  is it not so',
#  'forgive me don bobadilla  those positions have already been taken',
#  'may i ask by whom',
#  'don alonso de bobadilla',
#  'my letters of appointment',
#  'appointment to what',
#  'viceroy of the west indies',
#  'how far from here',
#  'i am not a seaman  but i heard it is no more than a week at sea  i hope you are not too disappointed',
#  'how could i be  the mainland has been found  exactly as i said it would',
#  'i want to go with you!',
#  'there will be a time',
#  'do you swear on all the holy saints in heaven',
#  'i have to explore the mainland',
#  'how are you feeling fernando',
#  'father',
#  'what are you listening to',
#  'what does he say',
#  'he asks when he can come to visit you  he left his address',
#  'i want you to tell me everything you remember father  from the beginning  everything',
#  "really  god i wouldn't know where to start and yet",
#  'no',
#  'no',
#  'i remind you senor colon that you are in no position to bargain with me',
#  'i am not bargaining!',
#  'and were you never ambitious excellency  or is ambition only a virtue among the nobles a fault for the rest of us',
#  "they don't see sin in their nakedness  they live according to nature in a never ending summer the islands are covered with trees filled with blossoms and fruits and",
#  'you defend yourself admirably',
#  'but we do have a lack of notaries you should contact my administration',
#  'don bobadilla is already a judge my dear don cristobal',
#  'you seem to have a special talent for making friends',
#  'what  do i have so many already',
#  'all i have to do is call the guards',
#  'i am not afraid of you  you are nothing but a dreamer',
#  'what do you see',
#  'roofs towers palaces spires',
#  'say not here!  cuba!',
#  'what is it  a tribe  an island',
#  'you come!  you speak first!',
#  'tell the chief we thank him',
#  'chief knows',
#  'chief says  how many',
#  'thousands',
#  'to bring the word of god',
#  'chief says  he has a god',
#  ' and also to bring medicine',
#  'chief says',
#  'we will work with his people  we want peace  ask the chief if he understands',
#  'he understands',
#  'you have to find them utapan  look what they did!',
#  'utapan will not you speak to me  you used to know how to speak to me',
#  'diego is a bright boy  a pleasure to teach  but so serious brothers should be raised together colon  even brothers from different mothers',
#  'god that is in a week!',
#  'that is what it says',
#  'how did you manage it',
#  'why do you wish to sail west',
#  'how can you be so certain  the ocean is said to be infinite',
#  'ignorance!  i believe the indies are no more than 750 leagues west of the canary islands',
#  'how can you be so certain',
#  'the calculations of toscanelli marin de tyr esdras',
#  'esdras is a jew',
#  "two minutes and already you are a dead man  don't let passion overwhelm you colon",
#  'i will try to remember that marchena',
#  'father marchena!',
#  'passion is something one cannot control!',
#  'you get so carried away when you are being contradicted!',
#  'i have been contradicted all my life eternity!',
#  "you mustn't give way to despair you must wait",
#  'wait!  i have waited seven years already!  how much longer do you want me to wait',
#  'if god intends you to go then you will go',
#  'colon!',
#  'all of them!  just lies!',
#  'in nomine patris et filius et spiritus sancti',
#  'i am listening my son',
#  'father i have betrayed my family i betrayed my men  and i betrayed you',
#  'what are you saying',
#  'i lied  the journey will be longer than i said',
#  'how long',
#  'may god forgive you!  you must tell them!  you must tell your men!',
#  'if i tell them they will not follow me  you know that i am right father  you trust me',
#  "my son my son  your certitudes are sometimes frightening  christopher you must speak to them and if you don't i will",
#  'i believed in you',
#  'i suppose we are both old men now',
#  'i have to disagree',
#  'i knew you would',
#  'new worlds create new people',
#  'oh  so you are a new man',
#  'i should not even be listening to you since my council said no  but santangel tells me you are a man of honor and sincerity and sanchez that you are not a fool',
#  'the ocean is uncrossable',
#  'what did they say about granada before today',
#  'i cannot ignore the verdict of my council',
#  'may i speak freely',
#  'you show no inclination to speak otherwise!',
#  "i know what i see  i see someone who doesn't accept the world as it is  who's not afraid  i see a women who thinks what if",
#  'how old are you senor colon',
#  'do they have such thoughts',
#  'but without your brothers  nor are you to return to santo domingo or any of the other colonies  you may explore the continent',
#  'thank you',
#  'there is one thing i would like to understand why do you want to go back after all this',
#  "and you say this is an indian vice by god!  i don't see any kind of pleasure that would make this a sin",
#  'we lost cousins friends  we will wash this in blood',
#  'you want a war  fine  we are a thousand  they outnumber us by ten! who will you kill  which tribe',
#  "we don't need to know",
#  'we cannot raise the wheel without it',
#  'don moxica  we all have to work',
#  'in one act of brutality you have created chaos  tribes who were fighting each other are now joining forces against us!  all that because of your criminal savagery!',
#  'savagery is what monkeys understand',
#  'you will be held in detention deprived of your privileges and possessions  until you are returned to spain where you will be judged have you anything to say',
#  'due west captain mendez  and may god be with us',
#  "well it's the men sir  they wonder how you know our position we have lost sight from land days ago",
#  'and what do you think mendez',
#  'well i surely know what a quadrant is!  but i have never seen it used at night before',
#  'what do you read',
#  'what is he doing',
#  'he is drawing an isthmus he is saying we are on an isthmus',
#  'where can i meet this man',
#  'you lied!  you cheated!  we are way past 750 leagues!',
#  'six days ago yes',
#  'you must be mad!',
#  'we have to keep the hopes of these men alive!',
#  'we are on the verge of a mutiny colon!',
#  "you think i don't know that",
#  'we are lost!',
#  'the land is there  i know it!',
#  "you don't know anything!  listen colon these are my ships right so i am telling you we are turning back!",
#  'and then what  half of the water has gone the rest is nearly putrid! you know that!',
#  'jesus maria!  i should have never listened to you!',
#  'you never did  you did all the talking for both of us remember',
#  'you bloody',
#  'pinzon pinzon all we can do now is go forward!  think about that!',
#  'you tell that to them!',
#  'is that the man i knew treasurer sanchez',
#  'you were right don sanchez his demands could never be granted',
#  ' into a monk',
#  'every ship returns with a cargo of sick and dying  but with no gold! the new world proves expensive your majesty',
#  ' but there is worse  he ordered the execution of five members of the nobility',
#  'then what do you suggest don sanchez',
#  'he must be replaced',
#  'i know i should not tolerate his impertinence',
#  'then why',
#  'are you my attorney  i am emil  i am insane',
#  'i am not your lawyer until i see the money',
#  'oh no!  no!  shit!',
#  'emil  take it easy  stay with me  sit down  what do you need  what are you looking for',
#  "don't say anything",
#  'where are we going',
#  'i am coming with you',
#  'yes  yes come with me!',
#  "i brought you some letters  it's really fan mail  women mostly  one wants to buy you clothes another sent a check another wants a check",
#  'you bring the cigarettes',
#  'delusions and paranoia',
#  'i was all of these',
#  "well you didn't appreciate the severity of it until recently  no question about that",
#  'what about oleg',
#  'disappeared  they are looking everywhere  maybe he went back to czechoslovakia',
#  'no he is here  shit',
#  "don't worry about him  think about yourself",
#  'what about my movie rights  book rights',
#  "look i haven't really focused on that kind of thing",
#  'what is your cut  how much',
#  'i would sayhalf  half is fair',
#  'no  no way',
#  "but it's",
#  "thirtypercent  no more  or i call another lawyer  this is the biggest case of your life  don't try to negotiate  thirty percent  say yes or no",
#  'this is not about money emil  i need your trust in me',
#  'what else do you need',
#  'i need to know about your background  i need to know about your upbringing  why you are here',
#  'tell me about yourself  what you did as a young boy what your parents were like',
#  'my father always degraded me  killed my selfesteem  and my mother was blind',
#  'your mother was blind',
#  'yeah she went blind giving birth to me she went to fucking black market doctor to induce me',
#  'back in the czech republic',
#  'yeah yeahbad doctor gave her bad drugs which made her go blind  and my father blamed me for her blindness',
#  "your father blamed you for your mother's blindness",
#  'that is what he did to me  he put cigarettes out on me',
#  'your father put cigarettes out on you',
#  'out on my back when i was a small boy',
#  "i am abused  don't you think",
#  'so we kill someone famous and if we are caught we are sent to mental hospital',
#  'my little sister and i shared a flat  i came home one night and a man was raping her  his gun was on the chair he came at me and i shot him',
#  'alright  that is a justifiable homicide',
#  'now i become custody of police department',
#  'if you cooperate with the da  maybe they will help you with your situation',
#  "i will if they don't send me back",
#  'are you married',
#  'divorced',
#  'i cannot take you to my place',
#  'the men are out of quarters  practicing putting out fires',
#  'sothe station is empty',
#  'you considered becoming a prostitute',
#  'yes i considered it',
#  'did you ever turn tricks before',
#  'no',
#  'what about back home',
#  "i came here  i had no money  i knew no one  i couldn't get a job because you have to have a green card to get work they approached me  i could have made a lot of money  i considered it but it's not who i am  they pay me below the table at ludwig's",
#  'so you were never a prostitute',
#  'what are you asking me',
#  'i am not a whore  i am not a whore',
#  'i know',
#  "you don't know  i am sorry  i was desperate  that is not me  i shot a cop  can you imagine what they will do to me when i got to prison",
#  'they are not gonna send you right back',
#  'are you alright',
#  "i still cannot believe eddie's gone",
#  'is he your boyfriend',
#  'ludwig  he is gay  are you jealous',
#  'if i was your boyfriend i might be',
#  'a good immigration lawyer could stall the process  eddie recommended one',
#  'no matter what happensi am glad i met you',
#  'you better get packed',
#  'do you have coffee',
#  'in the kitchen',
#  'i will make some for us',
#  'what are you doing',
#  'forget about me  you have enough problems of your own',
#  'do you really want me to forget about you',
#  "i don't want to drag you down with me",
#  "i told your partner i cannot help  i didn't see anything",
#  "c'mon start at the beginning  you know these people",
#  'tamina was a friend of mine  my shower was broken she let me use theirs',
#  'whether you tell us or not we will find out  better if it comes from you',
#  'if i tell you will you arrest me',
#  "are you here illegally  don't worry about that  we will talk to immigration they will not deport you",
#  'a cop',
#  'i am from a small town in slovakia  like the south here  the police is right a civilian is wrong  so i fled',
#  'look we can help you but right now we have to deal with what is happening here tell us the truthis that the truth',
#  'oh',
#  'it was my decision not his',
#  'well i am the deputy chief fire marshall and every now and then i would like to be included in decisions',
#  'look after jordy briefs me you can do the press conference  how about that the case is all yours',
#  'oh yeah  alright',
#  'i am ready to be briefed  excuse us',
#  'who did cause and origin',
#  'who do you think chief!',
#  "then why didn't you talk to the reporter",
#  'hey chief what are you doing here',
#  'ladder 20 was on the rock for training we stopped there so she could get cleaned up',
#  "what do you mean 'cleaned up'",
#  'i let her take a shower',
#  'a shower!  did you take one too',
#  'no!  nothing happened',
#  'chief  mind if i take her',
#  "the public doesn't have any idea what we do and now you are going to define our image!  this is going to be our rodney king!",
#  'what was i supposed to do  the guy tried to mug me  i was gonna send a cop back  i just forgot',
#  'forgot  you handcuffed a civilian to a tree!',
#  'chief  i know i screwed up  but this guy was no innocent civilian',
#  'well this is gonna end your career and probably mine',
#  'end my career',
#  "how are you going to fight this  maybe if oleg hadn't gotten away and you would been on the front page as a hero this thing would be easier to fight  you would have the good to weight against the bad! it's unfortunate that i have to make decisions based upon your press coverage but there's nothing i can do!  gimme your shield",
#  'but chief  over this',
#  "don't you guys understand  it's all about image  the better we look the more money i get to pay you guys overtime",
#  'yeah right',
#  'what was that korfin',
#  "i said yeah you are right chief  as soon as we get somethin' we will let you alert the media",
#  'did the da videotape her deposition',
#  'yeah  he finished awhile ago',
#  'alright  swing by her apartment  let her pick up her clothes and take her straight to hoover street  you got that',
#  'coffee for me i gotta slow down',
#  'vodka tonic',
#  'it was freaky i will tell you  stupid kid',
#  'i am gonna propose',
#  'when',
#  'tomorrow  at lunch',
#  'what is he looking for',
#  'where is she',
#  "takin' a bath",
#  'any id',
#  'sorrypd only',
#  'only one guys checked in',
#  'yeah',
#  "the other side of the street  the guy with the videocamera  don't look  put her in the car  stay this side",
#  'are you hit',
#  'he got my gun!  motherfucker was filming the whole time!',
#  "who's there",
#  'police  we would like to ask you a few questions',
#  "i have nothin' to say  if you wanna contact my attorney",
#  'what is wrong',
#  "we don't have her id yet but one of your girls was killed last night at the king edward hotel",
#  "yeah  he wanted a girl from czechoslovakia but i sent him honey 'cause once they get there you know it doesn't really matter  honey was killed  poor girl",
#  'do you have any czech girls working for you',
#  'no',
#  'boy she is so popular all the sudden',
#  'what are you saying',
#  'he said he was her cousin  i told him where she works  they were just here',
#  'describe him',
#  "tall shorthaired scary eyes  second guy with him wasshorter with a wrestler's build  and he wouldn't turn his videocamera off me",
#  'he had a videocamera  where is she quickly!',
#  "hey that is great you guys got it all wrapped up but you don't mind if we go through the routine  it gives us somethin' to do",
#  'you know what that is right',
#  'no what is it',
#  "it's your crime scene now  you can do what you want",
#  'watch the news',
#  'nah i musta missed it',
#  'well just so you know  i gave you guys the credit',
#  "well just so you know i don't care about that stuff",
#  'nah why should you',
#  "i don't even watch tv",
#  'did you get a report from the me',
#  'sure  but i would like to ask you something  you got a problem with me',
#  "if you found me steppin' on your crime scene  it might piss you off too  what about the report",
#  "the super said he would seen her before but she didn't live here",
#  'pretty',
#  'hmmmm',
#  "maybe you don't care about that either  prettiest suspect i have had in awhile",
#  'what would you call her',
#  "maybe it's a ritual thing or someone trying to send a message  burial rites are taken very seriously in eastern europe  it could be to humiliate them just burning them up no proper funeral it's like condemning them to hell",
#  'eastern europe  like what  romania hungary',
#  'i will come with you',
#  "there wasn't a fire  there will be nothing for you to do",
#  'i can watch you eddie  maybe i will learn something',
#  "this isn't homicide school",
#  'my parents are from poland  i can help with the eastern european angle',
#  'you are polish',
#  'my folks are',
#  "you goin' to the escort service",
#  'you got any better ideas',
#  'mind if i ride along with you',
#  'this has nothing to do with your fire',
#  'i will let you know what happens',
#  'this is ridiculous  i am not gonna be in your way  we can talk the case over',
#  "tell you what  i will flip you a coin if you win you can come with me  if you don't win you don't come",
#  'two heads',
#  "leon  meet us at 63rd and madison hair salon  ludwig's",
#  'you thirsty',
#  'i am on duty',
#  'so am i  alright i will go inside and you cover the back',
#  'of course',
#  "hey!  i always wanted to be a cop when i was a kid  i dreamed of running up to a door kicking it in pulling my gun and yelling 'freeze!' at the bad guy! what would you dream about",
#  'i wanted to run up to a building on fire kick in the door rush into the smoke and save a kid',
#  'what are you hiding  why are you afraid',
#  'she just saw two of her friends killed! they probably threatened her',
#  'why not',
#  'she is fucked  even if that story is true',
#  'look  let me talk to her  any leads i get they are all yours  just let me have a first crack at her',
#  'you wanna talk to her alone',
#  'yeah',
#  'what would your girlfriend think of that',
#  "i don't have a girlfriend",
#  'my point exactly',
#  'i am serious here',
#  'so am i',
#  "c'mon  you intimidate her 'cause you are a celebrity  she sees me differently",
#  'you are her savior  is she the kid you are gonna save from the burning building',
#  "okay tell you what i will give you a head start  you take her to the station house  don't let her out of your sight she is the only warm body we got left",
#  'hey  i am a professional',
#  "look eddie i am tellin' you  i didn't touch her",
#  "well you shoulda because nobody's gonna believe you didn'tincluding me",
#  'i took her there for a shower and that is it',
#  'yeah just her in the shower  nothing happened  look i am sure you probably think i am a fool and i fucked up but',
#  "no i don't think you were a fool i just think you were stupid about it  i mean to say the least you outta know better  you don't know her well enough she is got the potential to fucking hang you even if she suggests that you made a pass at her it's fuckin' over  you can deny it all you want but it will not make one fucking bit of difference you are dead",
#  'i told you you know i thought i was doing the right thing you know i think she is innocent',
#  "well it's not up to you to decide whether she is innocent or not  don't you understand that is why you are a professional",
#  "but i mean didn't you ever go out on a limb for somebody  i mean you shoulda heard her there  tellin' her whole storyi believed her",
#  'why would you help me back there with the chief  why would you stand up for me like that',
#  "sowho's nicky",
#  'what do you want',
#  'your opinion  you see they going to make a movie about me too eddie  and write books',
#  'what is your accomplishment',
#  'i kill someone famous',
#  'then do it asshole',
#  "so tabloids don't have to do re enactments  they going to have real movie this time",
#  "you really think you will be able to fool a jury with this bullshit  how fuckin' stupid are you",
#  'detective does it look like a murder',
#  "we don't know that yet  it's much too early  there's a lot to be done",
#  'how many victims are up there',
#  'there are two bodies found at this point',
#  'can we go up to the crime scene',
#  "you know you cannot do that  c'mon",
#  'is it drug related',
#  'detective  can you tell us what happened here',
#  'i understand but i noticed that the fire marshall is here with you  is this somehow related to the fire department',
#  'i really cannot give out any information right now at this point',
#  "okay  but i do understand that your partner leon jackson's been injured is that correct",
#  'he was hurt but not seriously  he will be fine',
#  'do you have the suspect in custody',
#  "umnow is not a good time okay detective jackson's hurt  he is fine i have got a fire marshall shot detective jackson is hurt but not seriously",
#  'eddie are you okay',
#  "yeah  now's not a good time",
#  'alright',
#  'alright',
#  'alright',
#  'alright',
#  'hey honey',
#  'what is your problem  why would you snap at me  i just wanted a statement',
#  'i cannoti cannot answer you just because you want me to answer you!',
#  "you didn't have to embarrass me in front of my colleagues  you could give me something",
#  'oh i am sorry  did i embarrass you sweetheart  oh',
#  'stop it',
#  'maybe i should just ya knowturn to the cameras and say do you mind if we just work something out',
#  "alright alright eddie  don't patronize me",
#  'i am not',
#  "yes you are  i am not just some reporter  i don't just stick a microphone in your face  you could give me something",
#  'yeah well you took the camera and put it right down on the evidence  that was',
#  'that was good  you were holding the evidence',
#  "you were merciless  you didn't give a shit if you got me or not",
#  'well who was it that taught me how to do that  huh',
#  'you are ruthless',
#  'look at this  you have blood on your shirt  whose is it',
#  "could be leon's",
#  "don't worry about the damn phone  i will not answer it",
#  'answer the phone',
#  'no  tell me what you want to say',
#  'answer it',
#  'oh my gd they want me to anchor  they want me to anchor tonight!',
#  'that is good',
#  'yeah',
#  'well that is great',
#  'okay  that is great  but i cannot go now we are in the middle of something here',
#  'no  go ahead  you are gonna be great',
#  'no  no listen to me here  i want to know what you are talking about  you know the shoe thing and the marriages and',
#  "i will tell you tonight  let's do it tonight  as soon as you get back we will talk  we will talk",
#  'promise',
#  'i promise  we will talk  you will be great  you will be fine  go ahead just imagine that uh just look into the lens and imagine you are talking to me',
#  'yeah  i will do that  as long as you are not patronizing me',
#  'patronizing you nay i love you',
#  'okay til tonight',
#  'tonight',
#  'you promise',
#  'yeah  i promise',
#  "okay  and you know what i will swing by my place grab a couple pairs of shoes and maybe just test them out next to yourshow's that would that be a good thing",
#  'yeah yeah  good thing',
#  'okay',
#  'see you later  good luck',
#  'thank you',
#  "so we are waitin' to hit this warrant  we got emergency service with the heavy weapons standin' by  ready to go  i say lemme get a cigar outta the car  i go to get the cigar and boom!  all the sudden i turn around and a kid with a shotgun let one go  right where i was standin'  that coulda been it  i coulda had my head blown off and for what  some stupid kid got panicky takes the safety off and it's over  if i hadn't gone back for that cigar  for a bad habit  i would have had my head blown off",
#  'sooner or later that is everybody',
#  'not chopped up  not chopped up like that  i mean what do i got left coupla articles  a medal or two plaque here and there and in a coupla years no one remembers me anymore',
#  'i think you are getting a little moody there eddie',
#  'how old are your kids',
#  'so what is unique',
#  'he is from antigua  his girlfriend was taking too long to put her makeup on they were late for a party  stabbed her with a beer bottle',
#  'that is unique',
#  "i hope this prick doesn't run  my knees are killing me  stay behind me",
#  'ready',
#  'keep them out of my way',
#  'okay  you ready',
#  'any chance we can do that again',
#  'okay  you work in a vodka factory  i understand that  and what kind of work do you do',
#  'i am butcher',
#  'you are a butcher  what do you use pig intestines for',
#  'you stuff sausage in it',
#  'and what do you do with the bones',
#  'are you married',
#  "come to 45 broadway  don't bring the police  come alone or you will be in my next film",
#  'look asshole  i have been threatened by better than you',
#  'no  i am the best that is ever threatened you',
#  'i will meet you on one condition  i get exclusivity and you surrender to me',
#  "we will talk about that  four o'clock gives you time to go to bank  three hundred thousand dollars",
#  "what  it doesn't work that way",
#  "if you don't want my film  i will call another show  and they will show it",
#  'wait a minute  wait a minute',
#  'were you a fireman  that how you knew how to rig the apartment',
#  "my father was  he gave me many lessons about fire  now it's my friend",
#  'you cannot kill me  you are not a cop just fireman with a gun  i bet you never shot anybody in your life',
#  "c'mon  pull the trigger  do it  oh look you are sweating  you don't have the balls",
#  'where is your partner',
#  'tell him to put his gun down!',
#  'let her go!  let her go!!',
#  'hi i am honey',
#  'where is czech girl',
#  "now i like to get business out of the way before we get down to pleasure  why don'tchya put my money on the dresser",
#  "it's an outcall service run out of an apartment  i don't meet the other girls  aren't you gonna get undressed",
#  'where is escort service',
#  'that is confidential  could you put the money on the dresser',
#  'i like to talk to the person who runs the service  can you give me address',
#  "listen to me  i don't want sex  just give me the address and then you go",
#  'give me the address!!',
#  'next  could i see your documents please',
#  'what is your intended purpose of your visit to the united states',
#  'two weeks holiday',
#  'how much money are you carrying with you',
#  'i have fivehundred dollars',
#  'is he with you  are you travelling together',
#  'yes',
#  'please join us  come on forward',
#  'is there a problem',
#  'we are both from prague',
#  'how long are you planning to stay',
#  'two weeks',
#  'i would like to speak for himself okay',
#  'who is he',
#  'this all you want',
#  'do you know how much killer gets for movie rights',
#  'in here says he wants a million',
#  'million!  the killer gets one million dollars for a television interview',
#  'hey tabloids paid ted bundy  famous serial killer  half a million for his interview  and how much you think monica got for writing book about the president coming on to her  it pays to be a killer or a whore in this country look you want magazine or not',
#  "just do what i do  say the same thing i say  don't open your mouth",
#  "don't fool around",
#  'did you hear what i said',
#  'look  times square  just like in the movies!',
#  "don't speak russian!",
#  'why  why do i always have to speak to you in czech',
#  'look  new videocameras  color viewfinder  image stabilization solarization  night vision',
#  ...]

# %%
clean_answers
# Out:
# ['well i thought we would start with pronunciation if that is okay with you',
#  'not the hacking and gagging and spitting part  please',
#  "okay then how 'bout we try out some french cuisine  saturday  night",
#  'forget it',
#  'cameron',
#  'the thing is cameron  i am at the mercy of a particularly hideous breed of loser  my sister  i cannot date until she does',
#  'seems like she could get a date easy enough',
#  'unsolved mystery  she used to be really popular when she started high school then it was just like she got sick of it or something',
#  'that is a shame',
#  'let me see what i can do',
#  'right  see  you are ready for the quiz',
#  "i don't want to know how to say that though  i want to know useful things like where the good stores are  how much does champagne cost  stuff like chat  i have never in my life had to point out my head to someone",
#  "that is because it's such a nice one",
#  'forget french',
#  "well there's someone i think might be ",
#  'where',
#  "i counted on you to help my cause you and that thug are obviously failing aren't we ever going on our date",
#  'you are sweet',
#  "eber's deep conditioner every two days and i never ever use a blowdryer without the diffuser attachment",
#  'i really really really wanna go but i cannot  not unless my sister goes',
#  "i am workin' on it but she doesn't seem to be goin' for him",
#  'lesbian  no i found a picture of jared leto in one of her drawers so i am pretty sure she is not harboring samesex tendencies',
#  'so that is the kind of guy she likes pretty ones',
#  'who knows  all i have ever heard her say is that she would dip before dating a guy that smokes',
#  'looks like things worked out tonight huh',
#  'i believe we share an art instructor',
#  'tons',
#  'i was',
#  "you never wanted to go out with 'me did you",
#  'then that is all you had to say',
#  'but',
#  'you always been this selfish',
#  'no',
#  'what crap',
#  'me  this endless blonde babble i am like boring myself',
#  'thank god!  if i had to hear one more story about your coiffure',
#  'what good stuff',
#  'the real you',
#  'like my fear of wearing pastels',
#  'no',
#  'okay  you are gonna need to learn how to lie',
#  "let's go",
#  'i hope so',
#  'they do not!',
#  'no',
#  'you might wanna think about it',
#  'who',
#  'joey',
#  'would you mind getting me a drink cameron',
#  'is he oily or dry',
#  "combination  i don't know  i thought he would be different  more of a gentleman",
#  'sometimes i wonder if the guys we are supposed to want to go out with are the ones we actually want to go out with you know',
#  'all i know is  i would give up my private line to go out with a guy like joey',
#  "i don't have to be home 'til two",
#  'i did',
#  'expensive',
#  'hopefully',
#  'queen harry',
#  "it's a gay cruise line but i will be like wearing a uniform and stuff",
#  'my agent says i have got a good shot at being the prada guy next year',
#  'hi joey',
#  "you are concentrating awfully hard considering it's gym class",
#  "you know the deal  i can ' t go if kat doesn't go ",
#  'nowhere hi daddy',
#  'can you at least start wearing a bra',
#  'it means that gigglepuss is playing at club skunk and we are going',
#  "oh i thought you might have a date  i don't know why i am bothering to ask but are you going to bogey lowenstein's party saturday night",
#  'what do you think',
#  'i think you are a freak  i think you do this to torture me  and i think you suck',
#  'what is normal',
#  "bogey lowenstein's party is normal but you are too busy listening to bitches who need prozac to know that",
#  'at least i am not a clouted fen sucked hedgepig',
#  "it's shakespeare  maybe you have heard of him",
#  "yeah he is your freak friend mandella's boyfriend  i guess since i am not allowed to go out i should obsess over a dead guy too",
#  'can we go now',
#  "i really don't think i need any social advice from you right now",
#  'you are welcome',
#  'like you care',
#  "i do care but i am a firm believer in doing something for your own reasons not someone else ' s ",
#  "i wish i had that luxury i am the only sophomore that got asked to the prom and i cannot go because you won ' t",
#  'what',
#  'in 9th  for a month',
#  'why',
#  'he was like a total babe',
#  'but you hate joey',
#  'now i do  back then was a different story',
#  'as in',
#  'you did what',
#  "just once  afterwards i told him i didn't want to anymore  i wasn't ready he got pissed  then he broke up with me",
#  "after that i swore i would never do anything just because everyone else was doing it  and i haven't since except for bogey's party and my stunning gastrointestinal display ",
#  "why didn't you tell me",
#  'i wanted to let you make up your own mind about him',
#  "no you didn't!  if you really thought i could make my own decisions you would have let me go out with him instead of helping daddy hold me hostage",
#  'i am not stupid enough to repeat your mistakes',
#  'i guess i thought i was protecting you',
#  'god you are just like him! just keep me locked away in the dark so i cannot experience anything for myself',
#  'not all experiences are good bianca you cannot always trust the people you want to',
#  'i guess i will never know will i',
#  'so did you',
#  'you set me up',
#  'i just wanted ',
#  'what to completely damage me  to send me to therapy forever what',
#  'no! i just wanted',
#  "it's just you",
#  'perm',
#  'no! you are not dating until your sister starts dating  end of discussion',
#  'what if she never starts dating',
#  'then neither will you  and i will get to sleep at night',
#  "but it's not fair  she is a mutant daddy!",
#  'exactly my point',
#  'and where are you going',
#  'if you must know we were attempting to go to a small study group of friends',
#  'otherwise known as an orgy',
#  "it's just a party daddy but i knew you would forbid me to go since gloria steinem over there isn't going ",
#  "if kat's not going you are not going",
#  "it's just a party daddy",
#  'daddy no!',
#  'just for a minute',
#  'why',
#  'because she will scare them away',
#  'the prom  kat has a date',
#  'no but',
#  "it's that hot rod joey right that ' s who you want me to bend my rules for",
#  'he is not a hot rod  whatever that is',
#  'you are not going unless your sister goes  end of story',
#  'fine  i see that i am a prisoner in my own house  i am not a daughter i am a possession!',
#  "i have a date daddy  and he ' s not a captain of oppression like some men we know",
#  "didn't have you pegged for a gigglepuss fan  aren't they a little too preteen bellybutton ring for you",
#  'fan of a fan  you see a couple of minors come in',
#  'never',
#  'padua girls  one tall decent body the other one kinda short and undersexed',
#  "just sent 'em through",
#  'so they tell me',
#  "c'mon  i am supposed to give you the tour",
#  'north actually  how would you   ',
#  'i was kidding people actually live there',
#  'yeah  a couple  we are outnumbered by the cows though',
#  'how many people were in your old school',
#  'thirtytwo',
#  'get out!',
#  'how many people go here',
#  'couple thousand most of them evil',
#  'yeah but these guys have never seen a horse  they just jack off to clint eastwood',
#  'you burn you pine you perish',
#  'who is she',
#  "bianca stratford  sophomore don't even think about it",
#  'why not',
#  "i could start with your haircut but it doesn't matter  she is not allowed to date until her older sister does  and that is an impossibility",
#  'because they are bred to  their mothers liked guys like that and their grandmothers before them their gene pool is rarely diluted',
#  'he always have that shiteating grin',
#  'joey dorsey  permashitgrin  i wish i could say he is a moron but he is number twelve in the class  and a model  mostly regional stuff but he is rumored to have a big tube sock ad coming out',
#  "sure do  my mom's from canada",
#  'guess who just signed up for a tutor',
#  'you mean i would get a chance to talk to her',
#  'you could consecrate with her my friend',
#  "that is her  bianca's sister",
#  'the mewling rampalian wretch herself',
#  'unlikely but even so she still cannot go out with you  so what is the point',
#  'you wanna go out with him',
#  'he seems like he thrives on danger',
#  'no kidding  he is a criminal  i heard he lit a state trooper on fire  he just got out of alcatraz',
#  'they always let felons sit in on honors biology',
#  'i am serious man he is whacked  he sold his own liver on the black market so he could buy new speakers',
#  'forget his reputation  do you think we have got a plan or not',
#  'did she actually say she would go out with you',
#  'that is what i just said',
#  'i thought you hated those people',
#  'hey  i have gotta have a few clients when i get to wall street',
#  'like we had a choice  besides  when you let the enemy think he is orchestrating the battle you are in a position of power we let him pretend he is calling the shots and while he is busy setting up the plan you have time to woo bianca',
#  'in that case we will need to make it a schoolwide blow out',
#  'will bogey get bent',
#  'are you kidding  he will piss himself with joy  he is the ultimate kiss ass',
#  "it's a lung cancer issue",
#  'her favorite uncle',
#  'dead at fortyone',
#  "okay!  i wasn't sure",
#  "it's her favorite band",
#  'hell i have just been going over the whole thing in my head and ',
#  "the hell is that  what kind of 'guy just picks up a girl and carries her away while you are talking to her",
#  'buttholus extremus  but hey you are making progress',
#  "no i ' m not",
#  'best case scenario you are back on the payroll for awhile',
#  'yeah  we will see',
#  'i have retrieved certain pieces of information on miss katarina stratford i think you will find helpful',
#  'so what does that give me  i am supposed to buy her some noodles and a book and sit around listening to chicks who cannot play their instruments',
#  "don't make me do it man",
#  "it's off the whole thing",
#  'she is partial to joey not me',
#  'sure',
#  'then go get her',
#  "i don ' t know  i decided not to nail her when she was too drunk to remember it",
#  'she just needs time to cool off i will give it a day',
#  'she kissed me',
#  'where',
#  'you get the girl',
#  'yeah and i noticed the only part of you featured in your big kmart spread was your elbow  tough break',
#  'they are running the rest of me next month',
#  'not at all',
#  'away',
#  'your sister here',
#  'and why would i do that',
#  'what do you think',
#  'yeah whatever  i want you to go out with her',
#  'sure sparky  i will get right on it',
#  'you just said',
#  'you need money to take a girl out',
#  'but you would go out with her if you had the cake',
#  'you are gonna pay me to take out some girl',
#  "i cannot date her sister until that one gets a boyfriend  and that is the catch she doesn't want a boyfriend",
#  'how much',
#  'fine thirty',
#  'fifty and you have got your man',
#  'i am on it',
#  "watching the bitch trash my car doesn't count as a date",
#  'i got her under control she just acts crazed in public to keep up the image',
#  'what',
#  'a hundred bucks a date',
#  'forget it',
#  'forget her sister then',
#  "a deal's a deal",
#  'do what',
#  'get her to act like a human',
#  "enough with the barbie n' ken shit i know",
#  'are you lost',
#  'nope  just came by to chat',
#  "we don't chat",
#  'well actually i thought i would run an idea by you  you know just to see if you are interested',
#  'we are not',
#  'does this conversation have a purpose',
#  "so what you need to do is recruit a guy who will go out with her  someone who's up for the job",
#  'uh  yeah  we are old friend*',
#  'you and verona',
#  'what  we took bathes together when we were kids',
#  "hey  it's all for the higher good right",
#  'patrick verona   random skid',
#  'that is pat verona the one who was gone for a year i heard he was doing porn movies',
#  'i am sure he is completely incapable of doing anything that interesting',
#  'he always look so',
#  'block e',
#  'just a little',
#  'an attempted slit',
#  'but imagine the things he would say during sex',
#  'you could always go with me  i am sure william has some friends',
#  'william would never have gone to a state school',
#  "william didn't even go to high school",
#  'that is never been proven',
#  'neither has his heterosexuality',
#  'does it matter',
#  "if i was bianca it would be any school you want precious  don't forget your tiara",
#  'no fear',
#  'who cares',
#  "i didn't have a choice",
#  "you didn't have a choice  where is kat and what have you done with her",
#  'i did bianca a favor and it backfired',
#  "you didn't",
#  'i got drunk  i puked  i got rejected it was big fun',
#  "well i guess we are not since we don't have dates ",
#  'listen to you!  you sound like betty all pissed off because archie is taking veronica',
#  "okay okay we will not go  it's not like i have a dress anyway",
#  "you ' re looking at this from the wrong perspective  we are making a statement",
#  'oh good  something new and different for us',
#  'who',
#  'william  he asked me to meet him here',
#  "oh honey  tell me we haven't' progressed to fullon hallucinations",
#  'sweating like a pig actually  and yourself',
#  "there's a way to get a guy's attention",
#  'my mission in life',
#  'oh right  friday',
#  'like where  the 7eleven on burnside do you even know my name screwboy',
#  'i know a lot more than that',
#  "i don't really think you warrant that strong an emotion",
#  'then say you will spend dollar night at the track with me',
#  'and why would i do that',
#  'come on  the ponies the flat beer you with money in your eyes me with my hand on your ass',
#  'you  covered in my vomit',
#  'seventhirty',
#  'i was in the laundromat i saw your car thought i would say hi',
#  'hi',
#  "depends on the topic my fenders don't really whip me into a verbal frenzy",
#  '',
#  "that is what you want isn't it",
#  'do you mind  you are sort of ruining it for me',
#  'you know who the raincoats are',
#  "why don't you",
#  "i am getting trashed man isn't that what you are supposed to do at a party",
#  'i say do what you wanna do',
#  'funny you are the only one',
#  'i am fine i am',
#  'i just need to lie down for awhile',
#  'uh uh you lie down and you will go to sleep',
#  'i know just let me sleep',
#  'what if you have a concussion my dog went to sleep with a concussion and woke up a vegetable not that i could tell the difference',
#  'leave it to you to use big words when you are shitfaced',
#  'why  are you doing this',
#  'i told you',
#  "you don't care if i die",
#  'sure i do',
#  'why',
#  'because then i would have to start taking out girls who like me',
#  'like you could find one',
#  'see that  who needs affection when i have got blind hatred',
#  'just let me sit down',
#  'who',
#  'dorsey',
#  'i hate him',
#  "i know  it would have to be a pretty big deal to get you to mainline tequila you don't seem like the type",
#  "hey man    you don ' t think i can be cool  you don't think i can be laid back like everyone else",
#  'i thought you were above all that',
#  'you know what they say',
#  'what',
#  "but it's gigglepuss  i know you like them  i saw you there",
#  'busy',
#  'were you in jail',
#  'maybe',
#  "no you weren't",
#  'then why would you ask',
#  'why would you lie',
#  'do what',
#  'this',
#  "my father wouldn't approve of that that",
#  "you don't strike me as the type that would ask permission",
#  "i am gettin' there",
#  'he just wants me to be someone i am not',
#  'who',
#  'bianca',
#  'no offense but you are sister is without  i know everyone likes her and all but ',
#  'what are you doing here',
#  'i heard there was a poetry reading',
#  'you  are so ',
#  'pleasant',
#  'unwelcome',
#  'unwelcome  i guess someone still has her panties in a twist',
#  "don't for one minute think that you had any effect whatsoever on my panties",
#  'so what did i have an effect on ',
#  'other than my upchuck reflex nothing',
#  'look up sunshine',
#  "c'mon  it's not that bad",
#  "try lookin' at it from this angle",
#  "forget it  i am stayin'",
#  'you want me to climb up and show you how to get down',
#  'maybe',
#  'i figured it had to be something ridiculous to win your respect  and piss you off',
#  'good call',
#  'so how would you get chapin to look the other way',
#  'i dazzled him with my wit',
#  "yeah well don't let it get out",
#  'so what is your excuse',
#  'acting the way we do',
#  'yes',
#  "i don't like to do what people expect then they expect it all the time and they get disappointed when you change",
#  'so if you disappoint them from the start you are covered',
#  'something like that',
#  'then you screwed up',
#  'how',
#  'you never disappointed me',
#  'for   ',
#  'fallacy',
#  'the duck',
#  'hearsay',
#  "i know the porn career's a lie",
#  'i hate peas',
#  'no  something real  something no one else knows',
#  'you are sweet  and sexy  and completely hot for me',
#  'what',
#  'no one else knows',
#  'you are amazingly selfassured has anyone ever told you that',
#  'go to the prom with me',
#  'you know what i mean',
#  'no',
#  'no what',
#  'no i will not go with you',
#  'why not',
#  "because i don't want to it's a stupid tradition",
#  'so i have to have a motive to be with you',
#  'you tell me',
#  'you need therapy  has anyone ever told you that',
#  'answer the question patrick',
#  "nothing!  there's nothing in it for me just the pleasure of your company",
#  "it's scurvy's  his date got convicted where would you get the dress",
#  "it's just something i had  you know",
#  'oh huh',
#  'look i am   sorry  that i questioned your motives  i was wrong',
#  'what',
#  "that is where i was last year  she would never lived alone  my grandfather died  i stayed with her  i wasn't in jail i don't know marilyn manson and i have never slept with a spice girl  i spent a year sitting next to my grandma on the couch watching wheel of fortune  end of story",
#  'it gets worse  you still have your freshman yearbook',
#  'you were paid to take me out!  by  the one person i truly hate  i knew it was a setup!',
#  "it wasn't like that",
#  'really  what was it like  a down payment now then a bonus for sleeping with me',
#  "i didn't care about the money",
#  'i thought you could use it when you start your band',
#  'is that right',
#  'yeah but then i fucked up i fell for her',
#  'because i like to torture you',
#  'oh bianca  can you get me my freshman yearbook',
#  "don ' t you even dare  ",
#  'i thought we decided you were going to school here  at u of 0',
#  'you decided',
#  'enough!',
#  'then tell them i had a seizure',
#  'is this about sarah lawrence you punishing me',
#  'i thought you were punishing me',
#  'why cannot we agree on this',
#  'because you are making decisions for me',
#  'as a parent that is my right',
#  "so what i want doesn't matter",
#  "you are eighteen  you don't know what you want  you will not know until you are fortyfive and you don't have it",
#  'i want to go to an east coast school! i want you to trust me to make my own choices  i want ',
#  'yeah  she left with some bikers big ones  full of sperm',
#  'funny',
#  'no daddy',
#  'so tell me about this dance was it fun',
#  'parts of it',
#  'which parts',
#  'the part where bianca beat the hell out of some guy',
#  'bianca did what',
#  'what is the matter  upset that i rubbed off on her',
#  'no  impressed',
#  'when i go',
#  "oh christ  don't tell me you have changed your mind  i already sent 'em a check",
#  'expressing my opinion is not a terrorist action',
#  "well yes compared to your other choices of expression this year today's events are quite mild  by the way bobby rictor's gonad retrieval operation went quite well in case you are interested",
#  'i still maintain that he kicked himself in the balls  i was merely a spectator',
#  'the point is kat  people perceive you as somewhat ',
#  'no  i believe heinous bitch is the term used most often',
#  'just smack her now',
#  'hi',
#  'cool pictures  you a fan',
#  'yeah  i guess',
#  'oh yeah',
#  'right',
#  'kat a fan too',
#  'yeah',
#  'what',
#  "whatever the hell it is you are standin' there waitin' to say",
#  'the situation is my man cameron here has a major jones for bianca stratford',
#  'what is it with this chick  she have three tits',
#  'dorsey can plow whoever he wants i am just in this for the cash',
#  'so dorsey can get the girl',
#  "patrick pat you are not looking at the big picture  joey's just a pawn we set this whole thing up so cameron can get the girl",
#  'we are your guys',
#  'good enough',
#  'just for now',
#  'yeah',
#  "i am likin' you guys better",
#  "no  i have got a sweetpayin' job that i am about to lose",
#  'sweet love renew thy force!',
#  "man  don't say shit like that to  me people can hear you",
#  'it says here you exposed yourself to a group of freshmen girls',
#  'it was a bratwurst  i was eating lunch',
#  'with the teeth of your zipper',
#  'touch of the flu',
#  'i am at a loss then  what should we talk about your year of absence',
#  'what is to discuss',
#  "you weren't abused you aren't stupid and as far as i can tell you are only slightly psychotic  so why is it that you are such a fuckup",
#  "well you know  there's the prestige of the job title and the benefits package is pretty good",
#  'see you next week!',
#  'make anyone cry today',
#  'sarah lawrence is on the other side of the country',
#  'tumescent!',
#  'you are not helping',
#  'pirate  no question',
#  "kissing  is that what you think happens  kissing isn't what keeps me up to my elbows in placenta all day",
#  'dr ruth',
#  'but  who  what ',
#  'your daughters went to the prom',
#  'did i have anything to say about it',
#  'absolutely not',
#  "that ' s what i thought",
#  "the water's going putrid in the barrels",
#  'you will be drinking your own piss for the glory of spain and admiral colon!  bastard!',
#  'ah leave him alone  he is doing no harm',
#  "with a face like that  i don't want you looking at me  you hear",
#  'we will all go crazy',
#  'we left three weeks ago alonso cannot be that near',
#  "cannot be that far i say  also i don't like the smell of the sea around here  smells like a cunt bad sign",
#  'yes your eminence  the voyage should not take more than six or seven weeks',
#  'unfortunately don colon that is precisely where our opinions differ  are you familiar with the work of aristotle  erathostene  ptolemeus',
#  'i am your eminence',
#  'then you cannot ignore that according to their calculations the circumference of the earth is approximately  22000 leagues or more  which makes the ocean uncrossable',
#  'excellency you are right',
#  'your life and that of others!',
#  'if they agree to follow me yes',
#  'is that all that interests you gold',
#  'no  the portuguese have already discovered blackskinned people  i too will find other populations  and bring them to the word of god',
#  "did he not choose a carpenter's son to reveal himself to the world",
#  'blind faith is what i consider heresy!',
#  'ifgodwillsit!',
#  'the judgment is ours!',
#  'naturally  but i would really deplore the loss of such a potential opportunity for spain for a dispute over a point of geography',
#  'indeed  the world is full of mercenaries  and states often make use of them when it benefits them  my only concern is the welfare and prosperity of spain',
#  'on the contrary your eminence  it seems to me the man is preparing his own cross',
#  'what a tragedy what a waste of a life',
#  'a waste  let me tell you something arojaz  if your name or mine is ever remembered  it will only be because of his',
#  'i know',
#  "i haven't given you much of a life",
#  "well that is true  i have a child by a man who will not marry me!  who's always leaving",
#  'are we going to argue',
#  'i would love to argue with you sometimes  but you are never here!',
#  'i find that hard to believe',
#  'thank god',
#  "i don't want you to wait for me",
#  'that is something you cannot decide',
#  "you don't usually ask",
#  'i can arrange for the queen to take fernando and diego into her service',
#  "they tried but i didn't let them",
#  "not everything do you think i care  i am a free man again  riches don't make a man rich they only make him busier",
#  'i am busy inside',
#  "i cannot keep my eyes off you  i would like to catch up with all the moments i didn't spend with you",
#  'forgive me don bobadilla  those positions have already been taken',
#  'may i ask by whom',
#  'bartolome and giacomo colon',
#  'yes i remember',
#  'appointment to what',
#  'viceroy of the west indies',
#  'congratulations  then i am free to search for the mainland',
#  'i am not a seaman  but i heard it is no more than a week at sea  i hope you are not too disappointed',
#  'how could i be  the mainland has been found  exactly as i said it would',
#  'i am afraid this is not the worst news',
#  'there will be a time',
#  'you promise  do you swear on st christopher',
#  'yes yes i do on all of them!',
#  'this time with me!',
#  'not bad',
#  'there must be a passage to that other ocean',
#  'i am not listening father  but i cannot help hearing',
#  'he asks when he can come to visit you  he left his address',
#  'he never had one except aboard my ships!',
#  "really  god i wouldn't know where to start and yet",
#  'tell me the first thing that comes to your mind',
#  'no',
#  'no!  i have waited too long fought too hard  now you expect me to take all the risks while you take the profit!  no i will not be your servant!',
#  'i am not bargaining!',
#  'then you are too ambitious',
#  'if you will not accept our proposal we will simply find someone who will',
#  'forgive me don colon  but what about gold',
#  ' for a commoner',
#  'don bobadilla is already a judge my dear don cristobal',
#  'good!  we are also in need of judges  except there are no thieves!',
#  'what  do i have so many already',
#  'to rise so high in so short a time is a dangerous occupation  a little hypocrisy goes a long way',
#  'call them',
#  'look out of that window',
#  'roofs towers palaces spires',
#  'all of them created by people like me',
#  'what is it  a tribe  an island',
#  'island  far',
#  'tell the chief we thank him',
#  'chief knows',
#  'tell him his country is very beautiful  tell him we are leaving men here  to build a fort',
#  'thousands',
#  'why',
#  'chief says  he has a god',
#  ' and also to bring medicine',
#  'chief says',
#  'he has medicine  tell him we admire his people',
#  'he understands',
#  'ask him if he will help',
#  'you did the same to your god!',
#  'you never learned how to speak my language',
#  'father i am doing what i think is the best for him  and he has the teacher i would have chosen for myself',
#  'that is what it says',
#  'how did you manage it',
#  'with some difficulty  i had to promise them you were not a total fool',
#  'to open a new route to asia  at the moment there are only two ways of reaching it',
#  'ignorance!  i believe the indies are no more than 750 leagues west of the canary islands',
#  'how can you be so certain',
#  'the calculations of toscanelli marin de tyr esdras',
#  'esdras is a jew',
#  'so was christ!',
#  'i will try to remember that marchena',
#  'father marchena!',
#  'passion is something one cannot control!',
#  'you get so carried away when you are being contradicted!',
#  'i have been contradicted all my life eternity!',
#  'only god knows the meaning of such words my son',
#  'wait!  i have waited seven years already!  how much longer do you want me to wait',
#  'if god intends you to go then you will go',
#  'damn god!',
#  'damn all of you!  you all set up theories based on what  you never leave the safety of your studies! go out!  find out what the world is about and then tell me something i can listen to!',
#  "colon!  don't!",
#  'forgive me father  for i have sinned',
#  'father i have betrayed my family i betrayed my men  and i betrayed you',
#  'what are you saying',
#  'i lied  the journey will be longer than i said',
#  'how long',
#  'i am not sure it could be twice the distance',
#  'if i tell them they will not follow me  you know that i am right father  you trust me',
#  "my son my son  your certitudes are sometimes frightening  christopher you must speak to them and if you don't i will",
#  'you are bound by an oath father',
#  'give me absolution',
#  'you will always be older than me father',
#  'i knew you would',
#  'new worlds create new people',
#  'oh  so you are a new man',
#  "i don't know i have the impression that i didn't change that much  i still cannot accept the world as it is!",
#  'no more than the woman who said she would take granada from the moors',
#  'what did they say about granada before today',
#  'that she was impregnable',
#  'surely you can do anything you want',
#  'you show no inclination to speak otherwise!',
#  "i know what i see  i see someone who doesn't accept the world as it is  who's not afraid  i see a women who thinks what if",
#  'a woman',
#  'thirty seven your majesty and you',
#  'they come and go as naked as the day god created them',
#  'thank you',
#  'there is one thing i would like to understand why do you want to go back after all this',
#  'your majesty  some men are content to read about things  i must see them with my own eyes  i cannot be other than i am',
#  'the indians have no such word don moxica',
#  'if you want to keep your head on your shoulders you will do as i say',
#  "we don't need to know",
#  'we came here to stay!  to build! not to start a crusade  in this forest there is enough danger to sweep us away in days!  so we will be brave and swallow our grief  and in the name of those who died we will accomplish what we came for',
#  "my horse doesn't work",
#  'you did not hear me don colon  not my horse',
#  'savagery is what monkeys understand',
#  'you will be held in detention deprived of your privileges and possessions  until you are returned to spain where you will be judged have you anything to say',
#  'you will regret this',
#  'god be with us admiral',
#  'and what do you think mendez',
#  'well i surely know what a quadrant is!  but i have never seen it used at night before',
#  'come over here',
#  'twenty eight',
#  'he is drawing an isthmus he is saying we are on an isthmus',
#  'we cannot be',
#  'immediately',
#  'six days ago yes',
#  'you must be mad!',
#  'we have to keep the hopes of these men alive!',
#  'we are on the verge of a mutiny colon!',
#  "you think i don't know that",
#  'we are lost!',
#  'the land is there  i know it!',
#  "you don't know anything!  listen colon these are my ships right so i am telling you we are turning back!",
#  'and then what  half of the water has gone the rest is nearly putrid! you know that!',
#  'jesus maria!  i should have never listened to you!',
#  'you never did  you did all the talking for both of us remember',
#  'you bloody',
#  'pinzon pinzon all we can do now is go forward!  think about that!',
#  'you tell that to them!',
#  'you are right  let the men decide',
#  'yes your majesty',
#  'never your majesty  although',
#  "yes  it would be a pity wouldn't it  call him back!",
#  "we weren't expecting immediate profits were we  we must have faith  we must give time for time",
#  'is this true brother buyl',
#  'he must be replaced',
#  'and who would you think of for such a task',
#  'then why',
#  'because he is not afraid of me',
#  'i am not your lawyer until i see the money',
#  'here  i have your money',
#  'emil  take it easy  stay with me  sit down  what do you need  what are you looking for',
#  'he has the camera!  he took the movie!',
#  'where are we going',
#  'i am coming with you',
#  'yes  yes come with me!',
#  'i am invoking rights  this man is represented by counsel  i am coming with him',
#  'you bring the cigarettes',
#  'oh sure',
#  'i was all of these',
#  "well you didn't appreciate the severity of it until recently  no question about that",
#  'what about oleg',
#  'disappeared  they are looking everywhere  maybe he went back to czechoslovakia',
#  'no he is here  shit',
#  "don't worry about him  think about yourself",
#  'what about my movie rights  book rights',
#  "look i haven't really focused on that kind of thing",
#  'what is your cut  how much',
#  'i would sayhalf  half is fair',
#  'no  no way',
#  "but it's",
#  "thirtypercent  no more  or i call another lawyer  this is the biggest case of your life  don't try to negotiate  thirty percent  say yes or no",
#  'this is not about money emil  i need your trust in me',
#  'what else do you need',
#  'i need to know about your background  i need to know about your upbringing  why you are here',
#  'give me another one please',
#  'my father always degraded me  killed my selfesteem  and my mother was blind',
#  'your mother was blind',
#  'yeah she went blind giving birth to me she went to fucking black market doctor to induce me',
#  'back in the czech republic',
#  'yeah yeahbad doctor gave her bad drugs which made her go blind  and my father blamed me for her blindness',
#  "your father blamed you for your mother's blindness",
#  'yeah he hated me from day when i was born  put it out  can you put the cigarette out',
#  'your father put cigarettes out on you',
#  'out on my back when i was a small boy',
#  'can i see your back',
#  "i don't think it's abuse i think it's torture",
#  "officers there's your killer do your duty arrest him!",
#  'alright  that is a justifiable homicide',
#  'yes but he was a cop',
#  'if you cooperate with the da  maybe they will help you with your situation',
#  "i will if they don't send me back",
#  'they will not until this is over',
#  'divorced',
#  'do you live alone  i have been in these clothes sincethe killings  could we stop at your place i could take a showerbefore i go into custody',
#  'somewhere else',
#  'sothe station is empty',
#  'yeah  this way',
#  'yes i considered it',
#  'did you ever turn tricks before',
#  'no',
#  'what about back home',
#  'no',
#  'so you were never a prostitute',
#  'what are you asking me',
#  'i am just trying to find out who you are',
#  'i know',
#  "you don't know  i am sorry  i was desperate  that is not me  i shot a cop  can you imagine what they will do to me when i got to prison",
#  'they are not gonna send you right back',
#  "i am sorry  i didn't mean toi am glad actually i am glad it's over  all this time  hiding  never being able to look anyone in the eyes always afraid that someone would find out who i was  never trusting anyone",
#  "i still cannot believe eddie's gone",
#  'i am sorry',
#  'ludwig  he is gay  are you jealous',
#  'if i was your boyfriend i might be',
#  "if you were my boyfriend i would suggest you find another girlfriend that isn't going to jail tenthousand miles away",
#  'no matter what happensi am glad i met you',
#  'i am glad i met you',
#  'right',
#  'in the kitchen',
#  'i will make some for us',
#  'i will get my clothes',
#  'pouring it out!',
#  'do you really want me to forget about you',
#  "i don't want to drag you down with me",
#  'daphne i',
#  "c'mon start at the beginning  you know these people",
#  'tamina was a friend of mine  my shower was broken she let me use theirs',
#  'go on',
#  'if i tell you will you arrest me',
#  'arrest you for what  why would we arrest you',
#  "no no don't talk to immigration!",
#  'i am from a small town in slovakia  like the south here  the police is right a civilian is wrong  so i fled',
#  'look we can help you but right now we have to deal with what is happening here tell us the truthis that the truth',
#  'you are a cop  you will never believe me',
#  'it was my decision not his',
#  'well i am the deputy chief fire marshall and every now and then i would like to be included in decisions',
#  'look after jordy briefs me you can do the press conference  how about that the case is all yours',
#  'oh yeah  alright',
#  'i am ready to be briefed  excuse us',
#  'yeah sure  beep me when you are ready for the press conference',
#  'who do you think chief!',
#  "then why didn't you talk to the reporter",
#  "'cause we got more important things to do like finding out who did it",
#  "i came to see how the investigation was going  i called and you are not here  i wait up at the station and you don't even show up!!!  i beep you  you don't return my call  where the hell have you been!",
#  "what do you mean 'cleaned up'",
#  'i let her take a shower',
#  'a shower!  did you take one too',
#  'no!  nothing happened',
#  "oh really  that is nice  you took a homicide witness to take a shower after your partner was shot  are you out of your fucking mind  are you having that much trouble gettin' dates!",
#  'okay  but not water sports',
#  'what was i supposed to do  the guy tried to mug me  i was gonna send a cop back  i just forgot',
#  'forgot  you handcuffed a civilian to a tree!',
#  'chief  i know i screwed up  but this guy was no innocent civilian',
#  'well this is gonna end your career and probably mine',
#  'end my career',
#  "how are you going to fight this  maybe if oleg hadn't gotten away and you would been on the front page as a hero this thing would be easier to fight  you would have the good to weight against the bad! it's unfortunate that i have to make decisions based upon your press coverage but there's nothing i can do!  gimme your shield",
#  'but chief  over this',
#  "there's nothing to talk about  get a good lawyer  you are suspended until your trial",
#  'yeah right',
#  'what was that korfin',
#  "i said yeah you are right chief  as soon as we get somethin' we will let you alert the media",
#  "you do that wiseguy  now let's solve this thing before eddie flemming does",
#  'yeah  he finished awhile ago',
#  'alright  swing by her apartment  let her pick up her clothes and take her straight to hoover street  you got that',
#  'yeah',
#  'vodka tonic',
#  'maybe you could just put in a shot of martell',
#  "what is the kid gonna say  sorry meanwhile i am not here anymore like last week  we were at the morgue and this guy was all chopped up  spleen here  liver there  his heart in a pan six hours ago this guy was walkin' his dog or buyin' a quart of milk  who knows  but some kid's robbed him for $3 or some shit and shot him and now you cannot tell if he is a piece of beef or a human being and i am thinkin' that is me sooner or later  that is me",
#  'when',
#  'tomorrow  at lunch',
#  'you ready',
#  'a timer',
#  "takin' a bath",
#  'any id',
#  'still unknown but we are running prints kid over there caught the case',
#  "it's okay",
#  'yeah',
#  "c'mere  you wanna go to homicide school  here  make yourself useful",
#  'stay with her',
#  'no  i am okay',
#  "i know  relax  take it easy  don't worry we will get those fuckers",
#  'police  we would like to ask you a few questions',
#  "i have nothin' to say  if you wanna contact my attorney",
#  "homicide miss hearn  it's detective eddie flemming  open up",
#  "we don't have her id yet but one of your girls was killed last night at the king edward hotel",
#  "oh my gd  honey!  honey's dead",
#  'do you have any czech girls working for you',
#  'no',
#  'did you tell him you did',
#  'what are you saying',
#  'daphne  another guy came in asking me about her too',
#  'describe him',
#  "tall shorthaired scary eyes  second guy with him wasshorter with a wrestler's build  and he wouldn't turn his videocamera off me",
#  'he had a videocamera  where is she quickly!',
#  "she washes hair up at ludwig's  a salon on 63rd and madison",
#  "no we don't mind  you mind leon",
#  'no what is it',
#  "why don't you explain it bobby  hey camello!  you mind punching a hole in the floor",
#  'watch the news',
#  'nah i musta missed it',
#  'well just so you know  i gave you guys the credit',
#  "well just so you know i don't care about that stuff",
#  'nah why should you',
#  "i don't even watch tv",
#  'good  good  commendable',
#  'sure  but i would like to ask you something  you got a problem with me',
#  "if you found me steppin' on your crime scene  it might piss you off too  what about the report",
#  'you were right they were both dead before the fire  the male was stabbed so hard the killer broke off the tip of the knife in his spine  that is usually an indicator of something personal',
#  'pretty',
#  'hmmmm',
#  "maybe you don't care about that either  prettiest suspect i have had in awhile",
#  'who says she is a suspect',
#  'look i am not even sure she has anything to do with this  i saw her outside after the fire  thought it was a lead maybe she saw something  maybe she was visiting somebody here  who knows',
#  'eastern europe  like what  romania hungary',
#  'or czechoslovakia  the slavs have been fighting the germans and the russians for a thousand years  these are very intense people and they take things personally',
#  "there wasn't a fire  there will be nothing for you to do",
#  'i can watch you eddie  maybe i will learn something',
#  "this isn't homicide school",
#  'my parents are from poland  i can help with the eastern european angle',
#  'you are polish',
#  'my folks are',
#  'stay here',
#  'you got any better ideas',
#  'mind if i ride along with you',
#  'this has nothing to do with your fire',
#  'but what if it does  you might need my help',
#  'this is ridiculous  i am not gonna be in your way  we can talk the case over',
#  "tell you what  i will flip you a coin if you win you can come with me  if you don't win you don't come",
#  'i will call it tails',
#  'better than one',
#  "i am on my way with eddie  ludwig's 63rd and madison  the suspects might be there already",
#  'i am on duty',
#  'so am i  alright i will go inside and you cover the back',
#  'of course',
#  "hey!  i always wanted to be a cop when i was a kid  i dreamed of running up to a door kicking it in pulling my gun and yelling 'freeze!' at the bad guy! what would you dream about",
#  'i wanted to run up to a building on fire kick in the door rush into the smoke and save a kid',
#  "then i guess we are doin' this the right way aren't we  if we pull up to a burning building i will gladly let you go first",
#  'she just saw two of her friends killed! they probably threatened her',
#  'is that all there is',
#  'something back home',
#  'raw deal',
#  'you wanna talk to her alone',
#  'yeah',
#  'what would your girlfriend think of that',
#  "i don't have a girlfriend",
#  'my point exactly',
#  'i am serious here',
#  'so am i',
#  "c'mon  you intimidate her 'cause you are a celebrity  she sees me differently",
#  'you are her savior  is she the kid you are gonna save from the burning building',
#  'you know what i am saying here',
#  'hey  i am a professional',
#  'women like that have a way of turning professionals into amateurs',
#  "well you shoulda because nobody's gonna believe you didn'tincluding me",
#  'i took her there for a shower and that is it',
#  'just a shower',
#  "no i don't think you were a fool i just think you were stupid about it  i mean to say the least you outta know better  you don't know her well enough she is got the potential to fucking hang you even if she suggests that you made a pass at her it's fuckin' over  you can deny it all you want but it will not make one fucking bit of difference you are dead",
#  'i told you you know i thought i was doing the right thing you know i think she is innocent',
#  "well it's not up to you to decide whether she is innocent or not  don't you understand that is why you are a professional",
#  "but i mean didn't you ever go out on a limb for somebody  i mean you shoulda heard her there  tellin' her whole storyi believed her",
#  "how you go out on a limb for somebody is by giving her a number of an immigration lawyer  here here's a number of an immigration lawyer  that is how you help her but you cannot get involved in her like that  you are gonna jeopardize your career your life and you are gonna jeopardize my case  and lemme give you another piece of advice  maybe you don't watch tv but i will let you in on a little secret  the whole fuckin' world watches television  and when you get out there they know your face  and the little fame the little fuckin' itty bitty fame that i get in this city makes it a lot easier for my job  and i get more done because of it",
#  "you know i don't know  i like you you remind me of a puppy i used to have he pissed on the rug all the time but i still kept him",
#  'what do you want',
#  'your opinion  you see they going to make a movie about me too eddie  and write books',
#  'what is your accomplishment',
#  'i kill someone famous',
#  'then do it asshole',
#  'good  be tough to the end  actor who plays you will want to die like hero',
#  'if you kill me and film it you are putting a noose around your neck',
#  'smarter than americans  you are fed cry baby talk shows all day long  not only will americans believe me they will cry for me  sodetective eddie flemming would you like to say goodbye to your nicolette maybe you can propose to her now',
#  "we don't know that yet  it's much too early  there's a lot to be done",
#  'how many victims are up there',
#  'there are two bodies found at this point',
#  'can we go up to the crime scene',
#  "you know you cannot do that  c'mon",
#  'is it drug related',
#  "we don't know  when i have more i will let you know",
#  'i cannot talk right now  we have some things to take care of',
#  'i really cannot give out any information right now at this point',
#  "okay  but i do understand that your partner leon jackson's been injured is that correct",
#  'he was hurt but not seriously  he will be fine',
#  'do you have the suspect in custody',
#  "umnow is not a good time okay detective jackson's hurt  he is fine i have got a fire marshall shot detective jackson is hurt but not seriously",
#  'alright cut cut cut',
#  "yeah  now's not a good time",
#  'alright',
#  'alright',
#  'alright',
#  'alright',
#  'okay',
#  'hey',
#  'i cannoti cannot answer you just because you want me to answer you!',
#  "you didn't have to embarrass me in front of my colleagues  you could give me something",
#  'oh i am sorry  did i embarrass you sweetheart  oh',
#  'stop it',
#  'maybe i should just ya knowturn to the cameras and say do you mind if we just work something out',
#  "alright alright eddie  don't patronize me",
#  'i am not',
#  "yes you are  i am not just some reporter  i don't just stick a microphone in your face  you could give me something",
#  'yeah well you took the camera and put it right down on the evidence  that was',
#  'that was good  you were holding the evidence',
#  "you were merciless  you didn't give a shit if you got me or not",
#  'well who was it that taught me how to do that  huh',
#  'you are ruthless',
#  'you are not so bad yourself',
#  "could be leon's",
#  'jesus  and last week you came over with blood on your shoes  what am i going to do with you',
#  'answer the phone',
#  'no  tell me what you want to say',
#  'answer it',
#  "okay  okay  hold that thought just for a second  they only call me when it's an emergency  just hold that thought  can you call back",
#  'that is good',
#  'yeah',
#  'well that is great',
#  'okay  that is great  but i cannot go now we are in the middle of something here',
#  'no  go ahead  you are gonna be great',
#  'no  no listen to me here  i want to know what you are talking about  you know the shoe thing and the marriages and',
#  "i will tell you tonight  let's do it tonight  as soon as you get back we will talk  we will talk",
#  'promise',
#  'i promise  we will talk  you will be great  you will be fine  go ahead just imagine that uh just look into the lens and imagine you are talking to me',
#  'yeah  i will do that  as long as you are not patronizing me',
#  'patronizing you nay i love you',
#  'i love you',
#  'tonight',
#  'you promise',
#  'yeah  i promise',
#  "okay  and you know what i will swing by my place grab a couple pairs of shoes and maybe just test them out next to yourshow's that would that be a good thing",
#  'yeah yeah  good thing',
#  'okay',
#  'see you later  good luck',
#  'thank you',
#  "don't be late",
#  'jesus christ',
#  'not chopped up  not chopped up like that  i mean what do i got left coupla articles  a medal or two plaque here and there and in a coupla years no one remembers me anymore',
#  'i think you are getting a little moody there eddie',
#  'i am not moody',
#  "my kids  let's seesusan's 15 aundrea's 9  don't tell me you are thinking about having a kid!  how old are you  never mind let me just tell you this every stupid cliche you hear about kids  they change your life they make you a better person they make you whole  it's all true!  before i had kids when friends talked about their kids i wanted to vomit  now  i get it  am i right leon",
#  'not what  who',
#  'that is unique',
#  'yeah  and he still went to the party',
#  'you are worried for my safety  i am touched',
#  'keep them out of my way',
#  'okay  you ready',
#  'yeah yeah  jesus',
#  "again  i didn't wanna do it the first time",
#  'i am butcher',
#  'you are a butcher  what do you use pig intestines for',
#  'you stuff sausage in it',
#  'and what do you do with the bones',
#  'dog food',
#  'no  are you proposing',
#  'look asshole  i have been threatened by better than you',
#  'no  i am the best that is ever threatened you',
#  'i will meet you on one condition  i get exclusivity and you surrender to me',
#  "we will talk about that  four o'clock gives you time to go to bank  three hundred thousand dollars",
#  "what  it doesn't work that way",
#  "if you don't want my film  i will call another show  and they will show it",
#  'wait a minute  wait a minute',
#  'come alone  bring cash  and we will talk about surrendering',
#  "my father was  he gave me many lessons about fire  now it's my friend",
#  'tommy take a walk',
#  'you will be my first',
#  'get down on your knees',
#  'the sheraton!  on broadway!  room 210 go get oleg  he will kill you',
#  'let her go!  let her go!!',
#  "if he doesn't lower his gun i will fucking kill her",
#  'where is czech girl',
#  'baby i am anybody you want me to be i am a little schoolgirl i am mommy i am a czech girl',
#  'i ordered a czech girl  daphne you know her',
#  'where is escort service',
#  'that is confidential  could you put the money on the dresser',
#  'i like to talk to the person who runs the service  can you give me address',
#  "look  do we have a problem here there's no reason to have a problem i am gonna make you feel real good  you wanna czech girl after i am done with you you will not miss her  now why don't you pay me",
#  "look man i don't give a shit if you want sex or not but you are payin' for my time",
#  "alright alright  don't hurt me! please it's in my book in my purse!",
#  'yes sir',
#  'two weeks holiday',
#  'how much money are you carrying with you',
#  'i have fivehundred dollars',
#  'can you show me  sir no cameras in the fis area!',
#  'yes',
#  'please join us  come on forward',
#  'is there a problem',
#  'no you are travelling together  i want to talk to you together  hi how are you  can i take a look at your documents  are you related',
#  'how long are you planning to stay',
#  'two weeks',
#  'i would like to speak for himself okay',
#  "he doesn't speak english",
#  "new york's finest  this is his case",
#  'do you know how much killer gets for movie rights',
#  'in here says he wants a million',
#  'million!  the killer gets one million dollars for a television interview',
#  'hey tabloids paid ted bundy  famous serial killer  half a million for his interview  and how much you think monica got for writing book about the president coming on to her  it pays to be a killer or a whore in this country look you want magazine or not',
#  'yes  both',
#  'okay',
#  'okay',
#  'i want to document my trip to america',
#  "don't speak russian!",
#  'why  why do i always have to speak to you in czech',
#  "because i don't like your ugly language i heard enough of it in school!  now speak czech or english  and don't fool around anymore  you almost got us thrown out!",
#  'we have no money  come on',
#  ...]

# %% [markdown]
# # Create a dictionary which map each word with how many time it occcurs

# %%
## For questions
word2count = {}
for question in clean_questions:
    for word in question.split():
        if word not in word2count:
            word2count[word] = 1
        else:
            word2count[word] += 1
## For Answers
for answer in clean_answers:
    for word in answer.split():
        if word not in word2count:
            word2count[word] = 1
        else:
            word2count[word] += 1

# %%
word2count
# Out:
# {'splendor': 2,
#  "mom's": 91,
#  'massed': 1,
#  'commuter': 2,
#  'hildy!': 20,
#  'behoove': 1,
#  'uangryu!': 2,
#  "debbie's": 15,
#  'withoutyou': 1,
#  'rectangles': 1,
#  'grabbed': 53,
#  'bonasera': 3,
#  'hazardous': 9,
#  'v2': 1,
#  'librarian': 13,
#  'insurrection': 5,
#  'champagne': 115,
#  'painkillers': 8,
#  'insipid': 3,
#  'shined': 2,
#  'hostile': 62,
#  '2004': 4,
#  'tomorra': 5,
#  'sacked': 4,
#  'tickled': 10,
#  'howand': 2,
#  'intestate': 5,
#  'mending': 1,
#  '1600': 4,
#  'fightand': 2,
#  'skulljust': 1,
#  'cryogenically': 2,
#  "bureau's": 7,
#  'owners!': 1,
#  'continuation': 2,
#  'cornfield': 2,
#  'coldly': 1,
#  'visions': 11,
#  "duke'": 1,
#  'recombination': 2,
#  'candy': 89,
#  'heada': 2,
#  'previously': 5,
#  'farmgirl': 1,
#  "cecile's": 2,
#  'magna': 5,
#  'salutation': 2,
#  'wellumher': 2,
#  'exchangers': 1,
#  'pisani': 1,
#  'drags': 8,
#  'umillionsu': 2,
#  'childs!': 4,
#  'described': 37,
#  'regards': 19,
#  'shmoe!': 1,
#  'hallie': 9,
#  'scotch!': 1,
#  'canyou': 3,
#  "building's": 8,
#  'jokes': 93,
#  'flashing': 11,
#  'beas': 1,
#  'forwarding': 5,
#  'shango': 2,
#  'workhe': 3,
#  'aerosol': 1,
#  'justsettle': 1,
#  'bioethics': 2,
#  'multigene': 1,
#  'robotics': 1,
#  'asslicking': 2,
#  'clifford': 15,
#  'soused': 2,
#  'havelook': 2,
#  'cerebellum': 4,
#  'puedes': 1,
#  "benjamin's": 3,
#  'bosnia': 8,
#  'smackers': 4,
#  'bulgarian': 3,
#  'ceida': 4,
#  'lopear': 4,
#  'yeeaahhh': 1,
#  'defensivehenry': 1,
#  'marthafuckingstewart': 1,
#  'sviluppate': 2,
#  "ruth's": 5,
#  'jameson': 13,
#  "mcgann's": 2,
#  'gower': 7,
#  'uweu': 27,
#  'fcc': 1,
#  'cocktail': 60,
#  'uptrying': 1,
#  'fluctuation': 1,
#  'lazyboy': 2,
#  'forfeited': 2,
#  'folders': 4,
#  'naish': 1,
#  'betters': 1,
#  'meyers!': 1,
#  'avionics': 3,
#  "masters'": 2,
#  'comings': 2,
#  'hunger': 32,
#  'monumentsand': 2,
#  'effort': 60,
#  'waldman': 6,
#  'twentyfourhour': 1,
#  'rolfe': 7,
#  "recorder's": 1,
#  'adjustable': 1,
#  'wholesome': 12,
#  'diagnose': 8,
#  'photostatic': 1,
#  'einsteinrosen': 2,
#  'theretold': 2,
#  'friend!': 32,
#  'spawned': 2,
#  'kristina': 8,
#  'youkilledhim': 2,
#  'directs': 3,
#  'naino': 1,
#  'cholet': 1,
#  'friendsbut': 2,
#  'fartsbishop!': 1,
#  "vada's": 7,
#  "clerc's": 1,
#  "stealin'": 2,
#  "chef'smate": 1,
#  'diesoon': 1,
#  "sword's": 3,
#  'plowing': 5,
#  'impertinent': 7,
#  'gusts': 3,
#  'flunked': 6,
#  'elves': 4,
#  "'loser'": 1,
#  'con': 96,
#  'drool': 13,
#  'nametag': 3,
#  "months'": 5,
#  "spendin'": 4,
#  'unameu': 2,
#  'luci': 2,
#  'acceptance': 9,
#  'petey': 2,
#  'serna': 1,
#  'umagneticu': 1,
#  "e'er": 4,
#  'hattie': 4,
#  'fullgrowed': 1,
#  'reachable': 4,
#  "'horsefucker'": 1,
#  'therechocolate': 1,
#  'hilton': 13,
#  'spleen': 11,
#  'excellency!': 3,
#  'poltergeist': 3,
#  '*india*!': 1,
#  'johnwhat': 2,
#  'exact': 132,
#  'defenseman': 2,
#  'mossy': 2,
#  'sheeit': 8,
#  'mumbled': 4,
#  'halide': 2,
#  'moving!': 16,
#  'bohort': 1,
#  'nummer': 2,
#  'wouldand': 2,
#  "hauser's": 3,
#  'throughuhpresents': 1,
#  "'small'": 1,
#  'ilia': 6,
#  'theyya': 2,
#  'ulifeu': 15,
#  'woke': 145,
#  "sixit's": 1,
#  'congratufuckinglations': 4,
#  'crane': 59,
#  'mother!!!': 2,
#  'loins': 8,
#  'bought!': 2,
#  "m'lord": 9,
#  'crazy!i': 2,
#  'copious': 1,
#  'erewhon': 1,
#  'cue': 24,
#  'passionfruit': 2,
#  'norm': 29,
#  'consensus': 7,
#  'raimondo!': 1,
#  'leadership': 20,
#  'killandtell': 1,
#  "n'who": 2,
#  'catching': 65,
#  'brooksy': 1,
#  'brotherin': 12,
#  'unattractive': 8,
#  'dinnercannot': 2,
#  'remained': 16,
#  'mission': 295,
#  'sugarcoat': 1,
#  'ezekiel': 6,
#  "terry's": 5,
#  'respectively': 2,
#  'adjustments': 12,
#  "bandit's": 2,
#  'noooooo!': 1,
#  'ridicules': 2,
#  "its'": 1,
#  'oomooooateo': 1,
#  'trumbo': 13,
#  'tracks!': 1,
#  "veteran's": 4,
#  "woulding'": 2,
#  'likeehto': 1,
#  'una': 4,
#  'manycome': 1,
#  'security': 406,
#  "134's": 1,
#  "marcus's": 1,
#  'sunpowered': 2,
#  'eh': 477,
#  'intranet': 1,
#  "'fucker": 1,
#  'teachers': 36,
#  'beatnik': 9,
#  'wretch': 4,
#  'prim': 2,
#  'confront': 20,
#  'helpbunnyquit': 2,
#  'restorations': 2,
#  'butbut': 16,
#  'uadviceu': 2,
#  'windowbuzz': 1,
#  'need': 5659,
#  'council!': 1,
#  'remit': 1,
#  'nudging': 1,
#  'ohohoh': 2,
#  'elmen': 1,
#  'faust!': 1,
#  'mayonaaise': 1,
#  'crazywhat': 2,
#  'machines': 96,
#  'remotest': 2,
#  'fleece': 3,
#  'mookie': 35,
#  'nitrate': 8,
#  'billa': 2,
#  'fleeing': 4,
#  'contreespionnage': 1,
#  'stash': 19,
#  'youjust': 1,
#  "80's": 5,
#  'stressing': 6,
#  'recruiter': 1,
#  'repetitious': 1,
#  'secondsas': 2,
#  'nonsmoker': 1,
#  'inkoros': 2,
#  'outsmuggling': 1,
#  'supplement': 1,
#  'unforgiving': 2,
#  'breakfast!': 2,
#  'neaponitan': 1,
#  "coffey's": 2,
#  'rememberthe': 2,
#  'alivewill': 1,
#  'wherefores': 2,
#  'meray': 1,
#  'helps': 104,
#  'arse!': 2,
#  'convenience': 27,
#  'hoovers': 3,
#  'kidneys!': 2,
#  'italics': 1,
#  'upassu': 2,
#  'coincidences!': 2,
#  'rieper!': 1,
#  'intruding': 16,
#  'scheme!': 2,
#  'ahh': 86,
#  'kodak': 2,
#  'belushi': 6,
#  'onenight': 1,
#  "toilet's": 3,
#  'chords': 2,
#  'calmo': 1,
#  'lights': 187,
#  'triads': 6,
#  'swell': 142,
#  'fate': 110,
#  'sold': 243,
#  '[italian': 4,
#  'macy': 5,
#  'levenworth': 1,
#  'okyou': 1,
#  'method': 32,
#  'forbade': 2,
#  'colleague': 27,
#  'influence': 89,
#  'levine': 6,
#  "but'cha": 1,
#  'ucertainu': 5,
#  'umaccorryu!you': 1,
#  'bending': 13,
#  'chomps': 1,
#  'confessionsupplied': 1,
#  'gunther': 5,
#  'criticisms': 1,
#  'unbefuckinglievable': 2,
#  'uhoh!': 4,
#  'constrained': 3,
#  '[line': 1,
#  '73rd': 2,
#  'roy!': 9,
#  "cow's": 1,
#  'reassurances': 2,
#  'unashamedly': 2,
#  'harass': 9,
#  'perky': 5,
#  "destiny's": 3,
#  'puttering': 4,
#  'want*and': 1,
#  'taxicab': 6,
#  'stand': 942,
#  'cabbages': 4,
#  'minis': 2,
#  'stalin': 5,
#  'kinds': 123,
#  'concentrated!': 1,
#  'retention': 3,
#  'betelgeuse': 6,
#  'lipstickred': 2,
#  'weed!': 2,
#  'grad': 12,
#  'joelistenall': 1,
#  'dix': 14,
#  'ordered': 147,
#  'parlortricks!': 2,
#  'maude': 37,
#  'howdido': 1,
#  'ike': 29,
#  'tiller': 4,
#  '*any*': 7,
#  'transfusion': 14,
#  'thermopod': 1,
#  'prosecutor': 14,
#  'barking': 16,
#  'intracranial': 1,
#  'xenia': 13,
#  'ubetrayalu': 2,
#  'quandary!': 1,
#  'perignon': 5,
#  'langenkamp': 6,
#  'firemen!': 1,
#  'meone': 1,
#  'sopersonal': 1,
#  "tougher'n": 1,
#  'witches': 28,
#  "valhere's": 3,
#  'strickland': 8,
#  'ooonn': 1,
#  'maintenance': 32,
#  'rarer': 2,
#  "bogey's": 2,
#  "should'a": 12,
#  'trouper': 2,
#  "thatcher's": 2,
#  'quiz': 13,
#  'auught!': 2,
#  'watchers': 4,
#  'guilt': 66,
#  'tumors': 1,
#  'rpm': 1,
#  'uptownand': 2,
#  'peculiarities': 5,
#  "kidding'": 2,
#  'chewbacca': 6,
#  'ffight': 2,
#  "disco's": 1,
#  '*missionary*': 1,
#  'greed!': 1,
#  "dumber's": 2,
#  'pegs': 1,
#  'components': 7,
#  "britain's": 2,
#  'ozoz': 1,
#  'r&r': 4,
#  'sanskrit': 5,
#  'shotbut': 2,
#  'typesand': 2,
#  'unwashed': 1,
#  'magistrate': 7,
#  "mitchell's": 11,
#  'obsessions': 6,
#  'gatecrash': 1,
#  'allamerican': 8,
#  'cornets': 1,
#  'maye': 2,
#  'burping': 2,
#  "barbie's": 4,
#  'template': 1,
#  "with's": 2,
#  'vulsellum': 2,
#  'pine': 23,
#  "startin'": 27,
#  'walser': 1,
#  'participation': 1,
#  'made': 2736,
#  'uwhole': 1,
#  "'artificial": 1,
#  'poem': 61,
#  'bodybuilding': 2,
#  'buttside': 1,
#  'sox': 33,
#  'beforeor': 2,
#  'duck': 75,
#  'pinheads': 2,
#  "yearsit's": 1,
#  'putterer': 16,
#  'expunged': 4,
#  'barnes': 89,
#  'hoof': 8,
#  "georgina's": 2,
#  'eitherwhy': 1,
#  'cruise': 31,
#  'twinkies': 10,
#  'paulette': 1,
#  'teresa!': 2,
#  'empossed': 1,
#  'burgundian': 3,
#  "system's": 16,
#  'bashed': 2,
#  'guyspeak': 4,
#  'egghead!': 1,
#  'eyowch!': 1,
#  'lazarus': 12,
#  'booted': 10,
#  'recede': 3,
#  'sobo': 1,
#  'platt': 1,
#  'alms': 2,
#  'galoshes!': 2,
#  'meringue': 6,
#  "maggie's": 4,
#  "becky's": 1,
#  'mo': 17,
#  'brutally': 6,
#  'hebrew': 15,
#  'ear': 193,
#  'judith': 1,
#  'universally': 6,
#  'espastico': 2,
#  'onethousand': 4,
#  'picahielo': 2,
#  'bored': 111,
#  'flamethrower!': 1,
#  "'frigerator": 2,
#  'docking': 7,
#  'thinner': 3,
#  'rossi': 6,
#  'stone': 205,
#  'insurmountable': 2,
#  "fairlane'": 2,
#  'unite': 8,
#  'flush': 29,
#  'differentlyplus': 2,
#  'corvis': 9,
#  "banister's": 5,
#  'disrupts': 1,
#  'diplomat!': 2,
#  'soonest': 4,
#  'slipups': 1,
#  'offland': 2,
#  'warmth': 11,
#  'ucrazyu': 2,
#  'rockies': 4,
#  'stamp': 46,
#  'heyshe': 2,
#  'roomi': 3,
#  'ponds': 10,
#  'warders': 3,
#  'ihejirai': 1,
#  "'voca'": 2,
#  'consort': 2,
#  'yaaa!': 1,
#  'entopologist': 1,
#  'malfunctioned': 2,
#  'failed': 86,
#  "ball's": 8,
#  'welby': 2,
#  'supreme': 38,
#  'jeopardy': 10,
#  'encore': 7,
#  'mat': 13,
#  "'world": 2,
#  'freedom': 136,
#  'intellectually': 9,
#  'motionless': 1,
#  "tie'm": 1,
#  '*with*': 4,
#  'scotia': 1,
#  'rox': 1,
#  "clip's": 3,
#  'previsions': 5,
#  'nation': 81,
#  'marylin!': 7,
#  'sexton': 4,
#  'loogies': 1,
#  'engaged': 116,
#  'edematous': 1,
#  'valerian': 5,
#  'cluttered': 1,
#  'thatned': 2,
#  "'rabbit": 1,
#  'deepsalvage': 1,
#  'uwatchu': 4,
#  'endorse': 13,
#  'enchilada': 2,
#  'rendition': 1,
#  'pittsburg': 1,
#  'raffle': 4,
#  'corset': 5,
#  'curvy': 1,
#  'sightlines': 2,
#  "shockin'": 1,
#  'tame': 13,
#  'dudes!': 4,
#  'cambodia': 7,
#  'astronomical': 1,
#  'thaistick': 2,
#  'nobly': 1,
#  'finger!': 3,
#  'gestapo': 26,
#  'tomwhy': 1,
#  'hollenbeck': 1,
#  'underbelly!': 2,
#  'letterreckon': 1,
#  'incise': 1,
#  'udriveru': 2,
#  'delilahish': 2,
#  'youthful': 8,
#  'drones': 1,
#  "d'etat": 6,
#  'downstairs': 145,
#  'hatch': 30,
#  'barman!': 1,
#  'uhenchmenu': 2,
#  'trattoria': 4,
#  'pickens': 1,
#  'mikhi': 4,
#  'cleaned': 99,
#  'nourishment': 10,
#  "go'on": 4,
#  'porfirio': 4,
#  'cambridge': 11,
#  'fanucci': 11,
#  'besserman': 1,
#  'enjoying': 71,
#  'pke': 2,
#  'longago': 4,
#  "'the": 92,
#  'hoitytoity!': 1,
#  'shastri': 1,
#  'gabriela!': 1,
#  'bridetobe': 1,
#  'recon': 17,
#  'airk!': 3,
#  'halfsmiles': 1,
#  'forced': 124,
#  'zwartze': 1,
#  'thief': 128,
#  'pans!': 1,
#  'toot': 4,
#  "nowdon't": 2,
#  'bikes!': 1,
#  'ourpartnership': 1,
#  'withthisbottleofdirtcheapchampagne': 1,
#  'renfield': 2,
#  'shopper': 4,
#  '*rock*': 1,
#  'bully!': 1,
#  'paints': 5,
#  'scramble': 7,
#  'splinters': 8,
#  'housecalls!': 2,
#  'collateral': 18,
#  'ginger': 47,
#  'nystrom': 2,
#  'responsiblewhat': 1,
#  'java': 4,
#  'fried': 62,
#  'affiliated': 2,
#  'zelazna': 1,
#  'spritz': 2,
#  'rekall': 26,
#  'sally!!!!': 1,
#  'phyllis': 26,
#  'noireuter': 2,
#  'brody!': 1,
#  'zionist': 4,
#  'conscientious': 4,
#  'corvisart': 4,
#  "earth'": 1,
#  'films': 76,
#  "practi'cly": 1,
#  'mordant!': 1,
#  'geuse': 1,
#  "schumann's": 4,
#  'zukovsky': 2,
#  'pantry': 4,
#  'waive': 1,
#  'nonowe': 2,
#  'down!!!': 2,
#  'decompressed': 1,
#  'bags': 103,
#  'uearnu': 2,
#  'automatics': 5,
#  'ross': 42,
#  'sonofabitch!': 26,
#  'uhuh!': 3,
#  'bulky': 4,
#  'sweaters!': 1,
#  'truthwhich': 1,
#  'weird!': 2,
#  'lateesha': 3,
#  'toowith': 1,
#  'suckered': 8,
#  "conduct'": 2,
#  'dishonored': 2,
#  'successor': 9,
#  'masturbated': 2,
#  'flattened': 3,
#  'treads': 3,
#  '23just': 1,
#  'filming': 8,
#  'member': 133,
#  'hobbies': 11,
#  'clemenza': 23,
#  '5099027': 2,
#  'pastels': 2,
#  '*me!': 2,
#  "'twill": 6,
#  "companies'": 1,
#  'tremor!': 1,
#  'territory!': 2,
#  'turnon': 9,
#  'viceprincipal': 2,
#  'this!': 283,
#  'parish': 6,
#  "nomad's": 2,
#  'knotholes': 2,
#  'discover': 46,
#  'contemptible': 4,
#  'plateglass': 3,
#  "crackin'": 3,
#  'utellu': 12,
#  'cicadas': 1,
#  'microchips': 10,
#  'glamorous': 10,
#  'town': 1199,
#  'indomitable': 1,
#  'jackets': 13,
#  'swallows': 18,
#  'retains': 2,
#  'smolensk': 1,
#  'importing': 2,
#  'fancy': 125,
#  'subtil': 2,
#  'loyola': 1,
#  'mayberry': 1,
#  'fishhook': 1,
#  'insparation': 1,
#  'hellton': 1,
#  'esp': 4,
#  'sixtyfirst': 3,
#  'whoaoh!': 1,
#  'canterbury': 1,
#  'originally': 35,
#  'fully': 109,
#  'ships': 89,
#  'journalism!': 4,
#  "snoopy's": 2,
#  'frazzle': 1,
#  "julian's": 1,
#  'grotty': 6,
#  'acknowledging': 5,
#  'tapdanced': 1,
#  'falconier': 2,
#  'refits': 2,
#  'justtry': 2,
#  'for30': 1,
#  'grubbing': 1,
#  'be': 27768,
#  'lungs!': 2,
#  'sacrilege': 3,
#  'youwhy': 1,
#  'stellas': 2,
#  'wendigos': 1,
#  'nino': 1,
#  'shishkbob': 2,
#  'list!': 5,
#  'bumper': 12,
#  'mangy': 5,
#  'courthouse': 30,
#  "tumor's": 2,
#  'sonormal': 1,
#  'arvn': 4,
#  'ugirlu!': 1,
#  'penfield': 14,
#  "'many": 1,
#  'bedchamber!': 2,
#  'donut!': 2,
#  'blower!': 1,
#  'citywide': 1,
#  'maybethe': 1,
#  'hung': 112,
#  'stack': 15,
#  'skua': 1,
#  'sides': 67,
#  'unit!': 2,
#  'sky!': 3,
#  'pictured': 7,
#  'countermeasures': 1,
#  'aboard8a': 1,
#  'campi': 1,
#  'vips': 1,
#  'dunnoseems': 2,
#  'littlebefore': 1,
#  'gigoloor': 2,
#  'unabridged': 2,
#  'waymake': 1,
#  'watergatemaybe': 2,
#  'alls': 5,
#  'industry': 44,
#  'kayem': 7,
#  'fucking': 2423,
#  "2's": 2,
#  'implored': 2,
#  'showing!': 1,
#  'lala': 4,
#  'rainforest': 2,
#  'ofbutchered': 1,
#  'coladas': 2,
#  'blades': 25,
#  'unpacked': 8,
#  'divorce!': 4,
#  'prosper!': 2,
#  'sadand': 2,
#  'risk': 255,
#  'again!': 124,
#  'valiant!': 1,
#  'external': 15,
#  "fender's": 1,
#  'secondguess': 1,
#  'revoir': 13,
#  'when': 10370,
#  'f': 68,
#  'checkee': 1,
#  'approach': 89,
#  'dailey': 1,
#  'inever': 1,
#  'pathologist': 9,
#  'hurriedly': 4,
#  'leaders': 34,
#  'youa': 4,
#  'husbandgoddamnbless': 1,
#  'kabobs': 4,
#  'sexy': 100,
#  'shiver': 4,
#  'cowardly': 17,
#  'sadistic': 11,
#  'i': 204535,
#  'yesbuthow': 1,
#  'interdependent': 1,
#  'delle': 5,
#  'culpa': 2,
#  'neph': 2,
#  "lovejoy's": 2,
#  "slogan's": 2,
#  'giff': 2,
#  'squirming': 1,
#  'jarheads': 1,
#  'parcels': 1,
#  'caltrust': 2,
#  'doobidoob': 1,
#  'catatonic': 7,
#  'persecutes': 2,
#  'details!': 2,
#  'ferris': 2,
#  'bus': 313,
#  'jantzen': 2,
#  'gruner!': 2,
#  'connive': 1,
#  'carefulweekly': 1,
#  "a'ight": 1,
#  'gubbed': 2,
#  'comprehends': 1,
#  "pauline's": 4,
#  'schoenick': 2,
#  'eluding': 2,
#  'emphysema': 3,
#  'zz': 1,
#  'humanly': 15,
#  'deion': 1,
#  'rinaldi': 4,
#  'forewarned': 1,
#  'blackface': 5,
#  'deadmaybe': 1,
#  'lockdown': 12,
#  'panel': 21,
#  'wouldo': 6,
#  "'after": 2,
#  'mythology': 13,
#  "counselin'": 2,
#  'redbirds': 2,
#  "want'em": 4,
#  'enslave': 3,
#  'downgive': 1,
#  'innocence': 31,
#  "stranger's": 3,
#  'airfield': 8,
#  'depreciate': 1,
#  'knowman': 2,
#  'thieving': 5,
#  "softer'n": 2,
#  'hammett': 2,
#  'von': 87,
#  'wiper': 3,
#  'poisonous!': 1,
#  'unrelenting': 1,
#  'awe': 14,
#  'becauseuh': 1,
#  'inlightened': 1,
#  'strengthened': 1,
#  'comanchechief': 1,
#  'dealey': 6,
#  "&lt&ltdon't": 2,
#  'lud': 2,
#  'foraging': 6,
#  'amish': 14,
#  'reprimand': 3,
#  'usphereu': 2,
#  'knowing': 267,
#  'geeeerta': 1,
#  'permanent': 38,
#  '38s': 2,
#  'unguent': 2,
#  'fruitful': 3,
#  'claudia!': 4,
#  'ofttimes': 1,
#  'sayyadina': 2,
#  'instilled': 3,
#  'wankers': 1,
#  'succinct': 2,
#  '426': 1,
#  "'man": 2,
#  'soundground': 1,
#  'cockfuckers': 1,
#  'noi': 55,
#  'itive': 1,
#  'threefifty': 8,
#  'lawyer!': 9,
#  'kendall': 35,
#  'prototype!': 1,
#  'unsheathed': 1,
#  'globber': 1,
#  'recognizing': 11,
#  'frenchman!': 1,
#  "nothin'!": 15,
#  'snookums': 2,
#  'willu': 8,
#  'areareuh': 2,
#  'prussian': 4,
#  'havta': 4,
#  'biogenetics': 2,
#  'out!!!': 6,
#  'demented': 12,
#  'uthisu': 36,
#  "time's": 59,
#  'clan': 7,
#  'withmarcus': 2,
#  'bigger': 218,
#  'goodeveninglaydeesandgent': 1,
#  "don'tyou": 2,
#  'punch!': 4,
#  'loudspeaker': 4,
#  'connelly': 2,
#  'inquest': 2,
#  'contraction': 3,
#  'sweet!': 8,
#  'neverspokeanotherword': 1,
#  'complexions': 1,
#  'beech': 2,
#  "vaughn's": 1,
#  'neurosis': 11,
#  "l'ouvrir": 2,
#  'snorri!': 3,
#  'stinking': 35,
#  'fossilized': 2,
#  'postponement': 2,
#  'abroad': 12,
#  'lowlife!': 2,
#  'backgrounds': 3,
#  'vulnerability': 4,
#  'seizure': 13,
#  'waylaid': 1,
#  "olivier's": 2,
#  'proved': 47,
#  'didwe': 3,
#  "'bad": 1,
#  'androscoggin': 7,
#  "roth'h'ar": 1,
#  'delta': 17,
#  'apparition': 2,
#  'stomach!': 5,
#  'karaoke': 5,
#  'sterners!': 1,
#  'monkeybone!': 2,
#  'chappy!': 1,
#  'dkq': 1,
#  'popsie': 4,
#  'envoy': 10,
#  'gravity': 49,
#  '$50000': 7,
#  'beuys': 2,
#  'anna': 144,
#  'waitlisted': 4,
#  'staircases': 2,
#  'slaughtering': 4,
#  'freshie[3]': 1,
#  'ohwill': 1,
#  'ustripu': 1,
#  'mercutiogood': 1,
#  'sensations': 5,
#  'szabo': 2,
#  'derive': 4,
#  'geology': 3,
#  'samuel!': 1,
#  'mwhat': 2,
#  'swamps': 3,
#  'worthily': 1,
#  'dorsetshire': 4,
#  "laughin'": 18,
#  'test!': 1,
#  'screenit': 1,
#  'ourselves!': 3,
#  "'stanwyk": 1,
#  'haderach': 5,
#  'okaytake': 2,
#  'settings': 7,
#  'fleegman!': 3,
#  'kitty': 32,
#  'ifyou': 2,
#  'shirley': 26,
#  'steeples': 1,
#  'blockbuster!': 2,
#  'relayed': 6,
#  'issueu!!': 2,
#  'bomb': 309,
#  'knowit': 2,
#  'epsom': 1,
#  'parrotlet': 2,
#  'savagely': 3,
#  'legalize': 1,
#  'saboteur': 3,
#  'pooh!': 4,
#  'implying': 31,
#  'tm': 1,
#  'invisibility': 2,
#  'pitchernow': 1,
#  'however!': 1,
#  "areligion'": 2,
#  'brettright': 1,
#  'lyme': 5,
#  'tazinari': 4,
#  'tocall': 2,
#  'retirement!': 1,
#  'bioubustingu': 2,
#  'funny': 975,
#  'chauffeur': 14,
#  "'good'": 2,
#  'stantonand': 1,
#  'yeoman': 1,
#  'ocean!': 4,
#  'pangborn': 2,
#  'powersthat': 1,
#  'emptynest': 1,
#  '[who': 11,
#  'gulls!': 1,
#  'buttshaft': 2,
#  'poliakoff': 3,
#  "timewatchin'": 2,
#  'profanity': 12,
#  'trask': 5,
#  ...}

# %% [markdown]
# # Creating two dictionary that map question word and answer word into unique integer

# %%
## Questions
threshold_questions = 20
questionswords2int = {}
word_number = 0
for word, count in word2count.items():
    if count >= threshold_questions:
        questionswords2int[word] = word_number
        word_number += 1
## Answers
threshold_answers = 20
answerswords2int = {}
word_number = 0
for word, count in word2count.items():
    if count >= threshold_answers:
        answerswords2int[word] = word_number
        word_number += 1

# %%
questionswords2int
# Out:
# {"mom's": 0,
#  'weaker': 7443,
#  'normally': 1165,
#  'breath': 3322,
#  'hildy!': 1,
#  'shots': 4411,
#  'leaving': 7731,
#  'voice': 5188,
#  'certain': 7732,
#  'grabbed': 2,
#  'indians': 7730,
#  'introduce': 6069,
#  'somewhere': 6619,
#  "guy's": 4412,
#  'champagne': 3,
#  'e': 2261,
#  'leave!': 7733,
#  'shhh': 7896,
#  'situations': 2277,
#  'llewelyn': 7734,
#  'plug': 3323,
#  'merlin': 5541,
#  'been': 2536,
#  'committee': 4413,
#  'radioactive': 4410,
#  'follow': 5543,
#  'cowboy': 5544,
#  'search': 2264,
#  'interesting': 5540,
#  'anymore!': 4432,
#  'doyle': 1875,
#  'bare': 125,
#  'said!': 1166,
#  'replace': 2265,
#  'shining': 2291,
#  'facts': 8400,
#  'sexually': 8250,
#  'entertaining': 6624,
#  'cab': 2266,
#  'candy': 5,
#  'veronica': 7330,
#  'afford': 6625,
#  'reject': 1167,
#  'bullshit': 5546,
#  'choir': 4415,
#  'something!': 3324,
#  'randy': 3325,
#  'helps': 29,
#  'hemingway': 3326,
#  'championship': 978,
#  'where': 3327,
#  'krauts': 5722,
#  'sugar': 6658,
#  'described': 6,
#  'brother': 2775,
#  'stayed': 2269,
#  "everything's": 289,
#  'brass': 5933,
#  'talk': 4447,
#  'profits': 7738,
#  'jokes': 7,
#  'sack': 5741,
#  'architect': 6098,
#  'th': 2260,
#  'erica': 6627,
#  'buddy': 2270,
#  'poor': 7352,
#  'handful': 7739,
#  'expect': 4461,
#  'jon': 6628,
#  'couldnt': 6883,
#  'thousand': 7867,
#  'thought': 3328,
#  'cheerful': 5374,
#  'wendy': 7165,
#  'again': 6629,
#  'porn': 4472,
#  'id': 4417,
#  'concentrate': 1168,
#  'poets': 354,
#  'deposit': 4474,
#  'uweu': 8,
#  'cocktail': 9,
#  'stanwyk': 4475,
#  'child': 2272,
#  'loses': 1169,
#  'corporate': 7740,
#  'reilly': 5549,
#  'vital': 6630,
#  'licked': 2273,
#  'easiest': 7571,
#  'dangerous': 1059,
#  'telling': 6287,
#  'started': 4010,
#  'hunger': 10,
#  'meets': 3848,
#  'dumb': 4483,
#  'effort': 11,
#  'understudy': 3153,
#  'wilt': 5551,
#  'las': 6288,
#  'connect': 6631,
#  'nah': 4418,
#  'medium': 6632,
#  'child!': 3089,
#  'negotiate': 7187,
#  'momma': 4167,
#  'location': 7741,
#  'friend!': 12,
#  'norville': 3332,
#  'price': 3811,
#  'covers': 7743,
#  'casting': 3333,
#  'coffin': 3334,
#  'wipe': 7749,
#  'servants': 1170,
#  'bateman': 3335,
#  "person's": 1171,
#  'dad': 2276,
#  'imagining': 6103,
#  'saxophone': 2278,
#  'it!': 3336,
#  'chromium': 2841,
#  'sense': 4421,
#  'civilians': 6688,
#  'different': 1172,
#  'firm': 6620,
#  'iced': 3337,
#  'yep': 6612,
#  'con': 13,
#  'fingerprints': 7744,
#  'assure': 2279,
#  'pathetic': 4422,
#  'inside': 6634,
#  'smear': 5553,
#  'pacific': 3338,
#  'passing': 7167,
#  'favour': 2280,
#  'quicker': 4424,
#  'goodbye': 6621,
#  'whites': 5610,
#  'occur': 2281,
#  'post': 1174,
#  'brain': 5554,
#  'sergeant': 4425,
#  'notion': 1175,
#  'programs': 6637,
#  'marry': 5542,
#  'apparently': 6638,
#  "'em!": 2284,
#  'shirley': 121,
#  'am': 7787,
#  'believed': 6640,
#  'routine': 3340,
#  'cable': 6641,
#  'twist': 7746,
#  'exact': 14,
#  'honorable': 3341,
#  'more!': 4426,
#  'insurance': 2780,
#  'brick': 4427,
#  'terrible!': 7535,
#  'altered': 3342,
#  'mother!': 1178,
#  'convinced': 4430,
#  'film': 1179,
#  'associated': 4431,
#  'quick!': 3344,
#  'terms': 2285,
#  'spooky': 7344,
#  'sake!': 2286,
#  'hearst': 6738,
#  'funds': 6622,
#  'interests': 4534,
#  'woke': 15,
#  'titanic': 8620,
#  'spain': 2287,
#  'crane': 16,
#  'bells': 3346,
#  'frightening': 5559,
#  'nerve': 2288,
#  'situation': 5560,
#  'churchill': 2289,
#  'outfit': 4414,
#  'toto': 1180,
#  'hawaii': 6643,
#  'choices': 7168,
#  'footage': 8138,
#  'trapped': 5561,
#  'cue': 17,
#  'norm': 18,
#  'selling': 3668,
#  'consequences': 7750,
#  'leadership': 19,
#  'represent': 2390,
#  'webster': 3224,
#  'catching': 20,
#  'pillow': 7751,
#  'cocky': 6644,
#  'angle': 4433,
#  'mission': 21,
#  'laughs': 1183,
#  'ethel': 6645,
#  'eleanor': 5545,
#  'king': 3349,
#  'corky': 3350,
#  'sleep': 2292,
#  'worries': 4434,
#  'welfare': 1184,
#  'unowu': 3352,
#  'ancient': 4435,
#  'possession': 5563,
#  'fucker': 7752,
#  'plead': 1185,
#  'wounded': 6802,
#  'security': 22,
#  'punishment': 1186,
#  'longest': 7209,
#  'rib': 4575,
#  'admission': 7691,
#  'eh': 23,
#  'road': 1187,
#  'pickup': 5564,
#  'farmer': 2404,
#  'teachers': 24,
#  'underwater': 4436,
#  'seats': 1188,
#  'hudson': 5566,
#  'shades': 5567,
#  'confront': 25,
#  'sabotage': 8135,
#  'armed': 4437,
#  'deuce': 2294,
#  'drama': 4018,
#  'professional': 312,
#  'need': 26,
#  'operator': 5568,
#  'perhaps': 7735,
#  'highly': 2296,
#  'brad': 4438,
#  'houston': 1182,
#  'technical': 2297,
#  'survive': 2419,
#  'significant': 4348,
#  'that': 4440,
#  'tease': 1189,
#  'machines': 27,
#  'mookie': 28,
#  'lillian': 7757,
#  'coward': 2433,
#  'scout': 7758,
#  'cells': 5570,
#  'blind': 5571,
#  'initiative': 5724,
#  'steak': 8229,
#  'shoots': 1190,
#  'denver': 2772,
#  'revolutionary': 5477,
#  'millionaire': 6647,
#  'psychology': 5572,
#  'bringing': 5288,
#  'before!': 6648,
#  'disturb': 1882,
#  'september': 2298,
#  'saunders': 8450,
#  'darn': 392,
#  'outer': 3354,
#  'axe': 1191,
#  'phrase': 6488,
#  'dieter': 4624,
#  'convenience': 30,
#  'niggers': 6652,
#  'cheers': 6653,
#  'disks': 6400,
#  'deadbeat': 2299,
#  'jackson': 5573,
#  'ahh': 31,
#  "waitin'": 5574,
#  'dough': 2452,
#  'remove': 8443,
#  'sentimental': 1192,
#  'twentyseven': 2300,
#  'pension': 227,
#  'precise': 5576,
#  'path': 2301,
#  'swell': 33,
#  'everything!': 1194,
#  'fate': 34,
#  'alvy': 3356,
#  'josh': 3357,
#  'sold': 35,
#  'mimi': 4442,
#  'share': 3358,
#  'surrounded': 1195,
#  'ignorance': 1196,
#  'method': 36,
#  'enterprise': 6655,
#  'toilet': 6988,
#  'cookie': 2303,
#  'damnit': 4645,
#  'risky': 1197,
#  'yea': 1198,
#  'tennis': 1199,
#  'wonderful': 2470,
#  'focus': 4443,
#  'cannot!': 6526,
#  'what': 2783,
#  'create': 5578,
#  'heads': 4444,
#  'ripped': 5938,
#  'ignorant': 7076,
#  'screamed': 7762,
#  'palm': 5547,
#  'divorced': 4445,
#  'grid': 8253,
#  'head': 1200,
#  'trace': 6661,
#  'elements': 3360,
#  'guy!': 7765,
#  'lotta': 3361,
#  'artist': 1201,
#  'fox': 3363,
#  'cheeks': 4446,
#  'stand': 39,
#  'shooting': 2305,
#  'use': 1202,
#  'ego': 3518,
#  'warn': 6351,
#  'kinds': 40,
#  'absolute': 2486,
#  'assumed': 5580,
#  'fazeli': 2306,
#  'day!': 3853,
#  'ordered': 41,
#  'maude': 42,
#  'relieve': 6663,
#  'ike': 43,
#  'belt': 6235,
#  'days!': 2335,
#  'step': 7767,
#  'anyplace': 3364,
#  'confession': 5581,
#  'chosen': 6928,
#  'humble': 2307,
#  'balcony': 275,
#  '90': 3435,
#  'fingers': 2308,
#  'nigga': 3366,
#  "c'mon": 4450,
#  'many': 8645,
#  'details': 5583,
#  'sight': 7769,
#  'witches': 44,
#  'mantan': 2309,
#  'ape': 6872,
#  'maintenance': 45,
#  'virtually': 1305,
#  'european': 6664,
#  'phase': 4451,
#  'easter': 6665,
#  'rowan': 288,
#  'gets': 8445,
#  'official': 5584,
#  'del': 5585,
#  'guilt': 46,
#  'power': 1204,
#  'daniel': 4453,
#  'bully': 5018,
#  'pieces': 202,
#  'trigger': 2311,
#  'programmed': 7771,
#  'season': 2312,
#  'million': 1206,
#  'pressing': 2313,
#  'servant': 3369,
#  'ooh': 2042,
#  'dropped': 5497,
#  'como': 7772,
#  'grown': 6666,
#  'intended': 1207,
#  'canadian': 7773,
#  'example': 5586,
#  'missy': 2314,
#  'playing': 6896,
#  'swim': 8446,
#  'sworn': 2085,
#  'popped': 2519,
#  'recognition': 5997,
#  'them': 1208,
#  'doing!': 4454,
#  'laplante': 2522,
#  'u': 313,
#  'searching': 2315,
#  'investigating': 3372,
#  'climb': 3373,
#  'satisfy': 3374,
#  'pine': 47,
#  "startin'": 48,
#  'circles': 805,
#  'fur': 4457,
#  'total': 1210,
#  'made': 49,
#  'string': 2316,
#  "son's": 5589,
#  'historical': 1211,
#  'sox': 51,
#  'inconvenience': 3377,
#  'seduce': 4625,
#  'duck': 52,
#  'arse': 6292,
#  'barnes': 53,
#  'liar': 985,
#  'steering': 5590,
#  'walker': 2541,
#  'uh': 7776,
#  'cruise': 54,
#  'nest': 4727,
#  'hamilton': 2317,
#  'coast': 5592,
#  'chemicals': 4465,
#  'whisky': 4466,
#  'objection': 6668,
#  'museum': 1212,
#  'confidentiality': 4467,
#  'picnic': 1397,
#  "deal's": 1213,
#  'tied': 3379,
#  'oven': 2836,
#  'dressed': 7777,
#  'offer': 7172,
#  'sad': 7928,
#  'launched': 2319,
#  'flood': 2320,
#  'institution': 4741,
#  'are': 6671,
#  'shed': 4468,
#  'liver': 3381,
#  'jet': 2129,
#  'ear': 55,
#  'bean': 6674,
#  'toddy': 5020,
#  'bored': 56,
#  'stroke': 443,
#  'fly': 6677,
#  'maya': 2561,
#  'marijuana': 1216,
#  'dragging': 5595,
#  'producing': 1217,
#  'bit': 4469,
#  'stone': 57,
#  'minus': 6938,
#  'charley': 3383,
#  'fingernails': 7174,
#  'rags': 4753,
#  'physically': 7252,
#  'flush': 58,
#  'mercury': 1888,
#  'profit': 5451,
#  'food': 8545,
#  'thanks': 4470,
#  'makes': 3384,
#  'hotels': 7780,
#  'stamp': 59,
#  'crash': 7134,
#  'prenup': 5597,
#  'equipment': 3385,
#  'penitent': 2322,
#  'gig': 2323,
#  'agent': 5729,
#  'failed': 60,
#  'view': 4473,
#  'supreme': 61,
#  'producer': 2324,
#  'bert': 3506,
#  "it's": 1989,
#  'kubelik': 2325,
#  'boone': 3330,
#  'casablanca': 1218,
#  'dot': 3290,
#  'eternity': 6090,
#  'chest': 6551,
#  'amnesia': 6293,
#  'result': 3386,
#  'wont': 1219,
#  'suspected': 2271,
#  'nation': 63,
#  'can!': 7350,
#  'groups': 5598,
#  'campaign': 4790,
#  'engaged': 64,
#  'tv': 8261,
#  'landing': 6681,
#  'darling!': 8820,
#  'desert': 1220,
#  'locker': 1221,
#  'mayfield': 7539,
#  'patch': 1038,
#  'added': 7783,
#  'copy': 1222,
#  'havent': 5467,
#  "mother's": 7713,
#  'sunday': 6769,
#  'twohundred': 3387,
#  'lime': 3388,
#  'kiddo': 5382,
#  'gestapo': 65,
#  'he': 1224,
#  'readers': 3389,
#  'instantly': 4477,
#  "aren't": 5600,
#  "more'n": 3390,
#  'downstairs': 66,
#  'thirtysix': 1225,
#  'twentieth': 6684,
#  'games': 3391,
#  'mitchell': 1588,
#  'addison': 7542,
#  'cleaned': 68,
#  'keep': 4478,
#  'paper': 7351,
#  'tasty': 1226,
#  'better!': 2327,
#  'toss': 8068,
#  'local': 3860,
#  'however': 7784,
#  'victory': 4527,
#  'table': 6686,
#  'slug': 6687,
#  'ronald': 1349,
#  "something's": 4480,
#  'principles': 2328,
#  'personally': 5604,
#  'world': 8369,
#  'music': 4481,
#  'connie': 7562,
#  'vampire': 4827,
#  'forced': 71,
#  'makeup': 806,
#  'pain': 4831,
#  'reserve': 1772,
#  'ask': 5550,
#  'competitive': 1227,
#  'lonesome': 6405,
#  'thus': 7785,
#  'starters': 7786,
#  'unknown': 3393,
#  'pushed': 428,
#  'biscuits': 1228,
#  'wayne': 7574,
#  'lip': 2329,
#  'level': 2634,
#  'pencil': 3394,
#  'zulu': 2330,
#  'patterns': 5607,
#  "'": 2331,
#  'hiring': 5608,
#  "i'11": 2639,
#  'chet': 435,
#  'flat': 5609,
#  'rekall': 75,
#  'enid': 6991,
#  'phyllis': 76,
#  'jabez': 4484,
#  'florida': 2332,
#  'tear': 2274,
#  'father!': 4485,
#  'films': 77,
#  'compromise': 8089,
#  'snitch': 6689,
#  "'n'": 7027,
#  'riddle': 6690,
#  'straight': 3395,
#  'heh': 1230,
#  'einstein': 2454,
#  'clock': 8526,
#  'cops': 4487,
#  'tests': 8178,
#  'bags': 78,
#  'teasing': 3396,
#  'ross': 79,
#  'aim': 2333,
#  'entry': 3397,
#  'picking': 3398,
#  'monitor': 6850,
#  'eagle': 5368,
#  'fisher': 6692,
#  'smashing': 4489,
#  'ropes': 5612,
#  'involves': 2334,
#  'xxxxxx': 4490,
#  'satisfaction': 2978,
#  'mi': 3675,
#  'accomplished': 8439,
#  '15': 5804,
#  'micheal': 4217,
#  'monkeys': 8610,
#  'functions': 8503,
#  'member': 81,
#  'intimidate': 2336,
#  'tying': 3542,
#  'clemenza': 82,
#  'mmmm': 4492,
#  'chickens': 7847,
#  'buzzing': 1232,
#  'analysis': 4493,
#  'knives': 1233,
#  'vanished': 4419,
#  'recorded': 7544,
#  'mayo': 3400,
#  'ambitious': 4494,
#  'this!': 83,
#  'slit': 4495,
#  'confusion': 6695,
#  'yeh': 6986,
#  'roll': 7789,
#  'discover': 84,
#  'attractive': 2337,
#  'crowd': 2338,
#  'quest': 1234,
#  'costume': 1235,
#  'quoting': 6696,
#  "friggin'": 2339,
#  'provided': 8721,
#  'town': 85,
#  'band': 4497,
#  'vow': 1516,
#  'payment': 2340,
#  'trailer': 4498,
#  'fancy': 86,
#  'vague': 5337,
#  'swedish': 3405,
#  'score': 1236,
#  'protest': 3406,
#  'recent': 1237,
#  'originally': 87,
#  'fully': 88,
#  'ships': 89,
#  'go': 4500,
#  'crushed': 2342,
#  'atlantic': 1238,
#  'possibly': 5977,
#  'donna': 6700,
#  'do!': 7792,
#  'scenery': 1239,
#  'macho': 7793,
#  'motherfucking': 5617,
#  'be!': 1240,
#  'certified': 6701,
#  'be': 90,
#  'soft': 3408,
#  'repeat': 1241,
#  'merrick': 7794,
#  'clouds': 1243,
#  'psychologist': 5619,
#  'dodge': 6703,
#  'unhappy': 7256,
#  'resistance': 3409,
#  'tourist': 5927,
#  'genes': 7086,
#  'courthouse': 91,
#  'rumors': 6704,
#  'baby': 5552,
#  'cuba': 4502,
#  'mister': 2344,
#  'violent': 6994,
#  'drill': 7093,
#  'george!': 4833,
#  'virgins': 2345,
#  'bullets': 2346,
#  'chains': 2718,
#  'helena': 4503,
#  'sides': 93,
#  'swallow': 807,
#  'doesnt': 2347,
#  'angeles': 3410,
#  'goin': 6707,
#  'arts': 3411,
#  'huey': 5622,
#  'clarify': 3412,
#  'setting': 6708,
#  'laugh': 4938,
#  'whispering': 2723,
#  'run': 2349,
#  'adore': 5725,
#  'sitting': 5623,
#  'indiana': 500,
#  'prison': 2275,
#  'arrive': 6300,
#  'horse': 2350,
#  'fucking': 95,
#  'retarded': 1245,
#  'visitors': 8456,
#  'cop': 5625,
#  'dumped': 2725,
#  'admit': 3413,
#  'knowi': 4504,
#  'blades': 96,
#  'return': 4505,
#  'remarkable': 7799,
#  'satellite': 3415,
#  'risk': 97,
#  'again!': 98,
#  'reliable': 2736,
#  'gulf': 8618,
#  'vader': 3416,
#  'shitless': 7125,
#  'amanda': 4506,
#  'z': 2842,
#  'weasel': 4507,
#  'signing': 6713,
#  'when': 99,
#  'f': 100,
#  'overtime': 1246,
#  'approach': 101,
#  'let': 5628,
#  'rio': 1247,
#  'whacked': 7801,
#  'chief': 1021,
#  "layin'": 3417,
#  'leaders': 102,
#  'pumping': 4220,
#  'dining': 5632,
#  'sexy': 103,
#  'driver': 4508,
#  'nazis': 1248,
#  'rode': 3681,
#  'i': 104,
#  'sooner': 3512,
#  'sign': 7088,
#  'son!': 7802,
#  'sixth': 5507,
#  'within': 4509,
#  'mobile': 2760,
#  'tammy': 7605,
#  'spitz': 2762,
#  'good': 1249,
#  'bus': 105,
#  'richards': 8673,
#  'stinks': 1250,
#  'change': 6714,
#  'priests': 5634,
#  'barely': 4998,
#  'blowing': 5635,
#  'insulted': 4510,
#  "ladies'": 2770,
#  'oath': 1520,
#  'cock': 5009,
#  'panel': 106,
#  'lo': 2352,
#  'isnt': 4573,
#  'follows': 2353,
#  'dayday': 2354,
#  'slaves': 3419,
#  'wes': 7805,
#  'explode': 4511,
#  'detroit': 7806,
#  'loomis': 5636,
#  'evening': 2355,
#  'godfather': 2785,
#  'push': 1254,
#  'portal': 4512,
#  'shift': 5734,
#  'airplane': 7546,
#  'lula': 2356,
#  'glance': 2357,
#  'print': 7549,
#  'caswell': 4513,
#  'knowing': 109,
#  'permanent': 110,
#  'auto': 7807,
#  'mount': 8345,
#  'robbery': 4514,
#  'sale': 6718,
#  'watched': 2358,
#  'kendall': 112,
#  'metropolis': 7808,
#  'hmm': 5639,
#  'picard': 3420,
#  'appointed': 2811,
#  'through': 5640,
#  'shape': 4515,
#  'led': 8251,
#  'gallagher': 3421,
#  'surrender': 3422,
#  'nailed': 1256,
#  'gambling': 2459,
#  'master': 3423,
#  'tonight!': 6721,
#  'effective': 5643,
#  'decide': 2359,
#  'pretty': 1700,
#  'script': 1257,
#  'furtwngler': 3424,
#  'nope': 1258,
#  "time's": 114,
#  'arrange': 5644,
#  'compliments': 6722,
#  'reality': 7201,
#  'violin': 3425,
#  'elliot': 2360,
#  'direct': 4517,
#  'bigger': 115,
#  'pistol': 5645,
#  'wanting': 4518,
#  'hon': 2361,
#  'jeez': 4519,
#  'bombing': 3427,
#  'insignificant': 4520,
#  'bigtime': 6636,
#  'purpose': 3428,
#  'sphere': 8461,
#  'teaches': 3339,
#  'surprising': 6822,
#  'marks': 2835,
#  'orbit': 8366,
#  'claws': 6524,
#  'lester': 3429,
#  'stinking': 116,
#  'you!': 2282,
#  'awfully': 4521,
#  'radar': 2362,
#  'inherited': 5980,
#  'evelyn': 6724,
#  'ratings': 7811,
#  'proved': 117,
#  'opportunities': 3430,
#  'elaine': 5737,
#  'screwing': 2846,
#  'brand': 1261,
#  'attacked': 7182,
#  'becker': 7402,
#  'leaves': 1262,
#  'flow': 7813,
#  'cameron': 4522,
#  'my': 8605,
#  'molly': 5646,
#  'move': 2283,
#  'true': 6725,
#  'mass': 3431,
#  'sat': 1263,
#  'rust': 1264,
#  'stupidity': 4523,
#  'north': 3432,
#  'joey': 7087,
#  'clown': 5555,
#  'anna': 119,
#  'bed!': 1265,
#  'vicious': 4819,
#  'cairo': 6726,
#  'norman': 3433,
#  'possibility': 8072,
#  'hugo': 4524,
#  'team': 6117,
#  'rocket': 3434,
#  'flying': 2092,
#  'tiny': 2797,
#  'singer': 7814,
#  'mmhm': 2363,
#  'safer': 1266,
#  'course!': 7069,
#  'color': 2364,
#  'press': 6727,
#  'peaceful': 1267,
#  'struck': 6792,
#  'stoned': 3436,
#  'shirts': 1268,
#  'scent': 2365,
#  'courts': 1269,
#  'cruel': 1176,
#  'parker': 8256,
#  'whadda': 1270,
#  'bits': 6007,
#  'rep': 5094,
#  'kitty': 120,
#  'bomb': 122,
#  'sauce': 7817,
#  'substantial': 6729,
#  'twentyeight': 7818,
#  'symptoms': 2879,
#  'unconscious': 2880,
#  'once!': 3438,
#  'grandparents': 2366,
#  'implying': 123,
#  'flies': 7264,
#  'hardon': 7551,
#  'terrible': 2619,
#  'centuries': 266,
#  'attached': 5650,
#  'shell': 4528,
#  'dwayne': 1273,
#  'inform': 5651,
#  'lou': 1274,
#  'healthy': 3439,
#  'wasting': 1275,
#  "how's": 6093,
#  'cadet': 2906,
#  'feelings': 6731,
#  "else's": 2367,
#  'fighters': 7820,
#  'expedition': 2368,
#  'umeu': 4530,
#  'shark': 1277,
#  'him': 6465,
#  'flop': 7525,
#  'kilometers': 7354,
#  'although': 1524,
#  'jockey': 126,
#  'distraction': 2370,
#  'plates': 8270,
#  'tee': 1639,
#  'bell': 3443,
#  'personal': 5653,
#  'sec': 7296,
#  'heights': 127,
#  'bail': 2633,
#  'coop': 1252,
#  'politicians': 2920,
#  'oliver': 8722,
#  'fats': 5028,
#  '19': 2371,
#  'financial': 2923,
#  'role': 762,
#  'chain': 6733,
#  'blessing': 2615,
#  'young': 3446,
#  'april': 1278,
#  'court': 7160,
#  'uhaveu': 767,
#  'suggests': 128,
#  'excellency': 3343,
#  'rely': 8359,
#  'zip': 5654,
#  'tow': 5655,
#  'cried': 7747,
#  'submit': 1279,
#  'occasion': 2262,
#  'lefferts': 4178,
#  'its': 5656,
#  'weapon': 6999,
#  'arnie': 5657,
#  'ridge': 2373,
#  'nevertheless': 8479,
#  'edgar': 7824,
#  'loaded': 6736,
#  'ian': 4532,
#  'documents': 7825,
#  'areu': 129,
#  'marshall': 3447,
#  'cure': 130,
#  'looked': 7973,
#  'hardest': 5613,
#  'tokyo': 2374,
#  'case!': 6472,
#  'crude': 7436,
#  'crying': 131,
#  'stag': 132,
#  'pleasant': 7278,
#  'standard': 3876,
#  'holland': 133,
#  'york': 2953,
#  'say!': 3448,
#  'articles': 3449,
#  'prettier': 7430,
#  'russia': 1282,
#  'activate': 2375,
#  'art': 4535,
#  'prime': 1283,
#  'truth': 8066,
#  'kitchen': 134,
#  'wood': 135,
#  'autograph': 3450,
#  'cooperate': 3451,
#  'above': 7828,
#  'marx': 2376,
#  "uncle's": 4537,
#  'spider': 4538,
#  'debate': 4539,
#  'project': 4540,
#  'assist': 5660,
#  'fleet': 4085,
#  'putting': 1284,
#  'don': 1656,
#  'lookout': 3453,
#  'mac': 4541,
#  'consider': 2377,
#  'yankee': 6743,
#  'breathing': 4542,
#  'guts': 1285,
#  'windows': 8220,
#  'dilemma': 136,
#  'clubs': 3345,
#  'random': 137,
#  'detail': 4543,
#  'sparazza': 138,
#  'rug': 8650,
#  'iyou': 5661,
#  'banner': 6828,
#  'freely': 1286,
#  'hatch': 67,
#  "ain't": 140,
#  ...}

# %% [markdown]
# # Encoding the Last tokens

# %%
## Questions
tokens = ['<PAD>', '<EOS>', '<OUT>', '<SOS>']
for token in tokens:
    questionswords2int[token] = len(questionswords2int) + 1
## Answers
for token in tokens:
    answerswords2int[token] = len(answerswords2int) + 1

# %% [markdown]
# # Creating Inverse Dictionary of the answerwords2int

# %%
answersints2word = {w_i: w for w, w_i in answerswords2int.items()}

# %%
answersints2word
# Out:
# {0: "mom's",
#  1: 'hildy!',
#  2: 'grabbed',
#  3: 'champagne',
#  4: 'hostile',
#  5: 'candy',
#  6: 'described',
#  7: 'jokes',
#  8: 'uweu',
#  9: 'cocktail',
#  10: 'hunger',
#  11: 'effort',
#  12: 'friend!',
#  13: 'con',
#  14: 'exact',
#  15: 'woke',
#  16: 'crane',
#  17: 'cue',
#  18: 'norm',
#  19: 'leadership',
#  20: 'catching',
#  21: 'mission',
#  22: 'security',
#  23: 'eh',
#  24: 'teachers',
#  25: 'confront',
#  26: 'need',
#  27: 'machines',
#  28: 'mookie',
#  29: 'helps',
#  30: 'convenience',
#  31: 'ahh',
#  32: 'lights',
#  33: 'swell',
#  34: 'fate',
#  35: 'sold',
#  36: 'method',
#  37: 'colleague',
#  38: 'influence',
#  39: 'stand',
#  40: 'kinds',
#  41: 'ordered',
#  42: 'maude',
#  43: 'ike',
#  44: 'witches',
#  45: 'maintenance',
#  46: 'guilt',
#  47: 'pine',
#  48: "startin'",
#  49: 'made',
#  50: 'poem',
#  51: 'sox',
#  52: 'duck',
#  53: 'barnes',
#  54: 'cruise',
#  55: 'ear',
#  56: 'bored',
#  57: 'stone',
#  58: 'flush',
#  59: 'stamp',
#  60: 'failed',
#  61: 'supreme',
#  62: 'freedom',
#  63: 'nation',
#  64: 'engaged',
#  65: 'gestapo',
#  66: 'downstairs',
#  67: 'hatch',
#  68: 'cleaned',
#  69: 'enjoying',
#  70: "'the",
#  71: 'forced',
#  72: 'thief',
#  73: 'ginger',
#  74: 'fried',
#  75: 'rekall',
#  76: 'phyllis',
#  77: 'films',
#  78: 'bags',
#  79: 'ross',
#  80: 'sonofabitch!',
#  81: 'member',
#  82: 'clemenza',
#  83: 'this!',
#  84: 'discover',
#  85: 'town',
#  86: 'fancy',
#  87: 'originally',
#  88: 'fully',
#  89: 'ships',
#  90: 'be',
#  91: 'courthouse',
#  92: 'hung',
#  93: 'sides',
#  94: 'industry',
#  95: 'fucking',
#  96: 'blades',
#  97: 'risk',
#  98: 'again!',
#  99: 'when',
#  100: 'f',
#  101: 'approach',
#  102: 'leaders',
#  103: 'sexy',
#  104: 'i',
#  105: 'bus',
#  106: 'panel',
#  107: 'innocence',
#  108: 'von',
#  109: 'knowing',
#  110: 'permanent',
#  111: 'noi',
#  112: 'kendall',
#  113: 'uthisu',
#  114: "time's",
#  115: 'bigger',
#  116: 'stinking',
#  117: 'proved',
#  118: 'gravity',
#  119: 'anna',
#  120: 'kitty',
#  121: 'shirley',
#  122: 'bomb',
#  123: 'implying',
#  124: 'funny',
#  125: 'bare',
#  126: 'jockey',
#  127: 'heights',
#  128: 'suggests',
#  129: 'areu',
#  130: 'cure',
#  131: 'crying',
#  132: 'stag',
#  133: 'holland',
#  134: 'kitchen',
#  135: 'wood',
#  136: 'dilemma',
#  137: 'random',
#  138: 'sparazza',
#  139: 'holiday',
#  140: "ain't",
#  141: 'noone',
#  142: 'grandfather',
#  143: 'half',
#  144: 'nonsense!',
#  145: 'deliberately',
#  146: "thing's",
#  147: 'delivery',
#  148: 'concerns',
#  149: "andy's",
#  150: 'alive',
#  151: 'demonstrate',
#  152: 'decisions',
#  153: 'poetry',
#  154: 'aaron',
#  155: 'san',
#  156: 'lasts',
#  157: 'marlon',
#  158: 'declared',
#  159: 'alma',
#  160: 'war',
#  161: 'kicks',
#  162: 'mother',
#  163: 'control',
#  164: 'likely',
#  165: 'kissed',
#  166: 'helluva',
#  167: 'federal',
#  168: 'ralph',
#  169: 'takes',
#  170: 'avoid',
#  171: 'erase',
#  172: 'unfortunately',
#  173: 'remembering',
#  174: 'whores',
#  175: 'dancing',
#  176: 'felson',
#  177: 'delightful',
#  178: 'help!',
#  179: 'brings',
#  180: 'doubt',
#  181: 'worse',
#  182: 'metal',
#  183: "ordell's",
#  184: 'napoleon',
#  185: 'track',
#  186: 'pond',
#  187: 'under',
#  188: 'bobby',
#  189: 'chicks',
#  190: 'scientist',
#  191: 'sheldon',
#  192: 'dean',
#  193: 'caution',
#  194: 'austin',
#  195: 'red',
#  196: 'investigate',
#  197: 'yelling',
#  198: 'stuff!',
#  199: 'bees',
#  200: 'ummm',
#  201: 'floor',
#  202: 'pieces',
#  203: 'afterwards',
#  204: 'lacking',
#  205: 'love',
#  206: 'same',
#  207: 'nunez',
#  208: 'alcohol',
#  209: 'root',
#  210: 'telephone',
#  211: 'divorce',
#  212: 'ruin',
#  213: 'feet',
#  214: 'wide',
#  215: 'warfare',
#  216: 'obvious',
#  217: 'assuming',
#  218: 'vomit',
#  219: 'williams',
#  220: 'arrives',
#  221: 'frankly',
#  222: 'kidnapping',
#  223: 'sessions',
#  224: 'quarantine',
#  225: 'tone',
#  226: 'sweet',
#  227: 'pension',
#  228: 'altogether',
#  229: 'attempting',
#  230: 'palace',
#  231: 'dialogue',
#  232: 'candles',
#  233: 'humor',
#  234: 'alan',
#  235: 'write',
#  236: 'selfish',
#  237: 'proposition',
#  238: 'nose',
#  239: 'phones',
#  240: 'choke',
#  241: 'oldfashioned',
#  242: 'former',
#  243: 'bob',
#  244: 'alex',
#  245: 'time',
#  246: 'record',
#  247: 'wesley',
#  248: 'located',
#  249: 'nearly',
#  250: 'truck!',
#  251: 'gym',
#  252: 'daniels',
#  253: 'atmosphere',
#  254: 'helicopter',
#  255: 'exotic',
#  256: 'malfunction',
#  257: 'counselor',
#  258: 'tapes',
#  259: 'shows',
#  260: 'cease',
#  261: 'iron',
#  262: 'illness',
#  263: 'thesis',
#  264: 'conscience',
#  265: 'pritchett',
#  266: 'centuries',
#  267: 'corny',
#  268: 'systems',
#  269: 'pointing',
#  270: 'impressive',
#  271: 'up!',
#  272: 'nicholas',
#  273: "driver's",
#  274: 'imagination',
#  275: 'balcony',
#  276: 'earth',
#  277: 'employee',
#  278: 'lifted',
#  279: 'admitting',
#  280: 'advanced',
#  281: 'sitter',
#  282: 'tell',
#  283: 'spirits',
#  284: 'amount',
#  285: 'dearest',
#  286: 'lawyers',
#  287: 'stir',
#  288: 'rowan',
#  289: "everything's",
#  290: '45',
#  291: 'ritual',
#  292: 'fossils',
#  293: 'boast',
#  294: 'request',
#  295: 'misunderstanding',
#  296: 'wigand',
#  297: 'fag',
#  298: 'roy',
#  299: 'interfere',
#  300: 'marquis',
#  301: 'police',
#  302: 'excuses',
#  303: 'sleeping',
#  304: 'marriages',
#  305: 'devil',
#  306: 'bucket',
#  307: 'rule',
#  308: 'uptown',
#  309: 'clip',
#  310: 'idea!',
#  311: 'delusions',
#  312: 'professional',
#  313: 'u',
#  314: 'raise',
#  315: 'rot',
#  316: 'guys!',
#  317: 'remind',
#  318: 'fax',
#  319: 'spends',
#  320: 'noon',
#  321: 'killers',
#  322: 'group',
#  323: 'themselves',
#  324: 'taste',
#  325: 'conrad',
#  326: 'volunteered',
#  327: 'badge',
#  328: 'disappoint',
#  329: 'drag',
#  330: 'dose',
#  331: 'voodoo',
#  332: 'overnight',
#  333: 'responding',
#  334: 'temptation',
#  335: 'yes',
#  336: 'amber',
#  337: 'pressure',
#  338: 'alarm',
#  339: 'obligation',
#  340: 'prospects',
#  341: 'hanging',
#  342: 'crosses',
#  343: 'hunters',
#  344: 'daughters',
#  345: 'living',
#  346: 'stolen',
#  347: 'anarchy',
#  348: 'swimming',
#  349: 'taped',
#  350: 'particles',
#  351: 'safely',
#  352: 'death!',
#  353: 'mind!',
#  354: 'poets',
#  355: 'immediate',
#  356: 'eighteen',
#  357: 'bust',
#  358: 'wash',
#  359: 'medication',
#  360: 'happy!',
#  361: 'break!',
#  362: 'independent',
#  363: 'surfer',
#  364: 'condemned',
#  365: 'groovy',
#  366: 'donald',
#  367: 'plastic',
#  368: 'gwen',
#  369: 'together!',
#  370: 'task',
#  371: 'grant',
#  372: 'reach',
#  373: 'meeks',
#  374: 'maureen',
#  375: 'wants',
#  376: 'ankles',
#  377: 'yup',
#  378: 'trip',
#  379: 'immortal',
#  380: 'process',
#  381: '5',
#  382: 'drapes',
#  383: 'somehow',
#  384: 'whereas',
#  385: 'boy!',
#  386: 'entire',
#  387: 'pentagon',
#  388: 'tigers',
#  389: 'standards',
#  390: 'steve',
#  391: 'bialystock',
#  392: 'darn',
#  393: 'china',
#  394: 'needs',
#  395: 'event',
#  396: 'setup',
#  397: 'mock',
#  398: 'services',
#  399: 'absurd',
#  400: 'gasoline',
#  401: 'confidential',
#  402: 'romance',
#  403: 'ever',
#  404: 'characters',
#  405: 'closing',
#  406: 'cows',
#  407: 'michigan',
#  408: 'mm',
#  409: 'mountains',
#  410: 'small',
#  411: 'toxic',
#  412: 'avoiding',
#  413: 'billion',
#  414: 'baron',
#  415: 'insect',
#  416: 'trick',
#  417: 'keys',
#  418: "blowin'",
#  419: 'eats',
#  420: 'spend',
#  421: 'celebrate',
#  422: 'fits',
#  423: 'door',
#  424: 'forgot',
#  425: 'deserved',
#  426: 'pike',
#  427: 'console',
#  428: 'pushed',
#  429: 'machine',
#  430: 'match',
#  431: '20',
#  432: 'retired',
#  433: 'wondered',
#  434: 'cannon',
#  435: 'chet',
#  436: 'lovebirds',
#  437: 'patriot',
#  438: 'are!',
#  439: 'polite',
#  440: 'bundle',
#  441: 'congratulations',
#  442: 'sacred',
#  443: 'stroke',
#  444: 'paula',
#  445: 'parade',
#  446: 'bowler',
#  447: 'seek',
#  448: "mustn't",
#  449: 'nuts!',
#  450: 'distinctly',
#  451: 'executive',
#  452: 'pitiful',
#  453: 'bright',
#  454: "'im",
#  455: 'manager',
#  456: 'lincoln',
#  457: 'fortress',
#  458: 'chrissake',
#  459: 'spit',
#  460: 'investment',
#  461: 'coverage',
#  462: 'delmar',
#  463: 'experts',
#  464: 'faith',
#  465: 'thoughts',
#  466: 'reckless',
#  467: 'comes',
#  468: 'lighthouse',
#  469: 'nothing',
#  470: 'scumbag',
#  471: 'bunny',
#  472: 'symbol',
#  473: 'messy',
#  474: 'presidential',
#  475: 'contacts',
#  476: 'restless',
#  477: 'care',
#  478: 'goes',
#  479: 'rob',
#  480: 'believe',
#  481: 'buttle',
#  482: 'contract',
#  483: 'handing',
#  484: 'tide',
#  485: 'chairs',
#  486: 'dope',
#  487: 'plenty',
#  488: 'civil',
#  489: 'tanks',
#  490: 'sissy',
#  491: 'betray',
#  492: 'courses',
#  493: 'throws',
#  494: 'pm',
#  495: 'wait',
#  496: 'dishes',
#  497: 'guaranteed',
#  498: 'affected',
#  499: 'purse',
#  500: 'indiana',
#  501: 'disguise',
#  502: 'turned',
#  503: 'merry',
#  504: 'informed',
#  505: 'hire',
#  506: 'patchett',
#  507: 'terrorists',
#  508: "billy's",
#  509: 'gallery',
#  510: 'cash',
#  511: 'parked',
#  512: 'ms',
#  513: 'neo',
#  514: 'annual',
#  515: 'go!',
#  516: 'yourselves',
#  517: 'solve',
#  518: 'tran',
#  519: 'pounds',
#  520: 'checking',
#  521: 'relationship',
#  522: 'two',
#  523: 'martins',
#  524: 'clients',
#  525: 'scratch',
#  526: 'reckon',
#  527: 'movies',
#  528: 'cooler',
#  529: 'myself!',
#  530: "doin'",
#  531: 'everybody',
#  532: 'you!!',
#  533: 'saloon',
#  534: 'television',
#  535: 'cigars',
#  536: 'british',
#  537: 'surge',
#  538: 'un',
#  539: 'perimeter',
#  540: 'adults',
#  541: "parents'",
#  542: 'promotion',
#  543: 'oswald',
#  544: 'times',
#  545: 'point!',
#  546: 'pulling',
#  547: 'lampert',
#  548: 'depressing',
#  549: 'schmuck',
#  550: 'procedures',
#  551: 'werewolf',
#  552: 'game',
#  553: '22',
#  554: 'slave',
#  555: "life's",
#  556: 'for',
#  557: 'insane',
#  558: 'model',
#  559: 'skiing',
#  560: 'packs',
#  561: 'belief',
#  562: 'lottery',
#  563: 'jumped',
#  564: 'wade',
#  565: 'dil',
#  566: 'deck',
#  567: 'face',
#  568: 'kurtz',
#  569: 'lightning',
#  570: 'lama',
#  571: "husband's",
#  572: 'database',
#  573: 'suspect',
#  574: 'baltimore',
#  575: 'experiences',
#  576: 'expected',
#  577: 'basis',
#  578: 'culture',
#  579: 'mitch',
#  580: 'bother',
#  581: "listenin'",
#  582: 'hotel',
#  583: 'redneck',
#  584: 'wondering',
#  585: 'butterfly',
#  586: 'schuyler',
#  587: 'marla',
#  588: 'trusted',
#  589: 'dynamite',
#  590: 'casino',
#  591: 'chum',
#  592: 'totally',
#  593: "dad's",
#  594: 'player',
#  595: 'statements',
#  596: 'fond',
#  597: 'dip',
#  598: 'symphony',
#  599: 'size',
#  600: 'rosa',
#  601: 'left!',
#  602: 'window',
#  603: 'famous',
#  604: 'rolls',
#  605: 'discouraged',
#  606: 'grades',
#  607: 'portion',
#  608: 'force',
#  609: 'chad',
#  610: 'allow',
#  611: 'honestly',
#  612: 'tray',
#  613: 'journal',
#  614: 'spare',
#  615: 'cecile',
#  616: 'permanently',
#  617: 'belong',
#  618: 'recognize',
#  619: 'ted',
#  620: 'discreet',
#  621: 'horizon',
#  622: 'forms',
#  623: 'runs',
#  624: 'attacking',
#  625: 'dug',
#  626: 'studying',
#  627: 'fiancee',
#  628: 'benjamin',
#  629: 'miller',
#  630: 'daddy!',
#  631: 'boarding',
#  632: 'leopard',
#  633: 'holds',
#  634: 'fred',
#  635: 'cast',
#  636: 'how',
#  637: 'implant',
#  638: 'greatness',
#  639: 'albania',
#  640: 'sacrifice',
#  641: 'moms',
#  642: 'ruled',
#  643: 'lion',
#  644: 'barnett',
#  645: 'offices',
#  646: 'ability',
#  647: 'song',
#  648: 'fridge',
#  649: 'decency',
#  650: 'poke',
#  651: 'disbarred',
#  652: 'kidding',
#  653: 'finishing',
#  654: 'exposure',
#  655: 'sixties',
#  656: 'webb',
#  657: 'going',
#  658: 'walter',
#  659: 'jesus!',
#  660: 'cecil',
#  661: 'bottles',
#  662: 'magua',
#  663: 'thousands',
#  664: 'restraining',
#  665: 'apes',
#  666: 'picture',
#  667: 'fool!',
#  668: 'snuck',
#  669: 'painting',
#  670: 'check',
#  671: 'anonymous',
#  672: 'row',
#  673: 'bastard',
#  674: 'mummy',
#  675: 'receipt',
#  676: 'leo',
#  677: 'yes!',
#  678: 'recovery',
#  679: 'biological',
#  680: 'negative',
#  681: 'mexican',
#  682: 'sucks',
#  683: 'pumpkin',
#  684: 'lesbian',
#  685: 'fences',
#  686: 'practical',
#  687: 'insides',
#  688: 'puppet',
#  689: 'terribly',
#  690: 'monkey',
#  691: 'bloodshed',
#  692: 'account',
#  693: "payin'",
#  694: 'solution',
#  695: 'entrance',
#  696: 'arcade',
#  697: 'heaven',
#  698: 'fail',
#  699: 'shirt',
#  700: 'pooch',
#  701: 'sharks',
#  702: "y'all",
#  703: 'lots',
#  704: 'meeting',
#  705: 'employment',
#  706: 'mechanical',
#  707: 'conor',
#  708: 'villain',
#  709: 'shields',
#  710: 'advised',
#  711: 'twentyone',
#  712: 'crunch',
#  713: 'senate',
#  714: 'lovely',
#  715: 'marked',
#  716: 'clerk',
#  717: 'agrees',
#  718: 'husbands',
#  719: 'have',
#  720: 'digging',
#  721: 'presume',
#  722: 'dork',
#  723: 'deeply',
#  724: 'wallpaper',
#  725: 'missile',
#  726: 'customer',
#  727: "how'm",
#  728: 'democrats',
#  729: 'declare',
#  730: 'sheep',
#  731: 'malcolm',
#  732: 'yet',
#  733: 'invention',
#  734: "child's",
#  735: 'gas',
#  736: 'beaten',
#  737: 'salary',
#  738: 'strength',
#  739: 'h',
#  740: 'puzzle',
#  741: 'him!',
#  742: 'toast',
#  743: 'ron',
#  744: 'subconscious',
#  745: 'troubles',
#  746: 'scenes',
#  747: "m'sieu",
#  748: 'navy',
#  749: 'company',
#  750: 'contracts',
#  751: 'explore',
#  752: 'filthy',
#  753: 'things',
#  754: 'remote',
#  755: 'panes',
#  756: 'archie',
#  757: 'ordinary',
#  758: 'spock',
#  759: 'dead!',
#  760: 'petty',
#  761: 'planted',
#  762: 'role',
#  763: 'dorothy!',
#  764: 'partner',
#  765: 'acquaintance',
#  766: 'emotions',
#  767: 'uhaveu',
#  768: 'which',
#  769: 'inquiry',
#  770: 'bastards',
#  771: '18',
#  772: 'philosophy',
#  773: 'oughta',
#  774: 'rain',
#  775: 'slightly',
#  776: 'fake',
#  777: 'no!!!',
#  778: 'pile',
#  779: 'ammo',
#  780: 'brought',
#  781: 'wakes',
#  782: 'basket',
#  783: 'battery',
#  784: 'chiefs',
#  785: 'marrow',
#  786: 'circumstances',
#  787: 'murder',
#  788: 'wisdom',
#  789: 'mmmmm',
#  790: 'czech',
#  791: 'going!',
#  792: 'bore',
#  793: 'ghosts',
#  794: 'names',
#  795: 'alexander',
#  796: 'roommate',
#  797: 'figuring',
#  798: 'afraid',
#  799: 'borrowed',
#  800: 'christine',
#  801: 'distance',
#  802: 'boot',
#  803: 'que',
#  804: 'underground',
#  805: 'circles',
#  806: 'makeup',
#  807: 'swallow',
#  808: 'formal',
#  809: 'explanation',
#  810: 'scaring',
#  811: 'ned',
#  812: 'ruins',
#  813: 'receiving',
#  814: 'thrilled',
#  815: 'love!',
#  816: 'stunt',
#  817: 'prices',
#  818: 'gorgeous',
#  819: 'jealousy',
#  820: 'nigel',
#  821: 'sins',
#  822: 'deaf',
#  823: 'beach',
#  824: 'interior',
#  825: 'blocks',
#  826: 'mercedes',
#  827: 'allergic',
#  828: 'huron',
#  829: 'denying',
#  830: 'sorry!',
#  831: 'columbia',
#  832: 'kastle',
#  833: 'terrance',
#  834: 'letting',
#  835: 'disappeared',
#  836: 'mainframe',
#  837: 'sometimes',
#  838: 'warning',
#  839: 'penthouse',
#  840: 'nanobot',
#  841: 'possibilities',
#  842: 'quaid',
#  843: 'nolan',
#  844: 'asks',
#  845: 'co',
#  846: 'allen',
#  847: 'figures',
#  848: 'youre',
#  849: 'indy',
#  850: 'low',
#  851: 'slice',
#  852: 'luis',
#  853: 'freud',
#  854: 'game!',
#  855: 'kidding!',
#  856: 'principle',
#  857: 'split',
#  858: 'lands',
#  859: 'wish',
#  860: 'spots',
#  861: 'suzie',
#  862: 'birth',
#  863: 'getaway',
#  864: 'government',
#  865: 'communists',
#  866: 'craig',
#  867: 'novel',
#  868: 'dramatic',
#  869: 'urgent',
#  870: 'christmas',
#  871: 'decision',
#  872: 'rooms',
#  873: 'hospital',
#  874: 'wins',
#  875: 'cabinet',
#  876: 'used',
#  877: 'sisters',
#  878: 'line!',
#  879: 'wrap',
#  880: 'invented',
#  881: 'warrior',
#  882: 'donut',
#  883: 'seems',
#  884: 'theme',
#  885: 'worlds',
#  886: 'bernie',
#  887: 'describe',
#  888: 'bourbon',
#  889: 'restaurants',
#  890: 'murderer',
#  891: 'n',
#  892: 'champ',
#  893: 'quadrant',
#  894: 'kindly',
#  895: 'deb',
#  896: 'otis',
#  897: 'coffee',
#  898: 'puff',
#  899: 'encounter',
#  900: 'death',
#  901: 'sandwich',
#  902: 'zoe',
#  903: 'nickname',
#  904: 'natural',
#  905: 'keeper',
#  906: 'carrier',
#  907: 'die',
#  908: 'house',
#  909: 'stanley',
#  910: 'frankenstein',
#  911: 'jumps',
#  912: 'save',
#  913: 'payday',
#  914: 'evil',
#  915: 'superior',
#  916: 'late',
#  917: 'lieutenant',
#  918: 'dumping',
#  919: 'upstairs',
#  920: 'complicated',
#  921: 'passes',
#  922: 'gus',
#  923: 'arrangement',
#  924: 'virginity',
#  925: 'online',
#  926: 'earned',
#  927: 'superstition',
#  928: 'common',
#  929: "jake's",
#  930: 'sanchez',
#  931: 'parking',
#  932: 'class',
#  933: 'hiding',
#  934: 'sane',
#  935: 'dessert',
#  936: 'babe',
#  937: 'earl',
#  938: 'ride',
#  939: 'membership',
#  940: 'bitch',
#  941: 'needle',
#  942: 'structure',
#  943: 'placed',
#  944: 'cooked',
#  945: 'ring',
#  946: 'restaurant',
#  947: 'coincidence',
#  948: 'pamela',
#  949: 'walks',
#  950: 'clearing',
#  951: "d'artagnan",
#  952: 'appetite',
#  953: 'cuervo',
#  954: 'josephine',
#  955: 'tucker',
#  956: 'comic',
#  957: 'trail',
#  958: 'pervert',
#  959: 'large',
#  960: "jack's",
#  961: 'dave',
#  962: 'health',
#  963: 'glades',
#  964: 'seventeen',
#  965: 'splendid',
#  966: 'christian',
#  967: 'middle',
#  968: 'camp',
#  969: 'misunderstood',
#  970: 'existence',
#  971: 'recognized',
#  972: 'ohio',
#  973: 'money',
#  974: 'in!',
#  975: 'weekends',
#  976: 'witnesses',
#  977: 'partial',
#  978: 'championship',
#  979: 'christ!',
#  980: 'senator',
#  981: 'crow',
#  982: 'whatta',
#  983: 'whose',
#  984: 'abort',
#  985: 'liar',
#  986: 'shrimp',
#  987: 'predict',
#  988: 'valentine',
#  989: 'almost',
#  990: 'bingo',
#  991: 'seriously',
#  992: 'gonna',
#  993: 'marcia',
#  994: 'idiots',
#  995: 'psych',
#  996: 'enough',
#  997: 'potential',
#  998: 'queen',
#  999: 'valet',
#  ...}

# %% [markdown]
# # Adding EOS to end of every answers

# %%
for i in range(len(clean_answers)):
    clean_answers[i] += ' <EOS>'

# %% [markdown]
# # Translate all questions and answers into unique integer format

# %%
## Questions
questions_into_int = []
for question in clean_questions:
    ints = []
    for word in question.split():
        if word not in questionswords2int:
            ints.append(questionswords2int['<OUT>'])
        else:
            ints.append(questionswords2int[word])
    questions_into_int.append(ints)
## Answers
answers_into_int = []
for answer in clean_answers:
    ints = []
    for word in answer.split():
        if word not in answerswords2int:
            ints.append(answerswords2int['<OUT>'])
        else:
            ints.append(answerswords2int[word])
    answers_into_int.append(ints)

# %%
questions_into_int
# Out:
# [[5205,
#   8193,
#   2120,
#   2183,
#   5247,
#   8824,
#   8824,
#   1473,
#   1917,
#   8824,
#   6671,
#   6382,
#   7871,
#   4883,
#   8824,
#   1535,
#   4916,
#   2160,
#   6269,
#   3770,
#   8824,
#   6629],
#  [2304,
#   104,
#   3328,
#   8193,
#   4829,
#   5464,
#   7084,
#   8824,
#   1013,
#   4440,
#   2247,
#   6693,
#   7084,
#   2596],
#  [6057, 3770, 8824, 1473, 8824, 1473, 8824, 4081, 3462],
#  [2596,
#   6671,
#   5778,
#   1750,
#   2862,
#   4440,
#   2247,
#   4877,
#   1047,
#   2783,
#   2247,
#   7584,
#   7073,
#   6629],
#  [6915, 6915, 1989, 8605, 4214, 8193, 5782, 719, 6419, 1767, 8824],
#  [4522],
#  [3770,
#   1837,
#   2247,
#   4522,
#   104,
#   7787,
#   6859,
#   3770,
#   6127,
#   2826,
#   6419,
#   3317,
#   8824,
#   7363,
#   2826,
#   5803,
#   8605,
#   7302,
#   104,
#   1161,
#   3647,
#   5389,
#   2043,
#   7835],
#  [1126],
#  [8824,
#   3918,
#   2043,
#   876,
#   4115,
#   90,
#   1509,
#   3239,
#   99,
#   2043,
#   4010,
#   5956,
#   8016,
#   6418,
#   3852,
#   5569,
#   3686,
#   5750,
#   2043,
#   8232,
#   3702,
#   2826,
#   3852,
#   7718,
#   7701],
#  [7714, 1013, 4349, 8193, 8403, 8781, 1881, 6419, 5688],
#  [8824, 2219, 8824, 2183, 2247, 8605, 1200],
#  [1550, 1719, 2596, 6671, 3178, 556, 3770, 8824],
#  [104,
#   4713,
#   1138,
#   4115,
#   8020,
#   636,
#   4115,
#   7418,
#   4440,
#   6379,
#   104,
#   1138,
#   4115,
#   8020,
#   2788,
#   753,
#   5750,
#   3327,
#   3770,
#   1249,
#   4251,
#   6671,
#   636,
#   7970,
#   7835,
#   3,
#   5465,
#   3426,
#   5750,
#   7198,
#   104,
#   719,
#   3866,
#   5317,
#   8605,
#   6435,
#   6961,
#   4115,
#   8543,
#   2862,
#   8605,
#   1200,
#   4115,
#   2817],
#  [4440, 2247, 3903, 1989, 2556, 6419, 8374, 3481],
#  [636, 2247, 7902, 3513, 8781, 3770, 8824, 6419, 3647, 3738, 8824],
#  [3838],
#  [2596, 8232, 7701, 6269, 7584, 4992],
#  [2596, 719, 8605, 3596, 1095, 6419, 2594],
#  [636, 6459, 2596, 4969, 7584, 1671, 4115, 5017, 5750, 4440],
#  [5772, 719],
#  [104,
#   1509,
#   1509,
#   1509,
#   8021,
#   4500,
#   1446,
#   104,
#   1161,
#   6057,
#   7555,
#   8605,
#   7302,
#   478],
#  [2043, 2247, 6057, 6419],
#  [684,
#   6915,
#   104,
#   3528,
#   6419,
#   666,
#   2826,
#   8824,
#   8824,
#   5317,
#   3481,
#   2826,
#   6241,
#   8824,
#   4877,
#   104,
#   7787,
#   1700,
#   5772,
#   2043,
#   2247,
#   6057,
#   8824,
#   8824,
#   8824],
#  [4877, 4440, 2247, 3770, 5903, 2826, 2011, 2043, 2688, 1700, 7416],
#  [1008],
#  [2596, 8020, 8824],
#  [719, 2198, 3375],
#  [104,
#   7973,
#   556,
#   2596,
#   7099,
#   6859,
#   3770,
#   1675,
#   1446,
#   2596,
#   6139,
#   1029,
#   4115,
#   90,
#   1036],
#  [104, 5569],
#  [2304, 6915],
#  [6418, 4440, 2247, 5557, 2596, 6961, 4115, 7418],
#  [1446],
#  [6418,
#   8824,
#   6862,
#   1013,
#   2596,
#   4500,
#   1072,
#   7183,
#   2596,
#   6671,
#   992,
#   5017,
#   5750,
#   7871,
#   2211,
#   6269,
#   8824],
#  [6459, 2596, 2124, 4115, 2183, 4232],
#  [2783, 4232],
#  [1750, 2183, 3507, 1422, 8824, 104, 7787, 5750, 7523, 2418],
#  [104, 5040, 2596, 4829, 4969, 4115, 3770, 1249, 3426, 6263],
#  [2783, 1249, 3426],
#  [3770, 4978, 2596],
#  [104,
#   7787,
#   652,
#   2596,
#   8020,
#   636,
#   837,
#   2596,
#   3686,
#   7056,
#   2183,
#   8824,
#   1473,
#   2596,
#   4713,
#   8020,
#   636,
#   4115,
#   8523],
#  [6915],
#  [7033],
#  [2043, 6693],
#  [5456, 6459, 6774],
#  [7428, 2596, 6714, 7584, 1671],
#  [6915],
#  [3327, 7428, 1224, 4500, 1224, 5569, 3686, 4235],
#  [7226],
#  [5923],
#  [1224,
#   3958,
#   6535,
#   99,
#   1224,
#   3528,
#   2862,
#   8193,
#   6961,
#   3770,
#   206,
#   8824,
#   104,
#   4191,
#   2212,
#   8824,
#   2247,
#   5923,
#   7871,
#   5557,
#   1446,
#   1224,
#   2247,
#   6057,
#   2630,
#   6171,
#   1675,
#   8785],
#  [2247, 1224, 8824, 7718, 6756],
#  [5869,
#   104,
#   4713,
#   1731,
#   3770,
#   8824,
#   2826,
#   7019,
#   7087,
#   8824,
#   6671,
#   657,
#   4115,
#   8128,
#   8824,
#   1473,
#   8824],
#  [837,
#   104,
#   1921,
#   1013,
#   3770,
#   2430,
#   8193,
#   6671,
#   3591,
#   4115,
#   1138,
#   4115,
#   4500,
#   2862,
#   7084,
#   6671,
#   3770,
#   7416,
#   8193,
#   5299,
#   1138,
#   4115,
#   4500,
#   2862,
#   7084,
#   2596,
#   8020],
#  [104, 719, 4115, 90, 6282, 5317, 6033, 1910],
#  [2596, 1731, 2596, 2331, 5914, 3770, 4349, 8824, 6859, 3770, 7327],
#  [1989, 7389],
#  [2630, 4877, 2596, 657, 4115, 8824, 8824, 1837, 6269, 3939],
#  [4877,
#   4207,
#   104,
#   719,
#   8232,
#   3770,
#   8824,
#   8824,
#   1837,
#   657,
#   1473,
#   3770,
#   2478,
#   7013,
#   2323,
#   4440,
#   2247,
#   992,
#   90,
#   3093,
#   1473,
#   6418,
#   104,
#   7787,
#   2160,
#   556,
#   7871,
#   7995,
#   556,
#   998,
#   4689,
#   8500,
#   4985],
#  [998, 4689],
#  [7119],
#  [5052, 226, 4446],
#  [1008, 7087],
#  [2124, 104, 1138, 4115, 4447, 4115, 2596, 4196, 3770, 7327],
#  [3327, 719, 2596, 2536],
#  [104,
#   719,
#   3770,
#   997,
#   4115,
#   4852,
#   3770,
#   4232,
#   2862,
#   2826,
#   2596,
#   1013,
#   2596,
#   4713,
#   4969,
#   2862,
#   2826,
#   8605,
#   8006],
#  [8784, 8605, 4241, 7835, 2183, 4191, 2596, 6671, 3440, 3648],
#  [3852, 2184, 4440, 8824, 2247, 6896, 6859, 2837, 8548, 1473, 8193, 6671, 657],
#  [8784,
#   104,
#   3328,
#   2596,
#   6225,
#   719,
#   6419,
#   3647,
#   104,
#   4713,
#   8020,
#   1126,
#   104,
#   7787,
#   8390,
#   4115,
#   5550,
#   1446,
#   6671,
#   2596,
#   657,
#   4115,
#   8824,
#   8824,
#   1675,
#   3939,
#   5529],
#  [2783, 6459, 2596, 1731],
#  [2596,
#   6671,
#   5351,
#   8605,
#   8824,
#   3903,
#   2596,
#   4566,
#   6057,
#   90,
#   3648,
#   104,
#   1161,
#   90,
#   3648],
#  [2783, 2247, 3648],
#  [1161, 2596, 5797, 556, 3686, 3481, 5529, 4440, 2596, 6671, 3625, 2768],
#  [5750, 104, 7787, 3591, 4115, 8020, 2783, 4440, 5728, 2184],
#  [1989, 2538, 1634, 2596, 719, 1000, 2826, 6465],
#  [2596, 6671, 4877, 3625, 8824],
#  [5869, 104, 26, 4115, 4447, 4115, 2596, 104, 26, 4115, 282, 2596],
#  [104,
#   4713,
#   4969,
#   2596,
#   2596,
#   1560,
#   5750,
#   2596,
#   6671,
#   3745,
#   1249,
#   556,
#   1072,
#   2826,
#   2183,
#   1473,
#   6418,
#   2596,
#   4500,
#   592,
#   8824,
#   99,
#   2596,
#   4969,
#   4235],
#  [2124,
#   104,
#   8020,
#   2596,
#   7529,
#   6382,
#   4115,
#   4104,
#   6282,
#   3903,
#   104,
#   7787,
#   6057,
#   4843,
#   5956,
#   8016],
#  [5750, 2596, 477],
#  [104,
#   6459,
#   477,
#   1446,
#   104,
#   7787,
#   6419,
#   6620,
#   3059,
#   5317,
#   5090,
#   7701,
#   556,
#   7584,
#   2529,
#   1669,
#   6057,
#   2817,
#   5524,
#   2331,
#   5073],
#  [7087, 3866, 6252, 2596, 8193, 7533, 2862, 7428, 1224],
#  [2783],
#  [5317, 8824, 556, 6419, 7017],
#  [1126],
#  [1224, 5569, 5750, 6419, 1210, 936],
#  [1446, 2596, 7529, 7087],
#  [4769, 104, 6459, 7099, 6418, 5569, 6419, 1172, 1941],
#  [1224, 2784, 8593, 5569, 5090, 3852, 4877, 104, 7428, 3852],
#  [2596, 7428, 2783],
#  [1446],
#  [3629,
#   4440,
#   104,
#   3011,
#   104,
#   4829,
#   3866,
#   6459,
#   5885,
#   3686,
#   3903,
#   8593,
#   5524,
#   5569,
#   5090,
#   3852,
#   1473,
#   104,
#   4784,
#   4995,
#   7006,
#   556,
#   8824,
#   1675,
#   1473,
#   8605,
#   8824,
#   8824,
#   5024],
#  [1126, 5782, 2596, 282, 1750],
#  [104, 6366, 4115, 5628, 2596, 2120, 2160, 7584, 2529, 4992, 4196, 6465],
#  [4440, 2247, 6057],
#  [104, 7787, 6057, 3824, 996, 4115, 1241, 7584, 6597],
#  [104, 4401, 104, 3328, 104, 5569, 3552, 2596],
#  [4241,
#   2596,
#   6671,
#   3686,
#   5750,
#   741,
#   3686,
#   4478,
#   1750,
#   7367,
#   1693,
#   5317,
#   3770,
#   8562,
#   4877,
#   104,
#   1161,
#   4238,
#   5885,
#   556,
#   2418],
#  [6057,
#   5557,
#   575,
#   6671,
#   1249,
#   5869,
#   2596,
#   1161,
#   6139,
#   6224,
#   3770,
#   6884,
#   2596,
#   1138,
#   4115],
#  [2596, 7973, 4846, 6411, 5529, 2596, 8020],
#  [5628, 515],
#  [2596, 2407, 1750, 2160],
#  [104, 3686, 6366],
#  [2783, 4115, 3625, 1555, 1750, 4115, 2585, 1750, 4115, 6426, 4712, 2783],
#  [2247, 4440, 7953, 6419, 2128, 8824, 7718, 2247, 3852, 3686, 1750],
#  [8798, 2247, 4440, 6419],
#  [4769,
#   4713,
#   4969,
#   6502,
#   6149,
#   1446,
#   2240,
#   2183,
#   1344,
#   1473,
#   104,
#   1731,
#   1224,
#   6225,
#   5550],
#  [6347,
#   2596,
#   6671,
#   6057,
#   7019,
#   5389,
#   7584,
#   7302,
#   3586,
#   7019,
#   4397,
#   2826,
#   4129],
#  [2783, 1013, 2043, 3866, 3586, 7019],
#  [6418, 6527, 4566, 2596, 1473, 104, 4566, 4969, 4115, 2292, 6859, 5529],
#  [1446, 2043, 1321, 1138, 4115, 3647],
#  [6149, 104],
#  [1473, 3327, 6671, 2596, 657],
#  [1013,
#   2596,
#   3370,
#   8020,
#   8193,
#   7446,
#   229,
#   4115,
#   4500,
#   4115,
#   6419,
#   410,
#   7245,
#   322,
#   2826,
#   4399],
#  [8185, 7558, 1095, 7871, 8824],
#  [6149, 6884, 4461, 1750, 4115, 90, 7504],
#  [8784, 4241, 1989, 2527],
#  [8039, 3770, 2225, 7227, 2596, 4500],
#  [6149, 6347],
#  [8744,
#   1750,
#   2596,
#   4566,
#   6057,
#   4447,
#   4115,
#   1072,
#   8423,
#   7555,
#   7584,
#   7302,
#   2247,
#   1417],
#  [1126],
#  [6149, 104, 1138, 4115, 2442, 3770, 7327, 7084, 2596, 1989, 1695, 5529],
#  [3770, 7327, 1881, 4584, 6419, 3647],
#  [6915, 1446],
#  [1989,
#   4440,
#   5922,
#   4152,
#   7087,
#   1550,
#   4440,
#   2331,
#   5073,
#   7226,
#   2596,
#   1138,
#   1750,
#   4115,
#   4589,
#   8605,
#   6360,
#   556],
#  [1224, 2247, 6057, 6419, 5922, 4152, 4455, 4440, 2247],
#  [2596, 6671, 6057, 657, 7555, 7584, 7302, 478, 4397, 2826, 1941],
#  [104, 7787, 5770, 7701],
#  [6139, 6419, 2934, 8824],
#  [5782,
#   719,
#   2596,
#   8824,
#   556,
#   6419,
#   8824,
#   5946,
#   5600,
#   5456,
#   6419,
#   3513,
#   3745,
#   8824,
#   8824,
#   945,
#   556,
#   2596],
#  [5946, 2826, 6419, 5946, 2596, 1719, 6419, 8268, 2826, 8824, 3718, 5317],
#  [3866],
#  [8824,
#   3516,
#   3481,
#   3039,
#   7633,
#   1821,
#   3770,
#   4953,
#   3481,
#   1009,
#   4230,
#   1473,
#   8824],
#  [2596, 3770, 2446, 2011],
#  [4877, 5456, 282, 1750],
#  [4877, 768, 2410, 2596, 2434],
#  [3432, 5299, 636, 4829, 2596],
#  [104, 5569, 652, 6884, 5299, 4439, 3838],
#  [4207, 6419, 8268, 8193, 6671, 8824, 4147, 3770, 406, 6379],
#  [636, 8645, 6884, 7446, 5317, 7584, 8715, 8016],
#  [6388],
#  [4969, 3623],
#  [636, 8645, 6884, 4500, 4235],
#  [4440, 104, 7787, 876, 4115],
#  [4440, 6489, 104],
#  [2596, 2661, 2596, 47, 2596, 8824],
#  [7226, 2247, 2043],
#  [5869, 8824, 8824, 4713, 5728, 1731, 4196, 3852],
#  [1126, 6057],
#  [1126, 6459, 3516, 5750, 4440, 6139, 5750, 2430, 5750, 4440],
#  [3903,
#   5456,
#   6671,
#   8824,
#   4115,
#   1074,
#   7460,
#   4069,
#   2430,
#   5750,
#   4440,
#   1473,
#   1074,
#   8824,
#   7227,
#   1208,
#   1074,
#   4802,
#   8063,
#   2247,
#   1395,
#   8824],
#  [1224, 6139, 719, 4440, 8824, 8824],
#  [2596, 8020, 8532],
#  [5772, 6459, 8605, 0, 2434, 5971],
#  [4401, 7226, 3686, 6536, 2160, 556, 6419, 8824],
#  [2596, 4191, 104, 4829, 4969, 6419, 7781, 4115, 4447, 4115, 6241],
#  [4207, 3686, 6419, 2012, 899, 7084, 3770, 8824],
#  [4440, 2247, 6241, 8824, 7302],
#  [104,
#   7012,
#   6241,
#   8532,
#   4969,
#   4115,
#   8020,
#   6241,
#   8824,
#   6241,
#   7084,
#   3120,
#   1473,
#   2043,
#   6570,
#   5317,
#   205,
#   7084,
#   1750],
#  [2783, 4196, 6465],
#  [2783, 3384, 2596, 1731, 1224, 4566, 6459, 3852],
#  [1224, 883, 5750, 1224, 8824, 6269, 3500],
#  [6915,
#   652,
#   1224,
#   2247,
#   6419,
#   1343,
#   104,
#   1000,
#   1224,
#   2954,
#   6419,
#   4382,
#   8824,
#   6269,
#   6281,
#   1224,
#   3686,
#   8232,
#   2862,
#   2826,
#   8824],
#  [5456, 6139, 5628, 8824, 4104, 5317, 6269, 8824, 8824],
#  [104,
#   7787,
#   7163,
#   7882,
#   1224,
#   2247,
#   7801,
#   1224,
#   35,
#   3664,
#   2529,
#   3381,
#   6269,
#   3770,
#   8247,
#   1785,
#   4877,
#   1224,
#   8403,
#   3759,
#   2446,
#   8824],
#  [5797, 3664, 3025, 6459, 2596, 1731, 8193, 719, 8232, 6419, 3738, 7718, 6057],
#  [7428, 2043, 5299, 7418, 2043, 4829, 4500, 2862, 7084, 2596],
#  [2596,
#   8020,
#   1013,
#   2596,
#   6459,
#   4500,
#   2862,
#   7084,
#   5869,
#   2596,
#   4829,
#   90,
#   2407,
#   2596,
#   4829,
#   8824,
#   8593,
#   2992,
#   8824,
#   7084,
#   1750,
#   4147,
#   7584,
#   1035],
#  [104, 3328, 2596, 5460, 8410, 6884],
#  [2596, 8232, 6465, 5371],
#  [2183,
#   2247,
#   3852,
#   6419,
#   3831,
#   4294,
#   8798,
#   5205,
#   5550,
#   8824,
#   4115,
#   3770,
#   1675],
#  [5317, 4440, 5178, 8193, 4566, 26, 4115, 2120, 3852, 6419, 8824, 6190, 2862],
#  [4566, 8824, 4969, 3022],
#  [8037, 3481, 2043, 5405, 8824],
#  [1989, 6419, 5516, 8168, 2709],
#  [6241, 4137, 2663],
#  [1224, 2247, 8824],
#  [8824, 7584, 7589, 556, 3481, 5529],
#  [2596, 6252, 1750, 4440, 4081, 7116],
#  [3122, 4797, 1500],
#  [3770,
#   8427,
#   2247,
#   4440,
#   2783,
#   5903,
#   2826,
#   8824,
#   3686,
#   1377,
#   2160,
#   6419,
#   6489,
#   1473,
#   4730,
#   6241,
#   1693,
#   8297,
#   2596,
#   6671,
#   2995,
#   4115,
#   6241],
#  [8824, 8824, 1446, 5052, 2596, 6671, 3901, 8597],
#  [2596,
#   2226,
#   3770,
#   8740,
#   640,
#   2813,
#   6269,
#   3770,
#   8824,
#   2826,
#   1808,
#   1473,
#   5728,
#   3770,
#   1236],
#  [1473, 1224, 2184, 4440, 2992, 5317, 6419, 5801, 8824, 8043, 2826, 8006],
#  [2783, 719, 2596, 8232, 556, 1750],
#  [6693,
#   2688,
#   8824,
#   8545,
#   8824,
#   8824,
#   1473,
#   6014,
#   8824,
#   6489,
#   4481,
#   2826,
#   3770,
#   8824,
#   8824],
#  [8824, 2247, 6896, 3838, 1695, 5529],
#  [4522, 104, 7787, 6419, 3513, 6944],
#  [2783, 6671, 2596, 2995, 4196],
#  [4522, 6459, 2596, 5750, 3770, 6489],
#  [5772],
#  [2783, 4829, 2596, 6459, 4115, 6241],
#  [2043,
#   5405,
#   2596,
#   7084,
#   3770,
#   6281,
#   2826,
#   6419,
#   7867,
#   8824,
#   4440,
#   2247,
#   6419,
#   4517,
#   2749],
#  [2596, 3116, 1072, 8824],
#  [2043, 165, 1750],
#  [2783, 2247, 3770, 5996],
#  [3770, 8824, 5017, 2247, 5519, 1881, 4784, 2596, 2536, 6311, 7584, 8824],
#  [4207,
#   1473,
#   104,
#   4581,
#   3770,
#   4349,
#   4081,
#   2826,
#   2596,
#   8824,
#   5317,
#   7584,
#   8478,
#   8824,
#   3672,
#   5569,
#   7584,
#   6034,
#   8764,
#   4916],
#  [5052, 6459, 2596, 4992],
#  [3327, 2959, 6707],
#  [1693],
#  [8340, 8605, 7302, 4838],
#  [4207],
#  [522, 5415, 8374, 7950],
#  [4207, 4455, 104, 1138, 2596, 4115, 4500, 2862, 7084, 6241],
#  [5772, 8824, 104, 4566, 4969, 1550, 6269, 3852],
#  [2596, 3686, 2784],
#  [2596, 26, 973, 4115, 1338, 6419, 6489, 2862],
#  [2596, 8232, 3852, 1317, 104, 5335, 2160, 3770, 7223, 2596, 6459, 3770, 8824],
#  [2596, 6671, 992, 6531, 1750, 4115, 1338, 2862, 6334, 6489],
#  [104,
#   1161,
#   3647,
#   6241,
#   7302,
#   5389,
#   4440,
#   3481,
#   8445,
#   6419,
#   5688,
#   1473,
#   4440,
#   2247,
#   3770,
#   2071,
#   2043,
#   1321,
#   1138,
#   6419,
#   5688],
#  [104, 1161, 1338, 6419, 6489, 5750, 4440, 2862, 6269, 6033, 1648],
#  [1338, 3852, 7718, 8340, 3852, 2183, 7147, 6419, 2013],
#  [99, 104, 4528, 2862, 1435, 104, 4461, 4402],
#  [104, 7787, 6269, 3852],
#  [7193, 3770, 940, 6087, 8605, 1450, 1321, 3920, 1095, 6419, 3647],
#  [104, 3686, 8824, 8605, 3811],
#  [2783],
#  [6419, 6456, 1648, 6419, 3647],
#  [5797, 3852],
#  [1989, 4196, 245],
#  [636, 4829, 2596, 6459, 3852],
#  [6459, 2783],
#  [104, 4713, 8020, 8824, 3770, 8824, 5949, 5596, 6456, 556, 3770, 8824],
#  [5052],
#  [6671, 2596, 4921],
#  [1258, 3686, 1276, 4147, 4115, 7198],
#  [8193, 4713, 7198],
#  [2304,
#   5299,
#   104,
#   3328,
#   104,
#   4829,
#   2349,
#   7871,
#   3309,
#   4147,
#   2596,
#   2596,
#   8020,
#   3686,
#   4115,
#   1719,
#   1013,
#   2596,
#   6671,
#   7141],
#  [1446,
#   2043,
#   1161,
#   4500,
#   2862,
#   7084,
#   2596,
#   3903,
#   6241,
#   7302,
#   2247,
#   2183,
#   557,
#   1200,
#   5178,
#   1473,
#   6915,
#   3481,
#   4566,
#   4500,
#   2862,
#   7084,
#   6241,
#   1550],
#  [7835, 2183, 8785, 719, 6419, 3428],
#  [104, 4701, 2596, 6671, 8824, 1317],
#  [7776, 4207, 8193, 6671, 8715, 8824],
#  [2596, 1473, 1317],
#  [2596, 1968, 6057, 2678, 2183, 2160, 104, 7787, 5066, 8222],
#  [5216, 4440],
#  [8798, 1317, 137, 8824],
#  [4440,
#   2247,
#   6494,
#   1317,
#   3770,
#   3481,
#   7226,
#   5569,
#   5406,
#   556,
#   6419,
#   7159,
#   104,
#   1000,
#   1224,
#   5569,
#   5090,
#   4472,
#   527],
#  [104, 7787, 5772, 1224, 2247, 3625, 6423, 2826, 5090, 5885, 4440, 5540],
#  [1224, 6139, 5017, 4877],
#  [8824, 6781, 7903, 2813, 2247, 6419, 8806, 1635, 8006, 4115, 907],
#  [2783, 2247, 2183],
#  [104,
#   4959,
#   4440,
#   3770,
#   8494,
#   2826,
#   2183,
#   4696,
#   4741,
#   6671,
#   8824,
#   204,
#   1446,
#   6960,
#   2813,
#   4877,
#   2596,
#   5205,
#   90,
#   7084,
#   2965,
#   2538,
#   2247,
#   4458,
#   3770,
#   1806,
#   2826,
#   3648,
#   1361,
#   8824,
#   2596,
#   6671,
#   8824,
#   8514,
#   5837,
#   8336,
#   4447,
#   8698,
#   8824,
#   1473,
#   6956,
#   3770,
#   8369,
#   2826,
#   8410,
#   7226,
#   26,
#   8806,
#   7963,
#   6426],
#  [3770, 6884, 6859, 2183, 8016, 6671, 4877, 4883, 3454],
#  [4877,
#   1224,
#   4584,
#   2183,
#   3093,
#   8824,
#   4380,
#   4196,
#   1792,
#   6709,
#   1473,
#   8824,
#   4440,
#   104,
#   4500,
#   4115,
#   3664,
#   8824,
#   8824,
#   8824,
#   1344,
#   8037,
#   3481,
#   4381,
#   6117,
#   8016,
#   104,
#   719,
#   6915,
#   7418,
#   6859,
#   5557],
#  [2965, 4829, 3866, 719, 5406, 4115, 6419, 4382, 8016],
#  [2965, 5782, 5728, 4500, 4115, 5956, 8016],
#  [4440, 2247, 3866, 2536, 3501],
#  [104,
#   5376,
#   7584,
#   4307,
#   4772,
#   6419,
#   8824,
#   900,
#   1446,
#   104,
#   7787,
#   8824,
#   6459,
#   2596,
#   4992],
#  [7835, 3852, 2543],
#  [2596, 1731, 2183, 4566, 8437],
#  [2783, 4829, 1224, 7418],
#  [2596,
#   7533,
#   4115,
#   3770,
#   1675,
#   104,
#   3328,
#   8193,
#   7446,
#   8105,
#   5186,
#   4115,
#   8824,
#   7532,
#   1380],
#  [104, 5782, 719, 6419, 8203],
#  [2596,
#   5782,
#   719,
#   6419,
#   8203,
#   3327,
#   2247,
#   1881,
#   1473,
#   2783,
#   719,
#   2596,
#   8042,
#   7084,
#   6241],
#  [104, 7428, 5869, 6419, 7121, 1473, 3852, 8824],
#  [2596, 5782],
#  [5205,
#   2596,
#   5728,
#   1991,
#   7226,
#   3770,
#   8427,
#   4829,
#   4500,
#   4115,
#   2183,
#   6419,
#   8824,
#   2826,
#   1904,
#   8824],
#  [2304, 104, 4401, 8193, 6671, 6057, 4995, 8193, 4713, 719, 3371],
#  [2124,
#   4115,
#   2282,
#   2596,
#   3444,
#   5750,
#   2849,
#   5557,
#   8414,
#   2388,
#   3903,
#   756,
#   2247,
#   7314,
#   7330],
#  [6693,
#   6693,
#   8193,
#   4566,
#   6057,
#   4500,
#   1989,
#   6057,
#   5750,
#   104,
#   719,
#   6419,
#   5181,
#   2448],
#  [2596,
#   2331,
#   5914,
#   7687,
#   6859,
#   2183,
#   2434,
#   3770,
#   8171,
#   5917,
#   8193,
#   6671,
#   3901,
#   6419,
#   1840],
#  [719, 2596, 7790, 6465],
#  [7226],
#  [2965, 1224, 2197, 1750, 4115, 2690, 6465, 4235],
#  [104, 4191, 7953, 636, 2959, 530],
#  [7039, 5750, 6419, 7317, 5299, 1473, 2813],
#  [2240, 6419, 8006, 4115, 4969, 6419, 4412, 8324],
#  [5335, 2596, 2160, 5060, 6418],
#  [3770,
#   5529,
#   104,
#   1338,
#   2596,
#   4115,
#   8717,
#   2596,
#   719,
#   3866,
#   2536,
#   7227,
#   1473,
#   7099],
#  [5750,
#   3327,
#   3770,
#   8824,
#   6269,
#   8824,
#   6459,
#   2596,
#   5728,
#   8020,
#   8605,
#   7073,
#   8824],
#  [2596, 7529, 1750, 4713, 2596],
#  [104, 4713, 1509, 1731, 2596, 7637, 4440, 5214, 7871, 8325],
#  [6418, 7418, 2596, 4566, 420, 8628, 5529, 6859, 3770, 185, 7084, 1750],
#  [1473, 1126, 4829, 104, 6459, 4440],
#  [3718,
#   6269,
#   3770,
#   8824,
#   3770,
#   5609,
#   7965,
#   2596,
#   7084,
#   973,
#   5317,
#   7584,
#   4986,
#   1750,
#   7084,
#   8605,
#   5490,
#   6269,
#   7584,
#   7702],
#  [2596, 8537, 5317, 8605, 218],
#  [6671, 2596, 1457, 1750],
#  [104,
#   5569,
#   5317,
#   3770,
#   8824,
#   104,
#   5425,
#   7584,
#   1450,
#   3328,
#   104,
#   4829,
#   7418,
#   1008],
#  [2596, 6671, 6057, 6419, 8478, 8824, 6671, 2596],
#  [5052, 5923, 8698, 3125],
#  [2886, 1750],
#  [4440, 2247, 2783, 2596, 1138, 7147, 3852],
#  [2596,
#   8020,
#   4610,
#   2430,
#   6671,
#   6915,
#   8824,
#   4711,
#   7718,
#   3770,
#   8824,
#   1446,
#   5456,
#   6671,
#   1550,
#   2160,
#   3838],
#  [2596, 8020, 7226, 3770, 8824, 6671],
#  [2783, 2247, 2183],
#  [104,
#   7787,
#   2093,
#   8824,
#   7882,
#   7147,
#   4440,
#   2783,
#   2596,
#   6671,
#   3591,
#   4115,
#   6459,
#   6859,
#   6419,
#   1675],
#  [104, 7418, 6459, 2783, 2596, 8021, 6459],
#  [6693],
#  [2596, 6671, 6057, 6693],
#  [104, 3686, 26, 4115, 3121, 8748, 556, 6179],
#  [7776, 7776, 2596, 3121, 8748, 1473, 2596, 4566, 4500, 4115, 2292],
#  [104, 8020, 3686, 5628, 1750, 2292],
#  [2183, 2247, 4877, 8824],
#  [8340, 3852, 4115, 2596, 4115, 1202, 8478, 2890, 99, 2596, 6671, 8824],
#  [1126, 6671, 2596, 5090, 2183],
#  [104, 6252, 2596],
#  [2596, 4713, 477, 1013, 104, 907],
#  [5772, 104, 6459],
#  [1126],
#  [3903, 6418, 104, 4829, 719, 4115, 5464, 7314, 2862, 3516, 7226, 5750, 1750],
#  [5750, 2596, 8403, 8781, 3481],
#  [1719, 4440, 7226, 394, 5174, 99, 104, 719, 8232, 5571, 4330],
#  [1126, 4829, 2596, 5628, 6465, 4969, 4115, 2596],
#  [7226],
#  [8824],
#  [104, 7529, 6465],
#  [104,
#   8020,
#   3852,
#   4829,
#   719,
#   4115,
#   90,
#   6419,
#   1700,
#   8478,
#   6118,
#   4115,
#   4969,
#   2596,
#   4115,
#   8824,
#   1043,
#   2596,
#   4713,
#   1931,
#   5750,
#   3770,
#   8043],
#  [5052,
#   7882,
#   2596,
#   1656,
#   2331,
#   6108,
#   1731,
#   104,
#   5205,
#   90,
#   3302,
#   2596,
#   4713,
#   1731,
#   104,
#   5205,
#   90,
#   6173,
#   7099,
#   5750,
#   8593,
#   5524],
#  [104, 3328, 2596, 7446, 7828, 5557, 4440],
#  [8824, 3185, 271],
#  [1473, 104, 7787, 5317, 163, 2826, 3852],
#  [99, 2596, 7446, 5406, 6411, 7159, 3327, 7446, 2596],
#  [6944],
#  [7446, 2596, 5317, 5098],
#  [1634],
#  [6915, 2596, 3707],
#  [6418, 1126, 4829, 2596, 5550],
#  [104, 2960, 6459, 2183],
#  [6459, 2783],
#  [5464, 6419, 4497],
#  [8605, 8221, 4205, 2994, 2826, 4440, 4440],
#  [8784, 4877, 4769, 2596, 1731, 2596, 8020, 1750],
#  [4877,
#   2783,
#   2331,
#   5073,
#   2160,
#   7084,
#   7584,
#   2276,
#   1224,
#   6419,
#   4831,
#   5317,
#   3770,
#   7702],
#  [1224, 3686, 375, 1750, 4115, 90, 2817, 104, 7787, 6057],
#  [7226],
#  [5869],
#  [2886, 1750, 719, 2596, 7790, 3770, 8824, 8824, 104, 4921, 8605, 1222],
#  [2783, 6671, 2596, 5090, 4235],
#  [104, 1000, 3838, 5569, 6419, 153, 6311],
#  [2596, 6671, 4877],
#  [8824],
#  [8824],
#  [8824, 104, 4401, 2817, 1569, 4584, 6241, 5051, 5317, 6419, 7746],
#  [4713,
#   556,
#   3481,
#   5231,
#   1731,
#   4440,
#   2596,
#   6961,
#   1072,
#   5273,
#   6789,
#   6269,
#   8605,
#   5051],
#  [4877, 2783, 7428, 104, 719, 7871, 5273, 6269],
#  [1224, 601, 104, 8824, 3770, 8824, 1473, 1224, 8824, 6269, 1750],
#  [104, 4401, 104, 3866, 6252, 2596, 104, 7787, 798, 2826, 127],
#  [4450, 1989, 6057, 4440, 2105],
#  [4702, 7584, 1550, 5548, 3838],
#  [5797, 3852, 104, 7787, 5012],
#  [2596, 1138, 1750, 4115, 3373, 2160, 1473, 8698, 2596, 636, 4115, 4969, 8748],
#  [3770, 8824, 7176],
#  [104,
#   5040,
#   3852,
#   6961,
#   4115,
#   90,
#   7701,
#   1085,
#   4115,
#   2716,
#   7584,
#   7899,
#   1473,
#   8763,
#   2596,
#   2388],
#  [1249, 3784],
#  [4877, 636, 4829, 2596, 4969, 8824, 4115, 5017, 3770, 4953, 8006],
#  [6419, 3408, 1035, 7226, 1879],
#  [4207, 2304, 4713, 5628, 3852, 4969, 2862],
#  [4877, 2783, 2247, 7584, 2886],
#  [5638, 3770, 8006, 8193, 6459],
#  [335],
#  [104,
#   4713,
#   5750,
#   4115,
#   6459,
#   2783,
#   6884,
#   4461,
#   6418,
#   5456,
#   4461,
#   3852,
#   5557,
#   3770,
#   245,
#   1473,
#   5456,
#   4969,
#   6044,
#   99,
#   2596,
#   6714],
#  [4877, 1013, 2596, 328, 1208, 2434, 3770, 5464, 2596, 6671, 8537],
#  [7701, 5750, 4440],
#  [6418, 2596, 4486, 2160],
#  [636],
#  [2596, 2160, 556, 3852],
#  [4382, 8824],
#  [8824],
#  [3770, 52],
#  [8824],
#  [282, 1750, 7701, 6725],
#  [104, 7529, 8824],
#  [6915, 7701, 4978, 7701, 6915, 3481, 5524, 1729],
#  [2596, 6671, 226, 1473, 103, 1473, 3625, 5922, 556, 1750],
#  [2783],
#  [6915, 3481, 5524, 1729],
#  [2596, 6671, 8824, 8824, 4584, 5016, 403, 6252, 2596, 4440],
#  [2247, 4440, 6419, 294, 7718, 6419, 8216],
#  [2596, 8020, 2783, 104, 4191],
#  [6915],
#  [6915, 2783],
#  [6915, 104, 4566, 6057, 4500, 7084, 2596],
#  [1126, 6057],
#  [5578, 6419, 3513, 4018, 5464, 6419, 2446, 2000, 2783],
#  [4877, 104, 719, 4115, 719, 6419, 1813, 4115, 90, 7084, 2596],
#  [2596, 282, 1750],
#  [2596, 26, 6426, 4584, 5016, 403, 6252, 2596, 4440],
#  [1559, 3770, 1434, 8798],
#  [636, 4829, 2596, 4969, 6419, 8824, 6859, 3770, 6411, 5231],
#  [1989, 8824, 3664, 3647, 8232, 4929, 3327, 4829, 2596, 4969, 3770, 5181],
#  [1989, 3686, 7701, 104, 6961, 2596, 8020],
#  [8784, 3125],
#  [8605, 8824],
#  [2783],
#  [4440, 2331, 5073, 3625, 8824],
#  [495, 104],
#  [2596,
#   7446,
#   1721,
#   4115,
#   1338,
#   1750,
#   3623,
#   4147,
#   3770,
#   3481,
#   6018,
#   104,
#   6856,
#   7529,
#   104,
#   1879,
#   3852,
#   5569,
#   6419,
#   8824],
#  [3852, 1759, 5750, 4440],
#  [1509,
#   2783,
#   5569,
#   3852,
#   5750,
#   6419,
#   8748,
#   2340,
#   4769,
#   6418,
#   6419,
#   2712,
#   556,
#   303,
#   7084,
#   1750],
#  [6419, 8824, 8824, 2596, 4259, 2183],
#  [6005,
#   104,
#   6961,
#   6334,
#   2211,
#   510,
#   6334,
#   8076,
#   1721,
#   1750,
#   4115,
#   1338,
#   2862,
#   6419,
#   1509,
#   5923,
#   6489],
#  [2247, 4440, 1550],
#  [1126, 2247, 8605, 8824, 4607, 3770, 4349, 2531, 2649, 6269, 2183, 8824],
#  [3903, 104, 5750, 4115, 7484, 2596],
#  [8784, 5869, 5205, 2596, 4969, 1750, 8605, 7721, 8824],
#  [104, 8020],
#  [104,
#   3328,
#   8193,
#   3194,
#   2596,
#   7446,
#   657,
#   4115,
#   8016,
#   4235,
#   6859,
#   313,
#   2826,
#   8824],
#  [2183, 2434, 2817, 983, 2595, 2247, 1511, 4115, 4137, 8824, 1041],
#  [8605, 2780, 7835, 6057, 1368, 7815],
#  [6418, 282, 1208, 104, 6961, 6419, 8824],
#  [2247, 2183, 4196, 1792, 6709, 2596, 8824, 1750],
#  [104, 3328, 2596, 7446, 8824, 1750],
#  [1126, 1161, 8193, 3821, 6269, 2183],
#  [3903, 2596, 6671, 3901, 152, 556, 1750],
#  [1095, 6419, 1502, 4440, 2247, 8605, 1550],
#  [4877, 2783, 104, 1138, 1321, 2543],
#  [2596,
#   6671,
#   356,
#   2596,
#   4713,
#   8020,
#   2783,
#   2596,
#   1138,
#   2596,
#   4566,
#   6057,
#   8020,
#   5389,
#   2596,
#   6671,
#   4596,
#   1473,
#   2596,
#   4713,
#   719,
#   3852],
#  [5569, 4440, 7584, 7302],
#  [4207, 2043, 5780, 7084, 6334, 8824, 8478, 7416, 6283, 2826, 4973],
#  [104,
#   4713,
#   8432,
#   3770,
#   8824,
#   2826,
#   8824,
#   8545,
#   2247,
#   2183,
#   7701,
#   104,
#   2960,
#   90,
#   6089,
#   4115],
#  [6915, 6149],
#  [4877, 282, 1750, 4196, 2183, 5419, 5569, 3852, 2198],
#  [2645, 2826, 3852],
#  [768, 2645],
#  [3770, 4081, 3327, 5869, 5788, 3770, 8427, 2862, 2826, 6334, 2011],
#  [5869, 7428, 2783],
#  [2783, 2247, 3770, 2543, 6502, 4440, 104, 8824, 2388, 6269, 6241],
#  [2596,
#   8020,
#   2186,
#   4713,
#   5750,
#   4115,
#   3413,
#   4440,
#   1074,
#   344,
#   6671,
#   4752,
#   2826,
#   7356,
#   1074,
#   2529,
#   6919,
#   3852,
#   2184,
#   8193,
#   719,
#   7056,
#   8824,
#   5869,
#   1569,
#   1034,
#   1750,
#   1552,
#   6419,
#   8024,
#   8824,
#   2596,
#   719,
#   6961,
#   1750,
#   6269,
#   3770,
#   8824,
#   556,
#   4587,
#   99,
#   2596,
#   4500,
#   4115,
#   1792,
#   6709,
#   104,
#   4566,
#   6057,
#   5728,
#   90,
#   3962,
#   4115,
#   7862,
#   3770,
#   552],
#  [99, 104, 4500],
#  [8824, 8824, 8605, 8605, 2596, 719, 2536, 8824, 512, 8824, 6629],
#  [8824, 8605, 5417, 2247, 6057, 6419, 6284, 7885],
#  [2304,
#   335,
#   4337,
#   4115,
#   7584,
#   4953,
#   7168,
#   2826,
#   3310,
#   2183,
#   7159,
#   7939,
#   1899,
#   6671,
#   3577,
#   8824,
#   4147,
#   3770,
#   8006,
#   188,
#   8824,
#   8824,
#   7592,
#   6238,
#   7533,
#   3577,
#   2304,
#   5317,
#   5178,
#   2596,
#   6671,
#   7141],
#  [104,
#   1569,
#   6798,
#   4440,
#   1224,
#   1141,
#   6730,
#   5317,
#   3770,
#   6077,
#   104,
#   5569,
#   1304,
#   6419,
#   8824],
#  [8824],
#  [7787,
#   104,
#   3591,
#   4115,
#   7677,
#   1968,
#   5750,
#   1550,
#   4769,
#   7718,
#   6459,
#   104,
#   719,
#   6334,
#   245,
#   4115,
#   1731,
#   4196,
#   3852],
#  [5052, 3838, 3496, 2826, 4542],
#  [1008],
#  [3302, 7320, 2596, 6419, 5946],
#  [2596, 1731],
#  [8824, 1550],
#  [1550],
#  [1881, 6419, 5946, 3745],
#  [7418, 3852],
#  [2783],
#  [2783, 3738],
#  [3770,
#   5560,
#   2247,
#   8605,
#   7882,
#   4522,
#   4235,
#   4584,
#   6419,
#   6413,
#   7366,
#   556,
#   5869,
#   8824],
#  [104,
#   1731,
#   104,
#   6438,
#   8824,
#   99,
#   104,
#   7418,
#   4440,
#   8824,
#   205,
#   2247,
#   3693,
#   8824,
#   3214,
#   7418,
#   7087,
#   8824],
#  [4440, 2247, 3327, 8193, 5205, 3976, 2596, 7084, 1881],
#  [4877, 8824, 5205, 4969, 3770, 6489],
#  [2596, 522, 6671, 992, 3976, 1750, 8824, 3770, 1811, 8086],
#  [1066],
#  [6671, 2596, 6287, 1750, 104, 7787, 6419, 8824],
#  [403, 2536, 4115, 2837, 8548],
#  [104,
#   6158,
#   4115,
#   1731,
#   2826,
#   3852,
#   6201,
#   1095,
#   7871,
#   6685,
#   4115,
#   2783,
#   3770,
#   3457,
#   1308],
#  [4877, 2596, 8232, 1929, 7084, 2043, 7226, 8824],
#  [2596, 7446, 1550, 2043, 2247, 1569, 8414],
#  [226, 205, 8824, 7904, 8824],
#  [104, 3131, 2596],
#  [3852, 6862, 4235, 2596, 2927, 2813, 4115, 6419, 322, 2826, 8824, 3516],
#  [3852, 5569, 6419, 8824, 104, 5569, 5961, 6548],
#  [104,
#   4713,
#   8432,
#   8798,
#   2596,
#   4784,
#   8042,
#   5885,
#   8824,
#   2183,
#   4985,
#   6671,
#   2596,
#   6057,
#   7526,
#   2304],
#  [8771, 2826, 3770, 1945],
#  [1126, 4713, 8193, 2442, 7584, 1094, 26, 4115, 90, 6419, 8824],
#  [2783, 2247, 4115, 2442],
#  [2596,
#   3707,
#   8824,
#   2596,
#   5600,
#   3824,
#   1473,
#   1095,
#   8514,
#   1095,
#   104,
#   5205,
#   282,
#   2596,
#   6671,
#   4349,
#   775,
#   7025,
#   4877,
#   1126,
#   2247,
#   3852,
#   4440,
#   2596,
#   6671,
#   2556,
#   6419,
#   8824],
#  [2596, 6671, 3625, 8824],
#  [5317, 3770, 7933],
#  [2783, 2247, 6419, 8824, 556, 8824],
#  [659, 5205, 6419, 7882, 5728, 5021, 6419, 901, 7227, 2596, 7206, 5464, 8824],
#  [8824],
#  [4829, 2596, 5397, 90, 8824, 4147, 6419, 6110, 7718, 6419, 536, 1533, 1117],
#  [5456,
#   4566,
#   5419,
#   5456,
#   4566,
#   6442,
#   5456,
#   4566,
#   3718,
#   6282,
#   5628,
#   6241,
#   4500],
#  [2783, 6459, 2596, 8021, 7862, 8193, 719, 8232, 4232, 4232, 4232, 7718, 4232],
#  [719, 6419, 5923, 245, 6511],
#  [2783, 3686, 2385],
#  [7584, 344, 7533, 4115, 3770, 7327],
#  [7428, 104, 719, 5885, 4115, 7418, 4196, 3852],
#  [5618, 6057],
#  [104, 3866, 7790, 3222, 5750, 83, 6057, 5728, 5317, 6288, 8824],
#  [3770, 8172, 657, 8824, 5317, 3770, 8824],
#  [2783, 6671, 2596, 1113, 4115, 2802, 7702],
#  [8365, 8340, 6465, 4838, 1224, 2247, 5090, 6915, 6067],
#  [1224, 2247, 3770, 7951, 2272],
#  [8193, 2960, 719, 7790, 6642],
#  [8193, 5780, 6476, 6543, 1698, 8824, 1161, 90, 4440, 8352],
#  [2596, 7418, 6175, 5205, 90, 3528, 4147, 7089, 8061],
#  [335,
#   7584,
#   8824,
#   3770,
#   1651,
#   2960,
#   6057,
#   1338,
#   7389,
#   3214,
#   5229,
#   7718,
#   3818,
#   6543],
#  [172,
#   1656,
#   8824,
#   4440,
#   2247,
#   1985,
#   3327,
#   7902,
#   3619,
#   8824,
#   6671,
#   2596,
#   4869,
#   7084,
#   3770,
#   8437,
#   2826,
#   8824,
#   8824,
#   8824],
#  [104, 7787, 7584, 8824],
#  [8824,
#   8824,
#   7871,
#   8184,
#   2234,
#   2556,
#   1095,
#   2813,
#   4566,
#   8432,
#   7902,
#   4525,
#   7084,
#   3770,
#   5525,
#   104,
#   7787,
#   6057,
#   1619,
#   4115,
#   719,
#   6269,
#   8605,
#   264,
#   3770,
#   5436,
#   2826,
#   8494,
#   7226,
#   4829,
#   719,
#   8824,
#   7599,
#   7902,
#   5122],
#  [7584,
#   8824,
#   3838,
#   2247,
#   4349,
#   3481,
#   8006,
#   4115,
#   8661,
#   3770,
#   2543,
#   1473,
#   4440,
#   2247,
#   4115,
#   2120,
#   3770,
#   1504,
#   104,
#   7787,
#   3178,
#   4115,
#   97,
#   8605,
#   6435,
#   4115,
#   6806,
#   3852,
#   6618],
#  [7584, 6435, 1473, 4440, 2826, 8824],
#  [4553,
#   7584,
#   3343,
#   5223,
#   4115,
#   8824,
#   5513,
#   3770,
#   6830,
#   2826,
#   393,
#   2247,
#   3481,
#   2826,
#   3770,
#   5931,
#   2826,
#   3770,
#   8369,
#   5728,
#   3770,
#   8824,
#   8495,
#   6671,
#   8824,
#   7084,
#   5119],
#  [2247, 4440, 5557, 4440, 4534, 2596, 5119],
#  [1013,
#   4241,
#   1207,
#   7902,
#   8824,
#   4115,
#   6175,
#   6459,
#   2596,
#   480,
#   1224,
#   4829,
#   719,
#   6073,
#   556,
#   2596,
#   4115,
#   8698,
#   3852,
#   4115,
#   3770,
#   8369],
#  [4713, 2596, 4959, 7584, 2890, 8403, 90, 1412, 8824],
#  [6175, 5205, 90, 3528, 4115, 3770, 8061, 1473, 104, 4566, 6806, 3852],
#  [3770,
#   4382,
#   4584,
#   6334,
#   4947,
#   4115,
#   90,
#   7141,
#   5317,
#   2183,
#   5504,
#   237,
#   7584,
#   8824],
#  [3770, 5122, 2247, 8824],
#  [1224,
#   2247,
#   6419,
#   8824,
#   7428,
#   1224,
#   6057,
#   7116,
#   6516,
#   4115,
#   6070,
#   3770,
#   3349,
#   2826,
#   8824,
#   2826,
#   3664,
#   399,
#   1495],
#  [3852,
#   4566,
#   6057,
#   90,
#   1420,
#   4115,
#   4969,
#   2010,
#   2826,
#   7584,
#   8824,
#   4769,
#   1656,
#   930],
#  [2596, 5205, 1719, 556, 2813],
#  [2783, 6419, 6432, 2783, 6419, 1949, 2826, 6419, 6435],
#  [104, 8403, 90, 5406, 556, 4587],
#  [104, 8020],
#  [104, 4784, 4531, 2596, 7970, 2826, 6419, 6435],
#  [2304,
#   4440,
#   2247,
#   6725,
#   104,
#   719,
#   6419,
#   2272,
#   4147,
#   6419,
#   7882,
#   7226,
#   4566,
#   6057,
#   5542,
#   3041,
#   5216,
#   6139,
#   7731],
#  [6671, 8193, 657, 4115, 3179],
#  [7735, 104, 5569, 3866, 8231, 4115, 4439, 7084, 6419, 7953],
#  [2043, 2784, 335],
#  [104, 7787, 6057, 5778, 2596, 4115, 2060, 4115, 5885],
#  [104, 4713, 1138, 2596, 4115, 495, 556, 1750],
#  [8824, 104, 1138, 4115, 5550, 2596, 7701],
#  [2596, 4713, 1960, 5550],
#  [4241,
#   2596,
#   6671,
#   4877,
#   7685,
#   104,
#   1161,
#   480,
#   6915,
#   4953,
#   7882,
#   4584,
#   403,
#   7079,
#   2596,
#   1693,
#   2434,
#   1750],
#  [5456, 6170, 5703],
#  [1161, 2596, 6169, 7084, 3180, 6419, 3513],
#  [2783, 2247, 3852, 4769, 282, 1750],
#  [104,
#   8432,
#   4440,
#   2596,
#   4566,
#   3712,
#   90,
#   8824,
#   8824,
#   556,
#   3770,
#   4765,
#   2247,
#   3852,
#   6057,
#   4877],
#  [1655, 1750, 1656, 8824, 8410, 5969, 719, 7116, 2536, 7079],
#  [8444, 104, 5550, 4147, 7674],
#  [1656, 8824, 8814, 8824],
#  [8605, 5746, 2826, 7755],
#  [7755, 4115, 2783],
#  [8824, 2826, 3770, 8061, 8824],
#  [636, 8514, 2434, 4235],
#  [104,
#   7787,
#   6057,
#   6419,
#   8824,
#   1446,
#   104,
#   1000,
#   3852,
#   2247,
#   6915,
#   7389,
#   3214,
#   6419,
#   4985,
#   6859,
#   8144,
#   104,
#   6817,
#   2596,
#   6671,
#   6057,
#   3745,
#   6044],
#  [636,
#   8403,
#   104,
#   90,
#   3770,
#   3203,
#   4584,
#   2536,
#   3528,
#   2630,
#   1095,
#   104,
#   2784,
#   3852,
#   4829],
#  [104, 1138, 4115, 4500, 7084, 2282],
#  [3838, 4566, 90, 6419, 245],
#  [6459, 2596, 2060, 6269, 5557, 3770, 4276, 5841, 5317, 697],
#  [104, 719, 4115, 751, 3770, 3203],
#  [636, 6671, 2596, 7526, 8824],
#  [8221],
#  [2783, 6671, 2596, 1113, 4115],
#  [2783, 7835, 1224, 7418],
#  [1224, 844, 99, 1224, 5205, 3718, 4115, 2673, 2596, 1224, 5780, 3664, 4988],
#  [104,
#   1138,
#   2596,
#   4115,
#   282,
#   1750,
#   5703,
#   2596,
#   1683,
#   8221,
#   2434,
#   3770,
#   2642,
#   5703],
#  [1509, 4241, 104, 4205, 8020, 3327, 4115, 5464, 1473, 732],
#  [6915],
#  [6915],
#  [104,
#   317,
#   2596,
#   8824,
#   8824,
#   4440,
#   2596,
#   6671,
#   5317,
#   6915,
#   4403,
#   4115,
#   2614,
#   7084,
#   1750],
#  [104, 7787, 6057, 8824],
#  [1473,
#   7446,
#   2596,
#   3866,
#   4494,
#   3343,
#   7718,
#   2247,
#   1738,
#   4349,
#   6419,
#   6425,
#   3956,
#   3770,
#   8824,
#   6419,
#   4214,
#   556,
#   3770,
#   1365,
#   2826,
#   3180],
#  [5456,
#   4713,
#   1719,
#   4817,
#   5317,
#   1074,
#   8824,
#   5456,
#   4439,
#   5223,
#   4115,
#   1883,
#   5317,
#   6419,
#   3866,
#   1723,
#   8555,
#   3770,
#   4765,
#   6671,
#   8537,
#   7084,
#   5433,
#   3475,
#   7084,
#   8824,
#   1473,
#   8824,
#   1473],
#  [2596, 8801, 2813, 8824],
#  [1446, 8193, 6459, 719, 6419, 1787, 2826, 8824, 2596, 2960, 6529, 8605, 2787],
#  [1656, 8824, 2247, 7116, 6419, 1876, 8605, 5985, 1656, 8824],
#  [2596, 1931, 4115, 719, 6419, 2734, 7849, 556, 3901, 4399],
#  [2783, 6459, 104, 719, 4877, 8645, 7116],
#  [5557, 104, 719, 4115, 6459, 2247, 3784, 3770, 4960],
#  [104, 7787, 6057, 798, 2826, 2596, 2596, 6671, 469, 1446, 6419, 8824],
#  [2783, 6459, 2596, 1719],
#  [8824, 6000, 8824, 8824],
#  [7418, 6057, 4955, 8824],
#  [2783, 2247, 3852, 6419, 3719, 7871, 6613],
#  [2596, 5171, 2596, 6438, 4951],
#  [282, 3770, 1021, 8193, 5321, 6465],
#  [1021, 1729],
#  [1021, 6862, 636, 8645],
#  [663],
#  [4115, 4855, 3770, 3596, 2826, 4241],
#  [1021, 6862, 1224, 4584, 6419, 4241],
#  [1473, 4847, 4115, 4855, 5354],
#  [1021, 6862],
#  [8193,
#   4566,
#   8437,
#   7084,
#   3664,
#   6884,
#   8193,
#   1138,
#   3202,
#   5550,
#   3770,
#   1021,
#   1013,
#   1224,
#   5349],
#  [1224, 5349],
#  [2596, 719, 4115, 8781, 1208, 8824, 5017, 2783, 5456, 6683],
#  [8824,
#   4566,
#   6057,
#   2596,
#   6438,
#   4115,
#   1750,
#   2596,
#   876,
#   4115,
#   8020,
#   636,
#   4115,
#   6438,
#   4115,
#   1750],
#  [8739,
#   2247,
#   6419,
#   453,
#   1344,
#   6419,
#   2934,
#   4115,
#   7012,
#   1446,
#   4877,
#   7163,
#   6121,
#   2960,
#   90,
#   4923,
#   6605,
#   8824,
#   5728,
#   6121,
#   2434,
#   1172,
#   7460],
#  [4241, 4440, 2247, 5317, 6419, 1674],
#  [4440, 2247, 2783, 3852, 6862],
#  [636, 7428, 2596, 7438, 3852],
#  [1126, 6459, 2596, 859, 4115, 4036, 8061],
#  [636, 5205, 2596, 90, 4877, 7732, 3770, 2539, 2247, 2784, 4115, 90, 8824],
#  [8824,
#   104,
#   480,
#   3770,
#   8824,
#   6671,
#   6915,
#   7389,
#   3214,
#   8824,
#   3990,
#   8061,
#   2826,
#   3770,
#   5282,
#   4765],
#  [636, 5205, 2596, 90, 4877, 7732],
#  [3770, 8824, 2826, 8824, 8824, 8814, 8824, 8824],
#  [8824, 2247, 6419, 5183],
#  [522,
#   1910,
#   1473,
#   7116,
#   2596,
#   6671,
#   6419,
#   7955,
#   7882,
#   4713,
#   5628,
#   8754,
#   8824,
#   2596,
#   8824],
#  [104, 4566, 6516, 4115, 1683, 4440, 8824],
#  [8221, 8824],
#  [8754, 2247, 7701, 3481, 1161, 8824],
#  [2596, 4969, 4877, 5765, 1693, 99, 2596, 6671, 3190, 8824],
#  [104, 719, 2536, 8824, 5557, 8605, 6435, 8824],
#  [2596, 448, 4256, 8006, 4115, 7682, 2596, 3370, 495],
#  [7282,
#   104,
#   719,
#   6073,
#   3818,
#   4587,
#   3368,
#   636,
#   7970,
#   4715,
#   6459,
#   2596,
#   1138,
#   1750,
#   4115,
#   495],
#  [1013, 4241, 8824, 2596, 4115, 4500, 6418, 2596, 4566, 4500],
#  [8824],
#  [5557, 2826, 7043, 3686, 8824],
#  [5317, 8824, 8824, 8750, 8824, 8750, 8824, 8824],
#  [104, 7787, 1113, 8605, 8592],
#  [8221,
#   104,
#   719,
#   5844,
#   8605,
#   7176,
#   104,
#   5844,
#   8605,
#   8494,
#   1473,
#   104,
#   5844,
#   2596],
#  [2783, 6671, 2596, 2421],
#  [104, 4644, 3770, 1504, 4566, 90, 4715, 3214, 104, 2784],
#  [636, 3402],
#  [8444, 4241, 1655, 2282, 2596, 3370, 282, 7043, 2596, 3370, 282, 7584, 8824],
#  [1013,
#   104,
#   282,
#   1208,
#   5456,
#   4566,
#   6057,
#   5543,
#   1750,
#   2596,
#   8020,
#   4440,
#   104,
#   7787,
#   1550,
#   8221,
#   2596,
#   6224,
#   1750],
#  [8605,
#   8592,
#   8605,
#   8592,
#   7584,
#   8824,
#   6671,
#   837,
#   5559,
#   8824,
#   2596,
#   3370,
#   6438,
#   4115,
#   1208,
#   1473,
#   1013,
#   2596,
#   4713,
#   104,
#   4566],
#  [104, 6640, 5317, 2596],
#  [104, 6824, 8193, 6671, 1339, 8715, 8494, 4769],
#  [104, 719, 4115, 1193],
#  [104, 1879, 2596, 4829],
#  [2446, 885, 5578, 2446, 6884],
#  [8784, 4877, 2596, 6671, 6419, 2446, 7882],
#  [104,
#   2960,
#   6057,
#   5728,
#   90,
#   1113,
#   4115,
#   2596,
#   4995,
#   8605,
#   2121,
#   2784,
#   6915,
#   1446,
#   8824,
#   4267,
#   1750,
#   2596,
#   6671,
#   6419,
#   7882,
#   2826,
#   5503,
#   1473,
#   8824,
#   1473,
#   930,
#   4440,
#   2596,
#   6671,
#   6057,
#   6419,
#   7164],
#  [3770, 2539, 2247, 8824],
#  [2783, 7428, 5456, 7418, 4196, 8824, 7227, 7873],
#  [104, 1161, 6732, 3770, 8824, 2826, 8605, 2121],
#  [8444, 104, 6438, 1286],
#  [2596, 8698, 6915, 8824, 4115, 6438, 8824],
#  [104,
#   8020,
#   2783,
#   104,
#   1719,
#   104,
#   1719,
#   2817,
#   7226,
#   1321,
#   4153,
#   3770,
#   8369,
#   1095,
#   3852,
#   2247,
#   5216,
#   6057,
#   798,
#   104,
#   1719,
#   6419,
#   7206,
#   7226,
#   8590,
#   2783,
#   1013],
#  [636, 8715, 6671, 2596, 8824, 8824],
#  [6459, 5456, 719, 2556, 465],
#  [1446,
#   3182,
#   7584,
#   6121,
#   7239,
#   6671,
#   2596,
#   4115,
#   4505,
#   4115,
#   8824,
#   8824,
#   7718,
#   1072,
#   2826,
#   3770,
#   4953,
#   8824,
#   2596,
#   8444,
#   751,
#   3770,
#   4906],
#  [5321, 2596],
#  [3838,
#   2247,
#   3481,
#   1837,
#   104,
#   4829,
#   5750,
#   4115,
#   8432,
#   1126,
#   6459,
#   2596,
#   1138,
#   4115,
#   4500,
#   7099,
#   3629,
#   5557,
#   2183],
#  [1473,
#   2596,
#   7418,
#   2183,
#   2247,
#   7871,
#   4964,
#   3807,
#   4147,
#   8207,
#   104,
#   4713,
#   1719,
#   1072,
#   5903,
#   2826,
#   2934,
#   4440,
#   4829,
#   2120,
#   2183,
#   6419,
#   4817],
#  [8193, 4921, 2091, 4399, 8193, 4566, 358, 2183, 5317, 7471],
#  [2596,
#   1138,
#   6419,
#   160,
#   4696,
#   8193,
#   6671,
#   6419,
#   7867,
#   5456,
#   8824,
#   3180,
#   4147,
#   8824,
#   7226,
#   4566,
#   2596,
#   4711,
#   768,
#   3719],
#  [8193, 4713, 26, 4115, 8020],
#  [8193, 1161, 314, 3770, 8110, 3182, 3852],
#  [1656, 8824, 8193, 5557, 719, 4115, 8437],
#  [5317,
#   3481,
#   1560,
#   2826,
#   8824,
#   2596,
#   719,
#   1705,
#   4007,
#   8824,
#   7226,
#   7446,
#   5579,
#   8097,
#   4953,
#   6671,
#   4769,
#   3523,
#   4333,
#   6401,
#   6761,
#   5557,
#   4440,
#   3903,
#   2826,
#   7584,
#   1343,
#   8824],
#  [8824, 2247, 2783, 8610, 8432],
#  [2596,
#   4566,
#   90,
#   1641,
#   5317,
#   8824,
#   8811,
#   2826,
#   7584,
#   8824,
#   1473,
#   8824,
#   5389,
#   2596,
#   6671,
#   8136,
#   4115,
#   2287,
#   3327,
#   2596,
#   4566,
#   90,
#   8824,
#   719,
#   2596,
#   5885,
#   4115,
#   7418],
#  [4914, 8061, 2234, 8824, 1473, 8444, 4241, 90, 7084, 3180],
#  [2304,
#   1989,
#   3770,
#   8494,
#   8701,
#   5456,
#   1921,
#   636,
#   2596,
#   8020,
#   7902,
#   4403,
#   8193,
#   719,
#   4921,
#   7769,
#   2434,
#   6642,
#   2962,
#   1698],
#  [1473, 2783, 6459, 2596, 1731, 8824],
#  [2304,
#   104,
#   7010,
#   8020,
#   2783,
#   6419,
#   893,
#   7177,
#   1446,
#   104,
#   719,
#   3866,
#   7790,
#   3852,
#   876,
#   6859,
#   5529,
#   7227],
#  [2783, 6459, 2596, 7267],
#  [2783, 2247, 1224, 5090],
#  [1224,
#   2247,
#   6623,
#   7871,
#   8824,
#   1224,
#   2247,
#   2421,
#   8193,
#   6671,
#   6269,
#   7871,
#   8824],
#  [3327, 5205, 104, 2690, 2183, 7882],
#  [2596, 8824, 2596, 8824, 8193, 6671, 8006, 5837, 8824, 8824],
#  [5229, 2962, 1698, 335],
#  [2596, 3370, 90, 2397],
#  [8193, 719, 4115, 4478, 3770, 3547, 2826, 4610, 8494, 7662],
#  [8193, 6671, 6269, 3770, 8777, 2826, 6419, 8824, 8824],
#  [2596, 1731, 104, 4713, 8020, 4440],
#  [8193, 6671, 8824],
#  [3770, 6642, 2247, 3838, 104, 8020, 3336],
#  [2596,
#   4713,
#   8020,
#   5682,
#   2124,
#   8824,
#   4610,
#   6671,
#   8605,
#   89,
#   1550,
#   4877,
#   104,
#   7787,
#   6287,
#   2596,
#   8193,
#   6671,
#   4901,
#   6478],
#  [1473,
#   6418,
#   2783,
#   143,
#   2826,
#   3770,
#   7809,
#   4584,
#   5406,
#   3770,
#   1365,
#   2247,
#   249,
#   8824,
#   2596,
#   8020,
#   3663],
#  [8358, 8824, 104, 2960, 719, 3866, 8362, 4115, 2282],
#  [2596, 3866, 7428, 2596, 7428, 5557, 3770, 2995, 556, 1339, 2826, 3180, 1683],
#  [2596, 3084],
#  [8824,
#   8824,
#   5557,
#   8193,
#   5205,
#   6459,
#   4769,
#   2247,
#   4500,
#   8824,
#   1731,
#   4196,
#   3663],
#  [2596, 282, 4440, 4115, 7043],
#  [2247, 4440, 3770, 7882, 104, 1879, 8824, 930],
#  [2596, 7446, 1550, 1656, 930, 3664, 5219, 8403, 3866, 90, 4210],
#  [2036, 6419, 8824],
#  [4388,
#   7103,
#   3691,
#   7084,
#   6419,
#   5396,
#   2826,
#   3702,
#   1473,
#   6880,
#   1446,
#   7084,
#   6915,
#   8824,
#   3770,
#   2446,
#   8369,
#   4981,
#   7963,
#   7584,
#   6285],
#  [1446,
#   3838,
#   2247,
#   181,
#   1224,
#   41,
#   3770,
#   8824,
#   2826,
#   8104,
#   5857,
#   2826,
#   3770,
#   8824],
#  [6418, 2783, 6459, 2596, 5267, 1656, 930],
#  [1224, 3370, 90, 5102],
#  [104, 8020, 104, 2960, 6057, 1928, 3664, 8824],
#  [6418, 1126],
#  [6671, 2596, 8605, 7877, 104, 7787, 8824, 104, 7787, 557],
#  [104, 7787, 6057, 7584, 8398, 5389, 104, 1719, 3770, 973],
#  [8784, 6347, 6347, 3092],
#  [8824,
#   1338,
#   3852,
#   1420,
#   6169,
#   7084,
#   1750,
#   4104,
#   8748,
#   2783,
#   6459,
#   2596,
#   26,
#   2783,
#   6671,
#   2596,
#   7687,
#   556],
#  [4713, 7418, 5885],
#  [3327, 6671, 8193, 657],
#  [104, 7787, 4200, 7084, 2596],
#  [335, 335, 3718, 7084, 3041],
#  [104,
#   780,
#   2596,
#   6334,
#   5746,
#   1989,
#   1509,
#   5946,
#   6796,
#   7206,
#   4459,
#   3481,
#   375,
#   4115,
#   3759,
#   2596,
#   8603,
#   5596,
#   6801,
#   6419,
#   670,
#   5596,
#   375,
#   6419,
#   670],
#  [2596, 4855, 3770, 8409],
#  [311, 1473, 7684],
#  [104, 5569, 5557, 2826, 4610],
#  [2304,
#   2596,
#   5782,
#   5376,
#   3770,
#   8824,
#   2826,
#   3852,
#   5389,
#   8570,
#   6915,
#   1434,
#   4196,
#   4440],
#  [2783, 4196, 8824],
#  [835, 5456, 6671, 7687, 1562, 1634, 1224, 7533, 7099, 4115, 8824],
#  [6915, 1224, 2247, 4235, 8272],
#  [4713, 4928, 4196, 6465, 1731, 4196, 2813],
#  [2783, 4196, 8605, 7663, 6951, 7476, 6951],
#  [5017, 104, 4784, 1509, 5771, 6269, 4440, 5903, 2826, 1837],
#  [2783, 2247, 7584, 1623, 636, 7970],
#  [104, 4829, 8824, 143, 2247, 6202],
#  [6915, 6915, 8006],
#  [1446, 1989],
#  [8824,
#   6915,
#   7389,
#   7718,
#   104,
#   3784,
#   5596,
#   8398,
#   2183,
#   2247,
#   3770,
#   5268,
#   5178,
#   2826,
#   7584,
#   6435,
#   4713,
#   6516,
#   4115,
#   7187,
#   7834,
#   7617,
#   7418,
#   335,
#   7718,
#   6915],
#  [2183, 2247, 6057, 4196, 973, 8824, 104, 26, 7584, 6224, 5317, 1750],
#  [2783, 5524, 6459, 2596, 26],
#  [104,
#   26,
#   4115,
#   8020,
#   4196,
#   7584,
#   2457,
#   104,
#   26,
#   4115,
#   8020,
#   4196,
#   7584,
#   8824,
#   1126,
#   2596,
#   6671,
#   4235],
#  [282,
#   1750,
#   4196,
#   2813,
#   2783,
#   2596,
#   7428,
#   1095,
#   6419,
#   3446,
#   1344,
#   2783,
#   7584,
#   2601,
#   7446,
#   5750],
#  [8605, 8221, 6139, 8824, 1750, 3249, 8605, 8824, 1473, 8605, 162, 5569, 5571],
#  [7584, 162, 5569, 5571],
#  [4207,
#   2043,
#   7533,
#   5571,
#   8177,
#   862,
#   4115,
#   1750,
#   2043,
#   7533,
#   4115,
#   95,
#   8247,
#   1785,
#   5088,
#   4115,
#   8824,
#   1750],
#  [7099, 5317, 3770, 790, 8824],
#  [4207,
#   8824,
#   5088,
#   7510,
#   6241,
#   2105,
#   2672,
#   768,
#   49,
#   6241,
#   4500,
#   5571,
#   1473,
#   8605,
#   8221,
#   4895,
#   1750,
#   556,
#   6241,
#   8824],
#  [7584, 8221, 4895, 2596, 556, 7584, 7713, 8824],
#  [4440,
#   2247,
#   2783,
#   1224,
#   7428,
#   4115,
#   1750,
#   1224,
#   4702,
#   8409,
#   2862,
#   6269,
#   1750],
#  [7584, 8221, 4702, 8409, 2862, 6269, 2596],
#  [2862, 6269, 8605, 7099, 99, 104, 5569, 6419, 410, 1344],
#  [104, 7787, 8824, 4713, 2596, 1731],
#  [4877,
#   8193,
#   4711,
#   2817,
#   603,
#   1473,
#   1013,
#   8193,
#   6671,
#   1612,
#   8193,
#   6671,
#   6801,
#   4115,
#   2771,
#   873],
#  [8605,
#   3513,
#   7302,
#   1473,
#   104,
#   6939,
#   6419,
#   5609,
#   104,
#   1276,
#   6282,
#   3481,
#   5529,
#   1473,
#   6419,
#   7882,
#   5569,
#   8824,
#   6241,
#   3664,
#   1712,
#   5569,
#   6269,
#   3770,
#   5006,
#   1224,
#   1276,
#   6859,
#   1750,
#   1473,
#   104,
#   8571,
#   6465],
#  [8431, 4440, 2247, 6419, 8824, 8060],
#  [4769, 104, 7056, 4150, 2826, 301, 7040],
#  [1013,
#   2596,
#   3451,
#   7084,
#   3770,
#   4868,
#   1634,
#   5456,
#   4566,
#   3976,
#   2596,
#   7084,
#   7584,
#   5560],
#  [104, 4566, 1013, 5456, 4713, 2585, 1750, 7099],
#  [6671, 2596, 6015],
#  [4445],
#  [104, 1161, 1338, 2596, 4115, 8605, 1301],
#  [3770, 8494, 6671, 2862, 2826, 4670, 2545, 1284, 2862, 2040],
#  [8824, 5673, 2247, 2833],
#  [2596, 1412, 3440, 6419, 3721],
#  [335, 104, 1412, 3852],
#  [7428, 2596, 403, 5833, 7235, 7227],
#  [6915],
#  [2783, 4196, 7099, 6282],
#  [104,
#   1276,
#   4235,
#   104,
#   6961,
#   6915,
#   973,
#   104,
#   1879,
#   6915,
#   3481,
#   104,
#   7298,
#   4969,
#   6419,
#   6955,
#   3903,
#   2596,
#   719,
#   4115,
#   719,
#   6419,
#   5751,
#   7889,
#   4115,
#   4969,
#   8437,
#   5456,
#   6952,
#   1750,
#   104,
#   8403,
#   719,
#   49,
#   6419,
#   1536,
#   2826,
#   973,
#   104,
#   1412,
#   3852,
#   1446,
#   1989,
#   6057,
#   7226,
#   104,
#   7787,
#   5456,
#   6531,
#   1750,
#   8731,
#   3770,
#   6686,
#   6859,
#   8824],
#  [4877, 2596, 7446, 3866, 6419, 3721],
#  [2783, 6671, 2596, 5778, 1750],
#  [104, 7787, 6057, 6419, 8547, 104, 7787, 6057, 6419, 8547],
#  [104, 8020],
#  [2596,
#   4713,
#   8020,
#   104,
#   7787,
#   6948,
#   104,
#   5569,
#   4183,
#   4440,
#   2247,
#   6057,
#   1750,
#   104,
#   8571,
#   6419,
#   5625,
#   5205,
#   2596,
#   1991,
#   2783,
#   5456,
#   4566,
#   6459,
#   4115,
#   1750,
#   99,
#   104,
#   8232,
#   4115,
#   2275],
#  [5456, 6671, 6057, 992, 2585, 2596, 1550, 7099],
#  [6671, 2596, 8431],
#  [104, 1569, 1161, 480, 8824, 5406],
#  [2247, 1224, 7584, 5688],
#  [8824, 1224, 2247, 7204, 6671, 2596, 2205],
#  [1013, 104, 5569, 7584, 5688, 104, 6225, 90],
#  [6419, 1249, 7387, 8398, 8403, 2137, 3770, 380, 1583, 1779, 3481],
#  [6915, 2543, 2783, 8824, 7787, 5664, 104, 6842, 2596],
#  [2596, 1968, 4969, 3053],
#  [6459, 2596, 719, 897],
#  [5317, 3770, 134],
#  [104, 4566, 2120, 6334, 556, 3180],
#  [2783, 6671, 2596, 5090],
#  [5797, 4196, 1750, 2596, 719, 996, 4106, 2826, 7584, 2529],
#  [6459, 2596, 1509, 1138, 1750, 4115, 5797, 4196, 2596],
#  [104, 4713, 1138, 4115, 329, 2596, 8748, 7084, 1750],
#  [104, 6252, 7584, 764, 104, 1161, 3976, 104, 5782, 1719, 5885],
#  [4450, 5464, 6859, 3770, 2642, 2596, 8020, 4610, 6884],
#  [8824,
#   5569,
#   6419,
#   2998,
#   2826,
#   6863,
#   8605,
#   3460,
#   5569,
#   1944,
#   2043,
#   5628,
#   1750,
#   1202,
#   5114],
#  [2773,
#   2596,
#   282,
#   3180,
#   7718,
#   6057,
#   8193,
#   4566,
#   8781,
#   2862,
#   1968,
#   1013,
#   3852,
#   467,
#   2434,
#   2596],
#  [1013, 104, 282, 2596, 4566, 2596, 7464, 1750],
#  [6671,
#   2596,
#   4235,
#   8824,
#   4713,
#   4928,
#   4196,
#   4440,
#   8193,
#   4566,
#   4447,
#   4115,
#   7387,
#   5456,
#   4566,
#   6057,
#   8824,
#   2596],
#  [6419, 5625],
#  [104,
#   7787,
#   2434,
#   6419,
#   410,
#   85,
#   5317,
#   8824,
#   5750,
#   3770,
#   8119,
#   4235,
#   3770,
#   301,
#   2247,
#   1550,
#   6419,
#   5906,
#   2247,
#   8171,
#   4877,
#   104,
#   7800],
#  [5017,
#   8193,
#   5205,
#   3976,
#   2596,
#   1446,
#   1550,
#   4769,
#   8193,
#   719,
#   4115,
#   6118,
#   7084,
#   2783,
#   2247,
#   1546,
#   4235,
#   282,
#   3180,
#   3770,
#   8824,
#   4440,
#   3770,
#   8066],
#  [8784],
#  [3852, 5569, 8605, 871, 6057, 3664],
#  [2304,
#   104,
#   7787,
#   3770,
#   5194,
#   1021,
#   6281,
#   3447,
#   1473,
#   4388,
#   4769,
#   1473,
#   6418,
#   104,
#   4829,
#   5750,
#   4115,
#   90,
#   7906,
#   5317,
#   152],
#  [5017,
#   3629,
#   8824,
#   8824,
#   1750,
#   2596,
#   5205,
#   6459,
#   3770,
#   6727,
#   7851,
#   636,
#   4196,
#   4440,
#   3770,
#   5178,
#   2247,
#   5557,
#   1874],
#  [8784, 4207, 8431],
#  [104, 7787, 3178, 4115, 90, 8824, 2886, 3180],
#  [7226, 7428, 3615, 1473, 3902],
#  [7226, 6459, 2596, 1731, 8824],
#  [6418, 1126, 5782, 2596, 4447, 4115, 3770, 6205],
#  [5052, 1021, 2783, 6671, 2596, 5090, 4235],
#  [2542,
#   431,
#   5569,
#   6269,
#   3770,
#   8611,
#   556,
#   5952,
#   8193,
#   2436,
#   3838,
#   4877,
#   2043,
#   8403,
#   4969,
#   68,
#   2160],
#  [2783, 6459, 2596, 4191, 8824, 8824],
#  [104, 5628, 6241, 1338, 6419, 3460],
#  [6419, 8824, 7428, 2596, 1338, 3481, 3745],
#  [6347, 469, 2385],
#  [1021, 4992, 1013, 104, 1338, 6241],
#  [3770,
#   1535,
#   1321,
#   719,
#   1072,
#   3309,
#   2783,
#   8193,
#   6459,
#   1473,
#   4769,
#   2596,
#   6671,
#   657,
#   4115,
#   1575,
#   7902,
#   8824,
#   2183,
#   2247,
#   657,
#   4115,
#   90,
#   7902,
#   8824,
#   6538],
#  [2783,
#   5569,
#   104,
#   3591,
#   4115,
#   6459,
#   3770,
#   2011,
#   3024,
#   4115,
#   8120,
#   1750,
#   104,
#   5569,
#   992,
#   2585,
#   6419,
#   5625,
#   7099,
#   104,
#   3686,
#   424],
#  [424, 2596, 8824, 6419, 5906, 4115, 6419, 8824],
#  [1021, 104, 8020, 104, 4486, 2160, 1446, 2183, 2011, 5569, 6915, 2697, 5906],
#  [2304, 2183, 2247, 992, 4397, 7584, 7075, 1473, 1068, 6863],
#  [4397, 8605, 7075],
#  [636,
#   6671,
#   2596,
#   657,
#   4115,
#   8081,
#   2183,
#   1634,
#   1013,
#   8824,
#   8815,
#   5011,
#   1693,
#   1473,
#   2596,
#   4829,
#   2536,
#   6269,
#   3770,
#   1589,
#   1793,
#   1095,
#   6419,
#   2943,
#   2183,
#   1837,
#   4829,
#   90,
#   6163,
#   4115,
#   8081,
#   2596,
#   4829,
#   719,
#   3770,
#   1249,
#   4115,
#   5206,
#   6401,
#   3770,
#   8824,
#   1989,
#   4797,
#   4440,
#   104,
#   719,
#   4115,
#   2120,
#   152,
#   7910,
#   7599,
#   7584,
#   6727,
#   461,
#   1446,
#   2240,
#   469,
#   104,
#   5205,
#   7792,
#   3601,
#   7584,
#   7870],
#  [1446, 1021, 5519, 2183],
#  [4713,
#   2596,
#   2430,
#   8432,
#   1989,
#   5557,
#   4196,
#   6992,
#   3770,
#   1968,
#   8193,
#   5017,
#   3770,
#   7389,
#   973,
#   104,
#   4969,
#   4115,
#   6531,
#   2596,
#   2430,
#   1246],
#  [4207, 1550],
#  [2783, 5569, 4440, 8824],
#  [104,
#   2784,
#   4207,
#   2596,
#   6671,
#   1550,
#   1021,
#   1095,
#   3712,
#   1095,
#   8193,
#   4969,
#   8122,
#   8193,
#   4566,
#   5628,
#   2596,
#   7299,
#   3770,
#   8180],
#  [7428, 3770, 4868, 8824, 6241, 2560],
#  [4207, 1224, 2900, 6179, 1698],
#  [8431,
#   3695,
#   4147,
#   6241,
#   3589,
#   5628,
#   6241,
#   5335,
#   2160,
#   6241,
#   8603,
#   1473,
#   1338,
#   6241,
#   3395,
#   4115,
#   3486,
#   5163,
#   2596,
#   8232,
#   4440],
#  [897, 556, 1750, 104, 5759, 1635, 8748],
#  [1291, 8824],
#  [3852, 5569, 6971, 104, 4566, 282, 2596, 3824, 5150],
#  [104, 7787, 992, 3095],
#  [99],
#  [1695, 6859, 6548],
#  [2783, 2247, 1224, 7687, 556],
#  [3327, 2247, 2043],
#  [6712, 6419, 6437],
# ...
#   7205,
#   3180,
#   8122,
#   4115,
#   6459],
#  [2596, 8020, 2783, 4440, 2247, 1550],
#  [6915, 2783, 2247, 3852],
#  [1989, 7584, 3673, 4312, 4769, 2596, 5205, 6459, 2783, 2596, 1138],
#  [7862, 3770, 3002],
#  [4418, 104, 1824, 3131, 3852],
#  [2304, 3686, 4877, 2596, 8020, 104, 7510, 2596, 2430, 3770, 4813],
#  [2304, 3686, 4877, 2596, 8020, 104, 4713, 477, 4196, 4440, 3426],
#  [4418, 1126, 2960, 2596],
#  [104, 4713, 5728, 7862, 8261],
#  [7428, 2596, 4969, 6419, 5815, 2434, 3770, 1750],
#  [5772,
#   1446,
#   104,
#   4829,
#   5750,
#   4115,
#   5550,
#   2596,
#   7701,
#   2596,
#   8232,
#   6419,
#   1375,
#   7084,
#   1750],
#  [1013,
#   2596,
#   3528,
#   1750,
#   8824,
#   6269,
#   7584,
#   3673,
#   4312,
#   3852,
#   6225,
#   8763,
#   2596,
#   2388,
#   3745,
#   2783,
#   4196,
#   3770,
#   5815],
#  [3770,
#   7483,
#   2784,
#   1224,
#   4829,
#   7790,
#   6241,
#   7227,
#   1446,
#   2043,
#   5782,
#   4439,
#   4235],
#  [1700],
#  [1914],
#  [1634,
#   2596,
#   4713,
#   477,
#   4196,
#   4440,
#   2758,
#   8824,
#   573,
#   104,
#   719,
#   6961,
#   5317,
#   6179],
#  [2783, 4829, 2596, 3784, 6241],
#  [1634,
#   1989,
#   6419,
#   291,
#   1837,
#   7718,
#   2817,
#   2096,
#   4115,
#   2585,
#   6419,
#   3472,
#   1340,
#   8824,
#   6671,
#   7079,
#   8806,
#   991,
#   5317,
#   2643,
#   7760,
#   3852,
#   8403,
#   90,
#   4115,
#   1155,
#   1208,
#   3686,
#   5862,
#   1208,
#   2160,
#   6915,
#   1767,
#   3855,
#   1989,
#   5750,
#   8824,
#   1208,
#   4115,
#   8427],
#  [2643, 7760, 5750, 2783, 8824, 8824],
#  [104, 4566, 3718, 7084, 2596],
#  [3838, 1759, 6419, 6281, 3838, 4566, 90, 469, 556, 2596, 4115, 6459],
#  [104, 5205, 7862, 2596, 1583, 1634, 104, 4566, 4737, 7701],
#  [2183, 7147, 8060, 8016],
#  [8605, 2601, 6671, 2434, 8824, 104, 5205, 3976, 7084, 3770, 2643, 6664, 4433],
#  [2596, 6671, 5736],
#  [8605, 5892, 6671],
#  [2596, 4202, 4115, 3770, 8151, 7990],
#  [2596, 8232, 1072, 1968, 8688],
#  [4992, 1013, 104, 938, 6546, 7084, 2596],
#  [2183, 4584, 469, 4115, 6459, 7084, 7584, 6281],
#  [104, 4566, 5628, 2596, 8020, 2783, 8624],
#  [2183,
#   2247,
#   1085,
#   104,
#   7787,
#   6057,
#   992,
#   90,
#   5317,
#   7584,
#   8006,
#   8193,
#   5205,
#   4447,
#   3770,
#   5178,
#   5519],
#  [282,
#   2596,
#   2783,
#   104,
#   4566,
#   3298,
#   2596,
#   6419,
#   2777,
#   1013,
#   2596,
#   2716,
#   2596,
#   5205,
#   3718,
#   7084,
#   1750,
#   1013,
#   2596,
#   4713,
#   2716,
#   2596,
#   4713,
#   3718],
#  [522, 4444],
#  [5481, 2690, 3180, 6859, 8824, 1473, 2167, 1671, 4423, 8824],
#  [2596, 8683],
#  [104, 7787, 6269, 4663],
#  [4877, 7787, 104, 8431, 104, 4566, 4500, 6634, 1473, 2596, 1368, 3770, 7099],
#  [2826, 8298],
#  [6694,
#   104,
#   6139,
#   6366,
#   4115,
#   90,
#   6419,
#   5625,
#   99,
#   104,
#   5569,
#   6419,
#   5150,
#   104,
#   1827,
#   2826,
#   7356,
#   2160,
#   4115,
#   6419,
#   423,
#   8155,
#   3852,
#   5317,
#   546,
#   8605,
#   1712,
#   1473,
#   197,
#   8824,
#   6859,
#   3770,
#   2105,
#   7765,
#   2783,
#   4829,
#   2596,
#   5237,
#   4196],
#  [104,
#   6366,
#   4115,
#   2349,
#   2160,
#   4115,
#   6419,
#   5897,
#   6269,
#   6281,
#   3470,
#   5317,
#   3770,
#   423,
#   1614,
#   2036,
#   3770,
#   6041,
#   1473,
#   912,
#   6419,
#   5150],
#  [2783, 6671, 2596, 933, 1126, 6671, 2596, 798],
#  [2043, 3686, 5425, 522, 2826, 6241, 4399, 6935, 5456, 1068, 1847, 6241],
#  [1126, 6057],
#  [2043, 2247, 1777, 5728, 1013, 4440, 1941, 2247, 6725],
#  [5017,
#   5628,
#   1750,
#   4447,
#   4115,
#   6241,
#   1072,
#   5671,
#   104,
#   4969,
#   5456,
#   6671,
#   5557,
#   1874,
#   3686,
#   5628,
#   1750,
#   719,
#   6419,
#   4389,
#   7392,
#   6859,
#   6241],
#  [2596, 8021, 4447, 4115, 6241, 4838],
#  [4207],
#  [2783, 4829, 7584, 3574, 1731, 2826, 4440],
#  [104, 4713, 719, 6419, 3574],
#  [8605, 8543, 2630],
#  [104, 7787, 7163, 4235],
#  [4877, 7787, 104],
#  [4450,
#   2596,
#   2336,
#   6241,
#   7548,
#   2596,
#   6671,
#   6419,
#   8002,
#   2043,
#   6199,
#   1750,
#   1181],
#  [2596,
#   6671,
#   6241,
#   8824,
#   2247,
#   2043,
#   3770,
#   5150,
#   2596,
#   6671,
#   992,
#   912,
#   2434,
#   3770,
#   5862,
#   5897],
#  [6693,
#   282,
#   2596,
#   2783,
#   104,
#   4566,
#   4256,
#   2596,
#   6419,
#   1200,
#   5464,
#   2596,
#   1338,
#   6241,
#   4115,
#   3770,
#   5673,
#   908,
#   4713,
#   5628,
#   6241,
#   2862,
#   2826,
#   7584,
#   7769,
#   2043,
#   2247,
#   3770,
#   4349,
#   3634,
#   1821,
#   8193,
#   8232,
#   5780],
#  [5052, 104, 7787, 6419, 312],
#  [5017, 1583, 104, 7787, 7450, 2596, 104, 5782, 8771, 6241],
#  [2304, 2596, 3034, 3903, 5899, 992, 480, 2596, 8824, 1750],
#  [104, 6170, 6241, 3838, 556, 6419, 3460, 1473, 4440, 2247, 3852],
#  [4207,
#   3686,
#   6241,
#   5317,
#   3770,
#   3460,
#   469,
#   2385,
#   5017,
#   104,
#   7787,
#   5772,
#   2596,
#   1068,
#   1731,
#   104,
#   7787,
#   6419,
#   7164,
#   1473,
#   104,
#   1777,
#   2160,
#   1446],
#  [6915,
#   104,
#   4713,
#   1731,
#   2596,
#   7446,
#   6419,
#   7164,
#   104,
#   3686,
#   1731,
#   2596,
#   7446,
#   3824,
#   4196,
#   3852,
#   104,
#   4191,
#   4115,
#   7418,
#   3770,
#   7827,
#   2596,
#   1456,
#   8020,
#   1968,
#   2596,
#   4713,
#   8020,
#   6241,
#   2304,
#   996,
#   2043,
#   2247,
#   8232,
#   3770,
#   997,
#   4115,
#   95,
#   5809,
#   2596,
#   5728,
#   1013,
#   2043,
#   128,
#   4440,
#   2596,
#   49,
#   6419,
#   2902,
#   6859,
#   6241,
#   1989,
#   2721,
#   5519,
#   2596,
#   5205,
#   1290,
#   3852,
#   5557,
#   2596,
#   1138,
#   1446,
#   3852,
#   4566,
#   6057,
#   2120,
#   3481,
#   95,
#   4469,
#   2826,
#   3608,
#   2596,
#   6671,
#   7955],
#  [104,
#   6252,
#   2596,
#   2596,
#   8020,
#   104,
#   3328,
#   104,
#   5569,
#   5090,
#   3770,
#   1550,
#   1837,
#   2596,
#   8020,
#   104,
#   1731,
#   2043,
#   2247,
#   2697],
#  [2304,
#   1989,
#   6057,
#   2160,
#   4115,
#   2596,
#   4115,
#   2359,
#   2773,
#   2043,
#   2247,
#   2697,
#   7718,
#   6057,
#   4713,
#   2596,
#   8432,
#   4440,
#   2247,
#   1126,
#   2596,
#   6671,
#   6419,
#   312],
#  [1446,
#   104,
#   4191,
#   5782,
#   2596,
#   403,
#   4500,
#   2862,
#   6269,
#   6419,
#   7316,
#   556,
#   6698,
#   104,
#   4191,
#   2596,
#   3034,
#   1000,
#   6241,
#   3838,
#   7450,
#   6241,
#   6766,
#   8824,
#   6640,
#   6241],
#  [1126,
#   4829,
#   2596,
#   3976,
#   1750,
#   7099,
#   3838,
#   7084,
#   3770,
#   1021,
#   1126,
#   4829,
#   2596,
#   39,
#   2160,
#   556,
#   1750,
#   5750,
#   4440],
#  [8824, 6162],
#  [2783, 6459, 2596, 1138],
#  [7584,
#   5417,
#   2596,
#   1719,
#   5456,
#   657,
#   4115,
#   2120,
#   6419,
#   7663,
#   4196,
#   1750,
#   3745,
#   1583,
#   1473,
#   235,
#   6547],
#  [2783, 2247, 7584, 8824],
#  [104, 4711, 2817, 603],
#  [6418, 6459, 3852, 8076],
#  [4877,
#   8824,
#   4713,
#   719,
#   4115,
#   6459,
#   5914,
#   8824,
#   5456,
#   657,
#   4115,
#   719,
#   4978,
#   7663,
#   2183,
#   245],
#  [2596,
#   1509,
#   1731,
#   2596,
#   4566,
#   90,
#   3962,
#   4115,
#   7164,
#   6419,
#   6839,
#   7084,
#   2183,
#   5546,
#   636,
#   2721,
#   3824,
#   6671,
#   2596],
#  [5264, 7835, 3852, 5017, 5750, 6419, 787],
#  [8193,
#   4713,
#   8020,
#   4440,
#   732,
#   1989,
#   7970,
#   3745,
#   7587,
#   2240,
#   6419,
#   1536,
#   4115,
#   90,
#   8042],
#  [636, 8645, 5175, 6671, 2160, 3838],
#  [3838, 6671, 522, 4761, 3528, 6859, 2183, 8543],
#  [5205, 8193, 4500, 2160, 4115, 3770, 3673, 4312],
#  [2596, 8020, 2596, 1161, 6459, 4440, 4450],
#  [2247, 3852, 3817, 2026],
#  [5264, 5205, 2596, 282, 3180, 2783, 2385, 4235],
#  [104,
#   8432,
#   1446,
#   104,
#   4581,
#   4440,
#   3770,
#   6281,
#   3447,
#   2247,
#   4235,
#   7084,
#   2596,
#   2247,
#   2183,
#   383,
#   2026,
#   4115,
#   3770,
#   6281,
#   7040],
#  [104, 1509, 1161, 4256, 2862, 1072, 6397, 1550, 4769, 6859, 2183, 8543],
#  [6693,
#   1446,
#   104,
#   6459,
#   8432,
#   4440,
#   7584,
#   764,
#   5481,
#   8824,
#   2536,
#   1464,
#   2247,
#   4440,
#   6042],
#  [1224, 5569, 1627, 1446, 6057, 991, 1224, 4566, 90, 4696],
#  [6459, 2596, 719, 3770, 573, 5317, 4150],
#  [8824,
#   2247,
#   6057,
#   6419,
#   1249,
#   245,
#   6693,
#   5264,
#   8824,
#   1627,
#   1224,
#   2247,
#   4696,
#   104,
#   719,
#   8232,
#   6419,
#   6281,
#   3447,
#   8571,
#   5264,
#   5573,
#   2247,
#   1627,
#   1446,
#   6057,
#   991],
#  [1583, 6671, 2596, 6693],
#  [4207, 7999, 6057, 6419, 1249, 245],
#  [8431],
#  [8431],
#  [8431],
#  [8431],
#  [5052, 1860],
#  [2783,
#   2247,
#   7584,
#   1375,
#   1126,
#   4829,
#   2596,
#   3661,
#   6859,
#   1750,
#   104,
#   3686,
#   6366,
#   6419,
#   1840],
#  [104, 8824, 1161, 1559, 2596, 3686, 3903, 2596, 1138, 1750, 4115, 1559, 2282],
#  [2596,
#   5782,
#   719,
#   4115,
#   6380,
#   1750,
#   5317,
#   1589,
#   2826,
#   8605,
#   1442,
#   2596,
#   8403,
#   4256,
#   1750,
#   7701],
#  [8784, 104, 7787, 6948, 7428, 104, 6380, 2596, 3474, 8784],
#  [1995, 3852],
#  [1634,
#   104,
#   2960,
#   3686,
#   2959,
#   8824,
#   4115,
#   3770,
#   6735,
#   1473,
#   7418,
#   6459,
#   2596,
#   4992,
#   1013,
#   8193,
#   3686,
#   8437,
#   7701,
#   2862],
#  [8431, 8431, 1583, 4713, 8824, 1750],
#  [104, 7787, 6057],
#  [335,
#   2596,
#   6671,
#   104,
#   7787,
#   6057,
#   3686,
#   6334,
#   6205,
#   104,
#   4713,
#   3686,
#   5309,
#   6419,
#   8824,
#   5317,
#   7584,
#   567,
#   2596,
#   8403,
#   4256,
#   1750,
#   7701],
#  [4207,
#   2304,
#   2596,
#   6170,
#   3770,
#   1367,
#   1473,
#   4702,
#   3852,
#   1550,
#   8748,
#   6269,
#   3770,
#   2079,
#   4440,
#   5569],
#  [4440, 5569, 1249, 2596, 7446, 2458, 3770, 2079],
#  [2596,
#   7446,
#   8824,
#   2596,
#   5782,
#   4256,
#   6419,
#   8272,
#   1013,
#   2596,
#   8232,
#   1750,
#   7718,
#   6057],
#  [2304, 7226, 5569, 3852, 4440, 8684, 1750, 636, 4115, 6459, 4440, 3125],
#  [2596, 6671, 8824],
#  [5017, 6859, 2183, 2596, 719, 7471, 6269, 7584, 699, 983, 2247, 3852],
#  [8403, 90, 8824],
#  [4713, 4928, 4196, 3770, 3074, 6468, 104, 4566, 6057, 1559, 3852],
#  [1559, 3770, 6468],
#  [6915, 282, 1750, 2783, 2596, 1138, 4115, 7418],
#  [1559, 3852],
#  [8784,
#   8605,
#   3613,
#   5456,
#   1138,
#   1750,
#   4115,
#   4335,
#   5456,
#   1138,
#   1750,
#   4115,
#   4335,
#   6721],
#  [4440, 2247, 1249],
#  [4207],
#  [2304, 4440, 2247, 5923],
#  [6693,
#   4440,
#   2247,
#   5923,
#   1446,
#   104,
#   1161,
#   4500,
#   4769,
#   8193,
#   6671,
#   5317,
#   3770,
#   967,
#   2826,
#   7701,
#   4235],
#  [6915, 4500, 8714, 2596, 6671, 992, 90, 5923],
#  [6915,
#   6915,
#   2124,
#   4115,
#   1750,
#   4235,
#   104,
#   1138,
#   4115,
#   8020,
#   2783,
#   2596,
#   6671,
#   2995,
#   4196,
#   2596,
#   8020,
#   3770,
#   6297,
#   1837,
#   1473,
#   3770,
#   304,
#   1473],
#  [104,
#   4566,
#   282,
#   2596,
#   3375,
#   7343,
#   6459,
#   3852,
#   3375,
#   1095,
#   3712,
#   1095,
#   2596,
#   4969,
#   7099,
#   8193,
#   4566,
#   4447,
#   8193,
#   4566,
#   4447],
#  [8744],
#  [104,
#   8744,
#   8193,
#   4566,
#   4447,
#   2596,
#   4566,
#   90,
#   5923,
#   2596,
#   4566,
#   90,
#   4696,
#   4500,
#   8714,
#   3686,
#   1991,
#   4440,
#   7776,
#   3686,
#   5017,
#   2036,
#   3770,
#   8824,
#   1473,
#   1991,
#   2596,
#   6671,
#   2995,
#   4115,
#   1750],
#  [4207, 104, 4566, 6459, 4440, 1095, 3402, 1095, 2596, 6671, 6057, 8824, 1750],
#  [8824, 2596, 5718, 104, 205, 2596],
#  [6693, 1865, 3375],
#  [3375],
#  [2596, 8744],
#  [4207, 104, 8744],
#  [6693,
#   1473,
#   2596,
#   8020,
#   2783,
#   104,
#   4566,
#   3695,
#   4147,
#   8605,
#   1301,
#   5021,
#   6419,
#   8268,
#   8824,
#   2826,
#   3021,
#   1473,
#   1634,
#   3686,
#   2403,
#   1208,
#   2862,
#   8500,
#   4115,
#   8824,
#   4440,
#   4829,
#   4440,
#   90,
#   6419,
#   1249,
#   1837],
#  [4207, 4207, 1249, 1837],
#  [6693],
#  [1719, 2596, 7261, 1249, 7987],
#  [5321, 2596],
#  [4877,
#   8193,
#   6671,
#   5574,
#   4115,
#   2567,
#   2183,
#   7637,
#   8193,
#   8232,
#   7864,
#   7990,
#   7084,
#   3770,
#   4934,
#   2829,
#   5336,
#   4147,
#   3178,
#   4115,
#   4500,
#   104,
#   7418,
#   6095,
#   4969,
#   6419,
#   5327,
#   1456,
#   3770,
#   1450,
#   104,
#   4500,
#   4115,
#   4969,
#   3770,
#   5327,
#   1473,
#   8824,
#   5557,
#   3770,
#   8096,
#   104,
#   5833,
#   7666,
#   1473,
#   6419,
#   5150,
#   7084,
#   6419,
#   5649,
#   5628,
#   3481,
#   4500,
#   1550,
#   3327,
#   104,
#   5569,
#   5336,
#   4440,
#   2967,
#   2536,
#   3852,
#   104,
#   2967,
#   6961,
#   8605,
#   1200,
#   5401,
#   2388,
#   1473,
#   556,
#   2783,
#   6334,
#   3824,
#   5150,
#   8232,
#   8824,
#   169,
#   3770,
#   8767,
#   2388,
#   1473,
#   1989,
#   5519,
#   1013,
#   104,
#   8815,
#   5406,
#   7099,
#   556,
#   4440,
#   5327,
#   556,
#   6419,
#   2105,
#   7186,
#   104,
#   4829,
#   719,
#   6961,
#   8605,
#   1200,
#   5401,
#   2388],
#  [3512, 7718, 7261, 4440, 2247, 531],
#  [6057,
#   2752,
#   2160,
#   6057,
#   2752,
#   2160,
#   5750,
#   4440,
#   104,
#   4191,
#   2783,
#   6459,
#   104,
#   8232,
#   5780,
#   6295,
#   3449,
#   6419,
#   3685,
#   7718,
#   522,
#   8824,
#   4235,
#   1473,
#   3838,
#   1473,
#   5317,
#   6419,
#   6295,
#   4587,
#   6915,
#   3481,
#   8380,
#   1750,
#   7279],
#  [104, 1731, 2596, 6671, 2093, 6419, 3513, 8824, 3838, 1583],
#  [636, 8715, 6671, 7584, 1136],
#  [4877, 2783, 2247, 8003],
#  [1224,
#   2247,
#   2434,
#   8824,
#   3664,
#   3574,
#   5569,
#   7314,
#   3745,
#   3402,
#   4115,
#   4702,
#   6241,
#   806,
#   6269,
#   5456,
#   7446,
#   916,
#   556,
#   6419,
#   1675,
#   5851,
#   6241,
#   7084,
#   6419,
#   7965,
#   3510],
#  [4440, 2247, 8003],
#  [104,
#   6817,
#   2183,
#   8779,
#   1321,
#   2349,
#   8605,
#   5711,
#   6671,
#   6960,
#   1750,
#   6169,
#   4296,
#   1750],
#  [3178],
#  [4478, 1208, 2862, 2826, 8605, 8006],
#  [6693, 2596, 3178],
#  [1072, 7781, 8193, 5205, 6459, 4440, 6629],
#  [6693,
#   2596,
#   8437,
#   5317,
#   6419,
#   1291,
#   2575,
#   104,
#   8432,
#   4440,
#   1473,
#   2783,
#   5903,
#   2826,
#   8437,
#   6459,
#   2596,
#   6459],
#  [104, 7787, 3886],
#  [2596, 6671, 6419, 3886, 2783, 6459, 2596, 1202, 7317, 8824, 556],
#  [2596, 3426, 8824, 5317, 3852],
#  [1473, 2783, 6459, 2596, 6459, 7084, 3770, 7196],
#  [6671, 2596, 6015],
#  [3718,
#   4115,
#   290,
#   8824,
#   4713,
#   4855,
#   3770,
#   301,
#   3718,
#   4838,
#   7718,
#   2596,
#   4566,
#   90,
#   5317,
#   8605,
#   8500,
#   1179],
#  [5017, 8076, 104, 719, 2536, 1847, 4147, 1968, 3214, 2596],
#  [6915, 104, 7787, 3770, 2763, 4440, 2247, 403, 1847, 2596],
#  [104,
#   4566,
#   2690,
#   2596,
#   6269,
#   3481,
#   5647,
#   104,
#   4969,
#   8824,
#   1473,
#   2596,
#   3422,
#   4115,
#   1750],
#  [8193,
#   4566,
#   4447,
#   4196,
#   4440,
#   3347,
#   3741,
#   7205,
#   2596,
#   245,
#   4115,
#   4500,
#   4115,
#   2901,
#   6476,
#   6456,
#   7867,
#   1064],
#  [2783, 3852, 1321, 8437, 4440, 8006],
#  [1013,
#   2596,
#   4713,
#   1138,
#   8605,
#   1179,
#   104,
#   4566,
#   3784,
#   5596,
#   8698,
#   1473,
#   5456,
#   4566,
#   8698,
#   3852],
#  [495, 6419, 5231, 495, 6419, 5231],
#  [7446, 2596, 6419, 1970, 4440, 636, 2596, 1879, 636, 4115, 6829, 3770, 3589],
#  [8605,
#   8221,
#   5569,
#   1224,
#   7510,
#   1750,
#   8645,
#   3606,
#   4196,
#   6281,
#   4769,
#   1989,
#   8605,
#   2998],
#  [2596,
#   1161,
#   4711,
#   1750,
#   2596,
#   6671,
#   6057,
#   6419,
#   5625,
#   3686,
#   1970,
#   7084,
#   6419,
#   1712,
#   104,
#   2115,
#   2596,
#   3866,
#   8571,
#   7111,
#   5317,
#   7584,
#   6435],
#  [4450,
#   4812,
#   3770,
#   2311,
#   6459,
#   3852,
#   8784,
#   5017,
#   2596,
#   6671,
#   7039,
#   2596,
#   4713,
#   719,
#   3770,
#   6077],
#  [3327, 2247, 7584, 764],
#  [282, 6465, 4115, 4702, 3664, 1712, 2830],
#  [5628, 6241, 515, 5628, 6241, 8824],
#  [1008, 104, 7787, 1860],
#  [3327, 2247, 790, 6489],
#  [4769,
#   104,
#   5750,
#   4115,
#   4969,
#   1973,
#   2862,
#   2826,
#   3770,
#   8006,
#   7227,
#   8193,
#   4969,
#   8748,
#   4115,
#   2934,
#   1126,
#   8824,
#   4702,
#   8605,
#   973,
#   6269,
#   3770,
#   8824],
#  [1989,
#   7871,
#   8824,
#   7990,
#   2349,
#   2862,
#   2826,
#   7871,
#   3589,
#   104,
#   4713,
#   2690,
#   3770,
#   4953,
#   3516,
#   5600,
#   2596,
#   992,
#   4969,
#   6750],
#  [3327, 2247, 8151, 7990],
#  [4440, 2247, 401, 8403, 2596, 4702, 3770, 973, 6269, 3770, 8824],
#  [104,
#   5750,
#   4115,
#   4447,
#   4115,
#   3770,
#   6018,
#   7226,
#   623,
#   3770,
#   7990,
#   5205,
#   2596,
#   4256,
#   1750,
#   4988],
#  [2124,
#   4115,
#   1750,
#   104,
#   4713,
#   1138,
#   7431,
#   3686,
#   4256,
#   1750,
#   3770,
#   4988,
#   1473,
#   6418,
#   2596,
#   4500],
#  [4256, 1750, 3770, 8824],
#  [8500, 8403, 104, 1719, 7584, 7825, 3462],
#  [2783, 2247, 7584, 1207, 3428, 2826, 7584, 2673, 4115, 3770, 6259, 8312],
#  [522, 6543, 139],
#  [636, 7970, 973, 6671, 2596, 2764, 7084, 2596],
#  [104, 719, 8824, 1064],
#  [2247, 1224, 7084, 2596, 6671, 2596, 6200, 6605],
#  [335],
#  [3462, 5496, 3180, 3718, 6269, 5710],
#  [2247, 3838, 6419, 1375],
#  [8193, 6671, 1339, 2434, 3731],
#  [636, 3402, 6671, 2596, 4353, 4115, 6169],
#  [522, 6543],
#  [104, 4829, 5750, 4115, 6438, 556, 6730, 6693],
#  [7226, 2247, 1224],
#  [2183, 5557, 2596, 1138],
#  [6459, 2596, 8020, 636, 7970, 5434, 8445, 556, 7663, 6951],
#  [5317, 4235, 6862, 1224, 375, 6419, 1206],
#  [8824, 3770, 5434, 8445, 3481, 1206, 1064, 556, 6419, 534, 2398],
#  [5052,
#   8824,
#   1721,
#   619,
#   3556,
#   603,
#   1465,
#   5434,
#   143,
#   6419,
#   1206,
#   556,
#   3664,
#   2398,
#   1473,
#   636,
#   7970,
#   2596,
#   1731,
#   2928,
#   8232,
#   556,
#   2682,
#   7476,
#   4196,
#   3770,
#   6697,
#   4200,
#   6269,
#   4115,
#   6241,
#   3852,
#   3709,
#   4115,
#   90,
#   6419,
#   5434,
#   7718,
#   6419,
#   8547,
#   5317,
#   2183,
#   2983,
#   5017,
#   2596,
#   1138,
#   2555,
#   7718,
#   6057],
#  [3686,
#   6459,
#   2783,
#   104,
#   6459,
#   7418,
#   3770,
#   206,
#   1837,
#   104,
#   7418,
#   4713,
#   7580,
#   7584,
#   5152],
#  [4713, 7164, 7666],
#  [7428, 2596, 4701, 2783, 104, 2784],
#  [5017, 544, 5164, 3686, 5750, 5317, 3770, 8824],
#  [4713, 6438, 8824],
#  [1126, 1126, 6459, 104, 6139, 719, 4115, 6438, 4115, 2596, 5317, 790],
#  [5017, 2446, 8824, 2364, 8824, 6992, 8824, 8824, 5529, 3890],
#  ...]

# %%
answers_into_int
# Out:
# [[2304,
#   104,
#   3328,
#   8193,
#   4829,
#   5464,
#   7084,
#   8824,
#   1013,
#   4440,
#   2247,
#   6693,
#   7084,
#   2596,
#   8823],
#  [6057, 3770, 8824, 1473, 8824, 1473, 8824, 4081, 3462, 8823],
#  [6693, 6418, 636, 3489, 8193, 6516, 2862, 6334, 8532, 8824, 3939, 5529, 8823],
#  [5797, 3852, 8823],
#  [4522, 8823],
#  [3770,
#   1837,
#   2247,
#   4522,
#   104,
#   7787,
#   6859,
#   3770,
#   6127,
#   2826,
#   6419,
#   3317,
#   8824,
#   7363,
#   2826,
#   5803,
#   8605,
#   7302,
#   104,
#   1161,
#   3647,
#   5389,
#   2043,
#   7835,
#   8823],
#  [883, 5750, 2043, 8403, 4969, 6419, 3647, 1420, 996, 8823],
#  [8824,
#   3918,
#   2043,
#   876,
#   4115,
#   90,
#   1509,
#   3239,
#   99,
#   2043,
#   4010,
#   5956,
#   8016,
#   6418,
#   3852,
#   5569,
#   3686,
#   5750,
#   2043,
#   8232,
#   3702,
#   2826,
#   3852,
#   7718,
#   7701,
#   8823],
#  [4440, 2247, 6419, 6486, 8823],
#  [5628, 1750, 1719, 2783, 104, 5205, 6459, 8823],
#  [1550, 1719, 2596, 6671, 3178, 556, 3770, 8824, 8823],
#  [104,
#   4713,
#   1138,
#   4115,
#   8020,
#   636,
#   4115,
#   7418,
#   4440,
#   6379,
#   104,
#   1138,
#   4115,
#   8020,
#   2788,
#   753,
#   5750,
#   3327,
#   3770,
#   1249,
#   4251,
#   6671,
#   636,
#   7970,
#   7835,
#   3,
#   5465,
#   3426,
#   5750,
#   7198,
#   104,
#   719,
#   3866,
#   5317,
#   8605,
#   6435,
#   6961,
#   4115,
#   8543,
#   2862,
#   8605,
#   1200,
#   4115,
#   2817,
#   8823],
#  [4440, 2247, 3903, 1989, 2556, 6419, 8374, 3481, 8823],
#  [5797, 8532, 8823],
#  [2304, 2240, 2817, 104, 1731, 6225, 90, 8823],
#  [3327, 8823],
#  [104,
#   7501,
#   6269,
#   2596,
#   4115,
#   3976,
#   8605,
#   3615,
#   2596,
#   1473,
#   4440,
#   8824,
#   6671,
#   3771,
#   8824,
#   5600,
#   8193,
#   403,
#   657,
#   6269,
#   7902,
#   3647,
#   8823],
#  [2596, 6671, 226, 8823],
#  [8824,
#   1566,
#   8824,
#   4388,
#   522,
#   2962,
#   1473,
#   104,
#   3866,
#   403,
#   1202,
#   6419,
#   8824,
#   3182,
#   3770,
#   8824,
#   8824,
#   8823],
#  [104,
#   1509,
#   1509,
#   1509,
#   8021,
#   4500,
#   1446,
#   104,
#   1161,
#   6057,
#   7555,
#   8605,
#   7302,
#   478,
#   8823],
#  [104,
#   7787,
#   4961,
#   6269,
#   3852,
#   1446,
#   2043,
#   1321,
#   1931,
#   4115,
#   90,
#   4202,
#   556,
#   6465,
#   8823],
#  [684,
#   6915,
#   104,
#   3528,
#   6419,
#   666,
#   2826,
#   8824,
#   8824,
#   5317,
#   3481,
#   2826,
#   6241,
#   8824,
#   4877,
#   104,
#   7787,
#   1700,
#   5772,
#   2043,
#   2247,
#   6057,
#   8824,
#   8824,
#   8824,
#   8823],
#  [4877, 4440, 2247, 3770, 5903, 2826, 2011, 2043, 2688, 1700, 7416, 8823],
#  [7226,
#   1729,
#   5557,
#   104,
#   719,
#   403,
#   1000,
#   6241,
#   7418,
#   2247,
#   4440,
#   2043,
#   4829,
#   597,
#   7227,
#   7019,
#   6419,
#   2011,
#   4440,
#   6262,
#   8823],
#  [6874, 5750, 753, 8708, 2862, 3375, 3125, 8823],
#  [104, 480, 8193, 3358, 7871, 4535, 8824, 8823],
#  [5031, 8823],
#  [104, 5569, 8823],
#  [2596, 3866, 6366, 4115, 4500, 2862, 7084, 8824, 7428, 2596, 8823],
#  [6418, 4440, 2247, 5557, 2596, 6961, 4115, 7418, 8823],
#  [1446, 8823],
#  [2596, 6139, 2536, 2183, 236, 8823],
#  [6915, 8823],
#  [2783, 4232, 8823],
#  [1750, 2183, 3507, 1422, 8824, 104, 7787, 5750, 7523, 2418, 8823],
#  [5321,
#   8207,
#   1013,
#   104,
#   6961,
#   4115,
#   4701,
#   3481,
#   7389,
#   1941,
#   4196,
#   7584,
#   8824,
#   8823],
#  [2783, 1249, 3426, 8823],
#  [3770, 4978, 2596, 8823],
#  [5750, 8605, 1961, 2826, 5761, 8824, 8823],
#  [6915, 8823],
#  [6693, 2596, 6671, 992, 26, 4115, 4737, 636, 4115, 3121, 8823],
#  [7343, 4500, 8823],
#  [104, 6817, 4877, 8823],
#  [5456, 6459, 8010, 8823],
#  [6915, 8823],
#  [2596, 6225, 8021, 1731, 4196, 3852, 8823],
#  [7226, 8823],
#  [7087, 8823],
#  [4829, 2596, 4992, 2093, 1750, 6419, 8326, 4522, 8823],
#  [2247, 1224, 8824, 7718, 6756, 8823],
#  [3700,
#   104,
#   4713,
#   8020,
#   104,
#   3328,
#   1224,
#   4829,
#   90,
#   1172,
#   7389,
#   2826,
#   6419,
#   2594,
#   8823],
#  [837,
#   104,
#   1921,
#   1013,
#   3770,
#   2430,
#   8193,
#   6671,
#   3591,
#   4115,
#   1138,
#   4115,
#   4500,
#   2862,
#   7084,
#   6671,
#   3770,
#   7416,
#   8193,
#   5299,
#   1138,
#   4115,
#   4500,
#   2862,
#   7084,
#   2596,
#   8020,
#   8823],
#  [5557,
#   104,
#   8020,
#   2247,
#   104,
#   4829,
#   4256,
#   2160,
#   8605,
#   4657,
#   2719,
#   4115,
#   4500,
#   2862,
#   7084,
#   6419,
#   2011,
#   5750,
#   7087,
#   8823],
#  [104, 4713, 719, 4115, 90, 6282, 7301, 522, 8823],
#  [104, 7428, 8823],
#  [7963, 8823],
#  [1579, 8823],
#  [998, 4689, 8823],
#  [1989,
#   6419,
#   7204,
#   54,
#   2719,
#   1446,
#   104,
#   4566,
#   90,
#   5750,
#   5761,
#   6419,
#   3954,
#   1473,
#   3426,
#   8823],
#  [8605,
#   5729,
#   6862,
#   104,
#   719,
#   8232,
#   6419,
#   1249,
#   8571,
#   6859,
#   3190,
#   3770,
#   8824,
#   2011,
#   8500,
#   7159,
#   8823],
#  [1008, 7087, 8823],
#  [2596, 6671, 8824, 4521, 3694, 6217, 1989, 251, 932, 8823],
#  [2596,
#   8020,
#   3770,
#   6118,
#   104,
#   5205,
#   2331,
#   6108,
#   4500,
#   1013,
#   1881,
#   1321,
#   4500,
#   8823],
#  [7619, 1008, 6149, 8823],
#  [5205, 2596, 6859, 7827, 5464, 5761, 6419, 4067, 8823],
#  [3852,
#   2184,
#   4440,
#   8824,
#   2247,
#   6896,
#   6859,
#   2837,
#   8548,
#   1473,
#   8193,
#   6671,
#   657,
#   8823],
#  [8784,
#   104,
#   3328,
#   2596,
#   6225,
#   719,
#   6419,
#   3647,
#   104,
#   4713,
#   8020,
#   1126,
#   104,
#   7787,
#   8390,
#   4115,
#   5550,
#   1446,
#   6671,
#   2596,
#   657,
#   4115,
#   8824,
#   8824,
#   1675,
#   3939,
#   5529,
#   8823],
#  [2783, 6459, 2596, 1731, 8823],
#  [104,
#   1731,
#   2596,
#   6671,
#   6419,
#   5106,
#   104,
#   1731,
#   2596,
#   6459,
#   2183,
#   4115,
#   7484,
#   1750,
#   1473,
#   104,
#   1731,
#   2596,
#   2656,
#   8823],
#  [2783, 2247, 3648, 8823],
#  [8824,
#   8824,
#   1675,
#   2247,
#   3648,
#   1446,
#   2596,
#   6671,
#   3745,
#   6944,
#   1113,
#   4115,
#   2386,
#   7226,
#   26,
#   8824,
#   4115,
#   8020,
#   4440,
#   8823],
#  [6859, 7827, 104, 7787, 6057, 6419, 8824, 8824, 7266, 8824, 8823],
#  [1989, 2538, 1634, 2596, 719, 1000, 2826, 6465, 8823],
#  [4207,
#   1224,
#   2247,
#   7584,
#   5106,
#   2998,
#   8824,
#   5688,
#   104,
#   4401,
#   4995,
#   104,
#   7787,
#   6057,
#   5979,
#   4115,
#   4500,
#   2862,
#   104,
#   2960,
#   8824,
#   5519,
#   6419,
#   7955,
#   2011,
#   3745,
#   8823],
#  [5205, 8193, 4500, 4769, 8823],
#  [104,
#   1509,
#   4713,
#   1731,
#   104,
#   26,
#   1072,
#   7532,
#   8491,
#   2434,
#   2596,
#   1550,
#   4769,
#   8823],
#  [2596, 6671, 6493, 8823],
#  [5750, 2596, 477, 8823],
#  [104,
#   6459,
#   477,
#   1446,
#   104,
#   7787,
#   6419,
#   6620,
#   3059,
#   5317,
#   5090,
#   7701,
#   556,
#   7584,
#   2529,
#   1669,
#   6057,
#   2817,
#   5524,
#   2331,
#   5073,
#   8823],
#  [104,
#   859,
#   104,
#   6961,
#   4440,
#   4176,
#   104,
#   7787,
#   3770,
#   4349,
#   8824,
#   4440,
#   8232,
#   2197,
#   4115,
#   3770,
#   7327,
#   1473,
#   104,
#   1161,
#   4500,
#   3903,
#   2596,
#   6125,
#   2331,
#   6108,
#   8823],
#  [2783, 8823],
#  [5317, 8824, 556, 6419, 7017, 8823],
#  [1126, 8823],
#  [1224, 5569, 5750, 6419, 1210, 936, 8823],
#  [1446, 2596, 7529, 7087, 8823],
#  [4769, 104, 6459, 7099, 6418, 5569, 6419, 1172, 1941, 8823],
#  [1095, 5317, 8823],
#  [2596, 7428, 2783, 8823],
#  [3686,
#   7109,
#   203,
#   104,
#   6252,
#   6465,
#   104,
#   5782,
#   1138,
#   4115,
#   7279,
#   104,
#   1759,
#   3178,
#   1224,
#   8232,
#   8414,
#   6418,
#   1224,
#   7590,
#   2160,
#   7084,
#   1750,
#   8823],
#  [3629,
#   4440,
#   104,
#   3011,
#   104,
#   4829,
#   3866,
#   6459,
#   5885,
#   3686,
#   3903,
#   8593,
#   5524,
#   5569,
#   5090,
#   3852,
#   1473,
#   104,
#   4784,
#   4995,
#   7006,
#   556,
#   8824,
#   1675,
#   1473,
#   8605,
#   8824,
#   8824,
#   5024,
#   8823],
#  [1126, 5782, 2596, 282, 1750, 8823],
#  [104, 6366, 4115, 5628, 2596, 2120, 2160, 7584, 2529, 4992, 4196, 6465, 8823],
#  [6915,
#   2596,
#   1378,
#   1013,
#   2596,
#   1509,
#   3328,
#   104,
#   8403,
#   2120,
#   8605,
#   2529,
#   152,
#   2596,
#   4829,
#   719,
#   5628,
#   1750,
#   4500,
#   2862,
#   7084,
#   6465,
#   3930,
#   2826,
#   4678,
#   6149,
#   1487,
#   1750,
#   6422,
#   8823],
#  [104, 7787, 6057, 3824, 996, 4115, 1241, 7584, 6597, 8823],
#  [104, 4401, 104, 3328, 104, 5569, 3552, 2596, 8823],
#  [4241,
#   2596,
#   6671,
#   3686,
#   5750,
#   741,
#   3686,
#   4478,
#   1750,
#   7367,
#   1693,
#   5317,
#   3770,
#   8562,
#   4877,
#   104,
#   1161,
#   4238,
#   5885,
#   556,
#   2418,
#   8823],
#  [6057,
#   5557,
#   575,
#   6671,
#   1249,
#   5869,
#   2596,
#   1161,
#   6139,
#   6224,
#   3770,
#   6884,
#   2596,
#   1138,
#   4115,
#   8823],
#  [104, 4401, 104, 4566, 3866, 8020, 4566, 104, 8823],
#  [4877, 7428, 2596, 8823],
#  [2596, 2407, 1750, 2160, 8823],
#  [104, 3686, 6366, 8823],
#  [2783,
#   4115,
#   3625,
#   1555,
#   1750,
#   4115,
#   2585,
#   1750,
#   4115,
#   6426,
#   4712,
#   2783,
#   8823],
#  [6347, 104, 3686, 6366, 8823],
#  [1989, 3686, 2596, 8823],
#  [8824, 8823],
#  [6347,
#   2596,
#   6671,
#   6057,
#   7019,
#   5389,
#   7584,
#   7302,
#   3586,
#   7019,
#   4397,
#   2826,
#   4129,
#   8823],
#  [2783, 1013, 2043, 3866, 3586, 7019, 8823],
#  [6418, 6527, 4566, 2596, 1473, 104, 4566, 4969, 4115, 2292, 6859, 5529, 8823],
#  [1446, 1989, 6057, 6202, 2043, 2247, 6419, 5517, 630, 8823],
#  [2630, 8605, 8543, 8823],
#  [1473, 3327, 6671, 2596, 657, 8823],
#  [1013,
#   2596,
#   3370,
#   8020,
#   8193,
#   7446,
#   229,
#   4115,
#   4500,
#   4115,
#   6419,
#   410,
#   7245,
#   322,
#   2826,
#   4399,
#   8823],
#  [8185, 7558, 1095, 7871, 8824, 8823],
#  [1989,
#   3686,
#   6419,
#   1675,
#   6149,
#   1446,
#   104,
#   1879,
#   2596,
#   4829,
#   5048,
#   1750,
#   4115,
#   4500,
#   4995,
#   1638,
#   8824,
#   5519,
#   3838,
#   7147,
#   657,
#   8823],
#  [1013, 8824, 6057, 657, 2596, 6671, 6057, 657, 8823],
#  [1989, 3686, 6419, 1675, 6149, 8823],
#  [6149, 6347, 8823],
#  [3686, 556, 6419, 5231, 8823],
#  [1126, 8823],
#  [3903, 2043, 4566, 8579, 1208, 1693, 8823],
#  [3770, 7327, 1881, 4584, 6419, 3647, 8823],
#  [6915, 1446, 8823],
#  [1989,
#   4440,
#   5922,
#   4152,
#   7087,
#   1550,
#   4440,
#   2331,
#   5073,
#   7226,
#   2596,
#   1138,
#   1750,
#   4115,
#   4589,
#   8605,
#   6360,
#   556,
#   8823],
#  [1224, 2247, 6057, 6419, 5922, 4152, 4455, 4440, 2247, 8823],
#  [2596, 6671, 6057, 657, 7555, 7584, 7302, 478, 4397, 2826, 1941, 8823],
#  [4696,
#   104,
#   1719,
#   4440,
#   104,
#   7787,
#   6419,
#   1735,
#   5317,
#   8605,
#   2529,
#   908,
#   104,
#   7787,
#   6057,
#   6419,
#   2503,
#   104,
#   7787,
#   6419,
#   8824,
#   8823],
#  [104,
#   719,
#   6419,
#   3647,
#   6149,
#   1473,
#   1224,
#   2331,
#   5073,
#   6057,
#   6419,
#   2234,
#   2826,
#   8824,
#   5750,
#   6334,
#   8494,
#   8193,
#   8020,
#   8823],
#  [5782,
#   719,
#   2596,
#   8824,
#   556,
#   6419,
#   8824,
#   5946,
#   5600,
#   5456,
#   6419,
#   3513,
#   3745,
#   8824,
#   8824,
#   945,
#   556,
#   2596,
#   8823],
#  [5946,
#   2826,
#   6419,
#   5946,
#   2596,
#   1719,
#   6419,
#   8268,
#   2826,
#   8824,
#   3718,
#   5317,
#   8823],
#  [3866, 8823],
#  [8824,
#   3516,
#   3481,
#   3039,
#   7633,
#   1821,
#   3770,
#   4953,
#   3481,
#   1009,
#   4230,
#   1473,
#   8824,
#   8823],
#  [3686, 6801, 3403, 5640, 8823],
#  [4877, 5456, 282, 1750, 8823],
#  [4450, 104, 7787, 3591, 4115, 4256, 2596, 3770, 4319, 8823],
#  [3432, 5299, 636, 4829, 2596, 8823],
#  [104, 5569, 652, 6884, 5299, 4439, 3838, 8823],
#  [4207, 6419, 8268, 8193, 6671, 8824, 4147, 3770, 406, 6379, 8823],
#  [636, 8645, 6884, 7446, 5317, 7584, 8715, 8016, 8823],
#  [6388, 8823],
#  [4969, 3623, 8823],
#  [636, 8645, 6884, 4500, 4235, 8823],
#  [8268, 7867, 8131, 2826, 1208, 914, 8823],
#  [4207,
#   1446,
#   4610,
#   2430,
#   719,
#   3866,
#   7790,
#   6419,
#   2350,
#   5456,
#   3686,
#   2657,
#   2388,
#   4115,
#   8824,
#   8824,
#   8823],
#  [2596, 2661, 2596, 47, 2596, 8824, 8823],
#  [7226, 2247, 2043, 8823],
#  [5869, 8824, 8824, 4713, 5728, 1731, 4196, 3852, 8823],
#  [1126, 6057, 8823],
#  [104,
#   8403,
#   5464,
#   7084,
#   7584,
#   2604,
#   1446,
#   3852,
#   1321,
#   2543,
#   2043,
#   2247,
#   6057,
#   5979,
#   4115,
#   3647,
#   5389,
#   6241,
#   7255,
#   7302,
#   7835,
#   1473,
#   4440,
#   2247,
#   7871,
#   8824,
#   8823],
#  [3903,
#   5456,
#   6671,
#   8824,
#   4115,
#   1074,
#   7460,
#   4069,
#   2430,
#   5750,
#   4440,
#   1473,
#   1074,
#   8824,
#   7227,
#   1208,
#   1074,
#   4802,
#   8063,
#   2247,
#   1395,
#   8824,
#   8823],
#  [1224, 6139, 719, 4440, 8824, 8824, 8823],
#  [7087,
#   8824,
#   8824,
#   104,
#   859,
#   104,
#   8403,
#   7418,
#   1224,
#   2247,
#   6419,
#   1024,
#   1446,
#   1224,
#   2247,
#   8037,
#   4570,
#   5317,
#   3770,
#   932,
#   1473,
#   6419,
#   558,
#   4459,
#   8824,
#   3426,
#   1446,
#   1224,
#   2247,
#   8824,
#   4115,
#   719,
#   6419,
#   8478,
#   2478,
#   7013,
#   7995,
#   4200,
#   2862,
#   8823],
#  [5772, 6459, 8605, 0, 2434, 5971, 8823],
#  [4401, 7226, 3686, 6536, 2160, 556, 6419, 8824, 8823],
#  [2596, 4191, 104, 4829, 4969, 6419, 7781, 4115, 4447, 4115, 6241, 8823],
#  [2596, 8403, 8824, 7084, 6241, 8605, 2998, 8823],
#  [4440, 2247, 6241, 8824, 7302, 8823],
#  [3770, 8824, 8824, 8824, 6040, 8823],
#  [1933,
#   1446,
#   5728,
#   4877,
#   2043,
#   1569,
#   1161,
#   4500,
#   2862,
#   7084,
#   2596,
#   4877,
#   2783,
#   2247,
#   3770,
#   8543,
#   8823],
#  [2596, 8021, 4500, 2862, 7084, 6465, 8823],
#  [1224, 883, 5750, 1224, 8824, 6269, 3500, 8823],
#  [6915,
#   652,
#   1224,
#   2247,
#   6419,
#   1343,
#   104,
#   1000,
#   1224,
#   2954,
#   6419,
#   4382,
#   8824,
#   6269,
#   6281,
#   1224,
#   3686,
#   8232,
#   2862,
#   2826,
#   8824,
#   8823],
#  [5456, 6139, 5628, 8824, 4104, 5317, 6269, 8824, 8824, 8823],
#  [104,
#   7787,
#   7163,
#   7882,
#   1224,
#   2247,
#   7801,
#   1224,
#   35,
#   3664,
#   2529,
#   3381,
#   6269,
#   3770,
#   8247,
#   1785,
#   4877,
#   1224,
#   8403,
#   3759,
#   2446,
#   8824,
#   8823],
#  [5797,
#   3664,
#   3025,
#   6459,
#   2596,
#   1731,
#   8193,
#   719,
#   8232,
#   6419,
#   3738,
#   7718,
#   6057,
#   8823],
#  [7428, 2043, 5299, 7418, 2043, 4829, 4500, 2862, 7084, 2596, 8823],
#  [4440, 2247, 2783, 104, 3686, 2784, 8823],
#  [104, 3328, 2596, 5460, 8410, 6884, 8823],
#  [5052,
#   104,
#   719,
#   5759,
#   719,
#   6419,
#   8024,
#   524,
#   99,
#   104,
#   4969,
#   4115,
#   5458,
#   5163,
#   8823],
#  [5750,
#   8193,
#   6961,
#   6419,
#   8203,
#   6005,
#   99,
#   2596,
#   5628,
#   3770,
#   8288,
#   1731,
#   1224,
#   2247,
#   8824,
#   3770,
#   4227,
#   2596,
#   6671,
#   5317,
#   6419,
#   4403,
#   2826,
#   1204,
#   8193,
#   5628,
#   6465,
#   3062,
#   1224,
#   2247,
#   4009,
#   3770,
#   4411,
#   1473,
#   8297,
#   1224,
#   2247,
#   6944,
#   6708,
#   2160,
#   3770,
#   3738,
#   2596,
#   719,
#   245,
#   4115,
#   8824,
#   5869,
#   8823],
#  [5317,
#   4440,
#   5178,
#   8193,
#   4566,
#   26,
#   4115,
#   2120,
#   3852,
#   6419,
#   8824,
#   6190,
#   2862,
#   8823],
#  [4566, 8824, 4969, 3022, 8823],
#  [6671,
#   2596,
#   652,
#   1224,
#   4566,
#   8763,
#   6730,
#   7084,
#   3835,
#   1224,
#   2247,
#   3770,
#   6929,
#   6442,
#   7702,
#   8823],
#  [1989, 6419, 5516, 8168, 2709, 8823],
#  [6241, 4137, 2663, 8823],
#  [7955, 6859, 8824, 8823],
#  [6946, 104, 1759, 5772, 8823],
#  [1989, 6241, 4137, 4497, 8823],
#  [8427,
#   104,
#   719,
#   3686,
#   2536,
#   657,
#   5519,
#   3770,
#   6766,
#   1837,
#   5317,
#   8605,
#   1200,
#   1473,
#   8823],
#  [3770,
#   8427,
#   2247,
#   4440,
#   2783,
#   5903,
#   2826,
#   8824,
#   3686,
#   1377,
#   2160,
#   6419,
#   6489,
#   1473,
#   4730,
#   6241,
#   1693,
#   8297,
#   2596,
#   6671,
#   2995,
#   4115,
#   6241,
#   8823],
#  [8824, 8824, 1446, 5052, 2596, 6671, 3901, 8597, 8823],
#  [6915, 104, 2331, 6837, 6057, 8823],
#  [2763, 5178, 5015, 2596, 6671, 7099, 6269, 3770, 6038, 556, 6179, 8823],
#  [4207, 8193, 4566, 1719, 8823],
#  [104,
#   719,
#   8824,
#   7732,
#   202,
#   2826,
#   6397,
#   6269,
#   8626,
#   8824,
#   8824,
#   104,
#   1731,
#   2596,
#   4566,
#   8781,
#   4138,
#   8823],
#  [4877,
#   2783,
#   7835,
#   4440,
#   4256,
#   1750,
#   104,
#   7787,
#   3591,
#   4115,
#   3759,
#   6241,
#   6334,
#   8824,
#   1473,
#   6419,
#   7476,
#   1473,
#   4104,
#   7666,
#   1113,
#   4115,
#   189,
#   7226,
#   1161,
#   1552,
#   1074,
#   7015,
#   8823],
#  [4713, 2120, 1750, 6459, 3852, 7882, 8823],
#  [1989, 2388, 3770, 6766, 1837, 8823],
#  [2043, 2247, 977, 4115, 7087, 6057, 1750, 8823],
#  [5772, 8823],
#  [6418, 4500, 4969, 6241, 8823],
#  [104,
#   1656,
#   2331,
#   6108,
#   8020,
#   104,
#   3194,
#   6057,
#   4115,
#   1480,
#   6241,
#   99,
#   2043,
#   5569,
#   3745,
#   8415,
#   4115,
#   1683,
#   3852,
#   8823],
#  [2043,
#   3686,
#   394,
#   245,
#   4115,
#   3302,
#   2388,
#   104,
#   4566,
#   4256,
#   3852,
#   6419,
#   4577,
#   8823],
#  [2043, 165, 1750, 8823],
#  [3327, 8823],
#  [2596, 4969, 3770, 6489, 8823],
#  [4207,
#   1473,
#   104,
#   4581,
#   3770,
#   4349,
#   4081,
#   2826,
#   2596,
#   8824,
#   5317,
#   7584,
#   8478,
#   8824,
#   3672,
#   5569,
#   7584,
#   6034,
#   8764,
#   4916,
#   8823],
#  [5456, 6671, 7356, 3770, 1365, 2826, 1750, 8500, 7017, 8823],
#  [6057, 6859, 5557, 8823],
#  [1693, 8823],
#  [7584, 7302, 4235, 8823],
#  [1473, 1126, 4829, 104, 6459, 4440, 8823],
#  [2783, 6459, 2596, 1731, 8823],
#  [4207, 4455, 104, 1138, 2596, 4115, 4500, 2862, 7084, 6241, 8823],
#  [5772, 8824, 104, 4566, 4969, 1550, 6269, 3852, 8823],
#  [2596, 3686, 2784, 8823],
#  [2596, 26, 973, 4115, 1338, 6419, 6489, 2862, 8823],
#  [1446,
#   2596,
#   4829,
#   4500,
#   2862,
#   7084,
#   6241,
#   1013,
#   2596,
#   6961,
#   3770,
#   1347,
#   8823],
#  [2596, 6671, 992, 6531, 1750, 4115, 1338, 2862, 6334, 6489, 8823],
#  [104,
#   1161,
#   3647,
#   6241,
#   7302,
#   5389,
#   4440,
#   3481,
#   8445,
#   6419,
#   5688,
#   1473,
#   4440,
#   2247,
#   3770,
#   2071,
#   2043,
#   1321,
#   1138,
#   6419,
#   5688,
#   8823],
#  [636, 7970, 8823],
#  [4696, 7834, 8823],
#  [1435, 1473, 2596, 719, 8232, 7584, 7882, 8823],
#  [104, 7787, 6269, 3852, 8823],
#  [7193, 3770, 940, 6087, 8605, 1450, 1321, 3920, 1095, 6419, 3647, 8823],
#  [104,
#   8232,
#   6241,
#   187,
#   163,
#   2043,
#   3686,
#   4286,
#   8824,
#   5317,
#   1535,
#   4115,
#   4478,
#   2160,
#   3770,
#   6992,
#   8823],
#  [2783, 8823],
#  [6419, 6456, 1648, 6419, 3647, 8823],
#  [5797, 3852, 8823],
#  [5797, 6241, 7302, 6418, 8823],
#  [6419, 1213, 6419, 6118, 8823],
#  [6459, 2783, 8823],
#  [4969, 6241, 4115, 1560, 5750, 6419, 7756, 8823],
#  [996, 7084, 3770, 8824, 8824, 1714, 8272, 104, 8020, 8823],
#  [6671, 2596, 4921, 8823],
#  [1258, 3686, 1276, 4147, 4115, 7198, 8823],
#  [8193, 4713, 7198, 8823],
#  [2304,
#   5299,
#   104,
#   3328,
#   104,
#   4829,
#   2349,
#   7871,
#   3309,
#   4147,
#   2596,
#   2596,
#   8020,
#   3686,
#   4115,
#   1719,
#   1013,
#   2596,
#   6671,
#   7141,
#   8823],
#  [8193, 6671, 6057, 8823],
#  [7835, 2183, 8785, 719, 6419, 3428, 8823],
#  [4877,
#   2783,
#   2596,
#   26,
#   4115,
#   6459,
#   2247,
#   8824,
#   6419,
#   2011,
#   7226,
#   4566,
#   4500,
#   2862,
#   7084,
#   6241,
#   2817,
#   5216,
#   2160,
#   556,
#   3770,
#   6955,
#   8823],
#  [7776, 4207, 8193, 6671, 8715, 8824, 8823],
#  [2596, 1473, 1317, 8823],
#  [2783, 8193, 6170, 8824, 6605, 99, 8193, 7446, 1136, 8823],
#  [5052, 1989, 5557, 556, 3770, 1672, 1249, 1550, 8823],
#  [8798, 1317, 137, 8824, 8823],
#  [4440,
#   2247,
#   6494,
#   1317,
#   3770,
#   3481,
#   7226,
#   5569,
#   5406,
#   556,
#   6419,
#   7159,
#   104,
#   1000,
#   1224,
#   5569,
#   5090,
#   4472,
#   527,
#   8823],
#  [104, 7787, 5772, 1224, 2247, 3625, 6423, 2826, 5090, 5885, 4440, 5540, 8823],
#  [1224, 6139, 5017, 4877, 8823],
#  [3532, 2261, 8823],
#  [3686, 6419, 3513, 8823],
#  [7871, 3763, 4495, 8823],
#  [1446, 1991, 3770, 753, 1224, 4829, 7418, 4365, 7431, 8823],
#  [2596,
#   8403,
#   6139,
#   4500,
#   7084,
#   1750,
#   104,
#   7787,
#   5772,
#   2965,
#   4584,
#   6334,
#   4399,
#   8823],
#  [2965, 4829, 3866, 719, 5406, 4115, 6419, 4382, 8016, 8823],
#  [2965, 5782, 5728, 4500, 4115, 5956, 8016, 8823],
#  [4440, 2247, 3866, 2536, 3501, 8823],
#  [6527, 4584, 3664, 8824, 8823],
#  [7835, 3852, 2543, 8823],
#  [1013,
#   104,
#   5569,
#   5869,
#   3852,
#   4829,
#   90,
#   1072,
#   8016,
#   2596,
#   1138,
#   2769,
#   4713,
#   5797,
#   7584,
#   8824,
#   8823],
#  [6915, 1961, 8823],
#  [7226, 1154, 8823],
#  [104, 5782, 719, 6419, 8203, 8823],
#  [2596,
#   5782,
#   719,
#   6419,
#   8203,
#   3327,
#   2247,
#   1881,
#   1473,
#   2783,
#   719,
#   2596,
#   8042,
#   7084,
#   6241,
#   8823],
#  [104, 7428, 5869, 6419, 7121, 1473, 3852, 8824, 8823],
#  [2596, 5782, 8823],
#  [104, 8232, 8415, 104, 8824, 104, 8232, 8527, 3852, 5569, 8478, 2198, 8823],
#  [2304, 104, 4401, 8193, 6671, 6057, 4995, 8193, 4713, 719, 3371, 8823],
#  [2124,
#   4115,
#   2282,
#   2596,
#   3444,
#   5750,
#   2849,
#   5557,
#   8414,
#   2388,
#   3903,
#   756,
#   2247,
#   7314,
#   7330,
#   8823],
#  [6693,
#   6693,
#   8193,
#   4566,
#   6057,
#   4500,
#   1989,
#   6057,
#   5750,
#   104,
#   719,
#   6419,
#   5181,
#   2448,
#   8823],
#  [2596,
#   2331,
#   5914,
#   7687,
#   6859,
#   2183,
#   2434,
#   3770,
#   8171,
#   5917,
#   8193,
#   6671,
#   3901,
#   6419,
#   1840,
#   8823],
#  [8784, 1249, 7701, 2446, 1473, 1172, 556, 3180, 8823],
#  [7226, 8823],
#  [2965, 1224, 2197, 1750, 4115, 2690, 6465, 4235, 8823],
#  [8784, 1860, 282, 1750, 8193, 8824, 8824, 4115, 8824, 8824, 8823],
#  [7039, 5750, 6419, 7317, 5299, 1473, 2813, 8823],
#  [2240, 6419, 8006, 4115, 4969, 6419, 4412, 8324, 8823],
#  [8605, 21, 5317, 6435, 8823],
#  [8784, 1550, 5060, 8823],
#  [5750,
#   3327,
#   3770,
#   8824,
#   6269,
#   8824,
#   6459,
#   2596,
#   5728,
#   8020,
#   8605,
#   7073,
#   8824,
#   8823],
#  [104, 8020, 6419, 1536, 7389, 3214, 4440, 8823],
#  [104, 4713, 1509, 1731, 2596, 7637, 4440, 5214, 7871, 8325, 8823],
#  [6418, 7418, 2596, 4566, 420, 8628, 5529, 6859, 3770, 185, 7084, 1750, 8823],
#  [1473, 1126, 4829, 104, 6459, 4440, 8823],
#  [3718,
#   6269,
#   3770,
#   8824,
#   3770,
#   5609,
#   7965,
#   2596,
#   7084,
#   973,
#   5317,
#   7584,
#   4986,
#   1750,
#   7084,
#   8605,
#   5490,
#   6269,
#   7584,
#   7702,
#   8823],
#  [2596, 8537, 5317, 8605, 218, 8823],
#  [8824, 8823],
#  [104,
#   5569,
#   5317,
#   3770,
#   8824,
#   104,
#   5425,
#   7584,
#   1450,
#   3328,
#   104,
#   4829,
#   7418,
#   1008,
#   8823],
#  [1008, 8823],
#  [2067,
#   6269,
#   3770,
#   6742,
#   8605,
#   8824,
#   4713,
#   1509,
#   1950,
#   1750,
#   2036,
#   6419,
#   2748,
#   8824,
#   8823],
#  [8823],
#  [4440, 2247, 2783, 2596, 1138, 7147, 3852, 8823],
#  [6459, 2596, 4992, 2596, 6671, 1600, 2826, 5351, 3852, 556, 1750, 8823],
#  [2596, 8020, 7226, 3770, 8824, 6671, 8823],
#  [1126, 4713, 2596, 8823],
#  [104,
#   7787,
#   2093,
#   8824,
#   7882,
#   7147,
#   4440,
#   2783,
#   2596,
#   6671,
#   3591,
#   4115,
#   6459,
#   6859,
#   6419,
#   1675,
#   8823],
#  [104, 7418, 6459, 2783, 2596, 8021, 6459, 8823],
#  [124, 2596, 6671, 3770, 4349, 3481, 8823],
#  [104, 7787, 4696, 104, 7787, 8823],
#  [104, 3686, 26, 4115, 3121, 8748, 556, 6179, 8823],
#  [7776, 7776, 2596, 3121, 8748, 1473, 2596, 4566, 4500, 4115, 2292, 8823],
#  [104, 8020, 3686, 5628, 1750, 2292, 8823],
#  [2783,
#   1013,
#   2596,
#   719,
#   6419,
#   8824,
#   8605,
#   3568,
#   7533,
#   4115,
#   2292,
#   7084,
#   6419,
#   8824,
#   1473,
#   15,
#   2160,
#   6419,
#   6123,
#   6057,
#   4440,
#   104,
#   8403,
#   282,
#   3770,
#   3608,
#   8823],
#  [8340, 3852, 4115, 2596, 4115, 1202, 8478, 2890, 99, 2596, 6671, 8824, 8823],
#  [1126, 6671, 2596, 5090, 2183, 8823],
#  [104, 6252, 2596, 8823],
#  [2596, 4713, 477, 1013, 104, 907, 8823],
#  [5772, 104, 6459, 8823],
#  [1126, 8823],
#  [3903,
#   6418,
#   104,
#   4829,
#   719,
#   4115,
#   5464,
#   7314,
#   2862,
#   3516,
#   7226,
#   5750,
#   1750,
#   8823],
#  [5750, 2596, 8403, 8781, 3481, 8823],
#  [1719, 4440, 7226, 394, 5174, 99, 104, 719, 8232, 5571, 4330, 8823],
#  [3686, 5628, 1750, 4104, 8748, 8823],
#  [7226, 8823],
#  [8824, 8823],
#  [104, 7529, 6465, 8823],
#  [104,
#   8020,
#   3852,
#   4829,
#   719,
#   4115,
#   90,
#   6419,
#   1700,
#   8478,
#   6118,
#   4115,
#   4969,
#   2596,
#   4115,
#   8824,
#   1043,
#   2596,
#   4713,
#   1931,
#   5750,
#   3770,
#   8043,
#   8823],
#  [5052,
#   7882,
#   2596,
#   1656,
#   2331,
#   6108,
#   1731,
#   104,
#   5205,
#   90,
#   3302,
#   2596,
#   4713,
#   1731,
#   104,
#   5205,
#   90,
#   6173,
#   7099,
#   5750,
#   8593,
#   5524,
#   8823],
#  [104, 3328, 2596, 7446, 7828, 5557, 4440, 8823],
#  [2596, 8020, 2783, 5456, 7418, 8823],
#  [2783, 8823],
#  [1446, 1989, 8824, 104, 8020, 2596, 5750, 1208, 104, 5425, 2596, 3838, 8823],
#  [6944, 8823],
#  [7446, 2596, 5317, 5098, 8823],
#  [1634, 8823],
#  [6915, 2596, 3707, 8823],
#  [6418, 1126, 4829, 2596, 5550, 8823],
#  [1126, 4829, 2596, 3121, 8823],
#  [6459, 2783, 8823],
#  [2183, 8823],
#  [8605, 8221, 4205, 2994, 2826, 4440, 4440, 8823],
#  [2596, 4713, 3029, 1750, 1095, 3770, 8043, 4440, 4829, 5550, 5950, 8823],
#  [104, 7787, 1033, 3838, 8823],
#  [1224, 3686, 375, 1750, 4115, 90, 2817, 104, 7787, 6057, 8823],
#  [7226, 8823],
#  [5869, 8823],
#  [6915,
#   3461,
#   1446,
#   2596,
#   6671,
#   7302,
#   2247,
#   3182,
#   104,
#   8020,
#   8593,
#   2688,
#   6241,
#   1473,
#   5557,
#   1446,
#   8823],
#  [2783, 6671, 2596, 5090, 4235, 8823],
#  [104, 1000, 3838, 5569, 6419, 153, 6311, 8823],
#  [2596, 6671, 4877, 8823],
#  [7278, 8823],
#  [8824, 8823],
#  [8824, 104, 4401, 2817, 1569, 4584, 6241, 5051, 5317, 6419, 7746, 8823],
#  [4713,
#   556,
#   3481,
#   5231,
#   1731,
#   4440,
#   2596,
#   6961,
#   1072,
#   5273,
#   6789,
#   6269,
#   8605,
#   5051,
#   8823],
#  [4877, 2783, 7428, 104, 719, 7871, 5273, 6269, 8823],
#  [4953, 3214, 8605, 8824, 8824, 469, 8823],
#  [5017, 2160, 8384, 8823],
#  [4450, 1989, 6057, 4440, 2105, 8823],
#  [6516, 2819, 6859, 3852, 2434, 2183, 4433, 8823],
#  [5797, 3852, 104, 7787, 5012, 8823],
#  [2596,
#   1138,
#   1750,
#   4115,
#   3373,
#   2160,
#   1473,
#   8698,
#   2596,
#   636,
#   4115,
#   4969,
#   8748,
#   8823],
#  [1634, 8823],
#  [104,
#   5040,
#   3852,
#   6961,
#   4115,
#   90,
#   7701,
#   1085,
#   4115,
#   2716,
#   7584,
#   7899,
#   1473,
#   8763,
#   2596,
#   2388,
#   8823],
#  [1249, 3784, 8823],
#  [4877, 636, 4829, 2596, 4969, 8824, 4115, 5017, 3770, 4953, 8006, 8823],
#  [104, 8824, 6465, 7084, 8605, 2163, 8823],
#  [4207, 2304, 4713, 5628, 3852, 4969, 2862, 8823],
#  [4877, 2783, 2247, 7584, 2886, 8823],
#  [5638, 3770, 8006, 8193, 6459, 8823],
#  [335, 8823],
#  [104,
#   4713,
#   5750,
#   4115,
#   6459,
#   2783,
#   6884,
#   4461,
#   6418,
#   5456,
#   4461,
#   3852,
#   5557,
#   3770,
#   245,
#   1473,
#   5456,
#   4969,
#   6044,
#   99,
#   2596,
#   6714,
#   8823],
#  [4877, 1013, 2596, 328, 1208, 2434, 3770, 5464, 2596, 6671, 8537, 8823],
#  [7701, 5750, 4440, 8823],
#  [6418, 2596, 4486, 2160, 8823],
#  [636, 8823],
#  [2596, 3866, 6044, 1750, 8823],
#  [556, 8823],
#  [8824, 8823],
#  [3770, 52, 8823],
#  [8824, 8823],
#  [104, 8020, 3770, 4472, 8824, 6419, 3121, 8823],
#  [104, 7529, 8824, 8823],
#  [6915, 7701, 4978, 7701, 6915, 3481, 5524, 1729, 8823],
#  [2596, 6671, 226, 1473, 103, 1473, 3625, 5922, 556, 1750, 8823],
#  [2783, 8823],
#  [6915, 3481, 5524, 1729, 8823],
#  [2596, 6671, 8824, 8824, 4584, 5016, 403, 6252, 2596, 4440, 8823],
#  [4500, 4115, 3770, 7327, 7084, 1750, 8823],
#  [2596, 8020, 2783, 104, 4191, 8823],
#  [6915, 8823],
#  [6915, 2783, 8823],
#  [6915, 104, 4566, 6057, 4500, 7084, 2596, 8823],
#  [1126, 6057, 8823],
#  [3903, 104, 4713, 1138, 4115, 1989, 6419, 3824, 7353, 8823],
#  [4877, 104, 719, 4115, 719, 6419, 1813, 4115, 90, 7084, 2596, 8823],
#  [2596, 282, 1750, 8823],
#  [2596, 26, 6426, 4584, 5016, 403, 6252, 2596, 4440, 8823],
#  [1559, 3770, 1434, 8798, 8823],
#  [7455,
#   2240,
#   469,
#   5317,
#   3852,
#   556,
#   1750,
#   3686,
#   3770,
#   2934,
#   2826,
#   7584,
#   749,
#   8823],
#  [1989,
#   8824,
#   3664,
#   3647,
#   8232,
#   4929,
#   3327,
#   4829,
#   2596,
#   4969,
#   3770,
#   5181,
#   8823],
#  [1989, 3686, 7701, 104, 6961, 2596, 8020, 8823],
#  [8784, 3125, 8823],
#  [5017, 104, 7787, 6948, 4440, 104, 2863, 7584, 2583, 104, 5569, 8171, 8823],
#  [2783, 8823],
#  [4440,
#   2247,
#   3327,
#   104,
#   5569,
#   6411,
#   7159,
#   2043,
#   4829,
#   3866,
#   8711,
#   4838,
#   8605,
#   142,
#   8141,
#   104,
#   2269,
#   7084,
#   6241,
#   104,
#   1759,
#   5317,
#   5098,
#   104,
#   4713,
#   8020,
#   8824,
#   8824,
#   1473,
#   104,
#   719,
#   3866,
#   5348,
#   7084,
#   6419,
#   1532,
#   6489,
#   104,
#   6835,
#   6419,
#   7159,
#   5623,
#   8500,
#   4115,
#   8605,
#   5095,
#   6269,
#   3770,
#   6176,
#   7193,
#   8110,
#   2826,
#   3564,
#   4397,
#   2826,
#   1941,
#   8823],
#  [3852, 8445, 181, 2596, 1569, 719, 7584, 7721, 8824, 8823],
#  [2596,
#   7446,
#   1721,
#   4115,
#   1338,
#   1750,
#   3623,
#   4147,
#   3770,
#   3481,
#   6018,
#   104,
#   6856,
#   7529,
#   104,
#   1879,
#   3852,
#   5569,
#   6419,
#   8824,
#   8823],
#  [3852, 1759, 5750, 4440, 8823],
#  [1509,
#   2783,
#   5569,
#   3852,
#   5750,
#   6419,
#   8748,
#   2340,
#   4769,
#   6418,
#   6419,
#   2712,
#   556,
#   303,
#   7084,
#   1750,
#   8823],
#  [104, 5782, 477, 4196, 3770, 973, 8823],
#  [104, 3328, 2596, 8403, 1202, 3852, 99, 2596, 5464, 7584, 4497, 8823],
#  [2247, 4440, 1550, 8823],
#  [4207, 1446, 6418, 104, 1777, 2160, 104, 6925, 556, 6241, 8823],
#  [3903, 104, 5750, 4115, 7484, 2596, 8823],
#  [8784, 5869, 5205, 2596, 4969, 1750, 8605, 7721, 8824, 8823],
#  [1656, 2331, 6108, 2596, 5728, 3522, 8823],
#  [104,
#   3328,
#   8193,
#   3194,
#   2596,
#   7446,
#   657,
#   4115,
#   8016,
#   4235,
#   6859,
#   313,
#   2826,
#   8824,
#   8823],
#  [2596, 3194, 8823],
#  [6795, 8823],
#  [6418, 282, 1208, 104, 6961, 6419, 8824, 8823],
#  [2247, 2183, 4196, 1792, 6709, 2596, 8824, 1750, 8823],
#  [104, 3328, 2596, 7446, 8824, 1750, 8823],
#  [1126, 1161, 8193, 3821, 6269, 2183, 8823],
#  [3903, 2596, 6671, 3901, 152, 556, 1750, 8823],
#  [1095, 6419, 1502, 4440, 2247, 8605, 1550, 8823],
#  [4877, 2783, 104, 1138, 1321, 2543, 8823],
#  [2596,
#   6671,
#   356,
#   2596,
#   4713,
#   8020,
#   2783,
#   2596,
#   1138,
#   2596,
#   4566,
#   6057,
#   8020,
#   5389,
#   2596,
#   6671,
#   4596,
#   1473,
#   2596,
#   4713,
#   719,
#   3852,
#   8823],
#  [104,
#   1138,
#   4115,
#   4500,
#   4115,
#   7871,
#   6820,
#   5592,
#   8824,
#   104,
#   1138,
#   2596,
#   4115,
#   6224,
#   1750,
#   4115,
#   2120,
#   8605,
#   2529,
#   7168,
#   104,
#   1138,
#   8823],
#  [4207, 2043, 5780, 7084, 6334, 8824, 8478, 7416, 6283, 2826, 4973, 8823],
#  [124, 8823],
#  [6915, 6149, 8823],
#  [4877, 282, 1750, 4196, 2183, 5419, 5569, 3852, 2198, 8823],
#  [2645, 2826, 3852, 8823],
#  [768, 2645, 8823],
#  [3770, 4081, 3327, 5869, 5788, 3770, 8427, 2862, 2826, 6334, 2011, 8823],
#  [5869, 7428, 2783, 8823],
#  [2783, 2247, 3770, 2543, 6502, 4440, 104, 8824, 2388, 6269, 6241, 8823],
#  [6915, 6757, 8823],
#  [99, 104, 4500, 8823],
#  [8784,
#   7844,
#   4713,
#   282,
#   1750,
#   2596,
#   719,
#   7341,
#   7584,
#   4992,
#   104,
#   7116,
#   6801,
#   3403,
#   6419,
#   670,
#   8823],
#  [8824, 8605, 5417, 2247, 6057, 6419, 6284, 7885, 8823],
#  [2304,
#   335,
#   4337,
#   4115,
#   7584,
#   4953,
#   7168,
#   2826,
#   3310,
#   2183,
#   7159,
#   7939,
#   1899,
#   6671,
#   3577,
#   8824,
#   4147,
#   3770,
#   8006,
#   188,
#   8824,
#   8824,
#   7592,
#   6238,
#   7533,
#   3577,
#   2304,
#   5317,
#   5178,
#   2596,
#   6671,
#   7141,
#   8823],
#  [104,
#   1569,
#   6798,
#   4440,
#   1224,
#   1141,
#   6730,
#   5317,
#   3770,
#   6077,
#   104,
#   5569,
#   1304,
#   6419,
#   8824,
#   8823],
#  [3770, 8543, 2247, 1881, 6884, 8824, 2596, 1095, 8656, 8823],
#  [6915, 104, 480, 8824, 940, 2247, 3770, 4341, 876, 8131, 1086, 8823],
#  [3686, 4852, 6241, 4769, 8823],
#  [1008, 8823],
#  [3302, 7320, 2596, 6419, 5946, 8823],
#  [4207, 104, 4401, 8823],
#  [8784, 4207, 8823],
#  [1550, 8823],
#  [1881, 6419, 5946, 3745, 8823],
#  [4207, 8823],
#  [2783, 8823],
#  [4455,
#   3770,
#   8427,
#   3852,
#   2247,
#   2596,
#   6671,
#   5336,
#   3838,
#   5574,
#   4115,
#   7418,
#   8823],
#  [3770,
#   5560,
#   2247,
#   8605,
#   7882,
#   4522,
#   4235,
#   4584,
#   6419,
#   6413,
#   7366,
#   556,
#   5869,
#   8824,
#   8823],
#  [2783, 2247, 3852, 7084, 2183, 2084, 2043, 719, 6476, 5422, 8823],
#  [8824,
#   5205,
#   8824,
#   4409,
#   1224,
#   375,
#   104,
#   7787,
#   3686,
#   5317,
#   2183,
#   556,
#   3770,
#   510,
#   8823],
#  [4877, 8824, 5205, 4969, 3770, 6489, 8823],
#  [8798,
#   6494,
#   2596,
#   6671,
#   6057,
#   7687,
#   6859,
#   3770,
#   8478,
#   666,
#   8824,
#   3686,
#   6419,
#   6060,
#   8193,
#   2407,
#   2183,
#   6766,
#   1837,
#   2160,
#   4877,
#   4522,
#   5205,
#   4969,
#   3770,
#   6489,
#   8823],
#  [8193, 6671, 7584, 2430, 8823],
#  [1249, 996, 8823],
#  [3686, 556, 4769, 8823],
#  [4207, 8823],
#  [104, 7787, 8824, 2596, 2430, 1968, 8823],
#  [6915,
#   104,
#   719,
#   8232,
#   6419,
#   8824,
#   6955,
#   4440,
#   104,
#   7787,
#   4196,
#   4115,
#   4246,
#   8823],
#  [226, 205, 8824, 7904, 8824, 8823],
#  [7882,
#   4713,
#   7418,
#   8272,
#   5750,
#   4440,
#   4115,
#   1750,
#   6884,
#   5205,
#   4701,
#   2596,
#   8823],
#  [3852, 6862, 4235, 2596, 2927, 2813, 4115, 6419, 322, 2826, 8824, 3516, 8823],
#  [3852, 5569, 6419, 8824, 104, 5569, 5961, 6548, 8823],
#  [7084, 3770, 5512, 2826, 7584, 8824, 8823],
#  [8771, 2826, 3770, 1945, 8823],
#  [104,
#   7787,
#   6859,
#   6419,
#   5436,
#   6418,
#   2783,
#   2960,
#   8193,
#   4447,
#   4196,
#   7584,
#   7159,
#   2826,
#   3169,
#   8823],
#  [2783, 2247, 4115, 2442, 8823],
#  [2596,
#   3707,
#   8824,
#   2596,
#   5600,
#   3824,
#   1473,
#   1095,
#   8514,
#   1095,
#   104,
#   5205,
#   282,
#   2596,
#   6671,
#   4349,
#   775,
#   7025,
#   4877,
#   1126,
#   2247,
#   3852,
#   4440,
#   2596,
#   6671,
#   2556,
#   6419,
#   8824,
#   8823],
#  [2304,
#   2596,
#   8020,
#   2240,
#   3770,
#   8824,
#   2826,
#   3770,
#   6955,
#   2587,
#   1473,
#   3770,
#   5884,
#   6888,
#   2247,
#   1700,
#   1249,
#   8823],
#  [1719, 2596, 8500, 1674, 8823],
#  [2120, 5016, 6436, 7873, 8823],
#  [1792, 6709, 2247, 6269, 3770, 4953, 1035, 2826, 3770, 2983, 8823],
#  [8824, 8823],
#  [2596, 6671, 6057, 4678, 8823],
#  [6110, 6915, 1434, 8823],
#  [5798,
#   2247,
#   4440,
#   2783,
#   2596,
#   1731,
#   8624,
#   5798,
#   7147,
#   2783,
#   4306,
#   1750,
#   2160,
#   4115,
#   8605,
#   8742,
#   5317,
#   8824,
#   5557,
#   4577,
#   8823],
#  [2212, 7982, 8823],
#  [1446, 7226, 2783, 8823],
#  [7584, 344, 7533, 4115, 3770, 7327, 8823],
#  [7428, 104, 719, 5885, 4115, 7418, 4196, 3852, 8823],
#  [5618, 6057, 8823],
#  [4440, 2331, 5073, 2783, 104, 3328, 8823],
#  [3770, 8172, 657, 8824, 5317, 3770, 8824, 8823],
#  [2596,
#   4566,
#   90,
#   8035,
#   7584,
#   2529,
#   8763,
#   556,
#   3770,
#   1826,
#   2826,
#   2287,
#   1473,
#   1117,
#   8824,
#   8429,
#   8823],
#  [8365, 8340, 6465, 4838, 1224, 2247, 5090, 6915, 6067, 8823],
#  [7084,
#   6419,
#   567,
#   5750,
#   4440,
#   104,
#   4713,
#   1138,
#   2596,
#   7687,
#   6859,
#   1750,
#   2596,
#   4701,
#   8823],
#  [8193, 4566, 5557, 4500, 7925, 8823],
#  [8193, 5780, 6476, 6543, 1698, 8824, 1161, 90, 4440, 8352, 8823],
#  [1161,
#   90,
#   4440,
#   8514,
#   104,
#   7418,
#   4847,
#   104,
#   4713,
#   5750,
#   3770,
#   3800,
#   2826,
#   3770,
#   8144,
#   7666,
#   4235,
#   6836,
#   5750,
#   6419,
#   4668,
#   2105,
#   7088,
#   8823],
#  [335,
#   7584,
#   8824,
#   3770,
#   1651,
#   2960,
#   6057,
#   1338,
#   7389,
#   3214,
#   5229,
#   7718,
#   3818,
#   6543,
#   8823],
#  [172,
#   1656,
#   8824,
#   4440,
#   2247,
#   1985,
#   3327,
#   7902,
#   3619,
#   8824,
#   6671,
#   2596,
#   4869,
#   7084,
#   3770,
#   8437,
#   2826,
#   8824,
#   8824,
#   8824,
#   8823],
#  [104, 7787, 7584, 8824, 8823],
#  [6418,
#   2596,
#   1161,
#   6732,
#   4440,
#   5223,
#   4115,
#   1074,
#   8824,
#   3770,
#   8824,
#   2826,
#   3770,
#   276,
#   2247,
#   5388,
#   8824,
#   3990,
#   7718,
#   7389,
#   768,
#   3384,
#   3770,
#   2539,
#   8824,
#   8823],
#  [3343, 2596, 6671, 1550, 8823],
#  [7584, 6435, 1473, 4440, 2826, 8824, 8823],
#  [1013, 5456, 3821, 4115, 5543, 1750, 335, 8823],
#  [2247, 4440, 5557, 4440, 4534, 2596, 5119, 8823],
#  [6915,
#   3770,
#   8824,
#   719,
#   7116,
#   5071,
#   8824,
#   6884,
#   104,
#   3745,
#   4566,
#   8781,
#   4953,
#   8824,
#   1473,
#   4855,
#   1208,
#   4115,
#   3770,
#   3596,
#   2826,
#   4241,
#   8823],
#  [7428,
#   1224,
#   6057,
#   1482,
#   6419,
#   8824,
#   8592,
#   4115,
#   2980,
#   6730,
#   4115,
#   3770,
#   8369,
#   8823],
#  [5571, 464, 2247, 2783, 104, 2377, 8824, 8823],
#  [8824, 8823],
#  [3770, 5122, 2247, 8824, 8823],
#  [2591,
#   1446,
#   104,
#   4829,
#   1509,
#   8824,
#   3770,
#   5436,
#   2826,
#   2556,
#   6419,
#   997,
#   4294,
#   556,
#   2287,
#   556,
#   6419,
#   8824,
#   5519,
#   6419,
#   8543,
#   2826,
#   8824,
#   8823],
#  [4697,
#   3770,
#   8369,
#   2247,
#   6283,
#   2826,
#   8824,
#   1473,
#   8312,
#   1086,
#   2120,
#   1202,
#   2826,
#   1208,
#   99,
#   3852,
#   5884,
#   1208,
#   8605,
#   4349,
#   4525,
#   2247,
#   3770,
#   1184,
#   1473,
#   8824,
#   2826,
#   2287,
#   8823],
#  [6269,
#   3770,
#   5131,
#   7584,
#   8824,
#   3852,
#   883,
#   4115,
#   1750,
#   3770,
#   7882,
#   2247,
#   3849,
#   3664,
#   2529,
#   1892,
#   8823],
#  [2783, 6419, 6432, 2783, 6419, 1949, 2826, 6419, 6435, 8823],
#  [6419,
#   1949,
#   5628,
#   1750,
#   282,
#   2596,
#   7701,
#   8824,
#   1013,
#   7584,
#   7073,
#   7718,
#   6863,
#   2247,
#   403,
#   1244,
#   3852,
#   4566,
#   4349,
#   90,
#   3903,
#   2826,
#   3664,
#   8823],
#  [104, 8020, 8823],
#  [104, 4784, 4531, 2596, 7970, 2826, 6419, 6435, 8823],
#  [2304,
#   4440,
#   2247,
#   6725,
#   104,
#   719,
#   6419,
#   2272,
#   4147,
#   6419,
#   7882,
#   7226,
#   4566,
#   6057,
#   5542,
#   3041,
#   5216,
#   6139,
#   7731,
#   8823],
#  [6671, 8193, 657, 4115, 3179, 8823],
#  [104,
#   4829,
#   205,
#   4115,
#   3179,
#   7084,
#   2596,
#   837,
#   1446,
#   2596,
#   6671,
#   3866,
#   4955,
#   8823],
#  [104, 8781, 4440, 3694, 4115, 480, 8823],
#  [5321, 4241, 8823],
#  [104, 4713, 1138, 2596, 4115, 495, 556, 1750, 8823],
#  [4440, 2247, 7701, 2596, 1161, 2359, 8823],
#  [2596, 4713, 1960, 5550, 8823],
#  [104,
#   5205,
#   5644,
#   556,
#   3770,
#   998,
#   4115,
#   1338,
#   8824,
#   1473,
#   8739,
#   2036,
#   6241,
#   7990,
#   8823],
#  [5456, 3024, 1446, 104, 5782, 5628, 1208, 8823],
#  [6057,
#   5703,
#   6459,
#   2596,
#   1731,
#   104,
#   477,
#   104,
#   7787,
#   6419,
#   1525,
#   7882,
#   6629,
#   8824,
#   4713,
#   2120,
#   6419,
#   7882,
#   8578,
#   5456,
#   4349,
#   2120,
#   6465,
#   8824,
#   8823],
#  [104, 7787, 6944, 6634, 8823],
#  [104,
#   1161,
#   4478,
#   8605,
#   4986,
#   2388,
#   2596,
#   104,
#   4829,
#   5750,
#   4115,
#   2071,
#   2160,
#   7084,
#   5557,
#   3770,
#   2827,
#   104,
#   5782,
#   420,
#   7084,
#   2596,
#   8823],
#  [1655, 1750, 1656, 8824, 8410, 5969, 719, 7116, 2536, 7079, 8823],
#  [8444, 104, 5550, 4147, 7674, 8823],
#  [8824, 1473, 8824, 8824, 8823],
#  [335, 104, 1683, 8823],
#  [7755, 4115, 2783, 8823],
#  [8824, 2826, 3770, 8061, 8824, 8823],
#  [441, 6418, 104, 7787, 1525, 4115, 2264, 556, 3770, 3203, 8823],
#  [104,
#   7787,
#   6057,
#   6419,
#   8824,
#   1446,
#   104,
#   1000,
#   3852,
#   2247,
#   6915,
#   7389,
#   3214,
#   6419,
#   4985,
#   6859,
#   8144,
#   104,
#   6817,
#   2596,
#   6671,
#   6057,
#   3745,
#   6044,
#   8823],
#  [636,
#   8403,
#   104,
#   90,
#   3770,
#   3203,
#   4584,
#   2536,
#   3528,
#   2630,
#   1095,
#   104,
#   2784,
#   3852,
#   4829,
#   8823],
#  [104, 7787, 798, 2183, 2247, 6057, 3770, 5996, 3002, 8823],
#  [3838, 4566, 90, 6419, 245, 8823],
#  [2596, 8744, 6459, 2596, 2060, 6269, 2537, 8824, 8823],
#  [335, 335, 104, 6459, 6269, 5557, 2826, 7043, 8823],
#  [2183, 245, 7084, 3041, 8823],
#  [6057, 2105, 8823],
#  [3838, 3370, 90, 6419, 1663, 4115, 4440, 4953, 2539, 8823],
#  [104, 7787, 6057, 1113, 8221, 1446, 104, 1161, 3976, 8604, 8823],
#  [1224,
#   844,
#   99,
#   1224,
#   5205,
#   3718,
#   4115,
#   2673,
#   2596,
#   1224,
#   5780,
#   3664,
#   4988,
#   8823],
#  [1224, 3866, 6961, 3481, 7006, 6760, 8605, 8824, 8823],
#  [1509, 4241, 104, 4205, 8020, 3327, 4115, 5464, 1473, 732, 8823],
#  [282, 1750, 3770, 4389, 1837, 4440, 467, 4115, 7584, 4992, 8823],
#  [6915, 8823],
#  [6347,
#   104,
#   719,
#   6073,
#   3745,
#   3402,
#   4899,
#   3745,
#   3694,
#   4769,
#   2596,
#   4461,
#   1750,
#   4115,
#   1338,
#   5557,
#   3770,
#   6950,
#   8297,
#   2596,
#   1338,
#   3770,
#   8824,
#   6915,
#   104,
#   4566,
#   6057,
#   90,
#   7584,
#   8824,
#   8823],
#  [104, 7787, 6057, 8824, 8823],
#  [6418, 2596, 6671, 3745, 4494, 8823],
#  [1013,
#   2596,
#   4566,
#   6057,
#   4153,
#   7902,
#   7600,
#   8193,
#   4566,
#   6201,
#   8781,
#   2817,
#   7226,
#   4566,
#   8823],
#  [1655, 1750, 1656, 8824, 1446, 2783, 4196, 5119, 8823],
#  [556, 6419, 8824, 8823],
#  [1656, 8824, 2247, 7116, 6419, 1876, 8605, 5985, 1656, 8824, 8823],
#  [5811,
#   8193,
#   6671,
#   4847,
#   5317,
#   26,
#   2826,
#   8824,
#   7006,
#   3838,
#   6671,
#   6915,
#   8824,
#   8823],
#  [2783, 6459, 104, 719, 4877, 8645, 7116, 8823],
#  [4115,
#   2535,
#   4877,
#   5956,
#   5317,
#   4877,
#   4230,
#   6419,
#   245,
#   2247,
#   6419,
#   1059,
#   8824,
#   6419,
#   3513,
#   8824,
#   478,
#   6419,
#   3402,
#   8006,
#   8823],
#  [3784, 1208, 8823],
#  [5017, 2862, 2826, 4440, 602, 8823],
#  [8824, 6000, 8824, 8824, 8823],
#  [5557, 2826, 1208, 1705, 4147, 6884, 5750, 1750, 8823],
#  [2783, 2247, 3852, 6419, 3719, 7871, 6613, 8823],
#  [6613, 8514, 8823],
#  [282, 3770, 1021, 8193, 5321, 6465, 8823],
#  [1021, 1729, 8823],
#  [282,
#   6465,
#   3664,
#   2983,
#   2247,
#   8806,
#   4846,
#   282,
#   6465,
#   8193,
#   6671,
#   7731,
#   8494,
#   4235,
#   4115,
#   4661,
#   6419,
#   4231,
#   8823],
#  [663, 8823],
#  [1126, 8823],
#  [1021, 6862, 1224, 4584, 6419, 4241, 8823],
#  [1473, 4847, 4115, 4855, 5354, 8823],
#  [1021, 6862, 8823],
#  [1224, 4584, 5354, 282, 6465, 8193, 7375, 3664, 6884, 8823],
#  [1224, 5349, 8823],
#  [5550, 6465, 1013, 1224, 4566, 3976, 8823],
#  [2596, 7428, 3770, 206, 4115, 7584, 8207, 8823],
#  [2596, 3866, 2971, 636, 4115, 6438, 8605, 4072, 8823],
#  [8221,
#   104,
#   7787,
#   5090,
#   2783,
#   104,
#   1731,
#   2247,
#   3770,
#   2763,
#   556,
#   6465,
#   1473,
#   1224,
#   4584,
#   3770,
#   8230,
#   104,
#   4829,
#   719,
#   6928,
#   556,
#   2418,
#   8823],
#  [4440, 2247, 2783, 3852, 6862, 8823],
#  [636, 7428, 2596, 7438, 3852, 8823],
#  [7084,
#   6334,
#   1507,
#   104,
#   6961,
#   4115,
#   8744,
#   1208,
#   2596,
#   7446,
#   6057,
#   6419,
#   1210,
#   7164,
#   8823],
#  [4115,
#   7580,
#   6419,
#   2446,
#   2069,
#   4115,
#   6175,
#   6859,
#   3770,
#   1019,
#   3838,
#   6671,
#   4349,
#   522,
#   6564,
#   2826,
#   5377,
#   3852,
#   8823],
#  [8824,
#   104,
#   480,
#   3770,
#   8824,
#   6671,
#   6915,
#   7389,
#   3214,
#   8824,
#   3990,
#   8061,
#   2826,
#   3770,
#   5282,
#   4765,
#   8823],
#  [636, 5205, 2596, 90, 4877, 7732, 8823],
#  [3770, 8824, 2826, 8824, 8824, 8814, 8824, 8824, 8823],
#  [8824, 2247, 6419, 5183, 8823],
#  [4877, 5569, 979, 8823],
#  [104, 4566, 6516, 4115, 1683, 4440, 8824, 8823],
#  [8221, 8824, 8823],
#  [8754, 2247, 7701, 3481, 1161, 8824, 8823],
#  [2596, 4969, 4877, 5765, 1693, 99, 2596, 6671, 3190, 8824, 8823],
#  [104, 719, 2536, 8824, 5557, 8605, 6435, 8824, 8823],
#  [4349, 4241, 1729, 3770, 4400, 2826, 2556, 2890, 8605, 8592, 8823],
#  [7282,
#   104,
#   719,
#   6073,
#   3818,
#   4587,
#   3368,
#   636,
#   7970,
#   4715,
#   6459,
#   2596,
#   1138,
#   1750,
#   4115,
#   495,
#   8823],
#  [1013, 4241, 8824, 2596, 4115, 4500, 6418, 2596, 4566, 4500, 8823],
#  [3074, 8207, 8823],
#  [3074,
#   5557,
#   2826,
#   2282,
#   2596,
#   5557,
#   2407,
#   2160,
#   3915,
#   7910,
#   6269,
#   2783,
#   2596,
#   3866,
#   8340,
#   3770,
#   8767,
#   2826,
#   7584,
#   8824,
#   4500,
#   3623,
#   8781,
#   2862,
#   2783,
#   3770,
#   8369,
#   2247,
#   4196,
#   1473,
#   6418,
#   282,
#   1750,
#   7701,
#   104,
#   5205,
#   2124,
#   6774,
#   8823],
#  [8824, 8344, 8823],
#  [1655, 1750, 8221, 556, 104, 719, 8824, 8823],
#  [8221,
#   104,
#   719,
#   5844,
#   8605,
#   7176,
#   104,
#   5844,
#   8605,
#   8494,
#   1473,
#   104,
#   5844,
#   2596,
#   8823],
#  [2783, 6671, 2596, 2421, 8823],
#  [104, 4644, 3770, 1504, 4566, 90, 4715, 3214, 104, 2784, 8823],
#  [636, 3402, 8823],
#  [104, 7787, 6057, 5772, 3852, 8403, 90, 4894, 3770, 801, 8823],
#  [1013,
#   104,
#   282,
#   1208,
#   5456,
#   4566,
#   6057,
#   5543,
#   1750,
#   2596,
#   8020,
#   4440,
#   104,
#   7787,
#   1550,
#   8221,
#   2596,
#   6224,
#   1750,
#   8823],
#  [8605,
#   8592,
#   8605,
#   8592,
#   7584,
#   8824,
#   6671,
#   837,
#   5559,
#   8824,
#   2596,
#   3370,
#   6438,
#   4115,
#   1208,
#   1473,
#   1013,
#   2596,
#   4713,
#   104,
#   4566,
#   8823],
#  [2596, 6671, 2487, 4147, 7871, 1520, 8221, 8823],
#  [4256, 1750, 8824, 8823],
#  [2596, 4566, 6139, 90, 7255, 3214, 1750, 8221, 8823],
#  [104, 1879, 2596, 4829, 8823],
#  [2446, 885, 5578, 2446, 6884, 8823],
#  [8784, 4877, 2596, 6671, 6419, 2446, 7882, 8823],
#  [104,
#   4713,
#   8020,
#   104,
#   719,
#   3770,
#   1333,
#   4440,
#   104,
#   5782,
#   6714,
#   4440,
#   7970,
#   104,
#   1569,
#   1161,
#   4153,
#   3770,
#   8369,
#   1095,
#   3852,
#   7177,
#   8823],
#  [6915,
#   7389,
#   3214,
#   3770,
#   7953,
#   7226,
#   2784,
#   2043,
#   4829,
#   1338,
#   8824,
#   2434,
#   3770,
#   8824,
#   8823],
#  [2783, 7428, 5456, 7418, 4196, 8824, 7227, 7873, 8823],
#  [4440, 2043, 5569, 8824, 8823],
#  [7010, 2596, 5205, 6459, 5885, 2596, 1138, 8823],
#  [2596, 8698, 6915, 8824, 4115, 6438, 8824, 8823],
#  [104,
#   8020,
#   2783,
#   104,
#   1719,
#   104,
#   1719,
#   2817,
#   7226,
#   1321,
#   4153,
#   3770,
#   8369,
#   1095,
#   3852,
#   2247,
#   5216,
#   6057,
#   798,
#   104,
#   1719,
#   6419,
#   7206,
#   7226,
#   8590,
#   2783,
#   1013,
#   8823],
#  [6419, 7953, 8823],
#  [7834, 3818, 7584, 6285, 1473, 2596, 8823],
#  [5456,
#   3718,
#   1473,
#   4500,
#   1095,
#   7891,
#   1095,
#   3770,
#   4577,
#   4241,
#   1705,
#   1208,
#   8823],
#  [5321, 2596, 8823],
#  [3838,
#   2247,
#   3481,
#   1837,
#   104,
#   4829,
#   5750,
#   4115,
#   8432,
#   1126,
#   6459,
#   2596,
#   1138,
#   4115,
#   4500,
#   7099,
#   3629,
#   5557,
#   2183,
#   8823],
#  [7584,
#   6285,
#   6334,
#   8494,
#   6671,
#   1027,
#   4115,
#   7267,
#   4196,
#   753,
#   104,
#   3370,
#   1719,
#   1208,
#   7084,
#   8605,
#   2529,
#   4986,
#   104,
#   1161,
#   90,
#   4953,
#   3214,
#   104,
#   7787,
#   8823],
#  [3770, 7730, 719, 6915, 2556, 3596, 1656, 8824, 8823],
#  [1013,
#   2596,
#   1138,
#   4115,
#   4478,
#   7584,
#   1200,
#   6269,
#   7584,
#   2546,
#   2596,
#   4566,
#   6459,
#   1095,
#   104,
#   7418,
#   8823],
#  [8193, 4713, 26, 4115, 8020, 8823],
#  [8193,
#   1276,
#   4235,
#   4115,
#   8824,
#   4115,
#   8824,
#   6057,
#   4115,
#   5464,
#   6419,
#   8824,
#   5317,
#   2183,
#   8375,
#   3838,
#   2247,
#   996,
#   3500,
#   4115,
#   7313,
#   3180,
#   1693,
#   5317,
#   2335,
#   4877,
#   8193,
#   4566,
#   90,
#   7268,
#   1473,
#   807,
#   7902,
#   8449,
#   1473,
#   5317,
#   3770,
#   7073,
#   2826,
#   8410,
#   7226,
#   8141,
#   8193,
#   4566,
#   2717,
#   2783,
#   8193,
#   1276,
#   556,
#   8823],
#  [8605, 2350, 1321, 8437, 8823],
#  [2596, 7428, 6057, 4701, 1750, 1656, 8824, 6057, 8605, 2350, 8823],
#  [8824, 2247, 2783, 8610, 8432, 8823],
#  [2596,
#   4566,
#   90,
#   1641,
#   5317,
#   8824,
#   8811,
#   2826,
#   7584,
#   8824,
#   1473,
#   8824,
#   5389,
#   2596,
#   6671,
#   8136,
#   4115,
#   2287,
#   3327,
#   2596,
#   4566,
#   90,
#   8824,
#   719,
#   2596,
#   5885,
#   4115,
#   7418,
#   8823],
#  [2596, 4566, 1886, 2183, 8823],
#  [4241, 90, 7084, 3180, 1117, 8823],
#  [1473, 2783, 6459, 2596, 1731, 8824, 8823],
#  [2304,
#   104,
#   7010,
#   8020,
#   2783,
#   6419,
#   893,
#   7177,
#   1446,
#   104,
#   719,
#   3866,
#   7790,
#   3852,
#   876,
#   6859,
#   5529,
#   7227,
#   8823],
#  [3718, 5519, 4235, 8823],
#  [6033, 1835, 8823],
#  [1224,
#   2247,
#   6623,
#   7871,
#   8824,
#   1224,
#   2247,
#   2421,
#   8193,
#   6671,
#   6269,
#   7871,
#   8824,
#   8823],
#  [8193, 1161, 90, 8823],
#  [5243, 8823],
#  [5229, 2962, 1698, 335, 8823],
#  [2596, 3370, 90, 2397, 8823],
#  [8193, 719, 4115, 4478, 3770, 3547, 2826, 4610, 8494, 7662, 8823],
#  [8193, 6671, 6269, 3770, 8777, 2826, 6419, 8824, 8824, 8823],
#  [2596, 1731, 104, 4713, 8020, 4440, 8823],
#  [8193, 6671, 8824, 8823],
#  [3770, 6642, 2247, 3838, 104, 8020, 3336, 8823],
#  [2596,
#   4713,
#   8020,
#   5682,
#   2124,
#   8824,
#   4610,
#   6671,
#   8605,
#   89,
#   1550,
#   4877,
#   104,
#   7787,
#   6287,
#   2596,
#   8193,
#   6671,
#   4901,
#   6478,
#   8823],
#  [1473,
#   6418,
#   2783,
#   143,
#   2826,
#   3770,
#   7809,
#   4584,
#   5406,
#   3770,
#   1365,
#   2247,
#   249,
#   8824,
#   2596,
#   8020,
#   3663,
#   8823],
#  [8358, 8824, 104, 2960, 719, 3866, 8362, 4115, 2282, 8823],
#  [2596,
#   3866,
#   7428,
#   2596,
#   7428,
#   5557,
#   3770,
#   2995,
#   556,
#   1339,
#   2826,
#   3180,
#   1683,
#   8823],
#  [2596, 3084, 8823],
#  [8824,
#   8824,
#   5557,
#   8193,
#   5205,
#   6459,
#   4769,
#   2247,
#   4500,
#   8824,
#   1731,
#   4196,
#   3663,
#   8823],
#  [2596, 282, 4440, 4115, 7043, 8823],
#  [2596, 6671, 1550, 5628, 3770, 8494, 2359, 8823],
#  [335, 7584, 6285, 8823],
#  [3866, 7584, 6285, 1524, 8823],
#  [335, 3852, 4829, 90, 6419, 1873, 4205, 3852, 3784, 6465, 6478, 8823],
#  [8193,
#   3707,
#   2911,
#   355,
#   7738,
#   7446,
#   8193,
#   8193,
#   3370,
#   719,
#   464,
#   8193,
#   3370,
#   4256,
#   245,
#   556,
#   245,
#   8823],
#  [2247, 2183, 6725, 2775, 8824, 8823],
#  [1224, 3370, 90, 5102, 8823],
#  [1473, 7226, 4829, 2596, 1731, 2826, 556, 2556, 6419, 370, 8823],
#  [6418, 1126, 8823],
#  [3903, 1224, 2247, 6057, 798, 2826, 1750, 8823],
#  [104, 7787, 6057, 7584, 8398, 5389, 104, 1719, 3770, 973, 8823],
#  [4235, 104, 719, 7584, 973, 8823],
#  [8824,
#   1338,
#   3852,
#   1420,
#   6169,
#   7084,
#   1750,
#   4104,
#   8748,
#   2783,
#   6459,
#   2596,
#   26,
#   2783,
#   6671,
#   2596,
#   7687,
#   556,
#   8823],
#  [1224, 4584, 3770, 8824, 1224, 6170, 3770, 8824, 8823],
#  [3327, 6671, 8193, 657, 8823],
#  [104, 7787, 4200, 7084, 2596, 8823],
#  [335, 335, 3718, 7084, 3041, 8823],
#  [104,
#   7787,
#   8824,
#   6951,
#   2183,
#   7882,
#   2247,
#   8824,
#   4147,
#   8113,
#   104,
#   7787,
#   4200,
#   7084,
#   6465,
#   8823],
#  [2596, 4855, 3770, 8409, 8823],
#  [8784, 5772, 8823],
#  [104, 5569, 5557, 2826, 4610, 8823],
#  [2304,
#   2596,
#   5782,
#   5376,
#   3770,
#   8824,
#   2826,
#   3852,
#   5389,
#   8570,
#   6915,
#   1434,
#   4196,
#   4440,
#   8823],
#  [2783, 4196, 8824, 8823],
#  [835, 5456, 6671, 7687, 1562, 1634, 1224, 7533, 7099, 4115, 8824, 8823],
#  [6915, 1224, 2247, 4235, 8272, 8823],
#  [4713, 4928, 4196, 6465, 1731, 4196, 2813, 8823],
#  [2783, 4196, 8605, 7663, 6951, 7476, 6951, 8823],
#  [5017, 104, 4784, 1509, 5771, 6269, 4440, 5903, 2826, 1837, 8823],
#  [2783, 2247, 7584, 1623, 636, 7970, 8823],
#  [104, 4829, 8824, 143, 2247, 6202, 8823],
#  [6915, 6915, 8006, 8823],
#  [1446, 1989, 8823],
#  [8824,
#   6915,
#   7389,
#   7718,
#   104,
#   3784,
#   5596,
#   8398,
#   2183,
#   2247,
#   3770,
#   5268,
#   5178,
#   2826,
#   7584,
#   6435,
#   4713,
#   6516,
#   4115,
#   7187,
#   7834,
#   7617,
#   7418,
#   335,
#   7718,
#   6915,
#   8823],
#  [2183, 2247, 6057, 4196, 973, 8824, 104, 26, 7584, 6224, 5317, 1750, 8823],
#  [2783, 5524, 6459, 2596, 26, 8823],
#  [104,
#   26,
#   4115,
#   8020,
#   4196,
#   7584,
#   2457,
#   104,
#   26,
#   4115,
#   8020,
#   4196,
#   7584,
#   8824,
#   1126,
#   2596,
#   6671,
#   4235,
#   8823],
#  [4256, 1750, 5596, 3481, 3462, 8823],
#  [8605,
#   8221,
#   6139,
#   8824,
#   1750,
#   3249,
#   8605,
#   8824,
#   1473,
#   8605,
#   162,
#   5569,
#   5571,
#   8823],
#  [7584, 162, 5569, 5571, 8823],
#  [4207,
#   2043,
#   7533,
#   5571,
#   8177,
#   862,
#   4115,
#   1750,
#   2043,
#   7533,
#   4115,
#   95,
#   8247,
#   1785,
#   5088,
#   4115,
#   8824,
#   1750,
#   8823],
#  [7099, 5317, 3770, 790, 8824, 8823],
#  [4207,
#   8824,
#   5088,
#   7510,
#   6241,
#   2105,
#   2672,
#   768,
#   49,
#   6241,
#   4500,
#   5571,
#   1473,
#   8605,
#   8221,
#   4895,
#   1750,
#   556,
#   6241,
#   8824,
#   8823],
#  [7584, 8221, 4895, 2596, 556, 7584, 7713, 8824, 8823],
#  [4207,
#   1224,
#   5460,
#   1750,
#   2434,
#   4577,
#   99,
#   104,
#   5569,
#   6214,
#   4702,
#   3852,
#   2862,
#   5205,
#   2596,
#   4702,
#   3770,
#   8208,
#   2862,
#   8823],
#  [7584, 8221, 4702, 8409, 2862, 6269, 2596, 8823],
#  [2862, 6269, 8605, 7099, 99, 104, 5569, 6419, 410, 1344, 8823],
#  [5205, 104, 1719, 7584, 7099, 8823],
#  [104, 4713, 1731, 1989, 7297, 104, 1731, 1989, 7484, 8823],
#  [4113, 2240, 7584, 5434, 6459, 7584, 4663, 7464, 741, 8823],
#  [8431, 4440, 2247, 6419, 8824, 8060, 8823],
#  [335, 1446, 1224, 5569, 6419, 5625, 8823],
#  [1013,
#   2596,
#   3451,
#   7084,
#   3770,
#   4868,
#   1634,
#   5456,
#   4566,
#   3976,
#   2596,
#   7084,
#   7584,
#   5560,
#   8823],
#  [104, 4566, 1013, 5456, 4713, 2585, 1750, 7099, 8823],
#  [5456, 4566, 6057, 5389, 2183, 2247, 5519, 8823],
#  [4445, 8823],
#  [6459,
#   2596,
#   4439,
#   4838,
#   104,
#   719,
#   2536,
#   5317,
#   4610,
#   8603,
#   8824,
#   8824,
#   8403,
#   8193,
#   1995,
#   6859,
#   7584,
# ...
#  [2183,
#   2247,
#   1085,
#   104,
#   7787,
#   6057,
#   992,
#   90,
#   5317,
#   7584,
#   8006,
#   8193,
#   5205,
#   4447,
#   3770,
#   5178,
#   5519,
#   8823],
#  [282,
#   2596,
#   2783,
#   104,
#   4566,
#   3298,
#   2596,
#   6419,
#   2777,
#   1013,
#   2596,
#   2716,
#   2596,
#   5205,
#   3718,
#   7084,
#   1750,
#   1013,
#   2596,
#   4713,
#   2716,
#   2596,
#   4713,
#   3718,
#   8823],
#  [104, 4566, 3784, 3852, 8824, 8823],
#  [1968, 3214, 3481, 8823],
#  [104,
#   7787,
#   6269,
#   8605,
#   8006,
#   7084,
#   1583,
#   8824,
#   8824,
#   1473,
#   2167,
#   3770,
#   3832,
#   6225,
#   90,
#   3838,
#   7116,
#   8823],
#  [104, 7787, 6269, 4663, 8823],
#  [4877,
#   7787,
#   104,
#   8431,
#   104,
#   4566,
#   4500,
#   6634,
#   1473,
#   2596,
#   1368,
#   3770,
#   7099,
#   8823],
#  [2826, 8298, 8823],
#  [6694,
#   104,
#   6139,
#   6366,
#   4115,
#   90,
#   6419,
#   5625,
#   99,
#   104,
#   5569,
#   6419,
#   5150,
#   104,
#   1827,
#   2826,
#   7356,
#   2160,
#   4115,
#   6419,
#   423,
#   8155,
#   3852,
#   5317,
#   546,
#   8605,
#   1712,
#   1473,
#   197,
#   8824,
#   6859,
#   3770,
#   2105,
#   7765,
#   2783,
#   4829,
#   2596,
#   5237,
#   4196,
#   8823],
#  [104,
#   6366,
#   4115,
#   2349,
#   2160,
#   4115,
#   6419,
#   5897,
#   6269,
#   6281,
#   3470,
#   5317,
#   3770,
#   423,
#   1614,
#   2036,
#   3770,
#   6041,
#   1473,
#   912,
#   6419,
#   5150,
#   8823],
#  [6418,
#   104,
#   4401,
#   8193,
#   6671,
#   530,
#   2183,
#   3770,
#   1550,
#   8006,
#   5600,
#   8193,
#   1013,
#   8193,
#   4812,
#   2160,
#   4115,
#   6419,
#   5862,
#   5897,
#   104,
#   4566,
#   3198,
#   5628,
#   2596,
#   4500,
#   4389,
#   8823],
#  [2043, 3686, 5425, 522, 2826, 6241, 4399, 6935, 5456, 1068, 1847, 6241, 8823],
#  [2247, 4440, 5557, 3838, 2247, 8823],
#  [7701, 7099, 6282, 8823],
#  [3050, 6118, 8823],
#  [2596, 8021, 4447, 4115, 6241, 4838, 8823],
#  [4207, 8823],
#  [2783, 4829, 7584, 3574, 1731, 2826, 4440, 8823],
#  [104, 4713, 719, 6419, 3574, 8823],
#  [8605, 8543, 2630, 8823],
#  [104, 7787, 7163, 4235, 8823],
#  [4877, 7787, 104, 8823],
#  [4450,
#   2596,
#   2336,
#   6241,
#   7548,
#   2596,
#   6671,
#   6419,
#   8002,
#   2043,
#   6199,
#   1750,
#   1181,
#   8823],
#  [2596,
#   6671,
#   6241,
#   8824,
#   2247,
#   2043,
#   3770,
#   5150,
#   2596,
#   6671,
#   992,
#   912,
#   2434,
#   3770,
#   5862,
#   5897,
#   8823],
#  [2596, 8020, 2783, 104, 7787, 2421, 4235, 8823],
#  [5052, 104, 7787, 6419, 312, 8823],
#  [7206, 5750, 4440, 719, 6419, 8006, 2826, 4901, 3156, 2036, 8824, 8823],
#  [2304, 2596, 3034, 3903, 5899, 992, 480, 2596, 8824, 1750, 8823],
#  [104, 6170, 6241, 3838, 556, 6419, 3460, 1473, 4440, 2247, 3852, 8823],
#  [3686, 6419, 3460, 8823],
#  [6915,
#   104,
#   4713,
#   1731,
#   2596,
#   7446,
#   6419,
#   7164,
#   104,
#   3686,
#   1731,
#   2596,
#   7446,
#   3824,
#   4196,
#   3852,
#   104,
#   4191,
#   4115,
#   7418,
#   3770,
#   7827,
#   2596,
#   1456,
#   8020,
#   1968,
#   2596,
#   4713,
#   8020,
#   6241,
#   2304,
#   996,
#   2043,
#   2247,
#   8232,
#   3770,
#   997,
#   4115,
#   95,
#   5809,
#   2596,
#   5728,
#   1013,
#   2043,
#   128,
#   4440,
#   2596,
#   49,
#   6419,
#   2902,
#   6859,
#   6241,
#   1989,
#   2721,
#   5519,
#   2596,
#   5205,
#   1290,
#   3852,
#   5557,
#   2596,
#   1138,
#   1446,
#   3852,
#   4566,
#   6057,
#   2120,
#   3481,
#   95,
#   4469,
#   2826,
#   3608,
#   2596,
#   6671,
#   7955,
#   8823],
#  [104,
#   6252,
#   2596,
#   2596,
#   8020,
#   104,
#   3328,
#   104,
#   5569,
#   5090,
#   3770,
#   1550,
#   1837,
#   2596,
#   8020,
#   104,
#   1731,
#   2043,
#   2247,
#   2697,
#   8823],
#  [2304,
#   1989,
#   6057,
#   2160,
#   4115,
#   2596,
#   4115,
#   2359,
#   2773,
#   2043,
#   2247,
#   2697,
#   7718,
#   6057,
#   4713,
#   2596,
#   8432,
#   4440,
#   2247,
#   1126,
#   2596,
#   6671,
#   6419,
#   312,
#   8823],
#  [1446,
#   104,
#   4191,
#   5782,
#   2596,
#   403,
#   4500,
#   2862,
#   6269,
#   6419,
#   7316,
#   556,
#   6698,
#   104,
#   4191,
#   2596,
#   3034,
#   1000,
#   6241,
#   3838,
#   7450,
#   6241,
#   6766,
#   8824,
#   6640,
#   6241,
#   8823],
#  [636,
#   2596,
#   4500,
#   2862,
#   6269,
#   6419,
#   7316,
#   556,
#   6698,
#   2247,
#   4147,
#   8177,
#   6241,
#   6419,
#   8037,
#   2826,
#   7871,
#   7387,
#   8398,
#   4235,
#   3891,
#   6419,
#   8037,
#   2826,
#   7871,
#   7387,
#   8398,
#   4440,
#   2247,
#   636,
#   2596,
#   3976,
#   6241,
#   1446,
#   2596,
#   1161,
#   4969,
#   5371,
#   5317,
#   6241,
#   5750,
#   4440,
#   2596,
#   6671,
#   992,
#   8824,
#   7584,
#   7075,
#   7584,
#   6435,
#   1473,
#   2596,
#   6671,
#   992,
#   8824,
#   8605,
#   5178,
#   1473,
#   6095,
#   4256,
#   2596,
#   5596,
#   6160,
#   2826,
#   8491,
#   1634,
#   2596,
#   4713,
#   7862,
#   8261,
#   1446,
#   104,
#   4566,
#   5628,
#   2596,
#   5317,
#   6269,
#   6419,
#   3513,
#   3843,
#   3770,
#   6766,
#   2721,
#   8369,
#   3063,
#   534,
#   1473,
#   99,
#   2596,
#   4969,
#   2862,
#   3838,
#   5456,
#   8020,
#   7584,
#   567,
#   1473,
#   3770,
#   3513,
#   7467,
#   3770,
#   3513,
#   2721,
#   8824,
#   8824,
#   7467,
#   4440,
#   104,
#   4969,
#   5317,
#   2183,
#   7456,
#   3384,
#   3852,
#   6419,
#   1536,
#   6163,
#   556,
#   8605,
#   6955,
#   1473,
#   104,
#   4969,
#   7389,
#   8042,
#   3903,
#   2826,
#   3852,
#   8823],
#  [2596,
#   8020,
#   104,
#   4713,
#   8020,
#   104,
#   5750,
#   2596,
#   2596,
#   317,
#   1750,
#   2826,
#   6419,
#   6484,
#   104,
#   876,
#   4115,
#   719,
#   1224,
#   8414,
#   6269,
#   3770,
#   8650,
#   5557,
#   3770,
#   245,
#   1446,
#   104,
#   1569,
#   4240,
#   6465,
#   8823],
#  [2783, 6459, 2596, 1138, 8823],
#  [7584,
#   5417,
#   2596,
#   1719,
#   5456,
#   657,
#   4115,
#   2120,
#   6419,
#   7663,
#   4196,
#   1750,
#   3745,
#   1583,
#   1473,
#   235,
#   6547,
#   8823],
#  [2783, 2247, 7584, 8824, 8823],
#  [104, 4711, 2817, 603, 8823],
#  [6418, 6459, 3852, 8076, 8823],
#  [1249,
#   90,
#   8764,
#   4115,
#   3770,
#   4397,
#   5403,
#   7226,
#   8756,
#   2596,
#   4566,
#   1138,
#   4115,
#   907,
#   5750,
#   2943,
#   8823],
#  [1013,
#   2596,
#   4711,
#   1750,
#   1473,
#   1179,
#   3852,
#   2596,
#   6671,
#   1284,
#   6419,
#   8824,
#   7666,
#   7584,
#   7000,
#   8823],
#  [1611,
#   3214,
#   6921,
#   2596,
#   6671,
#   6542,
#   6436,
#   5552,
#   4447,
#   259,
#   5557,
#   4577,
#   3402,
#   6057,
#   4349,
#   4566,
#   6921,
#   480,
#   1750,
#   5456,
#   4566,
#   6436,
#   556,
#   1750,
#   8824,
#   1583,
#   8824,
#   4829,
#   2596,
#   5750,
#   4115,
#   7418,
#   6621,
#   4115,
#   7584,
#   8824,
#   1634,
#   2596,
#   5205,
#   3095,
#   4115,
#   6241,
#   4769,
#   8823],
#  [8193,
#   4713,
#   8020,
#   4440,
#   732,
#   1989,
#   7970,
#   3745,
#   7587,
#   2240,
#   6419,
#   1536,
#   4115,
#   90,
#   8042,
#   8823],
#  [636, 8645, 5175, 6671, 2160, 3838, 8823],
#  [3838, 6671, 522, 4761, 3528, 6859, 2183, 8543, 8823],
#  [5205, 8193, 4500, 2160, 4115, 3770, 3673, 4312, 8823],
#  [2596, 8020, 2596, 1161, 6459, 4440, 4450, 8823],
#  [2247, 3852, 3817, 2026, 8823],
#  [8193, 4713, 8020, 99, 104, 719, 7389, 104, 4566, 5628, 2596, 8020, 8823],
#  [104,
#   1161,
#   4447,
#   1550,
#   4769,
#   8193,
#   719,
#   6334,
#   753,
#   4115,
#   1338,
#   477,
#   2826,
#   8823],
#  [104, 1509, 1161, 4256, 2862, 1072, 6397, 1550, 4769, 6859, 2183, 8543, 8823],
#  [6693,
#   1446,
#   104,
#   6459,
#   8432,
#   4440,
#   7584,
#   764,
#   5481,
#   8824,
#   2536,
#   1464,
#   2247,
#   4440,
#   6042,
#   8823],
#  [1224, 5569, 1627, 1446, 6057, 991, 1224, 4566, 90, 4696, 8823],
#  [6459, 2596, 719, 3770, 573, 5317, 4150, 8823],
#  [8824,
#   2247,
#   6057,
#   6419,
#   1249,
#   245,
#   6693,
#   5264,
#   8824,
#   1627,
#   1224,
#   2247,
#   4696,
#   104,
#   719,
#   8232,
#   6419,
#   6281,
#   3447,
#   8571,
#   5264,
#   5573,
#   2247,
#   1627,
#   1446,
#   6057,
#   991,
#   8823],
#  [8431, 1623, 1623, 1623, 8823],
#  [4207, 7999, 6057, 6419, 1249, 245, 8823],
#  [8431, 8823],
#  [8431, 8823],
#  [8431, 8823],
#  [8431, 8823],
#  [6693, 8823],
#  [5052, 8823],
#  [104,
#   8824,
#   1161,
#   1559,
#   2596,
#   3686,
#   3903,
#   2596,
#   1138,
#   1750,
#   4115,
#   1559,
#   2282,
#   8823],
#  [2596,
#   5782,
#   719,
#   4115,
#   6380,
#   1750,
#   5317,
#   1589,
#   2826,
#   8605,
#   1442,
#   2596,
#   8403,
#   4256,
#   1750,
#   7701,
#   8823],
#  [8784, 104, 7787, 6948, 7428, 104, 6380, 2596, 3474, 8784, 8823],
#  [1995, 3852, 8823],
#  [1634,
#   104,
#   2960,
#   3686,
#   2959,
#   8824,
#   4115,
#   3770,
#   6735,
#   1473,
#   7418,
#   6459,
#   2596,
#   4992,
#   1013,
#   8193,
#   3686,
#   8437,
#   7701,
#   2862,
#   8823],
#  [8431, 8431, 1583, 4713, 8824, 1750, 8823],
#  [104, 7787, 6057, 8823],
#  [335,
#   2596,
#   6671,
#   104,
#   7787,
#   6057,
#   3686,
#   6334,
#   6205,
#   104,
#   4713,
#   3686,
#   5309,
#   6419,
#   8824,
#   5317,
#   7584,
#   567,
#   2596,
#   8403,
#   4256,
#   1750,
#   7701,
#   8823],
#  [4207,
#   2304,
#   2596,
#   6170,
#   3770,
#   1367,
#   1473,
#   4702,
#   3852,
#   1550,
#   8748,
#   6269,
#   3770,
#   2079,
#   4440,
#   5569,
#   8823],
#  [4440, 5569, 1249, 2596, 7446, 2458, 3770, 2079, 8823],
#  [2596,
#   7446,
#   8824,
#   2596,
#   5782,
#   4256,
#   6419,
#   8272,
#   1013,
#   2596,
#   8232,
#   1750,
#   7718,
#   6057,
#   8823],
#  [2304, 7226, 5569, 3852, 4440, 8684, 1750, 636, 4115, 6459, 4440, 3125, 8823],
#  [2596, 6671, 8824, 8823],
#  [2596, 6671, 6057, 4877, 2105, 2813, 8823],
#  [8403, 90, 8824, 8823],
#  [8358,
#   1473,
#   6411,
#   4985,
#   2596,
#   1276,
#   5519,
#   7084,
#   7471,
#   6269,
#   7584,
#   3021,
#   2783,
#   7787,
#   104,
#   657,
#   4115,
#   6459,
#   7084,
#   2596,
#   8823],
#  [1559, 3770, 6468, 8823],
#  [6915, 282, 1750, 2783, 2596, 1138, 4115, 7418, 8823],
#  [1559, 3852, 8823],
#  [6693,
#   6693,
#   1487,
#   4440,
#   3328,
#   3686,
#   556,
#   6419,
#   2652,
#   5456,
#   4349,
#   3784,
#   1750,
#   99,
#   1989,
#   7871,
#   7864,
#   3686,
#   1487,
#   4440,
#   3328,
#   5205,
#   2596,
#   3784,
#   7099,
#   8823],
#  [4440, 2247, 1249, 8823],
#  [4207, 8823],
#  [2304, 4440, 2247, 5923, 8823],
#  [6693,
#   4440,
#   2247,
#   5923,
#   1446,
#   104,
#   1161,
#   4500,
#   4769,
#   8193,
#   6671,
#   5317,
#   3770,
#   967,
#   2826,
#   7701,
#   4235,
#   8823],
#  [6915, 4500, 8714, 2596, 6671, 992, 90, 5923, 8823],
#  [6915,
#   6915,
#   2124,
#   4115,
#   1750,
#   4235,
#   104,
#   1138,
#   4115,
#   8020,
#   2783,
#   2596,
#   6671,
#   2995,
#   4196,
#   2596,
#   8020,
#   3770,
#   6297,
#   1837,
#   1473,
#   3770,
#   304,
#   1473,
#   8823],
#  [104,
#   4566,
#   282,
#   2596,
#   3375,
#   7343,
#   6459,
#   3852,
#   3375,
#   1095,
#   3712,
#   1095,
#   2596,
#   4969,
#   7099,
#   8193,
#   4566,
#   4447,
#   8193,
#   4566,
#   4447,
#   8823],
#  [8744, 8823],
#  [104,
#   8744,
#   8193,
#   4566,
#   4447,
#   2596,
#   4566,
#   90,
#   5923,
#   2596,
#   4566,
#   90,
#   4696,
#   4500,
#   8714,
#   3686,
#   1991,
#   4440,
#   7776,
#   3686,
#   5017,
#   2036,
#   3770,
#   8824,
#   1473,
#   1991,
#   2596,
#   6671,
#   2995,
#   4115,
#   1750,
#   8823],
#  [4207,
#   104,
#   4566,
#   6459,
#   4440,
#   1095,
#   3402,
#   1095,
#   2596,
#   6671,
#   6057,
#   8824,
#   1750,
#   8823],
#  [8824, 2596, 5718, 104, 205, 2596, 8823],
#  [104, 205, 2596, 8823],
#  [3375, 8823],
#  [2596, 8744, 8823],
#  [4207, 104, 8744, 8823],
#  [6693,
#   1473,
#   2596,
#   8020,
#   2783,
#   104,
#   4566,
#   3695,
#   4147,
#   8605,
#   1301,
#   5021,
#   6419,
#   8268,
#   8824,
#   2826,
#   3021,
#   1473,
#   1634,
#   3686,
#   2403,
#   1208,
#   2862,
#   8500,
#   4115,
#   8824,
#   4440,
#   4829,
#   4440,
#   90,
#   6419,
#   1249,
#   1837,
#   8823],
#  [4207, 4207, 1249, 1837, 8823],
#  [6693, 8823],
#  [1719, 2596, 7261, 1249, 7987, 8823],
#  [5321, 2596, 8823],
#  [4713, 90, 916, 8823],
#  [8358, 7844, 8823],
#  [6057,
#   2752,
#   2160,
#   6057,
#   2752,
#   2160,
#   5750,
#   4440,
#   104,
#   4191,
#   2783,
#   6459,
#   104,
#   8232,
#   5780,
#   6295,
#   3449,
#   6419,
#   3685,
#   7718,
#   522,
#   8824,
#   4235,
#   1473,
#   3838,
#   1473,
#   5317,
#   6419,
#   6295,
#   4587,
#   6915,
#   3481,
#   8380,
#   1750,
#   7279,
#   8823],
#  [104, 1731, 2596, 6671, 2093, 6419, 3513, 8824, 3838, 1583, 8823],
#  [104, 7787, 6057, 8824, 8823],
#  [8605,
#   1136,
#   7343,
#   8824,
#   5804,
#   8824,
#   2033,
#   4713,
#   282,
#   1750,
#   2596,
#   6671,
#   5599,
#   4196,
#   6382,
#   6419,
#   6786,
#   636,
#   8715,
#   6671,
#   2596,
#   3866,
#   4992,
#   5628,
#   1750,
#   3686,
#   282,
#   2596,
#   2183,
#   4388,
#   3824,
#   8824,
#   2596,
#   4701,
#   4196,
#   1136,
#   5456,
#   6714,
#   7584,
#   6435,
#   5456,
#   2120,
#   2596,
#   6419,
#   1968,
#   6018,
#   5456,
#   2120,
#   2596,
#   6766,
#   1989,
#   5557,
#   6076,
#   7227,
#   104,
#   6961,
#   1136,
#   99,
#   4399,
#   2628,
#   4196,
#   1074,
#   1136,
#   104,
#   6366,
#   4115,
#   218,
#   4769,
#   104,
#   4969,
#   3852,
#   7787,
#   104,
#   1550,
#   5481,
#   8823],
#  [6057, 2783, 7226, 8823],
#  [4440, 2247, 8003, 8823],
#  [4207, 1473, 1224, 1569, 7533, 4115, 3770, 1675, 8823],
#  [2596, 6671, 2976, 556, 8605, 8767, 104, 7787, 8687, 8823],
#  [4478, 1208, 2862, 2826, 8605, 8006, 8823],
#  [6693, 2596, 3178, 8823],
#  [4207, 4207, 8358, 8823],
#  [6629, 104, 5782, 8021, 6459, 3852, 3770, 4389, 245, 8823],
#  [104, 7787, 3886, 8823],
#  [2596, 6671, 6419, 3886, 2783, 6459, 2596, 1202, 7317, 8824, 556, 8823],
#  [2596, 3426, 8824, 5317, 3852, 8823],
#  [1473, 2783, 6459, 2596, 6459, 7084, 3770, 7196, 8823],
#  [3568, 8545, 8823],
#  [6915, 6671, 2596, 2580, 8823],
#  [5017, 8076, 104, 719, 2536, 1847, 4147, 1968, 3214, 2596, 8823],
#  [6915, 104, 7787, 3770, 2763, 4440, 2247, 403, 1847, 2596, 8823],
#  [104,
#   4566,
#   2690,
#   2596,
#   6269,
#   3481,
#   5647,
#   104,
#   4969,
#   8824,
#   1473,
#   2596,
#   3422,
#   4115,
#   1750,
#   8823],
#  [8193,
#   4566,
#   4447,
#   4196,
#   4440,
#   3347,
#   3741,
#   7205,
#   2596,
#   245,
#   4115,
#   4500,
#   4115,
#   2901,
#   6476,
#   6456,
#   7867,
#   1064,
#   8823],
#  [2783, 3852, 1321, 8437, 4440, 8006, 8823],
#  [1013,
#   2596,
#   4713,
#   1138,
#   8605,
#   1179,
#   104,
#   4566,
#   3784,
#   5596,
#   8698,
#   1473,
#   5456,
#   4566,
#   8698,
#   3852,
#   8823],
#  [495, 6419, 5231, 495, 6419, 5231, 8823],
#  [3718, 4838, 4855, 510, 1473, 8193, 4566, 4447, 4196, 8824, 8823],
#  [8605,
#   8221,
#   5569,
#   1224,
#   7510,
#   1750,
#   8645,
#   3606,
#   4196,
#   6281,
#   4769,
#   1989,
#   8605,
#   2998,
#   8823],
#  [7597, 1338, 6419, 5669, 8823],
#  [2596, 4566, 90, 8605, 4389, 8823],
#  [4969, 8748, 6269, 7584, 5711, 8823],
#  [3770,
#   8824,
#   6269,
#   8824,
#   5246,
#   8824,
#   4500,
#   4969,
#   8824,
#   1224,
#   4566,
#   4711,
#   2596,
#   8823],
#  [5628, 6241, 515, 5628, 6241, 8824, 8823],
#  [1013, 1224, 1321, 3795, 3664, 1712, 104, 4566, 95, 4711, 6241, 8823],
#  [3327, 2247, 790, 6489, 8823],
#  [5552,
#   104,
#   7787,
#   7111,
#   2596,
#   1138,
#   1750,
#   4115,
#   90,
#   104,
#   7787,
#   6419,
#   3513,
#   8824,
#   104,
#   7787,
#   1298,
#   104,
#   7787,
#   6419,
#   790,
#   6489,
#   8823],
#  [104, 41, 6419, 790, 6489, 7502, 2596, 8020, 6241, 8823],
#  [3327, 2247, 8151, 7990, 8823],
#  [4440, 2247, 401, 8403, 2596, 4702, 3770, 973, 6269, 3770, 8824, 8823],
#  [104,
#   5750,
#   4115,
#   4447,
#   4115,
#   3770,
#   6018,
#   7226,
#   623,
#   3770,
#   7990,
#   5205,
#   2596,
#   4256,
#   1750,
#   4988,
#   8823],
#  [5017,
#   6459,
#   8193,
#   719,
#   6419,
#   1375,
#   4235,
#   2240,
#   6915,
#   4947,
#   4115,
#   719,
#   6419,
#   1375,
#   104,
#   7787,
#   992,
#   2120,
#   2596,
#   7677,
#   4978,
#   1249,
#   2596,
#   8021,
#   790,
#   6489,
#   3629,
#   104,
#   7787,
#   8042,
#   7084,
#   2596,
#   2596,
#   4566,
#   6057,
#   8626,
#   6241,
#   4769,
#   1126,
#   4713,
#   2596,
#   6531,
#   1750,
#   8823],
#  [5017,
#   7882,
#   104,
#   4713,
#   4256,
#   6419,
#   8272,
#   1013,
#   2596,
#   1138,
#   7431,
#   7718,
#   6057,
#   1446,
#   2596,
#   6671,
#   693,
#   556,
#   8605,
#   245,
#   8823],
#  [8431,
#   8431,
#   4713,
#   1627,
#   3041,
#   3462,
#   1989,
#   5317,
#   8605,
#   7476,
#   5317,
#   8605,
#   8824,
#   8823],
#  [335, 8701, 8823],
#  [522, 6543, 139, 8823],
#  [636, 7970, 973, 6671, 2596, 2764, 7084, 2596, 8823],
#  [104, 719, 8824, 1064, 8823],
#  [5205, 2596, 8698, 1750, 8701, 6915, 6735, 5317, 3770, 8824, 8824, 8823],
#  [335, 8823],
#  [3462, 5496, 3180, 3718, 6269, 5710, 8823],
#  [2247, 3838, 6419, 1375, 8823],
#  [6915,
#   2596,
#   6671,
#   6200,
#   6605,
#   104,
#   1138,
#   4115,
#   4447,
#   4115,
#   2596,
#   6605,
#   1008,
#   636,
#   6671,
#   2596,
#   5205,
#   104,
#   1338,
#   6419,
#   5017,
#   6859,
#   7584,
#   7825,
#   6671,
#   2596,
#   2026,
#   8823],
#  [636, 3402, 6671, 2596, 4353, 4115, 6169, 8823],
#  [522, 6543, 8823],
#  [104, 4829, 5750, 4115, 6438, 556, 6730, 6693, 8823],
#  [1224, 1321, 6438, 1426, 8823],
#  [2446, 8824, 3941, 2183, 2247, 3664, 5178, 8823],
#  [6459, 2596, 8020, 636, 7970, 5434, 8445, 556, 7663, 6951, 8823],
#  [5317, 4235, 6862, 1224, 375, 6419, 1206, 8823],
#  [8824, 3770, 5434, 8445, 3481, 1206, 1064, 556, 6419, 534, 2398, 8823],
#  [5052,
#   8824,
#   1721,
#   619,
#   3556,
#   603,
#   1465,
#   5434,
#   143,
#   6419,
#   1206,
#   556,
#   3664,
#   2398,
#   1473,
#   636,
#   7970,
#   2596,
#   1731,
#   2928,
#   8232,
#   556,
#   2682,
#   7476,
#   4196,
#   3770,
#   6697,
#   4200,
#   6269,
#   4115,
#   6241,
#   3852,
#   3709,
#   4115,
#   90,
#   6419,
#   5434,
#   7718,
#   6419,
#   8547,
#   5317,
#   2183,
#   2983,
#   5017,
#   2596,
#   1138,
#   2555,
#   7718,
#   6057,
#   8823],
#  [335, 1339, 8823],
#  [6693, 8823],
#  [6693, 8823],
#  [104, 1138, 4115, 4740, 8605, 378, 4115, 2050, 8823],
#  [4713, 6438, 8824, 8823],
#  [1126, 1126, 6459, 104, 6139, 719, 4115, 6438, 4115, 2596, 5317, 790, 8823],
#  [3903,
#   104,
#   4713,
#   5750,
#   7584,
#   7699,
#   4072,
#   104,
#   1000,
#   996,
#   2826,
#   3852,
#   5317,
#   8824,
#   4769,
#   6438,
#   790,
#   7718,
#   1426,
#   1473,
#   4713,
#   7164,
#   7666,
#   7279,
#   2596,
#   989,
#   8232,
#   3180,
#   3238,
#   3623,
#   8823],
#  [8193, 719, 6915, 973, 3718, 6269, 8823],
#  ...]

# %% [markdown]
# # Sorting the question and answers

# %%
sorted_clean_questions = []
sorted_clean_answers = []
for length in range(1, 25 + 1):
    for i in enumerate(questions_into_int):
        if len(i[1]) == length:
            sorted_clean_questions.append(questions_into_int[i[0]])
            sorted_clean_answers.append(answers_into_int[i[0]])

# %%
sorted_clean_questions
# Out:
# [[4522],
#  [1126],
#  [3838],
#  [1008],
#  [1446],
#  [6915],
#  [7033],
#  [6915],
#  [7226],
#  [5923],
#  [7119],
#  [2783],
#  [1126],
#  [1446],
#  [1126],
#  [3866],
#  [6388],
#  [5772],
#  [1693],
#  [4207],
#  [2783],
#  [5052],
#  [7226],
#  [6693],
#  [1126],
#  [7226],
#  [8824],
#  [6944],
#  [1634],
#  [7226],
#  [5869],
#  [8824],
#  [8824],
#  [335],
#  [636],
#  [8824],
#  [8824],
#  [2783],
#  [6915],
#  [2783],
#  [8824],
#  [1008],
#  [1550],
#  [2783],
#  [1066],
#  [8824],
#  [8221],
#  [6915],
#  [6915],
#  [663],
#  [8824],
#  [4445],
#  [6915],
#  [8784],
#  [99],
#  [4207],
#  [6915],
#  [1700],
#  [1914],
#  [4207],
#  [8431],
#  [8431],
#  [8431],
#  [8431],
#  [4207],
#  [8744],
#  [3375],
#  [6693],
#  [3178],
#  [335],
#  [2783],
#  [8547],
#  [4813],
#  [8824],
#  [8824],
#  [5386],
#  [4207],
#  [8278],
#  [2783],
#  [2783],
#  [4207],
#  [4551],
#  [4551],
#  [4551],
#  [4551],
#  [4551],
#  [4551],
#  [6693],
#  [335],
#  [1509],
#  [335],
#  [8784],
#  [636],
#  [1676],
#  [4551],
#  [4551],
#  [4551],
#  [8824],
#  [4551],
#  [4551],
#  [1509],
#  [1887],
#  [6725],
#  [6099],
#  [4207],
#  [7073],
#  [4207],
#  [1291],
#  [4207],
#  [5546],
#  [4207],
#  [2304],
#  [3838],
#  [2783],
#  [1126],
#  [6050],
#  [4470],
#  [4207],
#  [2657],
#  [4207],
#  [4207],
#  [3808],
#  [5052],
#  [2137],
#  [99],
#  [8824],
#  [7226],
#  [4207],
#  [3808],
#  [4748],
#  [3808],
#  [4207],
#  [3808],
#  [2219],
#  [1008],
#  [3092],
#  [8824],
#  [4609],
#  [8824],
#  [205],
#  [8824],
#  [8824],
#  [7776],
#  [2630],
#  [7776],
#  [4470],
#  [7004],
#  [8824],
#  [8824],
#  [3808],
#  [7072],
#  [4713],
#  [2783],
#  [5695],
#  [5546],
#  [8824],
#  [429],
#  [7913],
#  [6948],
#  [1583],
#  [2783],
#  [4207],
#  [1126],
#  [1331],
#  [3808],
#  [4482],
#  [6461],
#  [8205],
#  [6915],
#  [6693],
#  [3808],
#  [6693],
#  [3808],
#  [335],
#  [6915],
#  [6915],
#  [335],
#  [6915],
#  [2783],
#  [3808],
#  [6915],
#  [2783],
#  [6915],
#  [4877],
#  [8824],
#  [2783],
#  [1298],
#  [7138],
#  [8824],
#  [1388],
#  [8824],
#  [2783],
#  [7226],
#  [4207],
#  [218],
#  [2451],
#  [335],
#  [8824],
#  [3125],
#  [4877],
#  [8824],
#  [8824],
#  [4207],
#  [2304],
#  [4835],
#  [5885],
#  [3125],
#  [2783],
#  [8824],
#  [1126],
#  [3771],
#  [7226],
#  [7226],
#  [6915],
#  [335],
#  [8784],
#  [4207],
#  [5416],
#  [4207],
#  [8784],
#  [1509],
#  [5639],
#  [4207],
#  [4207],
#  [2783],
#  [4207],
#  [8824],
#  [4207],
#  [6915],
#  [335],
#  [335],
#  [335],
#  [335],
#  [2276],
#  [6943],
#  [6915],
#  [469],
#  [6693],
#  [3125],
#  [3125],
#  [4877],
#  [1634],
#  [8824],
#  [4207],
#  [4207],
#  [973],
#  [5462],
#  [636],
#  [5205],
#  [2783],
#  [8824],
#  [2657],
#  [8824],
#  [469],
#  [303],
#  [4207],
#  [4207],
#  [8824],
#  [8824],
#  [8824],
#  [564],
#  [7226],
#  [6378],
#  [3125],
#  [7226],
#  [973],
#  [4207],
#  [1388],
#  [4580],
#  [8824],
#  [6149],
#  [1126],
#  [7955],
#  [1328],
#  [636],
#  [335],
#  [6915],
#  [3347],
#  [5026],
#  [1995],
#  [2783],
#  [3481],
#  [1446],
#  [8824],
#  [8272],
#  [2783],
#  [8824],
#  [8824],
#  [8701],
#  [5737],
#  [8824],
#  [5737],
#  [619],
#  [5737],
#  [8824],
#  [8824],
#  [8824],
#  [3243],
#  [2891],
#  [1634],
#  [6099],
#  [680],
#  [680],
#  [8824],
#  [5772],
#  [4207],
#  [2783],
#  [335],
#  [8824],
#  [6915],
#  [8824],
#  [8824],
#  [774],
#  [619],
#  [335],
#  [8824],
#  [3083],
#  [335],
#  [6099],
#  [6099],
#  [335],
#  [335],
#  [4235],
#  [335],
#  [469],
#  [469],
#  [1126],
#  [3092],
#  [8824],
#  [4207],
#  [2783],
#  [8824],
#  [4403],
#  [2783],
#  [1830],
#  [7123],
#  [4877],
#  [8701],
#  [150],
#  [7367],
#  [1132],
#  [4470],
#  [2619],
#  [5406],
#  [8824],
#  [4697],
#  [8824],
#  [335],
#  [6915],
#  [3327],
#  [8581],
#  [1126],
#  [2783],
#  [2783],
#  [2783],
#  [6710],
#  [8701],
#  [2226],
#  [3327],
#  [4769],
#  [677],
#  [1126],
#  [3327],
#  [6347],
#  [8824],
#  [2783],
#  [6781],
#  [335],
#  [677],
#  [6347],
#  [677],
#  [8824],
#  [8824],
#  [8824],
#  [2783],
#  [8824],
#  [1509],
#  [8824],
#  [3375],
#  [4838],
#  [2783],
#  [8824],
#  [6694],
#  [8824],
#  [919],
#  [8824],
#  [8824],
#  [1509],
#  [335],
#  [4638],
#  [1509],
#  [335],
#  [8824],
#  [4053],
#  [2623],
#  [335],
#  [335],
#  [8824],
#  [8221],
#  [3327],
#  [335],
#  [2783],
#  [8824],
#  [8824],
#  [2304],
#  [2925],
#  [8824],
#  [8824],
#  [2783],
#  [335],
#  [6915],
#  [3530],
#  [1509],
#  [5697],
#  [335],
#  [2783],
#  [7226],
#  [2783],
#  [8824],
#  [335],
#  [335],
#  [335],
#  [335],
#  [2630],
#  [1791],
#  [1791],
#  [1791],
#  [4877],
#  [3327],
#  [2304],
#  [2783],
#  [335],
#  [335],
#  [2630],
#  [335],
#  [3327],
#  [5369],
#  [8824],
#  [335],
#  [335],
#  [6827],
#  [2783],
#  [335],
#  [7818],
#  [2783],
#  [1891],
#  [3923],
#  [4725],
#  [714],
#  [244],
#  [335],
#  [5885],
#  [6693],
#  [1446],
#  [2783],
#  [6915],
#  [6915],
#  [6915],
#  [6915],
#  [6915],
#  [6347],
#  [6915],
#  [244],
#  [4061],
#  [335],
#  [335],
#  [2657],
#  [6827],
#  [6693],
#  [3808],
#  [1550],
#  [4207],
#  [8824],
#  [3738],
#  [2657],
#  [4207],
#  [3162],
#  [1066],
#  [1066],
#  [1561],
#  [1561],
#  [335],
#  [3808],
#  [335],
#  [6915],
#  [8784],
#  [6948],
#  [4935],
#  [4207],
#  [4207],
#  [7131],
#  [8581],
#  [4470],
#  [1750],
#  [2719],
#  [2304],
#  [6915],
#  [2783],
#  [4769],
#  [335],
#  [2304],
#  [4715],
#  [8581],
#  [335],
#  [335],
#  [8824],
#  [335],
#  [5618],
#  [6915],
#  [1126],
#  [335],
#  [6915],
#  [335],
#  [2304],
#  [3125],
#  [335],
#  [636],
#  [2060],
#  [7100],
#  [1258],
#  [3233],
#  [6694],
#  [2783],
#  [2783],
#  [636],
#  [6948],
#  [6612],
#  [4846],
#  [6894],
#  [2304],
#  [8824],
#  [6371],
#  [2783],
#  [4877],
#  [8423],
#  [3777],
#  [4207],
#  [8824],
#  [8824],
#  [2783],
#  [6612],
#  [8824],
#  [5639],
#  [2783],
#  [5292],
#  [5416],
#  [335],
#  [4470],
#  [1509],
#  [1509],
#  [6078],
#  [1249],
#  [8256],
#  [8701],
#  [4440],
#  [683],
#  [335],
#  [8374],
#  [1835],
#  [335],
#  [1126],
#  [8798],
#  [335],
#  [1509],
#  [8824],
#  [6724],
#  [8824],
#  [8798],
#  [2783],
#  [8824],
#  [916],
#  [99],
#  [8824],
#  [335],
#  [8798],
#  [7226],
#  [8798],
#  [7672],
#  [5540],
#  [6948],
#  [1126],
#  [8824],
#  [2304],
#  [2783],
#  [2304],
#  [4207],
#  [7226],
#  [6915],
#  [897],
#  [8824],
#  [8625],
#  [8824],
#  [1986],
#  [8784],
#  [2783],
#  [6915],
#  [469],
#  [1656],
#  [2783],
#  [1473],
#  [3575],
#  [335],
#  [8561],
#  [8561],
#  [1446],
#  [1066],
#  [469],
#  [1126],
#  [46],
#  [2783],
#  [7218],
#  [2387],
#  [2783],
#  [7218],
#  [6915],
#  [7218],
#  [7218],
#  [2783],
#  [6693],
#  [1066],
#  [1066],
#  [3808],
#  [3960],
#  [181],
#  [2783],
#  [5256],
#  [4820],
#  [3960],
#  [7218],
#  [5639],
#  [245],
#  [2783],
#  [8784],
#  [8046],
#  [2783],
#  [335],
#  [6363],
#  [335],
#  [335],
#  [335],
#  [335],
#  [335],
#  [8824],
#  [2783],
#  [5772],
#  [2783],
#  [1126],
#  [1126],
#  [7226],
#  [4697],
#  [335],
#  [8824],
#  [8824],
#  [8824],
#  [335],
#  [1550],
#  [1008],
#  [5923],
#  [1126],
#  [1509],
#  [991],
#  [3510],
#  [195],
#  [4141],
#  [8247],
#  [900],
#  [205],
#  [1872],
#  [1883],
#  [8263],
#  [3843],
#  [205],
#  [6817],
#  [205],
#  [1961],
#  [205],
#  [2596],
#  [1986],
#  [7226],
#  [2596],
#  [7168],
#  [5462],
#  [1446],
#  [4998],
#  [1565],
#  [335],
#  [1446],
#  [8824],
#  [8766],
#  [6293],
#  [557],
#  [1126],
#  [3327],
#  [2783],
#  [1473],
#  [4236],
#  [3808],
#  [8824],
#  [4236],
#  [1249],
#  [335],
#  [4207],
#  [1126],
#  [335],
#  [1509],
#  [8824],
#  [8824],
#  [7914],
#  [8824],
#  [8806],
#  [7226],
#  [6275],
#  [4207],
#  [4470],
#  [5052],
#  [2183],
#  [3178],
#  [4169],
#  [3226],
#  [3125],
#  [8824],
#  [5052],
#  [1008],
#  [6693],
#  [8824],
#  [1008],
#  [1008],
#  [335],
#  [2783],
#  [8824],
#  [7896],
#  [6279],
#  [7267],
#  [2783],
#  [4207],
#  [6915],
#  [4207],
#  [4169],
#  [2783],
#  [8824],
#  [7138],
#  [6693],
#  [1069],
#  [3687],
#  [1656],
#  [6884],
#  [4207],
#  [7226],
#  [4207],
#  [4418],
#  [7226],
#  [335],
#  [1750],
#  [959],
#  [8824],
#  [7917],
#  [7917],
#  [3462],
#  [8824],
#  [4400],
#  [8824],
#  [1126],
#  [2309],
#  [8824],
#  [1497],
#  [8824],
#  [3808],
#  [3808],
#  [4470],
#  [6443],
#  [6915],
#  [4207],
#  [6915],
#  [8824],
#  [7666],
#  [5042],
#  [2783],
#  [1473],
#  [8824],
#  [7732],
#  [6915],
#  [3866],
#  [4920],
#  [677],
#  [2896],
#  [335],
#  [7226],
#  [6334],
#  [8824],
#  [3327],
#  [1126],
#  [1550],
#  [1870],
#  [5546],
#  [1126],
#  [5456],
#  [2304],
#  [1126],
#  [1634],
#  [8479],
#  [4207],
#  [335],
#  [1126],
#  [2635],
#  [2783],
#  [2681],
#  [2783],
#  [4207],
#  [6915],
#  [3347],
#  [2783],
#  [1509],
#  [8061],
#  [4418],
#  [636],
#  [495],
#  [5546],
#  [4207],
#  [4877],
#  [677],
#  [335],
#  [1126],
#  [8824],
#  [1656],
#  [4566],
#  [6915],
#  [4207],
#  [356],
#  [1509],
#  [1995],
#  [1509],
#  [1810],
#  [6693],
#  [1509],
#  [6693],
#  [1509],
#  [2276],
#  [8592],
#  [7138],
#  [2783],
#  [8784],
#  [8824],
#  [1509],
#  [3808],
#  [335],
#  [5416],
#  [335],
#  [4580],
#  [335],
#  [2783],
#  [8824],
#  [1550],
#  [3808],
#  [1249],
#  [1473],
#  [1550],
#  [1550],
#  [6915],
#  [4877],
#  [99],
#  [104],
#  [8824],
#  [3277],
#  [335],
#  [335],
#  [335],
#  [335],
#  [335],
#  [335],
#  [335],
#  [8824],
#  [8824],
#  [8824],
#  [2783],
#  [2783],
#  [2783],
#  [4696],
#  [6915],
#  [837],
#  [1126],
#  [2783],
#  [2596],
#  [6915],
#  [6915],
#  [2783],
#  [2783],
#  [6621],
#  [4455],
#  [1126],
#  [4470],
#  [8824],
#  [8824],
#  [335],
#  [5052],
#  [1008],
#  [5052],
#  [4207],
#  [5772],
#  [1968],
#  [2783],
#  [8824],
#  [6899],
#  [6948],
#  [3125],
#  [1935],
#  [8824],
#  [8824],
#  [8824],
#  [8448],
#  [5052],
#  [5052],
#  [4207],
#  [2783],
#  [4099],
#  [1126],
#  [2227],
#  [3302],
#  [7562],
#  [3229],
#  [4207],
#  [1231],
#  [8824],
#  [8824],
#  [8824],
#  [1231],
#  [3229],
#  [6915],
#  [6915],
#  [3219],
#  [335],
#  [8824],
#  [486],
#  [4207],
#  [1126],
#  [1249],
#  [3327],
#  [900],
#  [1126],
#  [6915],
#  [99],
#  [4207],
#  [4207],
#  [4207],
#  [335],
#  [8500],
#  [8824],
#  [8824],
#  [8824],
#  [6948],
#  [973],
#  [4400],
#  [4207],
#  [1258],
#  [335],
#  [7226],
#  [4207],
#  [8824],
#  [6948],
#  [1750],
#  [4877],
#  [4207],
#  [7955],
#  [4207],
#  [2783],
#  [5750],
#  [1986],
#  [1935],
#  [2783],
#  [2105],
#  [4470],
#  [8247],
#  [335],
#  [6915],
#  [2304],
#  [8824],
#  [2783],
#  [8824],
#  [4846],
#  [6033],
#  [3083],
#  [335],
#  [8824],
#  [1066],
#  [8824],
#  [1550],
#  [6629],
#  [1258],
#  [335],
#  [335],
#  [7929],
#  [6915],
#  [8824],
#  [2783],
#  [6693],
#  [6693],
#  [335],
#  [8046],
#  [5772],
#  [677],
#  [8824],
#  ...]

# %%
sorted_clean_answers
# Out:
# [[3770,
#   1837,
#   2247,
#   4522,
#   104,
#   7787,
#   6859,
#   3770,
#   6127,
#   2826,
#   6419,
#   3317,
#   8824,
#   7363,
#   2826,
#   5803,
#   8605,
#   7302,
#   104,
#   1161,
#   3647,
#   5389,
#   2043,
#   7835,
#   8823],
#  [8824,
#   3918,
#   2043,
#   876,
#   4115,
#   90,
#   1509,
#   3239,
#   99,
#   2043,
#   4010,
#   5956,
#   8016,
#   6418,
#   3852,
#   5569,
#   3686,
#   5750,
#   2043,
#   8232,
#   3702,
#   2826,
#   3852,
#   7718,
#   7701,
#   8823],
#  [3327, 8823],
#  [6874, 5750, 753, 8708, 2862, 3375, 3125, 8823],
#  [2596, 6139, 2536, 2183, 236, 8823],
#  [6693, 2596, 6671, 992, 26, 4115, 4737, 636, 4115, 3121, 8823],
#  [7343, 4500, 8823],
#  [2596, 6225, 8021, 1731, 4196, 3852, 8823],
#  [7087, 8823],
#  [4829, 2596, 4992, 2093, 1750, 6419, 8326, 4522, 8823],
#  [8605,
#   5729,
#   6862,
#   104,
#   719,
#   8232,
#   6419,
#   1249,
#   8571,
#   6859,
#   3190,
#   3770,
#   8824,
#   2011,
#   8500,
#   7159,
#   8823],
#  [5317, 8824, 556, 6419, 7017, 8823],
#  [1224, 5569, 5750, 6419, 1210, 936, 8823],
#  [3629,
#   4440,
#   104,
#   3011,
#   104,
#   4829,
#   3866,
#   6459,
#   5885,
#   3686,
#   3903,
#   8593,
#   5524,
#   5569,
#   5090,
#   3852,
#   1473,
#   104,
#   4784,
#   4995,
#   7006,
#   556,
#   8824,
#   1675,
#   1473,
#   8605,
#   8824,
#   8824,
#   5024,
#   8823],
#  [3903, 2043, 4566, 8579, 1208, 1693, 8823],
#  [8824,
#   3516,
#   3481,
#   3039,
#   7633,
#   1821,
#   3770,
#   4953,
#   3481,
#   1009,
#   4230,
#   1473,
#   8824,
#   8823],
#  [4969, 3623, 8823],
#  [6418, 4500, 4969, 6241, 8823],
#  [7584, 7302, 4235, 8823],
#  [2783, 6459, 2596, 1731, 8823],
#  [6419, 6456, 1648, 6419, 3647, 8823],
#  [6671, 2596, 4921, 8823],
#  [2965, 1224, 2197, 1750, 4115, 2690, 6465, 4235, 8823],
#  [104, 7787, 4696, 104, 7787, 8823],
#  [3903,
#   6418,
#   104,
#   4829,
#   719,
#   4115,
#   5464,
#   7314,
#   2862,
#   3516,
#   7226,
#   5750,
#   1750,
#   8823],
#  [8824, 8823],
#  [104, 7529, 6465, 8823],
#  [7446, 2596, 5317, 5098, 8823],
#  [6915, 2596, 3707, 8823],
#  [5869, 8823],
#  [6915,
#   3461,
#   1446,
#   2596,
#   6671,
#   7302,
#   2247,
#   3182,
#   104,
#   8020,
#   8593,
#   2688,
#   6241,
#   1473,
#   5557,
#   1446,
#   8823],
#  [8824, 8823],
#  [8824, 104, 4401, 2817, 1569, 4584, 6241, 5051, 5317, 6419, 7746, 8823],
#  [104,
#   4713,
#   5750,
#   4115,
#   6459,
#   2783,
#   6884,
#   4461,
#   6418,
#   5456,
#   4461,
#   3852,
#   5557,
#   3770,
#   245,
#   1473,
#   5456,
#   4969,
#   6044,
#   99,
#   2596,
#   6714,
#   8823],
#  [2596, 3866, 6044, 1750, 8823],
#  [3770, 52, 8823],
#  [104, 8020, 3770, 4472, 8824, 6419, 3121, 8823],
#  [6915, 3481, 5524, 1729, 8823],
#  [6915, 2783, 8823],
#  [4440,
#   2247,
#   3327,
#   104,
#   5569,
#   6411,
#   7159,
#   2043,
#   4829,
#   3866,
#   8711,
#   4838,
#   8605,
#   142,
#   8141,
#   104,
#   2269,
#   7084,
#   6241,
#   104,
#   1759,
#   5317,
#   5098,
#   104,
#   4713,
#   8020,
#   8824,
#   8824,
#   1473,
#   104,
#   719,
#   3866,
#   5348,
#   7084,
#   6419,
#   1532,
#   6489,
#   104,
#   6835,
#   6419,
#   7159,
#   5623,
#   8500,
#   4115,
#   8605,
#   5095,
#   6269,
#   3770,
#   6176,
#   7193,
#   8110,
#   2826,
#   3564,
#   4397,
#   2826,
#   1941,
#   8823],
#  [6915, 104, 480, 8824, 940, 2247, 3770, 4341, 876, 8131, 1086, 8823],
#  [3302, 7320, 2596, 6419, 5946, 8823],
#  [1881, 6419, 5946, 3745, 8823],
#  [4455,
#   3770,
#   8427,
#   3852,
#   2247,
#   2596,
#   6671,
#   5336,
#   3838,
#   5574,
#   4115,
#   7418,
#   8823],
#  [1249, 996, 8823],
#  [2596, 6671, 6057, 4678, 8823],
#  [3838, 3370, 90, 6419, 1663, 4115, 4440, 4953, 2539, 8823],
#  [6915, 8823],
#  [6347,
#   104,
#   719,
#   6073,
#   3745,
#   3402,
#   4899,
#   3745,
#   3694,
#   4769,
#   2596,
#   4461,
#   1750,
#   4115,
#   1338,
#   5557,
#   3770,
#   6950,
#   8297,
#   2596,
#   1338,
#   3770,
#   8824,
#   6915,
#   104,
#   4566,
#   6057,
#   90,
#   7584,
#   8824,
#   8823],
#  [1126, 8823],
#  [3074,
#   5557,
#   2826,
#   2282,
#   2596,
#   5557,
#   2407,
#   2160,
#   3915,
#   7910,
#   6269,
#   2783,
#   2596,
#   3866,
#   8340,
#   3770,
#   8767,
#   2826,
#   7584,
#   8824,
#   4500,
#   3623,
#   8781,
#   2862,
#   2783,
#   3770,
#   8369,
#   2247,
#   4196,
#   1473,
#   6418,
#   282,
#   1750,
#   7701,
#   104,
#   5205,
#   2124,
#   6774,
#   8823],
#  [6459,
#   2596,
#   4439,
#   4838,
#   104,
#   719,
#   2536,
#   5317,
#   4610,
#   8603,
#   8824,
#   8824,
#   8403,
#   8193,
#   1995,
#   6859,
#   7584,
#   1301,
#   104,
#   8403,
#   1338,
#   6419,
#   8824,
#   104,
#   4500,
#   2036,
#   4150,
#   8823],
#  [2783, 4196, 7099, 6282, 8823],
#  [3852, 5569, 8605, 871, 6057, 3664, 8823],
#  [1695, 6859, 6548, 8823],
#  [1327, 2596, 8021, 4500, 4115, 8060, 8016, 4235, 2120, 2813, 2788, 8823],
#  [7428, 2596, 282, 6465, 2596, 7428, 8823],
#  [1914, 8823],
#  [1634,
#   2596,
#   4713,
#   477,
#   4196,
#   4440,
#   2758,
#   8824,
#   573,
#   104,
#   719,
#   6961,
#   5317,
#   6179,
#   8823],
#  [2783, 4829, 7584, 3574, 1731, 2826, 4440, 8823],
#  [8431, 8823],
#  [8431, 8823],
#  [8431, 8823],
#  [6693, 8823],
#  [2304, 4440, 2247, 5923, 8823],
#  [104,
#   8744,
#   8193,
#   4566,
#   4447,
#   2596,
#   4566,
#   90,
#   5923,
#   2596,
#   4566,
#   90,
#   4696,
#   4500,
#   8714,
#   3686,
#   1991,
#   4440,
#   7776,
#   3686,
#   5017,
#   2036,
#   3770,
#   8824,
#   1473,
#   1991,
#   2596,
#   6671,
#   2995,
#   4115,
#   1750,
#   8823],
#  [2596, 8744, 8823],
#  [1719, 2596, 7261, 1249, 7987, 8823],
#  [4478, 1208, 2862, 2826, 8605, 8006, 8823],
#  [3462, 5496, 3180, 3718, 6269, 5710, 8823],
#  [3800, 5750, 8824, 2126, 2672, 8823],
#  [104, 7787, 8824, 2596, 719, 2643, 6664, 6489, 6419, 790, 6489, 8823],
#  [335,
#   7227,
#   8193,
#   5490,
#   5317,
#   3770,
#   8500,
#   8329,
#   104,
#   4702,
#   8824,
#   6269,
#   3852,
#   1473,
#   8605,
#   4813,
#   2247,
#   657,
#   4115,
#   7267,
#   6131,
#   4147,
#   8824,
#   8824,
#   8823],
#  [6915, 2596, 6671, 3770, 5359, 2596, 6671, 890, 104, 7787, 1800, 8824, 8823],
#  [8824, 8824, 8823],
#  [2783, 6671, 2596, 5090, 4235, 8823],
#  [6567, 2596, 719, 8232, 1136, 1550, 8823],
#  [4713, 6190, 7584, 8824, 8823],
#  [4440, 2247, 1126, 1224, 5569, 4877, 6441, 1224, 5569, 3146, 3180, 8823],
#  [3838,
#   5569,
#   6419,
#   7953,
#   104,
#   1731,
#   2043,
#   6366,
#   4115,
#   4447,
#   4115,
#   3180,
#   2043,
#   7973,
#   4076,
#   8784,
#   3092,
#   8784,
#   6347,
#   8823],
#  [1634, 2596, 5205, 90, 3664, 8824, 8823],
#  [104,
#   7787,
#   798,
#   104,
#   719,
#   4349,
#   8232,
#   6419,
#   8024,
#   1910,
#   1446,
#   104,
#   4829,
#   205,
#   4115,
#   8823],
#  [2043, 2247, 2470, 8823],
#  [2304,
#   104,
#   6824,
#   5456,
#   719,
#   2536,
#   6382,
#   6419,
#   4469,
#   2826,
#   8225,
#   7084,
#   6334,
#   2826,
#   3770,
#   3385,
#   8823],
#  [636, 7428, 5456, 7438, 4115, 6459, 4440, 3182, 1072, 6520, 8823],
#  [104,
#   7787,
#   6948,
#   2212,
#   8824,
#   1446,
#   104,
#   7787,
#   1509,
#   6057,
#   6859,
#   4830,
#   4115,
#   2442,
#   2183,
#   8823],
#  [8193, 6671, 2096, 4115, 4969, 3838, 104, 6817, 8193, 5205, 8823],
#  [6693, 3718, 6269, 8748, 8823],
#  [2304,
#   104,
#   8232,
#   3770,
#   5520,
#   6269,
#   8605,
#   5584,
#   8824,
#   4115,
#   8824,
#   522,
#   6543,
#   7227,
#   8193,
#   5780,
#   8823],
#  [335, 8823],
#  [7100,
#   104,
#   3494,
#   4120,
#   3770,
#   2493,
#   2888,
#   6859,
#   21,
#   163,
#   1473,
#   5557,
#   5456,
#   8403,
#   282,
#   1750,
#   5569,
#   4440,
#   5456,
#   4829,
#   8664,
#   3770,
#   8824,
#   8824,
#   556,
#   3770,
#   4953,
#   6476,
#   1446,
#   6057,
#   6863,
#   1473,
#   6638,
#   6057,
#   1874,
#   2758,
#   8823],
#  [335,
#   2596,
#   3370,
#   719,
#   1000,
#   3770,
#   8824,
#   4440,
#   7533,
#   7666,
#   4365,
#   8824,
#   8824,
#   8823],
#  [3686,
#   5550,
#   1676,
#   1989,
#   8824,
#   5456,
#   6225,
#   4478,
#   7701,
#   2434,
#   3180,
#   1446,
#   5456,
#   4829,
#   3866,
#   4478,
#   5885,
#   2434,
#   1676,
#   8823],
#  [335, 8823],
#  [335,
#   104,
#   1683,
#   2596,
#   6331,
#   3852,
#   104,
#   8232,
#   6863,
#   4196,
#   3770,
#   206,
#   245,
#   8823],
#  [7428, 5456, 719, 1072, 809, 556, 2183, 8823],
#  [2304, 2783, 2247, 3852, 8823],
#  [2304, 1989, 7190, 1446, 1013, 2596, 1138, 4115, 1126, 4713, 2596, 8823],
#  [1569, 2596, 1509, 4713, 480, 3852, 6459, 2596, 8823],
#  [2304,
#   3770,
#   4349,
#   2139,
#   8824,
#   2826,
#   3770,
#   21,
#   6671,
#   3327,
#   6671,
#   8193,
#   657,
#   2783,
#   4566,
#   8193,
#   6459,
#   99,
#   8193,
#   4969,
#   3838,
#   99,
#   6671,
#   8193,
#   4200,
#   7099,
#   1473,
#   1126,
#   6671,
#   8193,
#   657,
#   8823],
#  [335,
#   2304,
#   556,
#   3481,
#   1837,
#   6584,
#   2596,
#   6468,
#   3770,
#   1389,
#   5557,
#   2596,
#   5205,
#   4969,
#   2247,
#   6419,
#   2111,
#   768,
#   8824,
#   4440,
#   3770,
#   6468,
#   1127,
#   6671,
#   4398,
#   2862,
#   2826,
#   2637,
#   8823],
#  [3577,
#   221,
#   8193,
#   719,
#   6961,
#   6334,
#   8806,
#   2736,
#   6402,
#   3604,
#   4440,
#   6419,
#   3577,
#   7163,
#   8824,
#   4584,
#   1944,
#   2862,
#   6859,
#   8824,
#   7701,
#   8824,
#   2826,
#   7871,
#   3393,
#   3902,
#   2247,
#   2183,
#   5317,
#   2611,
#   2783,
#   4584,
#   2385,
#   8823],
#  [7902, 7643, 245, 2247, 8824, 2962, 2247, 4440, 6725, 8823],
#  [1676, 670, 5557, 6764, 7644, 4594, 8823],
#  [104, 1138, 4115, 5335, 2160, 8605, 1450, 8823],
#  [8824, 8823],
#  [1291, 8823],
#  [1634, 2596, 1968, 719, 6419, 8247, 3909, 8823],
#  [104, 5205, 7985, 8202, 1446, 2596, 5759, 4969, 1750, 1456, 4235, 4389, 8823],
#  [1989, 3770, 4349, 8006, 2596, 6671, 992, 4969, 8202, 8823],
#  [3852, 6874, 5750, 2596, 4259, 3852, 2388, 3481, 2826, 3770, 6121, 8823],
#  [1989,
#   6419,
#   3402,
#   8571,
#   8824,
#   876,
#   4115,
#   2831,
#   8125,
#   4235,
#   6419,
#   8024,
#   4587,
#   7099,
#   104,
#   1000,
#   6465,
#   4447,
#   4196,
#   3852,
#   8823],
#  [3370, 90, 508, 6489, 8823],
#  [1824, 8232, 6334, 8824, 8824, 8823],
#  [8824, 6269, 3770, 2283, 8823],
#  [2304, 2596, 8232, 4115, 3413, 8193, 3718, 6419, 3402, 8006, 8823],
#  [6915,
#   8225,
#   2657,
#   1446,
#   2124,
#   6824,
#   104,
#   6169,
#   6419,
#   3320,
#   3327,
#   4829,
#   2596,
#   4969,
#   3770,
#   3309,
#   4440,
#   2596,
#   8403,
#   2071,
#   1750,
#   8823],
#  [8824, 8824, 2596, 6005, 8824, 7584, 1712, 8823],
#  [4207, 8823],
#  [6516,
#   6057,
#   4115,
#   4969,
#   7584,
#   7702,
#   8571,
#   4115,
#   202,
#   8193,
#   8232,
#   996,
#   7955,
#   4487,
#   6269,
#   2183,
#   3481,
#   8823],
#  [1446,
#   4440,
#   2247,
#   2783,
#   2596,
#   7418,
#   4196,
#   5557,
#   2826,
#   3180,
#   5557,
#   3770,
#   8824,
#   8193,
#   6671,
#   6139,
#   3770,
#   7416,
#   95,
#   2160,
#   99,
#   2596,
#   282,
#   3852,
#   8823],
#  [1008, 1989, 1750, 8823],
#  [3471, 2160, 8823],
#  [2783, 6459, 2596, 1138, 8823],
#  [104, 1161, 4969, 3852, 5389, 6522, 3073, 8823],
#  [6859, 7584, 7990, 8823],
#  [3770, 4974, 2473, 3770, 61, 3190, 7584, 2757, 8823],
#  [5052, 8824, 7612, 4235, 8823],
#  [5052, 8824, 7787, 1335, 5557, 4577, 4235, 8823],
#  [2596,
#   6671,
#   6057,
#   4440,
#   2105,
#   3718,
#   6269,
#   8193,
#   4566,
#   4969,
#   2596,
#   4115,
#   6419,
#   5088,
#   8823],
#  [2596, 6671, 3770, 8824, 8824, 104, 8020, 5317, 2183, 116, 8824, 8823],
#  [719, 2596, 2985, 2813, 6605, 8823],
#  [2596, 3513, 8824, 8824, 8823],
#  [4713,
#   2596,
#   403,
#   5550,
#   1750,
#   556,
#   5596,
#   1837,
#   5317,
#   8605,
#   6435,
#   6629,
#   2596,
#   719,
#   3249,
#   7584,
#   7352,
#   162,
#   7084,
#   7584,
#   2529,
#   8824,
#   8823],
#  [7835, 3852, 4969, 1072, 1968, 7718, 1066, 8823],
#  [2783, 2247, 3852, 8823],
#  [104, 6824, 4440, 2184, 1008, 8823],
#  [8784, 8207, 8823],
#  [6057, 3694, 4115, 8781, 8824, 5543, 3770, 4007, 8823],
#  [677, 1446, 205, 7147, 3770, 8680, 3596, 4235, 3202, 7177, 8823],
#  [8824, 8823],
#  [5811, 6459, 2596, 8020, 636, 8193, 7418, 2120, 205, 8823],
#  [8824, 8823],
#  [1446,
#   104,
#   4713,
#   8020,
#   205,
#   104,
#   7787,
#   5750,
#   6419,
#   429,
#   7771,
#   4115,
#   912,
#   4953,
#   6132,
#   6919,
#   1446,
#   3866,
#   4115,
#   719,
#   3481,
#   2826,
#   8605,
#   2529,
#   8823],
#  [2596,
#   8020,
#   2596,
#   8403,
#   1627,
#   2817,
#   7084,
#   2183,
#   8824,
#   1837,
#   1989,
#   6057,
#   6736,
#   8823],
#  [2596, 6671, 6493, 8823],
#  [495, 7718, 1560, 8823],
#  [8605,
#   772,
#   6338,
#   6697,
#   2247,
#   8625,
#   4389,
#   5550,
#   4237,
#   7261,
#   104,
#   4713,
#   5750,
#   8824,
#   4871,
#   8823],
#  [4115, 7467, 8824, 8823],
#  [7123, 1989, 1750, 2124, 8806, 3378, 8823],
#  [3852,
#   4584,
#   4115,
#   90,
#   2183,
#   8006,
#   556,
#   4769,
#   3852,
#   4566,
#   6057,
#   90,
#   3402,
#   8823],
#  [2783, 5569, 104, 3591, 4115, 1731, 2385, 4115, 2282, 8823],
#  [2043, 2247, 5557, 104, 719, 8232, 2043, 2247, 3770, 4349, 6958, 8823],
#  [2783, 2596, 1719, 2247, 2783, 104, 8232, 2344, 8823],
#  [104, 7787, 6287, 2596, 8823],
#  [8280, 1729, 5885, 8823],
#  [1013, 1989, 6057, 6465, 2240, 6915, 6118, 8823],
#  [3327, 6671, 3770, 7206, 8823],
#  [4389, 753, 4389, 2596, 6225, 1138, 4115, 7862, 2183, 6338, 8255, 8823],
#  [4207, 5216, 2183, 8823],
#  [104, 8020, 2783, 2596, 7428, 8823],
#  [636, 7970, 7428, 1224, 6531, 2596, 8823],
#  [3903, 8193, 6671, 657, 3838, 8823],
#  [2304,
#   3891,
#   3770,
#   6118,
#   1331,
#   2183,
#   1837,
#   104,
#   7787,
#   6269,
#   1550,
#   4769,
#   4584,
#   7701,
#   4115,
#   6459,
#   7084,
#   804,
#   8824,
#   3426,
#   4440,
#   2247,
#   35,
#   187,
#   3770,
#   5840,
#   8824,
#   8823],
#  [3185, 2160, 1040, 7584, 2075, 2550, 3375, 8823],
#  [3327, 6671, 7584, 2601, 8823],
#  [7226, 2247, 2183, 5317, 3770, 5211, 7226, 2247, 1224, 8823],
#  [4459,
#   4440,
#   2247,
#   3327,
#   1224,
#   4010,
#   3664,
#   2136,
#   5897,
#   1224,
#   5569,
#   6419,
#   1249,
#   7882,
#   8824,
#   1095,
#   7871,
#   8824,
#   1446,
#   4440,
#   5569,
#   7701,
#   1224,
#   8824,
#   1224,
#   6366,
#   4115,
#   90,
#   8824,
#   8823],
#  [1013,
#   2596,
#   7446,
#   4115,
#   7245,
#   3852,
#   2596,
#   4829,
#   1719,
#   3770,
#   1367,
#   7113,
#   1693,
#   2596,
#   4829,
#   1719,
#   3770,
#   7235,
#   5456,
#   5205,
#   1552,
#   8823],
#  [8605, 3627, 3866, 4980, 7084, 973, 5604, 1887, 6057, 510, 8823],
#  [104, 7787, 4235, 8823],
#  [2585,
#   3852,
#   4115,
#   1750,
#   5640,
#   3770,
#   1174,
#   2888,
#   5750,
#   8193,
#   2181,
#   6915,
#   4505,
#   4988,
#   2596,
#   625,
#   2183,
#   2160,
#   5557,
#   4147,
#   2813,
#   8823],
#  [7914, 966, 7072, 8255, 4235, 8823],
#  [3808,
#   7914,
#   8824,
#   8605,
#   3019,
#   7964,
#   7366,
#   104,
#   7787,
#   6419,
#   4382,
#   8824,
#   8522,
#   8823],
#  [2304,
#   104,
#   7787,
#   1457,
#   2160,
#   6269,
#   7584,
#   2503,
#   1030,
#   4926,
#   8104,
#   3347,
#   5206,
#   6456,
#   8501,
#   519,
#   4549,
#   4986,
#   1422,
#   1671,
#   6214,
#   1278,
#   7698,
#   8824,
#   5770,
#   7388,
#   8824,
#   8824,
#   6419,
#   8824,
#   4440,
#   2247,
#   636,
#   2043,
#   2247,
#   8541,
#   2247,
#   2183,
#   6397,
#   6042,
#   8823],
#  [2043, 3686, 1029, 5756, 8823],
#  [2298, 4692, 8824, 4196, 6419, 7159, 3629, 1030, 835, 8823],
#  [2596, 2960, 90, 8823],
#  [1989,
#   6057,
#   1509,
#   8605,
#   1301,
#   1446,
#   1989,
#   6057,
#   1420,
#   556,
#   1750,
#   4115,
#   2407,
#   1709,
#   3770,
#   4657,
#   5264,
#   4081,
#   2826,
#   1750,
#   2758,
#   1719,
#   104,
#   8020,
#   6419,
#   3513,
#   4196,
#   5770,
#   1812,
#   99,
#   1136,
#   2349,
#   5456,
#   989,
#   6139,
#   8340,
#   6419,
#   8019,
#   1989,
#   46,
#   5456,
#   1138,
#   4115,
#   7418,
#   6621,
#   8823],
#  [7914,
#   8824,
#   1989,
#   7964,
#   6459,
#   2596,
#   1683,
#   104,
#   5569,
#   3838,
#   6419,
#   8024,
#   6543,
#   1698,
#   5778,
#   4196,
#   7584,
#   2503,
#   8823],
#  [1224,
#   8539,
#   6241,
#   8824,
#   1224,
#   1053,
#   8824,
#   1623,
#   6241,
#   2160,
#   7084,
#   8824,
#   8823],
#  [3770, 7413, 2596, 1161, 1719, 2813, 5317, 3852, 8823],
#  [2596, 6671, 3664, 7302, 1550, 8823],
#  [3852,
#   8414,
#   2388,
#   6419,
#   1536,
#   2826,
#   2601,
#   5223,
#   4115,
#   1309,
#   5456,
#   6734,
#   6465,
#   8748,
#   8824,
#   6465,
#   150,
#   8823],
#  [2783, 8823],
#  [99, 593, 8824, 8824, 5750, 3362, 1989, 8824, 8823],
#  [3718, 6269, 66, 1224, 4566, 6057, 1627, 2596, 1224, 394, 3180, 1339, 8823],
#  [1989,
#   3770,
#   558,
#   2596,
#   719,
#   2536,
#   4605,
#   2160,
#   556,
#   104,
#   6366,
#   2596,
#   4115,
#   719,
#   3852,
#   556,
#   7584,
#   378,
#   8823],
#  [8806, 124, 8823],
#  [4995, 99, 6671, 2596, 2556, 6419, 4272, 8824, 8823],
#  [104, 719, 8232, 4115, 4500, 8823],
#  [6322, 8193, 719, 8232, 4115, 4969, 4115, 4506, 7227, 1989, 3745, 916, 8823],
#  [8784,
#   1224,
#   5569,
#   2183,
#   4435,
#   2011,
#   104,
#   7267,
#   4196,
#   7226,
#   5750,
#   3249,
#   3664,
#   1136,
#   7548,
#   5456,
#   5782,
#   1138,
#   4115,
#   2349,
#   3770,
#   6830,
#   3770,
#   8006,
#   1224,
#   3328,
#   5456,
#   2960,
#   8823],
#  [4440,
#   2184,
#   5456,
#   6671,
#   992,
#   4256,
#   1750,
#   3770,
#   6002,
#   4115,
#   3770,
#   8063,
#   4877,
#   104,
#   5205,
#   5767,
#   2160,
#   99,
#   104,
#   7787,
#   8042,
#   8823],
#  [6457, 8823],
#  [104,
#   7787,
#   6057,
#   2900,
#   104,
#   4364,
#   8824,
#   6419,
#   1536,
#   1473,
#   1013,
#   1634,
#   3686,
#   1634,
#   2817,
#   7718,
#   6334,
#   1837,
#   3249,
#   6241,
#   104,
#   4829,
#   5750,
#   4115,
#   4701,
#   4196,
#   3336,
#   8823],
#  [768, 2247, 3770, 3481, 8193, 719, 4115, 4928, 4196, 8823],
#  [4877, 5456, 1612, 2160, 7084, 2596, 3745, 8823],
#  [104, 6225, 719, 6419, 8592, 5750, 8824, 8823],
#  [4877,
#   5557,
#   2826,
#   6419,
#   8096,
#   3664,
#   4349,
#   8592,
#   5180,
#   2862,
#   2826,
#   8016,
#   90,
#   8824,
#   3901,
#   1900,
#   5750,
#   6419,
#   8824,
#   6419,
#   4978,
#   8824,
#   8824,
#   1473,
#   8824,
#   8824,
#   3770,
#   8028,
#   8824,
#   8606,
#   3770,
#   1940,
#   8824,
#   420,
#   3770,
#   8824,
#   8824,
#   8824,
#   8824,
#   8823],
#  [7810,
#   5750,
#   3336,
#   3080,
#   3784,
#   2434,
#   6419,
#   410,
#   8824,
#   2480,
#   8824,
#   6613,
#   1473,
#   8824,
#   3481,
#   8824,
#   8824,
#   8823],
#  [8824,
#   1473,
#   104,
#   5205,
#   1338,
#   3770,
#   5667,
#   8748,
#   8824,
#   3852,
#   7666,
#   3770,
#   3571,
#   1473,
#   8823],
#  [6975, 4701, 4440, 8823],
#  [104, 7787, 7084, 8824, 8823],
#  [4440,
#   2247,
#   2470,
#   8824,
#   8824,
#   8590,
#   5456,
#   5205,
#   2444,
#   3770,
#   1277,
#   6362,
#   4877,
#   8193,
#   5205,
#   4812,
#   8824,
#   8824,
#   8823],
#  [1989,
#   6618,
#   104,
#   8403,
#   8824,
#   3481,
#   2826,
#   3770,
#   4063,
#   6150,
#   268,
#   4115,
#   3770,
#   8824,
#   4877,
#   3852,
#   4829,
#   8824,
#   6269,
#   3770,
#   8824,
#   99,
#   1224,
#   6289,
#   2434,
#   3770,
#   1039,
#   8823],
#  [3852, 4566, 90, 5557, 1550, 8193, 6671, 8715, 8824, 8823],
#  [1013,
#   8193,
#   8403,
#   4969,
#   6634,
#   3770,
#   8824,
#   1202,
#   7902,
#   8824,
#   1634,
#   8193,
#   8403,
#   1623,
#   3770,
#   1277,
#   1796,
#   8823],
#  [7584, 2998, 5569, 4115, 8544, 3327, 1224, 2467, 8823],
#  [104,
#   719,
#   8824,
#   2596,
#   4115,
#   4505,
#   7084,
#   1750,
#   6546,
#   7084,
#   2822,
#   4953,
#   8824,
#   556,
#   7245,
#   8193,
#   4566,
#   3732,
#   2596,
#   1473,
#   3770,
#   1727,
#   84,
#   8824,
#   8824,
#   4115,
#   8824,
#   5317,
#   7902,
#   8824,
#   8823],
#  [4386, 6225, 90, 6419, 8824, 8824, 8823],
#  [7289, 6378, 3770, 7026, 7405, 7226, 8232, 8571, 6698, 1053, 6465, 8823],
#  [2596, 8020, 2657, 8824, 3770, 5150, 104, 8437, 7084, 8823],
#  [1224,
#   1824,
#   3528,
#   2862,
#   5456,
#   6961,
#   4115,
#   4969,
#   2010,
#   2826,
#   6465,
#   1473,
#   2657,
#   4566,
#   4969,
#   4895,
#   8823],
#  [4696, 104, 4566, 26, 6419, 8824, 8824, 2596, 5205, 6796, 3852, 8823],
#  [2596,
#   6225,
#   90,
#   1968,
#   2388,
#   4062,
#   1095,
#   2304,
#   1095,
#   8824,
#   4115,
#   3686,
#   4500,
#   556,
#   3770,
#   8823],
#  [2596, 6225, 6057, 4711, 3852, 8823],
#  [2596,
#   8432,
#   2783,
#   104,
#   7787,
#   2421,
#   104,
#   1138,
#   6419,
#   4620,
#   6419,
#   7955,
#   3481,
#   6057,
#   6419,
#   7238,
#   7718,
#   8824,
#   8823],
#  [8824, 4147, 3770, 195, 51, 8823],
#  [2871,
#   2763,
#   8824,
#   4115,
#   3718,
#   2862,
#   2826,
#   2446,
#   4258,
#   4995,
#   1345,
#   8824,
#   8823],
#  [5456, 2784, 8823],
#  [3770,
#   4349,
#   3608,
#   2480,
#   1750,
#   1473,
#   4440,
#   8824,
#   6269,
#   8261,
#   2247,
#   7987,
#   8272,
#   7987,
#   8823],
#  [2183, 8006, 8823],
#  [3327, 4829, 2596, 4969, 3770, 7471, 8823],
#  [5425, 6465, 6459, 3852, 8823],
#  [6378, 5772, 1095, 8427, 4566, 6057, 90, 2305, 3852, 6629, 8823],
#  [2862,
#   2826,
#   2183,
#   95,
#   6955,
#   2183,
#   6955,
#   682,
#   5169,
#   1531,
#   5317,
#   3770,
#   3996,
#   682,
#   8823],
#  [5017, 8410, 1136, 6671, 1569, 8824, 8228, 5456, 6671, 1569, 2862, 8823],
#  [6915, 2783, 8823],
#  [8358, 1126, 8823],
#  [4440, 2247, 5557, 2596, 8232, 4115, 7418, 335, 8823],
#  [2043,
#   4566,
#   6057,
#   90,
#   4235,
#   556,
#   6419,
#   143,
#   4133,
#   1731,
#   2596,
#   5205,
#   39,
#   3852,
#   4440,
#   3402,
#   8823],
#  [3327,
#   6459,
#   2596,
#   4461,
#   4115,
#   495,
#   556,
#   6241,
#   3771,
#   66,
#   7084,
#   3770,
#   4953,
#   1136,
#   7147,
#   1249,
#   996,
#   8823],
#  [104, 7787, 5664, 2596, 6671, 4235, 5205, 2596, 6169, 556, 6419, 8297, 8823],
#  [4369, 8605, 8221, 1989, 3664, 8823],
#  [2783, 6459, 2596, 1138, 6418, 8823],
#  [2596, 1161, 719, 469, 6197, 8193, 26, 6548, 6338, 4157, 8823],
#  [4696, 8823],
#  [6859,
#   3770,
#   8016,
#   2552,
#   5317,
#   3664,
#   8824,
#   2967,
#   1627,
#   6334,
#   1136,
#   104,
#   7787,
#   992,
#   357,
#   3664,
#   7702,
#   8823],
#  [104, 5040, 2596, 7116, 1000, 8823],
#  [1224,
#   7418,
#   5885,
#   4196,
#   3770,
#   8824,
#   104,
#   3024,
#   4115,
#   4256,
#   6465,
#   3418,
#   4205,
#   4153,
#   3852,
#   8823],
#  [2596, 1473, 3166, 7610, 8823],
#  [3327, 2247, 6197, 8823],
#  [2043, 2247, 6666, 2160, 6334, 4555, 2043, 8823],
#  [104, 7787, 6948, 4196, 2783, 104, 2784, 8823],
#  [2657, 1321, 26, 973, 8823],
#  [1731, 5456, 6671, 8431, 8823],
#  [104, 4713, 8020, 556, 2916, 2286, 8823],
#  [3384, 1750, 7928, 3852, 5569, 6241, 3930, 2826, 1750, 104, 3034, 8824, 8823],
#  [3770, 7088, 3852, 6874, 5750, 1989, 8824, 8171, 7718, 7701, 8823],
#  [4440,
#   2251,
#   7953,
#   8590,
#   2043,
#   5205,
#   7586,
#   6197,
#   2388,
#   1473,
#   8340,
#   1750,
#   4838,
#   5750,
#   2183,
#   104,
#   7787,
#   7389,
#   3214,
#   8414,
#   1692,
#   104,
#   7787,
#   6419,
#   6766,
#   1536,
#   7389,
#   3214,
#   8414,
#   104,
#   2536,
#   4440,
#   487,
#   1473,
#   104,
#   8020,
#   3770,
#   3608,
#   2183,
#   2247,
#   1172,
#   8823],
#  [3770, 4953, 2011, 8823],
#  [6419,
#   1123,
#   5317,
#   8437,
#   1473,
#   5656,
#   8824,
#   2596,
#   4566,
#   5321,
#   1750,
#   556,
#   2183,
#   3481,
#   4577,
#   8015,
#   5833,
#   2388,
#   4440,
#   8824,
#   8823],
#  [2596, 8824, 8824, 8823],
#  [2596, 1683, 1692, 8824, 8823],
#  [104,
#   8468,
#   6269,
#   6241,
#   2043,
#   6961,
#   3770,
#   6228,
#   8824,
#   3724,
#   4713,
#   580,
#   6241,
#   1095,
#   7970,
#   1095,
#   1750,
#   768,
#   2247,
#   1126,
#   104,
#   4256,
#   6241,
#   3770,
#   8824,
#   8823],
#  [8824, 8823],
#  [2596, 1473, 1750, 8823],
#  [469,
#   5317,
#   3770,
#   95,
#   908,
#   4115,
#   8326,
#   6057,
#   6419,
#   95,
#   1837,
#   8605,
#   908,
#   8605,
#   973,
#   8605,
#   3548,
#   8824,
#   8823],
#  [564, 8823],
#  [4207,
#   2775,
#   5017,
#   104,
#   5569,
#   4009,
#   3615,
#   4584,
#   3838,
#   2536,
#   5885,
#   6269,
#   8261,
#   5317,
#   4058,
#   4196,
#   6419,
#   5446,
#   5001,
#   7084,
#   6419,
#   2011,
#   3467,
#   6378,
#   7289,
#   6378,
#   8823],
#  [6378, 8823],
#  [6915, 8272, 8823],
#  [3770, 5529, 7227, 3770, 2305, 8823],
#  [6197,
#   104,
#   5569,
#   5599,
#   2826,
#   2093,
#   6419,
#   8398,
#   1634,
#   2596,
#   5205,
#   3976,
#   1750,
#   8823],
#  [7226,
#   4829,
#   6531,
#   6465,
#   4440,
#   5903,
#   2826,
#   973,
#   6057,
#   3770,
#   3491,
#   5456,
#   8232,
#   1074,
#   2529,
#   2430,
#   8824,
#   8823],
#  [104, 7529, 4115, 328, 2596, 1446, 104, 4713, 1731, 3852, 2385, 8823],
#  [4580, 3686, 2183, 7109, 4256, 3852, 6419, 1365, 8823],
#  [335, 5985, 8823],
#  [6149, 8823],
#  [1388, 104, 8823],
#  [3903, 3852, 2247, 8605, 4663, 8823],
#  [636, 8645, 1727, 3249, 8823],
#  [1072, 2826, 3180, 8823],
#  [8824,
#   8824,
#   1989,
#   3770,
#   4349,
#   1301,
#   2596,
#   1968,
#   4969,
#   8824,
#   8748,
#   3838,
#   3127,
#   7555,
#   2826,
#   8298,
#   2596,
#   4829,
#   5397,
#   90,
#   6419,
#   8824,
#   3214,
#   6419,
#   8824,
#   8823],
#  [1126, 6459, 2596, 5200, 3852, 8823],
#  [7418, 7701, 5985, 8823],
#  [5026, 8823],
#  [6476, 8823],
#  [2596, 4566, 6459, 3852, 8823],
#  [104, 8626, 2596, 1473, 104, 8626, 6241, 8823],
#  [1446, 8823],
#  [522, 6476, 515, 8823],
#  [8701, 8823],
#  [636, 4755, 3852, 2536, 4995, 2596, 4886, 8701, 8823],
#  [104, 3686, 859, 3852, 5569, 4440, 7957, 8823],
#  [8824, 8823],
#  [8701, 8823],
#  [2596, 1968, 1338, 2183, 8823],
#  [8824, 8823],
#  [4440, 2247, 6057, 2139, 4769, 5737, 8193, 719, 4115, 4447, 8823],
#  [619, 3462, 2596, 6671, 3686, 3901, 753, 5101, 556, 2813, 8823],
#  [6057, 4769, 8824, 8823],
#  [619,
#   104,
#   4713,
#   8020,
#   1126,
#   2596,
#   8232,
#   6269,
#   2183,
#   5394,
#   104,
#   4713,
#   8020,
#   2783,
#   2596,
#   6671,
#   2096,
#   4115,
#   6806,
#   8823],
#  [8824, 8823],
#  [5737, 2783, 2247, 657, 6269, 8823],
#  [3243, 8823],
#  [8824, 8823],
#  [7226,
#   4829,
#   480,
#   4440,
#   5737,
#   3667,
#   5569,
#   7109,
#   6419,
#   5842,
#   6269,
#   3770,
#   8824,
#   2349,
#   8823],
#  [2891, 2783, 6671, 2596, 8824, 8823],
#  [2596, 5205, 6459, 3852, 2434, 2160, 4235, 2234, 8823],
#  [4440, 1321, 2120, 4421, 1241, 4493, 8823],
#  [4440, 2247, 6057, 6618, 8823],
#  [5205, 104, 1487, 6465, 8823],
#  [1224, 2247, 6419, 1344, 3568, 8823],
#  [6459, 2596, 5750, 3852, 99, 8824, 8065, 6269, 3664, 7099, 2164, 8823],
#  [4440,
#   2247,
#   1550,
#   3144,
#   4769,
#   6915,
#   2432,
#   657,
#   4115,
#   1627,
#   2596,
#   1473,
#   6915,
#   3481,
#   4584,
#   4115,
#   8020,
#   2783,
#   2247,
#   8171,
#   7084,
#   2596,
#   8823],
#  [1989,
#   6419,
#   1408,
#   4115,
#   2690,
#   2596,
#   8701,
#   104,
#   7787,
#   4869,
#   7084,
#   5557,
#   7584,
#   8437,
#   8823],
#  [568, 2596, 6671, 8415, 5216, 5317, 8216, 2826, 2183, 7103, 8823],
#  [5557,
#   1550,
#   7555,
#   104,
#   5205,
#   4969,
#   5557,
#   4610,
#   6884,
#   4115,
#   6419,
#   873,
#   5935,
#   104,
#   1161,
#   5728,
#   90,
#   5772,
#   2826,
#   4605,
#   1074,
#   6919,
#   4769,
#   2247,
#   3838,
#   5016,
#   5524,
#   6269,
#   2263,
#   7226,
#   5205,
#   6642,
#   2183,
#   1443,
#   8823],
#  [8824, 8823],
#  [104,
#   1276,
#   6282,
#   7587,
#   1473,
#   3528,
#   7584,
#   8019,
#   104,
#   4401,
#   2596,
#   8231,
#   556,
#   1750,
#   4115,
#   7267,
#   3852,
#   7261,
#   5737,
#   104,
#   719,
#   8232,
#   4115,
#   4447,
#   4115,
#   2596,
#   8823],
#  [1473, 6419, 3513, 2989, 8823],
#  [335, 8823],
#  [104, 6366, 2596, 4115, 8020, 4769, 104, 7787, 8806, 6558, 8823],
#  [104, 1731, 4877, 1446, 104, 719, 3866, 7790, 3852, 4877, 8824, 8823],
#  [104, 7787, 3325, 8823],
#  [8784,
#   5842,
#   8605,
#   3627,
#   2247,
#   8806,
#   3702,
#   5205,
#   2596,
#   6459,
#   7701,
#   3462,
#   8823],
#  [3125, 8823],
#  [3125, 8823],
#  [2240, 6419, 3513, 6489, 6269, 2263, 5216, 4832, 1473, 8823],
#  [104,
#   7787,
#   4425,
#   8824,
#   1473,
#   2183,
#   2247,
#   5264,
#   8824,
#   8498,
#   3410,
#   301,
#   7040,
#   8823],
#  [6459, 3336, 8823],
#  [2304,
#   2240,
#   6419,
#   1837,
#   4196,
#   6911,
#   4196,
#   3190,
#   4496,
#   764,
#   2596,
#   6459,
#   556,
#   8097,
#   4953,
#   1473,
#   4953,
#   6132,
#   6360,
#   4713,
#   4191,
#   8272,
#   1989,
#   3770,
#   6360,
#   2407,
#   2160,
#   2480,
#   3770,
#   522,
#   2826,
#   2596,
#   4440,
#   2247,
#   5557,
#   4440,
#   6603,
#   8432,
#   6693,
#   2304,
#   8605,
#   2998,
#   1473,
#   764,
#   5569,
#   8571,
#   6411,
#   5529,
#   1473,
#   104,
#   7787,
#   3629,
#   3770,
#   8824,
#   4440,
#   7428,
#   3852,
#   1095,
#   8605,
#   764,
#   104,
#   7787,
#   5778,
#   2596,
#   4115,
#   7899,
#   1750,
#   1473,
#   3976,
#   1750,
#   8781,
#   6465,
#   8823],
#  [469, 8823],
#  [3730, 8193, 3732, 1074, 5653, 3812, 8823],
#  [3462, 104, 3370, 4969, 2862, 4235, 8823],
#  [8824, 8823],
#  [2783, 2247, 4440, 8823],
#  [8549,
#   556,
#   2596,
#   2596,
#   8232,
#   6465,
#   5317,
#   1339,
#   2826,
#   3664,
#   2304,
#   2783,
#   8193,
#   8824,
#   6573,
#   4115,
#   1095,
#   6518,
#   8823],
#  [5052,
#   5017,
#   8193,
#   719,
#   7558,
#   8824,
#   4995,
#   4995,
#   2043,
#   5569,
#   8824,
#   5317,
#   4440,
#   8361,
#   2160,
#   5317,
#   8478,
#   7998,
#   1683,
#   2596,
#   1473,
#   5113,
#   6945,
#   3770,
#   5458,
#   4877,
#   3694,
#   1750,
#   1473,
#   7520,
#   7446,
#   3398,
#   8824,
#   2862,
#   2826,
#   7902,
#   1671,
#   556,
#   6419,
#   4985,
#   8823],
#  [4403, 8823],
#  [1161, 5767, 2160, 8823],
#  [104,
#   7787,
#   1509,
#   3770,
#   4349,
#   3481,
#   7952,
#   4115,
#   8824,
#   3770,
#   7103,
#   2448,
#   480,
#   1750,
#   104,
#   4829,
#   6158,
#   6057,
#   4115,
#   104,
#   8444,
#   90,
#   8824,
#   1446,
#   104,
#   7787,
#   6057,
#   3824,
#   8823],
#  [2043, 2247, 150, 5456, 780, 6241, 4235, 1473, 2596, 8020, 3852, 8823],
#  [8168,
#   1914,
#   5456,
#   1569,
#   4784,
#   2273,
#   4440,
#   3481,
#   8824,
#   8824,
#   8824,
#   8824,
#   3513,
#   8824,
#   4853,
#   6915,
#   1542,
#   8823],
#  [8824, 3770, 8824, 4363, 2562, 8748, 8823],
#  [335, 6514, 8823],
#  [3393,
#   1446,
#   3852,
#   6874,
#   5750,
#   5557,
#   2826,
#   1208,
#   5519,
#   6859,
#   3770,
#   8824,
#   8824,
#   8824,
#   187,
#   3770,
#   8119,
#   2423,
#   8823],
#  [39, 7099, 8823],
#  [4713, 90, 3402, 1132, 8823],
#  [7776, 2783, 2247, 8500, 8823],
#  [3686, 2619, 4440, 2247, 1968, 3214, 7100, 6859, 7827, 8823],
#  [2596, 4191, 7955, 8823],
#  [1550, 4235, 5552, 1550, 4235, 8823],
#  [4610, 8824, 1887, 8020, 1249, 4481, 99, 5456, 4701, 3852, 8823],
#  [1249, 7348, 8823],
#  [2247, 3838, 6419, 4081, 556, 1750, 8823],
#  [636, 6459, 2596, 8020, 8823],
#  [5317, 6419, 8824, 8823],
#  [6419, 6415, 8824, 8823],
#  [6874, 1473, 7849, 4713, 6139, 4500, 6605, 8824, 8823],
#  [3770, 8824, 8823],
#  [4713, 580, 8823],
#  [104,
#   4161,
#   2043,
#   2247,
#   3770,
#   8824,
#   5317,
#   4440,
#   7040,
#   3838,
#   1161,
#   90,
#   1072,
#   4953,
#   4947,
#   2596,
#   4829,
#   5542,
#   2817,
#   5750,
#   4440,
#   8823],
#  [8784,
#   8701,
#   677,
#   1224,
#   2247,
#   4196,
#   4115,
#   2120,
#   3770,
#   5996,
#   6753,
#   2826,
#   3664,
#   6435,
#   6334,
#   3513,
#   8824,
#   3082,
#   2247,
#   2096,
#   4115,
#   416,
#   6465,
#   2036,
#   7692,
#   104,
#   8020,
#   8605,
#   8592,
#   1224,
#   2247,
#   3745,
#   7957,
#   4115,
#   1719,
#   3770,
#   3929,
#   1473,
#   3838,
#   2247,
#   6915,
#   3481,
#   3838,
#   7226,
#   1509,
#   1154,
#   556,
#   6465,
#   8823],
#  [7584, 8592, 2247, 7871, 8824, 5752, 8824, 6428, 8823],
#  [636,
#   7970,
#   8824,
#   7787,
#   104,
#   4115,
#   8824,
#   2434,
#   2596,
#   3770,
#   7389,
#   1740,
#   104,
#   610,
#   2596,
#   3770,
#   7389,
#   2596,
#   1338,
#   8823],
#  [104, 1138, 4115, 4500, 7099, 4115, 6517, 8823],
#  [677, 8823],
#  [1126, 8823],
#  [104, 7677, 8171, 104, 7677, 8171, 3190, 4235, 8823],
#  [8193, 6671, 5317, 3770, 7195, 2826, 3770, 8824, 2826, 8824, 8823],
#  [3686,
#   7418,
#   3852,
#   2596,
#   4566,
#   1719,
#   1989,
#   8806,
#   7163,
#   8373,
#   8824,
#   8373,
#   8824,
#   8823],
#  [1993,
#   1446,
#   8824,
#   1446,
#   104,
#   8824,
#   205,
#   1446,
#   104,
#   205,
#   1699,
#   2596,
#   104,
#   205,
#   2282,
#   8823],
#  [8824, 8824, 8823],
#  [335, 8823],
#  [6781, 8605, 5697, 8823],
#  [2304, 4713, 6459, 4440, 98, 8823],
#  [677, 8823],
#  [104, 205, 2282, 104, 205, 2282, 8823],
#  [2783, 636, 5205, 2596, 90, 4877, 7523, 8824, 8823],
#  [6915,
#   1989,
#   1550,
#   1224,
#   2960,
#   4701,
#   104,
#   7787,
#   3702,
#   4115,
#   900,
#   2826,
#   3852,
#   8193,
#   1161,
#   6459,
#   5885,
#   1550,
#   556,
#   2596,
#   5205,
#   8193,
#   8823],
#  [335, 8605, 205, 8823],
#  [7584, 8221, 2247, 7955, 8823],
#  [3530, 636, 5205, 104, 3976, 2596, 8823],
#  [8605,
#   3627,
#   2247,
#   6419,
#   6558,
#   7882,
#   8701,
#   1224,
#   4829,
#   90,
#   7547,
#   1013,
#   1224,
#   1879,
#   104,
#   4829,
#   3718,
#   8823],
#  [335, 8823],
#  [4838, 8823],
#  [2783, 556, 8823],
#  [2960,
#   8193,
#   6169,
#   4235,
#   1989,
#   6419,
#   3923,
#   5246,
#   104,
#   205,
#   4610,
#   8824,
#   7446,
#   5456,
#   4235,
#   5631,
#   104,
#   5782,
#   6776,
#   1208,
#   104,
#   6824,
#   104,
#   5569,
#   3745,
#   1609,
#   8823],
#  [8824, 8823],
#  [6694, 8823],
#  [8824, 8823],
#  [8824, 8823],
#  [2596, 1161, 90, 6141, 8824, 8823],
#  [1989,
#   2556,
#   7871,
#   8453,
#   556,
#   3180,
#   4115,
#   719,
#   2596,
#   4235,
#   6141,
#   1791,
#   1473,
#   556,
#   8824,
#   8823],
#  [8365, 3243, 4235, 2043, 467, 8823],
#  [2596, 7116, 8824, 7871, 8048, 2434, 1791, 8823],
#  [2304, 3838, 3852, 2247, 8823],
#  [1095,
#   6419,
#   2543,
#   2826,
#   2611,
#   3481,
#   2826,
#   8605,
#   2529,
#   2623,
#   6419,
#   8806,
#   3446,
#   7814,
#   6252,
#   1750,
#   2043,
#   5569,
#   1982,
#   3878,
#   8823],
#  [8824, 6285, 4894, 5317, 3770, 8298, 2826, 3770, 206, 1123, 8823],
#  [7428, 8193, 5874, 5317, 3770, 4397, 556, 1454, 7718, 8388, 8823],
#  [2304,
#   8605,
#   8491,
#   2247,
#   4115,
#   5542,
#   2183,
#   3923,
#   3446,
#   6349,
#   1473,
#   6169,
#   7084,
#   3180,
#   5317,
#   6517,
#   8823],
#  [335, 8823],
#  [335, 8823],
#  [636, 8645, 8823],
#  [4713, 4928, 104, 7787, 6057, 5105, 4235, 4115, 90, 6419, 3705, 8823],
#  [8824,
#   104,
#   7787,
#   2995,
#   4115,
#   3664,
#   6285,
#   7584,
#   6285,
#   104,
#   859,
#   4115,
#   5160,
#   4349,
#   3481,
#   1837,
#   4440,
#   2596,
#   7226,
#   6671,
#   3770,
#   8221,
#   2826,
#   3180,
#   5557,
#   8403,
#   7012,
#   7902,
#   1542,
#   3770,
#   8504,
#   5456,
#   4647,
#   4115,
#   2186,
#   3852,
#   2247,
#   6057,
#   556,
#   469,
#   4440,
#   3770,
#   4974,
#   8824,
#   4267,
#   3180,
#   8824,
#   7584,
#   8221,
#   1473,
#   162,
#   4440,
#   7584,
#   2962,
#   8444,
#   90,
#   3402,
#   7599,
#   3770,
#   8824,
#   8823],
#  [4235, 5317, 3664, 3255, 5456, 4589, 6465, 1550, 5519, 8823],
#  [6671, 2596, 6141, 1791, 8823],
#  [5456,
#   4566,
#   90,
#   1721,
#   556,
#   4147,
#   6419,
#   5923,
#   3271,
#   7718,
#   1874,
#   7226,
#   4677,
#   4115,
#   8544,
#   8824,
#   671,
#   8823],
#  [8824, 8823],
#  [8824, 6169, 4235, 8823],
#  [8824, 6834, 8824, 8823],
#  [104,
#   282,
#   2596,
#   104,
#   2372,
#   2160,
#   6419,
#   7556,
#   5317,
#   8824,
#   6411,
#   4985,
#   4570,
#   5548,
#   3402,
#   8824,
#   2160,
#   4115,
#   5229,
#   1493,
#   3686,
#   5750,
#   6419,
#   7351,
#   5946,
#   1989,
#   6419,
#   2666,
#   8823],
#  [2826, 7069, 2783, 5524, 6459, 2596, 1731, 5456, 6438, 4235, 8823],
#  [4702, 3852, 2830, 8823],
#  [2783, 3770, 8824, 2783, 4829, 2596, 1731, 8823],
#  [5205, 104, 1719, 3852, 8823],
#  [1126, 6057, 8823],
#  [2183,
#   2247,
#   6141,
#   1791,
#   8605,
#   5985,
#   3770,
#   3446,
#   7882,
#   6141,
#   8824,
#   1779,
#   4115,
#   7012,
#   7902,
#   8824,
#   3327,
#   2247,
#   2043,
#   8823],
#  [8824, 8824, 8824, 8823],
#  [6419, 124, 3513, 2144, 1446, 3852, 8824, 6334, 1249, 753, 8823],
#  [104, 3866, 1879, 4440, 4481, 5750, 4440, 5569, 6618, 8823],
#  [104, 7787, 3745, 3446, 4115, 90, 4877, 3702, 8823],
#  [3770, 7882, 1224, 2247, 4235, 8823],
#  [6419, 6281, 768, 3866, 2169, 5862, 3481, 4712, 8823],
#  [3718, 7343, 8533, 8823],
#  [4877, 4769, 6419, 2012, 4619, 8823],
#  [6860,
#   8682,
#   2652,
#   5788,
#   2527,
#   6269,
#   2261,
#   8824,
#   8824,
#   8824,
#   1473,
#   6204,
#   8682,
#   6204,
#   5788,
#   8612,
#   8824,
#   8824,
#   8824,
#   7995,
#   8824,
#   6459,
#   2596,
#   719,
#   4440,
#   8823],
#  [6204, 8682, 2652, 5788, 100, 8824, 8824, 8824, 8824, 8824, 8824, 8824, 8823],
#  [6418,
#   5628,
#   1750,
#   4701,
#   3852,
#   5557,
#   2826,
#   3852,
#   3770,
#   6766,
#   1837,
#   2434,
#   3770,
#   2642,
#   3243,
#   8823],
#  [6418, 1126, 8213, 7835, 3852, 719, 4115, 90, 5317, 1454, 8823],
#  [5456,
#   7529,
#   8605,
#   4481,
#   3852,
#   8824,
#   1208,
#   3770,
#   4349,
#   3444,
#   8824,
#   8432,
#   2247,
#   8824,
#   8824,
#   1473,
#   8824,
#   8824,
#   1473,
#   8824,
#   2434,
#   4235,
#   4115,
#   8824,
#   8824,
#   8824,
#   8824,
#   8824,
#   5885,
#   5524,
#   2247,
#   8824,
#   8823],
#  [8698,
#   1208,
#   3481,
#   5540,
#   8824,
#   1473,
#   5456,
#   6457,
#   8824,
#   8824,
#   8824,
#   8824,
#   6671,
#   8167,
#   994,
#   1473,
#   2596,
#   1138,
#   1208,
#   4115,
#   1876,
#   8605,
#   7935,
#   8823],
#  [4638,
#   4349,
#   8048,
#   5205,
#   6459,
#   2183,
#   5317,
#   6419,
#   1552,
#   1013,
#   7389,
#   3214,
#   3481,
#   6018,
#   6754,
#   6859,
#   3770,
#   206,
#   245,
#   1989,
#   3686,
#   5372,
#   6915,
#   3481,
#   5205,
#   8432,
#   6419,
#   3596,
#   1446,
#   7084,
#   4481,
#   7084,
#   4481,
#   2596,
#   5205,
#   719,
#   6033,
#   8824,
#   5557,
#   2995,
#   6859,
#   7109,
#   1473,
#   1989,
#   6057,
#   5372,
#   1989,
#   6419,
#   5042,
#   6560,
#   7147,
#   4440,
#   6848,
#   8823],
#  [5317, 3770, 7769, 2826, 4241, 4440, 2247, 6419, 4817, 8823],
#  [4235, 5317, 6517, 8823],
#  [104, 1886, 3852, 2247, 6057, 3745, 4869, 8823],
#  [3664,
#   3855,
#   1991,
#   3336,
#   3770,
#   4174,
#   5557,
#   6517,
#   5623,
#   3838,
#   3664,
#   3334,
#   8824,
#   3513,
#   3334,
#   5317,
#   3770,
#   967,
#   1473,
#   4619,
#   5317,
#   4440,
#   1584,
#   4481,
#   6419,
#   5875,
#   4481,
#   8824,
#   2862,
#   5519,
#   1208,
#   5557,
#   6419,
#   5923,
#   3431,
#   2826,
#   900,
#   8824,
#   3431,
#   556,
#   8824,
#   1791,
#   8824,
#   4147,
#   3664,
#   1511,
#   2998,
#   8824,
#   8824,
#   2783,
#   8824,
#   2783,
#   8824,
#   2783,
#   8754,
#   5317,
#   3770,
#   7935,
#   8824,
#   4584,
#   2536,
#   8687,
#   4147,
#   4241,
#   6859,
#   6411,
#   1473,
#   4241,
#   71,
#   4115,
#   2124,
#   8824,
#   8824,
#   4115,
#   1995,
#   3852,
#   104,
#   6859,
#   3770,
#   4397,
#   556,
#   7109,
#   4604,
#   6859,
#   6465,
#   6459,
#   2596,
#   8432,
#   6459,
#   2596,
#   8823],
#  [3770,
#   4349,
#   1837,
#   4440,
#   2976,
#   1750,
#   5569,
#   3770,
#   5220,
#   6960,
#   636,
#   7835,
#   3481,
#   6459,
#   4440,
#   636,
#   7835,
#   3481,
#   4711,
#   6419,
#   7882,
#   1989,
#   3481,
#   1837,
#   4115,
#   5237,
#   4196,
#   3852,
#   1989,
#   8806,
#   1172,
#   99,
#   2596,
#   719,
#   4115,
#   6459,
#   3852,
#   7084,
#   7584,
#   2529,
#   1615,
#   8823],
#  [1791, 2247, 2682, 6419, 2446, 8048, 7871, 8388, 8048, 8823],
#  [1224, 2247, 6708, 4440, 1552, 4115, 4481, 8823],
#  [2596, 3370, 90, 4851, 8823],
#  [3866, 4992, 8823],
#  [3770, 8425, 4584, 4531, 6465, 5950, 8823],
#  [104, 4566, 3784, 1695, 8823],
#  [2783, 7428, 1224, 7418, 8823],
#  [5456,
#   7446,
#   7496,
#   3838,
#   7446,
#   6915,
#   976,
#   6915,
#   6451,
#   4061,
#   3770,
#   6766,
#   3703,
#   2247,
#   933,
#   3770,
#   8066,
#   2826,
#   2783,
#   5299,
#   2385,
#   2160,
#   3838,
#   8823],
#  [104, 180, 3852, 1446, 1989, 7701, 4115, 6459, 8823],
#  [6419, 1472, 8823],
#  [2596, 4784, 5341, 7584, 6548, 8823],
#  [104, 7787, 2300, 8823],
#  [104,
#   7787,
#   7163,
#   2596,
#   4713,
#   8020,
#   1750,
#   1473,
#   104,
#   8020,
#   469,
#   4196,
#   2596,
#   8193,
#   719,
#   6419,
#   5042,
#   521,
#   8823],
#  [3923, 8823],
#  [4725, 8823],
#  [714, 8823],
#  [3770, 7494, 8823],
#  [335, 8823],
#  [4566, 2596, 90, 4235, 5317, 4196, 7634, 1910, 8823],
#  [282, 1750, 4440, 1989, 7190, 2826, 1750, 4115, 90, 8824, 8823],
#  [104, 719, 5780, 8410, 7742, 556, 2596, 8823],
#  [4812, 5519, 8823],
#  [8193, 6961, 7871, 4733, 1224, 2247, 3190, 7190, 8823],
#  [6915, 2783, 8823],
#  [2304, 5557, 1550, 6418, 90, 4440, 8006, 4235, 807, 2183, 8823],
#  [3770,
#   5088,
#   4566,
#   90,
#   2100,
#   7261,
#   4829,
#   2596,
#   5750,
#   6419,
#   666,
#   7476,
#   4115,
#   5017,
#   6859,
#   8193,
#   719,
#   6334,
#   714,
#   124,
#   8824,
#   8823],
#  [1550, 8823],
#  [6915, 2783, 8823],
#  [628, 719, 2596, 403, 2536, 8824, 736, 4196, 3770, 567, 1473, 7000, 8823],
#  [104, 3328, 6057, 8823],
#  [8626, 3811, 3770, 4953, 8408, 4440, 8824, 2596, 8823],
#  [4769,
#   8193,
#   719,
#   3686,
#   4531,
#   2596,
#   6419,
#   1700,
#   5214,
#   8824,
#   4877,
#   6516,
#   4115,
#   4969,
#   6334,
#   1365,
#   4769,
#   8626,
#   3811,
#   4566,
#   1719,
#   4115,
#   7584,
#   394,
#   1365,
#   4769,
#   8823],
#  [5017,
#   2212,
#   8824,
#   104,
#   8020,
#   104,
#   719,
#   2536,
#   8824,
#   1446,
#   2657,
#   5569,
#   8320,
#   2624,
#   104,
#   5425,
#   6465,
#   6419,
#   7882,
#   1161,
#   6459,
#   4440,
#   4115,
#   2817,
#   7084,
#   3664,
#   125,
#   1615,
#   8823],
#  [1249, 8823],
#  [6827, 8823],
#  [2596, 6671, 6057, 6382, 6419, 1249, 245, 6671, 2596, 8823],
#  [5265, 8193, 8823],
#  [8374, 4115, 1719, 2596, 8823],
#  [8171, 8823],
#  [6419, 8824, 8823],
#  [8824, 5782, 8824, 8823],
#  [7343, 3686, 4478, 2255, 8823],
#  [4207, 8823],
#  [3327, 6671, 8193, 657, 8823],
#  [1066, 8823],
#  [6827,
#   4769,
#   104,
#   8020,
#   2183,
#   8444,
#   90,
#   3694,
#   556,
#   2596,
#   1446,
#   104,
#   719,
#   4115,
#   6351,
#   2596,
#   8823],
#  [2596, 1988, 1473, 4769, 2596, 5265, 1528, 3770, 6840, 8823],
#  [2124,
#   4115,
#   3041,
#   1338,
#   7584,
#   2529,
#   6435,
#   6827,
#   1989,
#   7902,
#   4349,
#   7781,
#   8823],
#  [3770,
#   8824,
#   3770,
#   7360,
#   2826,
#   8824,
#   1989,
#   5557,
#   6725,
#   1338,
#   7584,
#   2529,
#   4651,
#   2952,
#   6827,
#   5496,
#   1750,
#   8823],
#  [4969, 2862, 2826, 4235, 8559, 8823],
#  [8824,
#   2247,
#   3770,
#   7882,
#   2596,
#   1053,
#   5317,
#   3770,
#   5184,
#   8193,
#   3328,
#   3852,
#   2763,
#   2596,
#   5782,
#   1719,
#   6465,
#   1095,
#   1224,
#   2247,
#   6419,
#   7831,
#   4711,
#   1473,
#   1569,
#   1700,
#   473,
#   8823],
#  [2035, 8824, 1473, 8824, 8824, 6671, 4235, 4115, 1719, 2596, 5088, 8823],
#  [8784, 8823],
#  [1446, 104, 5205, 3222, 6334, 2160, 556, 2596, 1013, 2596, 4829, 5750, 8823],
#  [4584, 6338, 8824, 2784, 5885, 6246, 3770, 4878, 6269, 3770, 8824, 8823],
#  [4207,
#   1224,
#   4566,
#   719,
#   6419,
#   8764,
#   245,
#   5599,
#   2160,
#   6419,
#   8824,
#   556,
#   2183,
#   3481,
#   8823],
#  [3891, 4482, 7867, 8823],
#  [5628, 1750, 719, 8501, 1648, 8823],
#  [4207, 8823],
#  [2596, 8432, 8823],
#  [6698, 3370, 90, 5317, 1249, 233, 1224, 5569, 8824, 162, 8824, 8823],
#  [3190,
#   4838,
#   7084,
#   2596,
#   4584,
#   6139,
#   8042,
#   2183,
#   4115,
#   1750,
#   2596,
#   8020,
#   4440,
#   8823],
#  [4455, 3852, 2247, 4440, 3384, 2596, 2556, 6419, 1372, 7084, 7206, 8823],
#  [2304, 2783, 8823],
#  [104, 1138, 4115, 90, 8352, 2282, 8823],
#  [4713, 2596, 8020, 104, 719, 2536, 7925, 4196, 2596, 556, 4587, 8823],
#  [335, 4769, 8823],
#  [104,
#   7787,
#   689,
#   6948,
#   104,
#   4829,
#   3684,
#   5557,
#   4196,
#   2596,
#   104,
#   7787,
#   4877,
#   6948,
#   5985,
#   8823],
#  [4713,
#   2596,
#   5797,
#   4440,
#   104,
#   7787,
#   1569,
#   3770,
#   1200,
#   7882,
#   7666,
#   4235,
#   3745,
#   4769,
#   8193,
#   4566,
#   4969,
#   3770,
#   4807,
#   7341,
#   556,
#   1695,
#   5529,
#   2596,
#   1473,
#   104,
#   6671,
#   657,
#   2862,
#   6605,
#   6093,
#   4440,
#   8823],
#  [104, 4784, 8232, 1072, 2446, 7383, 556, 1208, 2183, 7348, 2758, 8823],
#  [8784,
#   6347,
#   1989,
#   6057,
#   556,
#   2596,
#   2596,
#   6671,
#   4349,
#   657,
#   4115,
#   4969,
#   6015,
#   7914,
#   4331,
#   1473,
#   104,
#   6671,
#   657,
#   4115,
#   4500,
#   6269,
#   3770,
#   6932,
#   8823],
#  [1834,
#   104,
#   7787,
#   657,
#   4115,
#   3998,
#   3686,
#   1095,
#   3712,
#   1095,
#   3770,
#   2901,
#   5361,
#   2120,
#   5557,
#   3770,
#   6579,
#   4566,
#   2596,
#   8823],
#  [6338, 8824, 8823],
#  [335, 8823],
#  [4969, 7914, 4331, 6269, 3770, 6468, 8823],
#  [1989, 3664, 6435, 2780, 973, 2596, 8020, 8823],
#  [2304,
#   1338,
#   8605,
#   3596,
#   556,
#   3852,
#   1473,
#   4713,
#   6516,
#   3852,
#   1989,
#   8824,
#   1013,
#   3852,
#   7446,
#   6334,
#   4953,
#   7953,
#   104,
#   8403,
#   1880,
#   6241,
#   1446,
#   3629,
#   5557,
#   2596,
#   1161,
#   525,
#   6419,
#   8824,
#   4986,
#   2862,
#   4769,
#   5205,
#   2596,
#   8823],
#  [3718, 4235, 6511, 8823],
#  [6419,
#   2998,
#   2826,
#   6863,
#   4207,
#   1509,
#   3664,
#   162,
#   5569,
#   689,
#   3702,
#   1473,
#   2043,
#   5569,
#   6880,
#   4829,
#   2596,
#   480,
#   3852,
#   8823],
#  [8784, 2596, 1731, 104, 7787, 7496, 8823],
#  [5557, 1550, 104, 7787, 7496, 4713, 5797, 2596, 4120, 1750, 6419, 985, 8823],
#  [2304, 1224, 5569, 3901, 205, 4115, 6241, 8823],
#  [2783, 245, 7428, 4935, 4549, 4969, 5317, 8823],
#  [2783, 245, 7428, 2596, 4969, 5317, 8823],
#  [7418,
#   8193,
#   357,
#   2036,
#   6419,
#   2901,
#   8193,
#   8162,
#   8193,
#   6671,
#   3770,
#   8824,
#   8824,
#   6884,
#   6671,
#   992,
#   90,
#   5599,
#   3770,
#   1087,
#   6808,
#   1893,
#   2247,
#   3838,
#   7871,
#   7255,
#   6808,
#   1893,
#   636,
#   3718,
#   8193,
#   3866,
#   1000,
#   2826,
#   3770,
#   7255,
#   6808,
#   1893,
#   4877,
#   6884,
#   6671,
#   2096,
#   4115,
#   3455,
#   4440,
#   2862,
#   3930,
#   2826,
#   8417,
#   1074,
#   4385,
#   8823],
#  [104, 2060, 8823],
#  [2304, 6698, 1968, 4500, 282, 3770, 3074, 8824, 8823],
#  [6418, 104, 205, 3852, 8823],
#  [5456,
#   2784,
#   3903,
#   3770,
#   3242,
#   7446,
#   5169,
#   556,
#   3770,
#   7040,
#   2826,
#   3770,
#   824,
#   8823],
#  [2901, 8824, 6858, 3770, 5436, 6859, 1435, 7867, 1064, 8823],
#  [2124, 1224, 2247, 8605, 2775, 1473, 104, 4713, 1138, 4115, 5464, 8225, 8823],
#  [2596, 2959, 1458, 2826, 6107, 8824, 4235, 8824, 8824, 8823],
#  [104,
#   1731,
#   104,
#   5425,
#   2596,
#   8350,
#   4147,
#   3770,
#   1589,
#   423,
#   3686,
#   1095,
#   104,
#   5569,
#   4200,
#   5317,
#   3770,
#   7099,
#   8823],
#  [4713, 5628, 3852, 6395, 6629, 8823],
#  [1126,
#   5600,
#   8193,
#   3770,
#   8824,
#   1893,
#   104,
#   4191,
#   2240,
#   6476,
#   1087,
#   6121,
#   1473,
#   4349,
#   522,
#   6808,
#   6121,
#   4235,
#   8823],
#  [4769, 3770, 3481, 245, 3481, 2826, 3180, 467, 2160, 7084, 7871, 3309, 8823],
#  [6419, 3929, 8823],
#  [104, 7787, 5599, 8823],
#  [2630, 3903, 2183, 2247, 6419, 160, 8823],
#  [8784,
#   2596,
#   6671,
#   5317,
#   4315,
#   8193,
#   140,
#   6911,
#   1072,
#   7389,
#   6371,
#   2596,
#   282,
#   4236,
#   1087,
#   3327,
#   1473,
#   99,
#   4115,
#   938,
#   8823],
#  [3327, 2247, 6371, 6808, 8823],
#  [99,
#   719,
#   2596,
#   403,
#   7558,
#   8715,
#   7882,
#   955,
#   6057,
#   4115,
#   90,
#   197,
#   6859,
#   531,
#   8823],
#  [4500, 6282, 4140, 5456, 140, 992, 5809, 6915, 7389, 4830, 8423, 8823],
#  [2556, 1095, 8823],
#  [6419, 160, 6401, 3770, 5278, 2783, 3770, 8427, 7446, 8193, 5599, 8823],
#  [8193, 6671, 3686, 4696, 5321, 2596, 8701, 8823],
#  [8193,
#   8020,
#   2219,
#   4769,
#   8193,
#   8232,
#   4115,
#   4969,
#   2596,
#   4115,
#   4140,
#   8824,
#   8823],
#  [531,
#   5317,
#   3770,
#   4148,
#   1729,
#   3852,
#   5569,
#   2596,
#   7226,
#   8824,
#   4236,
#   8193,
#   6671,
#   5557,
#   4877,
#   6558,
#   2826,
#   2596,
#   6371,
#   1473,
#   6057,
#   6419,
#   7473,
#   8824,
#   2536,
#   35,
#   4115,
#   3770,
#   5278,
#   4995,
#   2596,
#   6671,
#   7541,
#   2943,
#   8823],
#  [7446, 2596, 4353, 6269, 5798, 1750, 99, 2596, 2900, 6696, 8823],
#  [6371,
#   2783,
#   6671,
#   2596,
#   5599,
#   3838,
#   6671,
#   8106,
#   343,
#   1473,
#   8824,
#   5557,
#   5519,
#   2183,
#   8824,
#   8823],
#  [5639, 2783, 8823],
#  [1013, 2596, 4713, 1719, 3852, 1989, 6057, 4978, 8823],
#  [104, 4566, 3897, 6269, 3770, 8006, 8823],
#  [2596,
#   6961,
#   5557,
#   8410,
#   5813,
#   3838,
#   4877,
#   104,
#   4829,
#   1731,
#   3770,
#   2211,
#   8494,
#   7446,
#   5317,
#   85,
#   2434,
#   3770,
#   5813,
#   8240,
#   8823],
#  [3770,
#   406,
#   6961,
#   6419,
#   1261,
#   2434,
#   6419,
#   1649,
#   3686,
#   8104,
#   8586,
#   2862,
#   2826,
#   85,
#   8823],
#  [104,
#   4829,
#   3686,
#   1095,
#   3712,
#   4711,
#   2596,
#   6371,
#   6808,
#   1446,
#   8707,
#   2596,
#   169,
#   2160,
#   3745,
#   7970,
#   2826,
#   8605,
#   245,
#   8823],
#  [104, 6817, 104, 7787, 6057, 3190, 3745, 5710, 8823],
#  [4713, 4447, 4196, 3852, 7970, 6379, 8823],
#  [6347,
#   3852,
#   2247,
#   6057,
#   8605,
#   2934,
#   4115,
#   719,
#   4115,
#   8340,
#   8605,
#   2263,
#   5246,
#   4115,
#   3718,
#   4115,
#   2183,
#   8824,
#   6160,
#   2826,
#   4242,
#   4115,
#   84,
#   1126,
#   5317,
#   3770,
#   7073,
#   2826,
#   5557,
#   4440,
#   2247,
#   4276,
#   2596,
#   1161,
#   1931,
#   4115,
#   8824,
#   6419,
#   8024,
#   7957,
#   3769,
#   2434,
#   1074,
#   4422,
#   3513,
#   8824,
#   4877,
#   4440,
#   104,
#   8444,
#   4661,
#   3770,
#   7294,
#   5278,
#   4440,
#   2183,
#   2983,
#   4584,
#   403,
#   8824,
#   8823],
#  [172,
#   6057,
#   8701,
#   6419,
#   1893,
#   2826,
#   3860,
#   7312,
#   5266,
#   4115,
#   5742,
#   6465,
#   2434,
#   3770,
#   8824,
#   6057,
#   4349,
#   4584,
#   2183,
#   2321,
#   3409,
#   2434,
#   3770,
#   4953,
#   3769,
#   3770,
#   8824,
#   6338,
#   234,
#   8824,
#   5569,
#   991,
#   1464,
#   4365,
#   3770,
#   8689,
#   8823],
#  [8701, 8823],
#  [2783, 2247, 4440, 8823],
#  [8784, 4440, 104, 4566, 5628, 8824, 3897, 8823],
#  [335, 8823],
#  [683, 2596, 6671, 7019, 7871, 8076, 8823],
#  [2596, 5750, 3852, 3838, 4713, 2596, 8823],
#  [5335, 1750, 2160, 8823],
#  [2183, 2247, 8824, 8823],
#  [3903,
#   2596,
#   719,
#   4115,
#   8340,
#   143,
#   7871,
#   8643,
#   6859,
#   3770,
#   1436,
#   4115,
#   2071,
#   3770,
#   608,
#   2826,
#   3770,
#   8824,
#   3335,
#   104,
#   7787,
#   2093,
#   2862,
#   2826,
#   4235,
#   3327,
#   2247,
#   7584,
#   8824,
#   8823],
#  [335, 8823],
#  [469, 8823],
#  [8605, 2998, 6252, 1750, 104, 2960, 1634, 5728, 4969, 6419, 8398, 8823],
#  [4969, 6015, 719, 6419, 3270, 8823],
#  [335, 6990, 8823],
#  [3327, 6671, 2596, 657, 8823],
#  [2783, 8824, 104, 4566, 3784, 2596, 8823],
#  [1989, 6419, 95, 8824, 2826, 8824, 8824, 8823],
#  [8824,
#   8020,
#   1989,
#   6419,
#   3513,
#   916,
#   1446,
#   2247,
#   3852,
#   6618,
#   4115,
#   1772,
#   6419,
#   6686,
#   556,
#   522,
#   6859,
#   1835,
#   7718,
#   8824,
#   7735,
#   8823],
#  [8824, 932, 6948, 1072, 6979, 8823],
#  [3629, 5229, 8823],
#  [3686, 7418, 6915, 8823],
#  [2247, 4440, 3770, 2122, 1485, 4470, 4713, 8039, 4440, 4414, 6629, 8823],
#  [8824, 7672, 8823],
#  [5264, 366, 8824, 8823],
#  [5205, 2596, 4855, 6338, 8823],
#  [335, 8798, 8823],
#  [6671, 2596, 4023, 5016, 104, 4191, 991, 8823],
#  [7672, 2783, 8823],
#  [8824, 8823],
#  [2783, 2247, 3852, 8798, 6671, 2596, 8431, 8823],
#  [104, 6837, 2036, 2304, 1318, 1473, 8824, 4459, 8823],
#  [2596, 1731, 104, 7787, 4483, 2596, 1731, 5557, 3227, 6671, 4483, 8823],
#  [7147,
#   3852,
#   1085,
#   4200,
#   5557,
#   3770,
#   8006,
#   2160,
#   4235,
#   1446,
#   2596,
#   8020,
#   5456,
#   1509,
#   6671,
#   3770,
#   2763,
#   8823],
#  [8784,
#   1161,
#   104,
#   7787,
#   798,
#   8824,
#   2826,
#   5858,
#   8824,
#   2124,
#   104,
#   719,
#   1509,
#   8232,
#   4115,
#   4500,
#   104,
#   8824,
#   4566,
#   3784,
#   2596,
#   8823],
#  [7365, 7996, 8823],
#  [6459, 2596, 719, 1072, 2435, 7718, 8824, 104, 4829, 1338, 6419, 8824, 8823],
#  [6915, 104, 7787, 6693, 8823],
#  [6338, 8824, 6419, 3510, 2826, 155, 8824, 8823],
#  [636, 8715, 6671, 2596, 8823],
#  [4207, 2596, 8824, 2862, 8823],
#  [2304,
#   104,
#   719,
#   6961,
#   6419,
#   3694,
#   245,
#   2093,
#   7871,
#   5220,
#   8824,
#   6419,
#   2745,
#   8824,
#   6862,
#   1224,
#   5425,
#   6465,
#   6859,
#   6419,
#   946,
#   3838,
#   1446,
#   104,
#   8468,
#   3852,
#   2862,
#   1473,
#   2783,
#   2385,
#   2247,
#   1224,
#   8824,
#   6419,
#   8824,
#   8824,
#   556,
#   7365,
#   4877,
#   8823],
#  [5569,
#   1224,
#   5371,
#   6859,
#   5557,
#   6459,
#   2596,
#   1731,
#   5317,
#   8824,
#   7718,
#   4175,
#   5226,
#   8823],
#  [104,
#   8020,
#   3852,
#   7810,
#   5750,
#   6419,
#   2832,
#   1434,
#   1446,
#   5317,
#   2446,
#   1163,
#   104,
#   8020,
#   2183,
#   7810,
#   5750,
#   6419,
#   2832,
#   1434,
#   1446,
#   6411,
#   8824,
#   4713,
#   8020,
#   1013,
#   2596,
#   719,
#   1000,
#   4196,
#   2183,
#   1446,
#   6419,
#   3446,
#   8824,
#   5569,
#   8570,
#   7498,
#   1473,
#   3934,
#   7084,
#   8824,
#   6419,
#   3446,
#   8824,
#   6489,
#   1473,
#   4930,
#   331,
#   8824,
#   7084,
#   7901,
#   1821,
#   2645,
#   8823],
#  [6961, 3664, 3589, 2536, 8824, 8823],
#  [6884, 8824, 8823],
#  [8824, 5809, 2862, 4235, 6419, 1536, 8823],
#  [4440, 2247, 6057, 3770, 6397, 104, 719, 8664, 8823],
#  [104, 719, 2863, 6465, 8823],
#  [335, 1473, 1224, 8824, 3852, 6379, 6859, 4389, 1224, 7298, 90, 5772, 8823],
#  [2304, 7835, 3575, 719, 7871, 2526, 8823],
#  [6438, 2160, 3718, 6269, 8823],
#  [4969,
#   6419,
#   8005,
#   6955,
#   8561,
#   2596,
#   719,
#   8232,
#   6419,
#   680,
#   8317,
#   4440,
#   2247,
#   2783,
#   2247,
#   4274,
#   2596,
#   2596,
#   719,
#   8232,
#   4115,
#   4969,
#   7584,
#   1560,
#   6605,
#   104,
#   4566,
#   3976,
#   2596,
#   8823],
#  [5782, 2596, 2673, 3770, 6954, 8823],
#  [5067, 5569, 3249, 6411, 5529, 8823],
#  [469, 8823],
#  [1683, 8824, 4090, 8823],
#  [1013, 104, 4829, 2269, 8748, 3838, 1634, 2183, 4205, 719, 2385, 8823],
#  [1126,
#   1321,
#   1224,
#   5550,
#   3180,
#   4115,
#   3664,
#   1675,
#   1224,
#   2247,
#   3866,
#   5728,
#   6842,
#   2596,
#   8823],
#  [104,
#   8020,
#   2596,
#   1731,
#   104,
#   7787,
#   3745,
#   5650,
#   4115,
#   6465,
#   1446,
#   1569,
#   104,
#   7787,
#   8724,
#   4115,
#   5256,
#   1473,
#   2596,
#   6671,
#   3770,
#   8131,
#   8824,
#   6018,
#   5317,
#   8605,
#   6435,
#   104,
#   7787,
#   657,
#   7099,
#   4115,
#   3770,
#   8824,
#   1301,
#   1126,
#   2960,
#   104,
#   90,
#   6960,
#   2418,
#   8823],
#  [5017, 6859, 3041, 104, 7787, 992, 6714, 8823],
#  [104,
#   8020,
#   2596,
#   2596,
#   6671,
#   992,
#   2349,
#   7099,
#   4115,
#   8437,
#   1550,
#   3629,
#   7237,
#   104,
#   1138,
#   8605,
#   6442,
#   4769,
#   8823],
# ...
#  [4633, 2488, 8824, 8247, 8823],
#  [104, 8020, 6241, 2663, 4399, 2826, 3770, 7176, 8823],
#  [8784, 4955, 1550, 4235, 4758, 7850, 8193, 3707, 2911, 2596, 732, 8823],
#  [2183,
#   85,
#   2247,
#   5703,
#   6419,
#   7882,
#   8403,
#   5550,
#   556,
#   1473,
#   1013,
#   104,
#   7446,
#   4115,
#   4397,
#   2160,
#   4235,
#   104,
#   4829,
#   2377,
#   2418,
#   8549,
#   1446,
#   3770,
#   2611,
#   2247,
#   104,
#   7787,
#   6057,
#   3178,
#   4115,
#   4397,
#   2160,
#   4429,
#   8823],
#  [1656, 8823],
#  [2783, 3770, 8427, 6671, 2596, 5090, 2183, 2247, 8605, 6489, 6221, 8823],
#  [2212, 5252, 1989, 1249, 4115, 1719, 2596, 8605, 2757, 954, 8823],
#  [7584,
#   162,
#   1276,
#   5317,
#   4196,
#   6476,
#   5317,
#   3770,
#   7008,
#   6241,
#   1102,
#   3580,
#   6241,
#   6269,
#   692,
#   2826,
#   7584,
#   8221,
#   5569,
#   6269,
#   1973,
#   5317,
#   3842,
#   2596,
#   7446,
#   6214,
#   6419,
#   4985,
#   7587,
#   1446,
#   3838,
#   7446,
#   6915,
#   1547,
#   3852,
#   5569,
#   6419,
#   5042,
#   147,
#   4769,
#   7584,
#   8221,
#   5569,
#   6948,
#   4115,
#   8626,
#   3852,
#   1446,
#   3852,
#   1759,
#   3770,
#   8824,
#   556,
#   3770,
#   8494,
#   4115,
#   90,
#   5317,
#   3770,
#   5246,
#   556,
#   8824,
#   6418,
#   4877,
#   104,
#   1161,
#   1719,
#   1095,
#   3852,
#   4829,
#   719,
#   2536,
#   7970,
#   1172,
#   6961,
#   1224,
#   2536,
#   3838,
#   1473,
#   4440,
#   2247,
#   3770,
#   4978,
#   1941,
#   2826,
#   636,
#   2596,
#   7446,
#   6214,
#   8823],
#  [1989, 6057, 6419, 7953, 1989, 6419, 1907, 6915, 3481, 403, 8259, 6241, 8823],
#  [104,
#   7787,
#   1835,
#   4440,
#   2184,
#   99,
#   104,
#   7787,
#   356,
#   2596,
#   4566,
#   90,
#   5659,
#   1473,
#   99,
#   104,
#   7787,
#   5659,
#   2596,
#   4566,
#   4349,
#   90,
#   8629,
#   8823],
#  [2596,
#   6671,
#   8549,
#   4115,
#   4969,
#   3347,
#   2890,
#   2862,
#   2826,
#   1208,
#   5317,
#   1426,
#   1446,
#   1013,
#   2596,
#   7446,
#   4115,
#   5669,
#   5640,
#   3770,
#   3275,
#   2596,
#   4829,
#   4701,
#   1208,
#   7210,
#   3770,
#   8131,
#   2244,
#   8532,
#   8410,
#   8824,
#   4447,
#   4196,
#   5703,
#   2207,
#   527,
#   7648,
#   5703,
#   1446,
#   3671,
#   8823],
#  [5456, 7446, 8824, 3770, 3106, 8824, 3770, 661, 8824, 3770, 8824, 8823],
#  [4205,
#   3121,
#   4115,
#   2596,
#   1473,
#   5456,
#   719,
#   8232,
#   8824,
#   8824,
#   2596,
#   5205,
#   6781,
#   6419,
#   1536,
#   1161,
#   2596,
#   8823],
#  [8050,
#   4758,
#   1473,
#   8824,
#   104,
#   6459,
#   1138,
#   2596,
#   4115,
#   8340,
#   1810,
#   1446,
#   104,
#   1138,
#   4115,
#   8340,
#   7084,
#   2596,
#   2596,
#   1731,
#   2183,
#   85,
#   2247,
#   3745,
#   410,
#   556,
#   2596,
#   2304,
#   1989,
#   3745,
#   410,
#   556,
#   6419,
#   7882,
#   2826,
#   8605,
#   1738,
#   104,
#   1161,
#   1719,
#   5105,
#   4235,
#   6419,
#   4577,
#   4715,
#   8823],
#  [6693, 8823],
#  [6856, 104, 5425, 3852, 5317, 3770, 3571, 8823],
#  [1473,
#   4388,
#   4577,
#   104,
#   7510,
#   6465,
#   6419,
#   4159,
#   4388,
#   4577,
#   6418,
#   104,
#   8232,
#   3702,
#   1473,
#   5569,
#   2862,
#   556,
#   6419,
#   8268,
#   2826,
#   6543,
#   1473,
#   99,
#   104,
#   7533,
#   7099,
#   3838,
#   2596,
#   8020,
#   2783,
#   1224,
#   2784,
#   8823],
#  [6725, 1941, 8823],
#  [8592, 8823],
#  [5205, 8193, 4447, 8823],
#  [2783, 8823],
#  [104, 7787, 2096, 4115, 2120, 6419, 8824, 4235, 8823],
#  [1446,
#   2596,
#   6671,
#   8171,
#   104,
#   6459,
#   8020,
#   2596,
#   6859,
#   7827,
#   4147,
#   3025,
#   4758,
#   7850,
#   2434,
#   8824,
#   1719,
#   104,
#   7787,
#   5299,
#   64,
#   4115,
#   6419,
#   1344,
#   2434,
#   8824,
#   1656,
#   3811,
#   1224,
#   5569,
#   6419,
#   8024,
#   4587,
#   7255,
#   3214,
#   2596,
#   8823],
#  [5456, 6671, 7584, 4137, 1872, 8823],
#  [2240, 6419, 1536, 2826, 8824, 104, 4713, 1138, 4115, 328, 8605, 1366, 8823],
#  [104, 1759, 2911, 2596, 8823],
#  [8748,
#   3770,
#   1050,
#   6269,
#   3770,
#   1550,
#   3770,
#   423,
#   4043,
#   2596,
#   719,
#   4115,
#   1509,
#   4812,
#   3852,
#   8823],
#  [5416, 2783, 8823],
#  [636,
#   2247,
#   4440,
#   6618,
#   104,
#   4191,
#   2596,
#   6516,
#   4115,
#   5550,
#   6465,
#   6419,
#   1434,
#   1473,
#   4619,
#   1989,
#   5596,
#   3481,
#   2826,
#   3664,
#   7383,
#   2596,
#   1161,
#   611,
#   7418,
#   2596,
#   8020,
#   6465,
#   8823],
#  [335, 8823],
#  [8193, 4566, 1995, 6418, 8823],
#  [2596,
#   1000,
#   2783,
#   104,
#   2784,
#   104,
#   7787,
#   5390,
#   104,
#   719,
#   2536,
#   4143,
#   2160,
#   556,
#   6543,
#   8823],
#  [4115, 3676, 1048, 3770, 2901, 2434, 3770, 1533, 8823],
#  [2596, 5205, 1719, 1126, 1989, 7495, 8823],
#  [104,
#   3328,
#   2596,
#   8403,
#   4256,
#   3180,
#   3770,
#   4319,
#   2183,
#   7348,
#   1600,
#   2826,
#   90,
#   7902,
#   4964,
#   5847,
#   8823],
#  [1473, 8823],
#  [1473,
#   2783,
#   2596,
#   4191,
#   2434,
#   3770,
#   2642,
#   8358,
#   5205,
#   104,
#   7776,
#   6693,
#   1095,
#   8193,
#   7418,
#   5317,
#   1282,
#   5205,
#   104,
#   1623,
#   6419,
#   3402,
#   1941,
#   4230,
#   6693,
#   8824,
#   2247,
#   8605,
#   3513,
#   4024,
#   7006,
#   2043,
#   2247,
#   6057,
#   1446,
#   8193,
#   7418,
#   4024,
#   2183,
#   2247,
#   556,
#   2596,
#   8823],
#  [8193, 1968, 7862, 6465, 1224, 2247, 7925, 8823],
#  [104,
#   7787,
#   5403,
#   1224,
#   2247,
#   5403,
#   1524,
#   1224,
#   2247,
#   7871,
#   5403,
#   443,
#   4882,
#   104,
#   3686,
#   8824,
#   6546,
#   104,
#   7787,
#   6057,
#   4877,
#   1249,
#   1224,
#   3384,
#   1750,
#   5017,
#   5750,
#   6419,
#   1859,
#   1224,
#   6262,
#   1750,
#   104,
#   4713,
#   4191,
#   1224,
#   6262,
#   1750,
#   8823],
#  [1550, 4877, 104, 5205, 7418, 1224, 6262, 1750, 4877, 8823],
#  [4877,
#   104,
#   3718,
#   4115,
#   6458,
#   7084,
#   4953,
#   7981,
#   4115,
#   2120,
#   259,
#   104,
#   2690,
#   2183,
#   5106,
#   2434,
#   8824,
#   104,
#   282,
#   6465,
#   2826,
#   2596,
#   1473,
#   2802,
#   1473,
#   3770,
#   6155,
#   4235,
#   8193,
#   6671,
#   8823],
#  [104, 5425, 2596, 1335, 3838, 4147, 3770, 2874, 8823],
#  [104,
#   719,
#   4610,
#   7776,
#   2043,
#   7475,
#   4115,
#   2596,
#   99,
#   104,
#   5569,
#   6419,
#   3513,
#   6489,
#   8605,
#   8221,
#   6961,
#   4610,
#   4846,
#   8715,
#   8490,
#   5750,
#   104,
#   4713,
#   8020,
#   3770,
#   3596,
#   5750,
#   556,
#   7193,
#   7776,
#   556,
#   7193,
#   3770,
#   7249,
#   8823],
#  [8824, 1224, 6961, 4610, 8824, 1224, 4584, 4240, 2434, 3770, 160, 8823],
#  [4702,
#   3770,
#   95,
#   8824,
#   8748,
#   282,
#   8824,
#   282,
#   6465,
#   4702,
#   3852,
#   8748,
#   7718,
#   104,
#   7787,
#   657,
#   4115,
#   2120,
#   6465,
#   8823],
#  [1550, 6693, 1249, 8823],
#  [104,
#   3686,
#   1161,
#   8781,
#   6419,
#   4727,
#   3770,
#   209,
#   2826,
#   3770,
#   1375,
#   104,
#   719,
#   7973,
#   1562,
#   2783,
#   2247,
#   3770,
#   3909,
#   556,
#   4982,
#   6948,
#   4440,
#   2247,
#   6419,
#   3824,
#   6948,
#   2183,
#   2247,
#   5462,
#   7147,
#   3852,
#   8823],
#  [104, 7787, 1700, 1609, 6671, 2596, 8823],
#  [104, 4191, 6833, 104, 719, 8232, 6419, 1375, 7084, 6833, 8823],
#  [104, 2115, 2783, 4196, 1750, 7787, 104, 636, 2596, 6998, 8823],
#  [1249, 7718, 2960, 104, 6438, 8824, 8823],
#  [6459, 2596, 5543, 7718, 2960, 104, 6438, 8824, 8823],
#  [8824, 8823],
#  [2515, 6155, 2515, 6155, 8823],
#  [335, 104, 8020, 8823],
#  [104, 7787, 657, 4115, 90, 3702, 3327, 2247, 3770, 8823],
#  [3471, 2160, 719, 2596, 8232, 7584, 4744, 8823],
#  [104, 2784, 104, 4713, 719, 1072, 8823],
#  [1989, 6600, 2826, 7584, 1973, 8823],
#  [6693, 8193, 4566, 6057, 4447, 4196, 3852, 8823],
#  [837, 768, 8823],
#  [2304,
#   1989,
#   3686,
#   4440,
#   3770,
#   3328,
#   2096,
#   4115,
#   3120,
#   2160,
#   7871,
#   8824,
#   5317,
#   1589,
#   2826,
#   6419,
#   7953,
#   7718,
#   4838,
#   556,
#   4440,
#   2543,
#   3384,
#   1750,
#   1138,
#   4115,
#   907,
#   8823],
#  [2596, 8823],
#  [104, 8232, 2783, 104, 1721, 556, 8823],
#  [719, 2596, 6961, 1072, 7227, 8823],
#  [6671, 2596, 4076, 8823],
#  [3770, 4066, 3770, 6489, 7084, 410, 4986, 3770, 3481, 5317, 7584, 8824, 8823],
#  [104, 4713, 8020, 1126, 104, 2784, 3852, 104, 7787, 6948, 8823],
#  [2596, 5782, 8460, 1750, 3277, 8824, 8823],
#  [104, 7787, 6948, 8823],
#  [104, 7787, 6057, 5778, 2596, 4115, 5542, 1750, 8823],
#  [636, 6459, 2596, 1138, 4115, 6531, 8823],
#  [8581, 7510, 1750, 6419, 5464, 8823],
#  [335, 8823],
#  [104, 26, 4115, 7776, 8823],
#  [5052,
#   2596,
#   1759,
#   8824,
#   8437,
#   1446,
#   4440,
#   8824,
#   1977,
#   2160,
#   6859,
#   3770,
#   5840,
#   4256,
#   1750,
#   7584,
#   6282,
#   4988,
#   6817,
#   2596,
#   4713,
#   4992,
#   1750,
#   7838,
#   5519,
#   8823],
#  [5052, 8823],
#  [2596, 140, 3770, 8824, 6671, 2596, 8823],
#  [4104, 8748, 7882, 26, 6419, 7965, 8823],
#  [8824, 7343, 4969, 2399, 2407, 2160, 4235, 8823],
#  [4207, 8823],
#  [4610,
#   8494,
#   2596,
#   2160,
#   187,
#   636,
#   2596,
#   5628,
#   1208,
#   6459,
#   2959,
#   5750,
#   4440,
#   8823],
#  [2184,
#   2959,
#   8824,
#   4877,
#   5557,
#   2183,
#   8824,
#   2120,
#   1750,
#   1731,
#   6269,
#   7795,
#   7795,
#   1475,
#   3770,
#   8824,
#   2826,
#   3770,
#   8824,
#   7882,
#   8068,
#   1804,
#   6269,
#   8611,
#   6269,
#   3770,
#   8824,
#   6334,
#   6925,
#   5317,
#   8824,
#   2596,
#   8020,
#   3770,
#   1941,
#   8823],
#  [1249,
#   4769,
#   104,
#   8232,
#   3770,
#   8824,
#   6269,
#   4391,
#   6859,
#   6419,
#   8697,
#   1473,
#   1228,
#   3178,
#   4115,
#   6943,
#   5317,
#   3770,
#   2836,
#   8824,
#   1473,
#   456,
#   2862,
#   5393,
#   8824,
#   2160,
#   3770,
#   8082,
#   2783,
#   6459,
#   2596,
#   8020,
#   636,
#   4115,
#   2120,
#   8823],
#  [6874, 5750, 2596, 8020, 6419, 647, 8823],
#  [104,
#   4713,
#   6271,
#   4440,
#   2596,
#   7893,
#   4196,
#   7226,
#   104,
#   1731,
#   2596,
#   7893,
#   4196,
#   2596,
#   4191,
#   8448,
#   8448,
#   8824,
#   103,
#   3513,
#   857,
#   7488,
#   5750,
#   2596,
#   7418,
#   104,
#   1161,
#   5270,
#   2596,
#   2160,
#   7084,
#   4440,
#   104,
#   8232,
#   522,
#   3516,
#   3481,
#   140,
#   5317,
#   85,
#   3770,
#   4953,
#   3481,
#   5390,
#   4877,
#   2596,
#   6269,
#   7584,
#   2529,
#   8823],
#  [1224, 5868, 4440, 8823],
#  [4500, 5550, 6465, 8823],
#  [8824,
#   5750,
#   6419,
#   6117,
#   2826,
#   1122,
#   4500,
#   4115,
#   8437,
#   6269,
#   6241,
#   1473,
#   2043,
#   4713,
#   5728,
#   4916,
#   6419,
#   1984,
#   2043,
#   2036,
#   6142,
#   2596,
#   8020,
#   2596,
#   8232,
#   6419,
#   5168,
#   6269,
#   7584,
#   3197,
#   2596,
#   4969,
#   4440,
#   2860,
#   5317,
#   2959,
#   6967,
#   104,
#   140,
#   2646,
#   8823],
#  [2596, 6792, 6334, 5119, 5782, 2959, 8823],
#  [104,
#   4713,
#   1719,
#   1126,
#   8193,
#   5759,
#   3121,
#   3489,
#   3852,
#   99,
#   2596,
#   1473,
#   104,
#   8020,
#   2183,
#   140,
#   992,
#   8437,
#   8823],
#  [5052, 8823],
#  [2596, 4713, 5759, 4969, 2160, 1446, 104, 5759, 4500, 8823],
#  [3686,
#   4196,
#   5885,
#   2596,
#   8020,
#   3852,
#   5205,
#   90,
#   124,
#   7718,
#   6057,
#   3686,
#   282,
#   1750,
#   8122,
#   8823],
#  [4276, 8272, 8824, 2596, 6671, 6419, 2721, 8611, 4695, 8823],
#  [4969, 2010, 2826, 3852, 8823],
#  [1989,
#   6057,
#   8824,
#   1473,
#   3770,
#   4349,
#   8006,
#   2596,
#   6671,
#   992,
#   1995,
#   7111,
#   7084,
#   3852,
#   2247,
#   4115,
#   8698,
#   3852,
#   4115,
#   6465,
#   1473,
#   8297,
#   1224,
#   2247,
#   4604,
#   2596,
#   5205,
#   6112,
#   3852,
#   8748,
#   3664,
#   3104,
#   8823],
#  [2860, 7702, 3408, 7199, 8823],
#  [2596, 5557, 1550, 2596, 6693, 8823],
#  [5557, 1550, 6093, 3770, 2446, 764, 8823],
#  [4256, 3180, 6419, 4916, 8823],
#  [104, 4566, 4969, 6465, 556, 2596, 1231, 8823],
#  [1013, 2596, 6671, 992, 4256, 1750, 6419, 3694, 245, 495, 1531, 8823],
#  [8824, 1907, 8720, 1347, 8824, 7789, 8824, 8824, 8115, 4096, 8823],
#  [1249, 8806, 1249, 8823],
#  [104, 4566, 670, 3852, 2862, 8823],
#  [8824, 8823],
#  [6419, 8024, 1910, 1668, 8193, 6225, 719, 1256, 6465, 8823],
#  [7343, 4500, 6465, 4389, 8823],
#  [6057, 4769, 7882, 6693, 6057, 4769, 8437, 7084, 1750, 8823],
#  [104, 4713, 8020, 8823],
#  [3784, 556, 3976, 8823],
#  [7871, 1531, 6018, 6419, 8824, 6419, 8824, 2596, 1750, 7389, 2596, 8823],
#  [6057, 5317, 4440, 749, 8823],
#  [3328, 2596, 1879, 7584, 8006, 7666, 8562, 8824, 5264, 8823],
#  [1224,
#   2247,
#   6366,
#   5317,
#   4037,
#   5456,
#   1138,
#   6465,
#   4389,
#   6418,
#   8193,
#   5205,
#   719,
#   6465,
#   8823],
#  [1224,
#   4566,
#   8781,
#   2862,
#   2596,
#   6170,
#   1750,
#   104,
#   7787,
#   8824,
#   1224,
#   4566,
#   4711,
#   3180,
#   5557,
#   2826,
#   3180,
#   2596,
#   4713,
#   39,
#   6419,
#   7781,
#   8823],
#  [4429, 8823],
#  [104, 7787, 798, 4440, 2247, 6419, 3513, 2862, 2826, 8605, 8823],
#  [3903,
#   4147,
#   3770,
#   2652,
#   4577,
#   2826,
#   8824,
#   1072,
#   5570,
#   4440,
#   719,
#   8824,
#   8824,
#   8824,
#   4256,
#   2535,
#   4115,
#   8824,
#   8824,
#   5750,
#   3898,
#   7731,
#   6419,
#   8824,
#   7103,
#   3770,
#   7103,
#   8824,
#   8823],
#  [99, 6459, 2596, 7985, 7584, 4540, 8823],
#  [1695, 1224, 6862, 8823],
#  [8824,
#   4235,
#   6246,
#   3770,
#   8824,
#   2596,
#   6192,
#   6269,
#   6955,
#   8824,
#   8824,
#   8824,
#   4440,
#   3770,
#   4349,
#   8824,
#   8351,
#   4440,
#   8824,
#   8232,
#   2247,
#   3770,
#   4875,
#   5707,
#   2596,
#   1968,
#   4969,
#   6269,
#   3852,
#   8823],
#  [2183, 2247, 8824, 6671, 2596, 4838, 8823],
#  [2043, 2247, 6057, 7084, 2596, 8823],
#  [6459, 2596, 719, 7701, 6401, 7465, 8823],
#  [3543,
#   8824,
#   8824,
#   8824,
#   8118,
#   5717,
#   1475,
#   8824,
#   1227,
#   7771,
#   4115,
#   2445,
#   2934,
#   556,
#   3402,
#   4341,
#   8824,
#   8823],
#  [8571, 2826, 1291, 3462, 8823],
#  [8824, 8823],
#  [8824, 8823],
#  [5052, 1989, 6693, 104, 5750, 4115, 6510, 4877, 636, 6671, 2596, 5090, 8823],
#  [6915, 104, 8232, 6419, 1375, 8823],
#  [4400, 2596, 4713, 2349, 1095, 3127, 1095, 2596, 876, 4115, 8823],
#  [7584, 4992, 4240, 6737, 4440, 7994, 1750, 8823],
#  [2596, 6671, 657, 4115, 90, 5519, 3770, 6086, 8823],
#  [5205, 104, 3718, 5317, 8823],
#  [3770, 6489, 4440, 1321, 5017, 5750, 4440, 6489, 8823],
#  [104, 7787, 7084, 3770, 7334, 4156, 2826, 2724, 7391, 8823],
#  [6948, 8823],
#  [6694, 6459, 7584, 6955, 1446, 4713, 8812, 6863, 3125, 8823],
#  [1473, 7226, 6459, 104, 4500, 4115, 4196, 2596, 8823],
#  [4877, 104, 7787, 6419, 6160, 2826, 3385, 1202, 1750, 8823],
#  [104, 7787, 6948, 8823],
#  [8784, 8823],
#  [4440, 2247, 5596, 1837, 104, 1161, 6459, 8823],
#  [104, 4713, 8020, 104, 1731, 104, 3131, 7701, 8823],
#  [104, 7787, 6057, 5772, 2247, 3838, 6419, 3843, 8823],
#  [719, 2596, 403, 68, 7584, 3589, 8823],
#  [2783, 2247, 6419, 3402, 245, 8823],
#  [4440,
#   6334,
#   2826,
#   3770,
#   5892,
#   7666,
#   4235,
#   6671,
#   7389,
#   7771,
#   6418,
#   1750,
#   8823],
#  [2828, 1020, 2596, 4829, 1968, 4969, 5317, 4235, 8824, 1335, 556, 2596, 8823],
#  [8247, 8823],
#  [3462, 8823],
#  [8824,
#   8824,
#   2826,
#   3770,
#   1849,
#   8824,
#   4260,
#   7722,
#   8824,
#   2826,
#   3770,
#   8824,
#   7722,
#   8824,
#   8824,
#   2826,
#   3770,
#   1062,
#   8823],
#  [1446, 5317, 7584, 6198, 4440, 2247, 6419, 97, 8823],
#  [1013, 2043, 2247, 3770, 429, 1071, 8823],
#  [5557,
#   8824,
#   6397,
#   2247,
#   3190,
#   6542,
#   2036,
#   7584,
#   8824,
#   7560,
#   7871,
#   8824,
#   8824,
#   104,
#   480,
#   1473,
#   6419,
#   4228,
#   8824,
#   8824,
#   2247,
#   3190,
#   8824,
#   8823],
#  [2783, 1220, 8823],
#  [8050, 8824, 7132, 8823],
#  [4470, 8823],
#  [2783, 2247, 7584, 1375, 8823],
#  [335, 8823],
#  [104,
#   5569,
#   584,
#   1013,
#   2596,
#   6225,
#   3976,
#   1750,
#   8513,
#   1931,
#   4115,
#   719,
#   4921,
#   8605,
#   8824,
#   3685,
#   2826,
#   5503,
#   6619,
#   7666,
#   4235,
#   8823],
#  [8824, 8823],
#  [104,
#   7787,
#   6948,
#   1473,
#   5415,
#   5415,
#   7284,
#   1473,
#   1671,
#   2304,
#   7147,
#   1224,
#   1473,
#   8824,
#   1095,
#   2304,
#   8823],
#  [6419, 2255, 1149, 4752, 2826, 8354, 5526, 6419, 8824, 8823],
#  [104,
#   1879,
#   3336,
#   4877,
#   2439,
#   2596,
#   4969,
#   6269,
#   6419,
#   105,
#   1473,
#   7227,
#   2596,
#   8020,
#   3852,
#   2596,
#   6671,
#   2862,
#   4235,
#   5317,
#   3770,
#   155,
#   8824,
#   7983,
#   3182,
#   6419,
#   4690,
#   768,
#   179,
#   3180,
#   4115,
#   4235,
#   6042,
#   6629,
#   8823],
#  [3327, 6671, 2596, 5105, 3770, 139, 5312, 8823],
#  [2304,
#   4440,
#   3273,
#   5703,
#   4969,
#   3770,
#   2678,
#   1693,
#   2434,
#   4188,
#   104,
#   4191,
#   7082,
#   8823],
#  [1473, 4440, 2247, 3852, 8823],
#  [104, 4713, 719, 4115, 1338, 6419, 4636, 5317, 7584, 7485, 7103, 8823],
#  [7929, 8824, 2596, 6961, 741, 4500, 6478, 4500, 6478, 8823],
#  [8824, 8823],
#  [8784,
#   1995,
#   3663,
#   8207,
#   2124,
#   104,
#   8020,
#   2596,
#   5750,
#   1750,
#   104,
#   5205,
#   282,
#   1446,
#   2596,
#   8020,
#   2783,
#   6419,
#   1536,
#   2826,
#   2430,
#   5750,
#   1750,
#   6057,
#   1750,
#   2630,
#   1989,
#   7389,
#   5750,
#   3770,
#   5415,
#   7718,
#   3770,
#   7284,
#   7718,
#   3770,
#   1671,
#   7718,
#   6334,
#   3700,
#   2826,
#   3770,
#   7828,
#   8823],
#  [1126, 7835, 3852, 3866, 8437, 2862, 2596, 8824, 8823],
#  [3852,
#   3866,
#   1071,
#   2862,
#   3903,
#   104,
#   7787,
#   2036,
#   5415,
#   1473,
#   6562,
#   1473,
#   1671,
#   529,
#   4440,
#   2247,
#   8046,
#   4877,
#   104,
#   5747,
#   2160,
#   7084,
#   2430,
#   7226,
#   6671,
#   8806,
#   1249,
#   7687,
#   1446,
#   5728,
#   7389,
#   8824,
#   3214,
#   104,
#   7787,
#   1013,
#   2596,
#   5205,
#   666,
#   4440,
#   4769,
#   1013,
#   2596,
#   4566,
#   2886,
#   1750,
#   104,
#   719,
#   4115,
#   4500,
#   8781,
#   5596,
#   8824,
#   8824,
#   6955,
#   3327,
#   6334,
#   2011,
#   3467,
#   7519,
#   4306,
#   6287,
#   1750,
#   636,
#   5379,
#   3664,
#   7692,
#   2247,
#   8823],
#  [4769, 7343, 1338, 3770, 3548, 7099, 1473, 4969, 7701, 4115, 6781, 8823],
#  [2783, 556, 8823],
#  [104, 4713, 1138, 4115, 90, 4838, 8823],
#  [104, 5782, 8020, 4440, 8823],
#  [104, 5750, 3852, 8823],
#  [104, 3328, 4349, 4550, 5167, 8410, 753, 8823],
#  ...]

# %% [markdown]
# # BUILDING OF SEQ2SEQ MODEL

# %% [markdown]
# # Creating Placeholders for the input and targets

# %%
def model_inputs():
    inputs = tf.placeholder(tf.int32, [None, None], name = 'input')
    targets = tf.placeholder(tf.int32, [None, None], name = 'target')
    lr = tf.placeholder(tf.float32, name = 'learning_rate')
    keep_prob = tf.placeholder(tf.float32, name = 'keep_prob')
    return inputs, targets, lr, keep_prob

# %% [markdown]
# # Preprocessing of targets

# %%
def preprocess_targets(targets, word2int, batch_size):
    left_side = tf.fill([batch_size, 1], word2int['<SOS>'])
    right_side = tf.strided_slice(targets, [0,0], [batch_size, -1], [1,1])
    preprocessed_targets = tf.concat([left_side, right_side], 1)
    return preprocessed_targets

# %% [markdown]
# # Creating the encoder of RNN layer

# %%
def encoder_rnn(rnn_inputs, rnn_size, num_layers, keep_prob, sequence_length):
    lstm = tf.contrib.rnn.BasicLSTMCell(rnn_size)
    lstm_dropout = tf.contrib.rnn.DropoutWrapper(lstm, input_keep_prob = keep_prob)
    encoder_cell = tf.contrib.rnn.MultiRNNCell([lstm_dropout] * num_layers)
    encoder_output, encoder_state = tf.nn.bidirectional_dynamic_rnn(cell_fw = encoder_cell,
                                                                    cell_bw = encoder_cell,
                                                                    sequence_length = sequence_length,
                                                                    inputs = rnn_inputs,
                                                                    dtype = tf.float32)
    return encoder_state

# %% [markdown]
# # Decoding of training set

# %%
def decode_training_set(encoder_state, decoder_cell, decoder_embedded_input, sequence_length, decoding_scope, output_function, keep_prob, batch_size):
    attention_states = tf.zeros([batch_size, 1, decoder_cell.output_size])
    attention_keys, attention_values, attention_score_function, attention_construct_function = tf.contrib.seq2seq.prepare_attention(attention_states, attention_option = "bahdanau", num_units = decoder_cell.output_size)
    training_decoder_function = tf.contrib.seq2seq.attention_decoder_fn_train(encoder_state[0],
                                                                              attention_keys,
                                                                              attention_values,
                                                                              attention_score_function,
                                                                              attention_construct_function,
                                                                              name = "attn_dec_train")
    decoder_output, decoder_final_state, decoder_final_context_state = tf.contrib.seq2seq.dynamic_rnn_decoder(decoder_cell,
                                                                                                              training_decoder_function,
                                                                                                              decoder_embedded_input,
                                                                                                              sequence_length,
                                                                                                              scope = decoding_scope)
    decoder_output_dropout = tf.nn.dropout(decoder_output, keep_prob)
    return output_function(decoder_output_dropout)

# %% [markdown]
# # Decoding of test/validation set

# %%
def decode_test_set(encoder_state, decoder_cell, decoder_embeddings_matrix, sos_id, eos_id, maximum_length, num_words, decoding_scope, output_function, keep_prob, batch_size):
    attention_states = tf.zeros([batch_size, 1, decoder_cell.output_size])
    attention_keys, attention_values, attention_score_function, attention_construct_function = tf.contrib.seq2seq.prepare_attention(attention_states, attention_option = "bahdanau", num_units = decoder_cell.output_size)
    test_decoder_function = tf.contrib.seq2seq.attention_decoder_fn_inference(output_function,
                                                                              encoder_state[0],
                                                                              attention_keys,
                                                                              attention_values,
                                                                              attention_score_function,
                                                                              attention_construct_function,
                                                                              decoder_embeddings_matrix,
                                                                              sos_id,
                                                                              eos_id,
                                                                              maximum_length,
                                                                              num_words,
                                                                              name = "attn_dec_inf")
    test_predictions, decoder_final_state, decoder_final_context_state = tf.contrib.seq2seq.dynamic_rnn_decoder(decoder_cell,
                                                                                                                test_decoder_function,
                                                                                                                scope = decoding_scope)
    return test_predictions

# %% [markdown]
# # Creating The Decoder rnn

# %%
def decoder_rnn(decoder_embedded_input, decoder_embeddings_matrix, encoder_state, num_words, sequence_length, rnn_size, num_layers, word2int, keep_prob, batch_size):
    with tf.variable_scope("decoding") as decoding_scope:
        lstm = tf.contrib.rnn.BasicLSTMCell(rnn_size)
        lstm_dropout = tf.contrib.rnn.DropoutWrapper(lstm, input_keep_prob = keep_prob)
        decoder_cell = tf.contrib.rnn.MultiRNNCell([lstm_dropout] * num_layers)
        weights = tf.truncated_normal_initializer(stddev = 0.1)
        biases = tf.zeros_initializer()
        output_function = lambda x: tf.contrib.layers.fully_connected(x,
                                                                      num_words,
                                                                      None,
                                                                      scope = decoding_scope,
                                                                      weights_initializer = weights,
                                                                      biases_initializer = biases)
        training_predictions = decode_training_set(encoder_state,
                                                   decoder_cell,
                                                   decoder_embedded_input,
                                                   sequence_length,
                                                   decoding_scope,
                                                   output_function,
                                                   keep_prob,
                                                   batch_size)
        decoding_scope.reuse_variables()
        test_predictions = decode_test_set(encoder_state,
                                           decoder_cell,
                                           decoder_embeddings_matrix,
                                           word2int['<SOS>'],
                                           word2int['<EOS>'],
                                           sequence_length - 1,
                                           num_words,
                                           decoding_scope,
                                           output_function,
                                           keep_prob,
                                           batch_size)
    return training_predictions, test_predictions

# %% [markdown]
# # Building final Model

# %%
def seq2seq_model(inputs, targets, keep_prob, batch_size, sequence_length, answers_num_words, questions_num_words, encoder_embedding_size, decoder_embedding_size, rnn_size, num_layers, questionswords2int):
    encoder_embedded_input = tf.contrib.layers.embed_sequence(inputs,
                                                              answers_num_words + 1,
                                                              encoder_embedding_size,
                                                              initializer = tf.random_uniform_initializer(0, 1))
    encoder_state = encoder_rnn(encoder_embedded_input, rnn_size, num_layers, keep_prob, sequence_length)
    preprocessed_targets = preprocess_targets(targets, questionswords2int, batch_size)
    decoder_embeddings_matrix = tf.Variable(tf.random_uniform([questions_num_words + 1, decoder_embedding_size], 0, 1))
    decoder_embedded_input = tf.nn.embedding_lookup(decoder_embeddings_matrix, preprocessed_targets)
    training_predictions, test_predictions = decoder_rnn(decoder_embedded_input,
                                                         decoder_embeddings_matrix,
                                                         encoder_state,
                                                         questions_num_words,
                                                         sequence_length,
                                                         rnn_size,
                                                         num_layers,
                                                         questionswords2int,
                                                         keep_prob,
                                                         batch_size)
    return training_predictions, test_predictions

# %% [markdown]
# # Starting of HyperParameters

# %%
epochs = 5
batch_size = 32
rnn_size = 512
num_layers = 512
encoding_embedding_size = 512
decoding_embedding_size = 512
learning_rate = 0.01
learning_rate_decay = 0.8
min_learning_rate = 0.0001
keep_probability = 0.5

# %% [markdown]
# # Defining a session

# %%
tf.reset_default_graph()
session = tf.InteractiveSession()

# %% [markdown]
# # Loading model inputs

# %%
inputs, targets, lr, keep_prob = model_inputs()

# %% [markdown]
# # Setting the sequence Link

# %%
sequence_length = tf.placeholder_with_default(25, None, name = 'sequence_length')

# %% [markdown]
# # Getting the shape of the input tensor

# %%
input_shape = tf.shape(inputs)

# %% [markdown]
# # Getting the training and test predictions

# %%
training_predictions, test_predictions = seq2seq_model(tf.reverse(inputs, [-1]),
                                                       targets,
                                                       keep_prob,
                                                       batch_size,
                                                       sequence_length,
                                                       len(answerswords2int),
                                                       len(questionswords2int),
                                                       encoding_embedding_size,
                                                       decoding_embedding_size,
                                                       rnn_size,
                                                       num_layers,
                                                       questionswords2int)

# %% [markdown]
# # Setting  up the loss error, the optimizer and gradient clipping

# %%
with tf.name_scope("optimization"):
    loss_error = tf.contrib.seq2seq.sequence_loss(training_predictions,
                                                  targets,
                                                  tf.ones([input_shape[0], sequence_length]))
    optimizer = tf.train.AdamOptimizer(learning_rate)
    gradients = optimizer.compute_gradients(loss_error)
    clipped_gradients = [(tf.clip_by_value(grad_tensor, -5., 5.), grad_variable) for grad_tensor, grad_variable in gradients if grad_tensor is not None]
    optimizer_gradient_clipping = optimizer.apply_gradients(clipped_gradients)

# %% [markdown]
# # Padding the sequences with PAD tokens

# %%
 def apply_padding(batch_of_sequences, word2int):
    max_sequence_length = max([len(sequence) for sequence in batch_of_sequences])
    return [sequence + [word2int['<PAD>']] * (max_sequence_length - len(sequence)) for sequence in batch_of_sequences]

# %% [markdown]
# # splitting the data into batches of questions and answers

# %%
def split_into_batches(questions, answers, batch_size):
    for batch_index in range(0, len(questions) // batch_size):
        start_index = batch_index * batch_size
        questions_in_batch = questions[start_index : start_index + batch_size]
        answers_in_batch = answers[start_index : start_index + batch_size]
        padded_questions_in_batch = np.array(apply_padding(questions_in_batch, questionswords2int))
        padded_answers_in_batch = np.array(apply_padding(answers_in_batch, answerswords2int))
        yield padded_questions_in_batch, padded_answers_in_batch

# %% [markdown]
# # spliting questions and answers in training and validation sets

# %%
training_validation_split = int(len(sorted_clean_questions) * 0.15)
training_questions = sorted_clean_questions[training_validation_split:]
training_answers = sorted_clean_answers[training_validation_split:]
validation_questions = sorted_clean_questions[:training_validation_split]
validation_answers = sorted_clean_answers[:training_validation_split]

# %% [markdown]
# # Training

# %%
batch_index_check_training_loss = 100
batch_index_check_validation_loss = ((len(training_questions)) // batch_size // 2) - 1
total_training_loss_error = 0
list_validation_loss_error = []
early_stopping_check = 0
early_stopping_stop = 1000
checkpoint = "E:\Data\cornell movie-dialogs corpus/chatbot_weights.ckpt" # For Windows users, replace this line of code by: checkpoint = "./chatbot_weights.ckpt"
session.run(tf.global_variables_initializer())
for epoch in range(1, epochs + 1):
    for batch_index, (padded_questions_in_batch, padded_answers_in_batch) in enumerate(split_into_batches(training_questions, training_answers, batch_size)):
        starting_time = time.time()
        _, batch_training_loss_error = session.run([optimizer_gradient_clipping, loss_error], {inputs: padded_questions_in_batch,
                                                                                               targets: padded_answers_in_batch,
                                                                                               lr: learning_rate,
                                                                                               sequence_length: padded_answers_in_batch.shape[1],
                                                                                               keep_prob: keep_probability})
        total_training_loss_error += batch_training_loss_error
        ending_time = time.time()
        batch_time = ending_time - starting_time
        if batch_index % batch_index_check_training_loss == 0:
            print('Epoch: {:>3}/{}, Batch: {:>4}/{}, Training Loss Error: {:>6.3f}, Training Time on 100 Batches: {:d} seconds'.format(epoch,
                                                                                                                                       epochs,
                                                                                                                                       batch_index,
                                                                                                                                       len(training_questions) // batch_size,
                                                                                                                                       total_training_loss_error / batch_index_check_training_loss,
                                                                                                                                       int(batch_time * batch_index_check_training_loss)))
            total_training_loss_error = 0
        if batch_index % batch_index_check_validation_loss == 0 and batch_index > 0:
            total_validation_loss_error = 0
            starting_time = time.time()
            for batch_index_validation, (padded_questions_in_batch, padded_answers_in_batch) in enumerate(split_into_batches(validation_questions, validation_answers, batch_size)):
                batch_validation_loss_error = session.run(loss_error, {inputs: padded_questions_in_batch,
                                                                       targets: padded_answers_in_batch,
                                                                       lr: learning_rate,
                                                                       sequence_length: padded_answers_in_batch.shape[1],
                                                                       keep_prob: 1})
                total_validation_loss_error += batch_validation_loss_error
            ending_time = time.time()
            batch_time = ending_time - starting_time
            average_validation_loss_error = total_validation_loss_error / (len(validation_questions) / batch_size)
            print('Validation Loss Error: {:>6.3f}, Batch Validation Time: {:d} seconds'.format(average_validation_loss_error, int(batch_time)))
            learning_rate *= learning_rate_decay
            if learning_rate < min_learning_rate:
                learning_rate = min_learning_rate
            list_validation_loss_error.append(average_validation_loss_error)
            if average_validation_loss_error <= min(list_validation_loss_error):
                print('I speak better now!!')
                early_stopping_check = 0
                saver = tf.train.Saver()
                saver.save(session, checkpoint)
            else:
                print("Sorry I do not speak better, I need to practice more.")
                early_stopping_check += 1
                if early_stopping_check == early_stopping_stop:
                    break
    if early_stopping_check == early_stopping_stop:
        print("My apologies, I cannot speak better anymore. This is the best I can do.")
        break
print("Game Over")
# Out:
# Epoch:   1/1, Batch:    0/28892, Training Loss Error:  0.091, Training Time on 100 Batches: 121 seconds
# Epoch:   1/1, Batch:  100/28892, Training Loss Error:  3.792, Training Time on 100 Batches: 93 seconds
# Epoch:   1/1, Batch:  200/28892, Training Loss Error:  2.771, Training Time on 100 Batches: 46 seconds
# Epoch:   1/1, Batch:  300/28892, Training Loss Error:  3.057, Training Time on 100 Batches: 45 seconds
# Epoch:   1/1, Batch:  400/28892, Training Loss Error:  2.745, Training Time on 100 Batches: 47 seconds
# Epoch:   1/1, Batch:  500/28892, Training Loss Error:  2.909, Training Time on 100 Batches: 43 seconds
# Epoch:   1/1, Batch:  600/28892, Training Loss Error:  2.945, Training Time on 100 Batches: 37 seconds
# Epoch:   1/1, Batch:  700/28892, Training Loss Error:  2.928, Training Time on 100 Batches: 93 seconds
# Epoch:   1/1, Batch:  800/28892, Training Loss Error:  2.841, Training Time on 100 Batches: 90 seconds
# Epoch:   1/1, Batch:  900/28892, Training Loss Error:  2.803, Training Time on 100 Batches: 33 seconds
# Epoch:   1/1, Batch: 1000/28892, Training Loss Error:  2.680, Training Time on 100 Batches: 73 seconds
# Epoch:   1/1, Batch: 1100/28892, Training Loss Error:  2.784, Training Time on 100 Batches: 46 seconds
# Epoch:   1/1, Batch: 1200/28892, Training Loss Error:  2.805, Training Time on 100 Batches: 41 seconds
# Epoch:   1/1, Batch: 1300/28892, Training Loss Error:  2.825, Training Time on 100 Batches: 29 seconds
# Epoch:   1/1, Batch: 1400/28892, Training Loss Error:  2.669, Training Time on 100 Batches: 63 seconds
# Epoch:   1/1, Batch: 1500/28892, Training Loss Error:  2.757, Training Time on 100 Batches: 50 seconds
# Epoch:   1/1, Batch: 1600/28892, Training Loss Error:  2.833, Training Time on 100 Batches: 35 seconds
# Epoch:   1/1, Batch: 1700/28892, Training Loss Error:  2.722, Training Time on 100 Batches: 28 seconds
# Epoch:   1/1, Batch: 1800/28892, Training Loss Error:  2.872, Training Time on 100 Batches: 28 seconds
# Epoch:   1/1, Batch: 1900/28892, Training Loss Error:  2.790, Training Time on 100 Batches: 25 seconds
# Epoch:   1/1, Batch: 2000/28892, Training Loss Error:  2.806, Training Time on 100 Batches: 42 seconds
# Epoch:   1/1, Batch: 2100/28892, Training Loss Error:  2.690, Training Time on 100 Batches: 24 seconds
# Epoch:   1/1, Batch: 2200/28892, Training Loss Error:  2.714, Training Time on 100 Batches: 27 seconds
# Epoch:   1/1, Batch: 2300/28892, Training Loss Error:  2.739, Training Time on 100 Batches: 43 seconds
# Epoch:   1/1, Batch: 2400/28892, Training Loss Error:  2.654, Training Time on 100 Batches: 21 seconds
# Epoch:   1/1, Batch: 2500/28892, Training Loss Error:  2.697, Training Time on 100 Batches: 32 seconds
# Epoch:   1/1, Batch: 2600/28892, Training Loss Error:  2.782, Training Time on 100 Batches: 16 seconds
# Epoch:   1/1, Batch: 2700/28892, Training Loss Error:  2.688, Training Time on 100 Batches: 28 seconds
# Epoch:   1/1, Batch: 2800/28892, Training Loss Error:  2.758, Training Time on 100 Batches: 44 seconds
# Epoch:   1/1, Batch: 2900/28892, Training Loss Error:  2.826, Training Time on 100 Batches: 48 seconds
# Epoch:   1/1, Batch: 3000/28892, Training Loss Error:  2.738, Training Time on 100 Batches: 19 seconds
# Epoch:   1/1, Batch: 3100/28892, Training Loss Error:  2.776, Training Time on 100 Batches: 38 seconds
# Epoch:   1/1, Batch: 3200/28892, Training Loss Error:  2.697, Training Time on 100 Batches: 27 seconds
# Epoch:   1/1, Batch: 3300/28892, Training Loss Error:  2.770, Training Time on 100 Batches: 21 seconds
# Epoch:   1/1, Batch: 3400/28892, Training Loss Error:  2.695, Training Time on 100 Batches: 25 seconds
# Epoch:   1/1, Batch: 3500/28892, Training Loss Error:  2.777, Training Time on 100 Batches: 37 seconds
# Epoch:   1/1, Batch: 3600/28892, Training Loss Error:  2.729, Training Time on 100 Batches: 23 seconds
# Epoch:   1/1, Batch: 3700/28892, Training Loss Error:  2.722, Training Time on 100 Batches: 24 seconds
# Epoch:   1/1, Batch: 3800/28892, Training Loss Error:  2.642, Training Time on 100 Batches: 22 seconds
# Epoch:   1/1, Batch: 3900/28892, Training Loss Error:  2.842, Training Time on 100 Batches: 42 seconds
# Epoch:   1/1, Batch: 4000/28892, Training Loss Error:  2.568, Training Time on 100 Batches: 17 seconds
# Epoch:   1/1, Batch: 4100/28892, Training Loss Error:  2.851, Training Time on 100 Batches: 39 seconds
# Epoch:   1/1, Batch: 4200/28892, Training Loss Error:  2.628, Training Time on 100 Batches: 33 seconds
# Epoch:   1/1, Batch: 4300/28892, Training Loss Error:  2.866, Training Time on 100 Batches: 51 seconds
# Epoch:   1/1, Batch: 4400/28892, Training Loss Error:  2.639, Training Time on 100 Batches: 25 seconds
# Epoch:   1/1, Batch: 4500/28892, Training Loss Error:  2.743, Training Time on 100 Batches: 37 seconds
# Epoch:   1/1, Batch: 4600/28892, Training Loss Error:  2.690, Training Time on 100 Batches: 32 seconds
# Epoch:   1/1, Batch: 4700/28892, Training Loss Error:  2.751, Training Time on 100 Batches: 24 seconds
# Epoch:   1/1, Batch: 4800/28892, Training Loss Error:  2.679, Training Time on 100 Batches: 47 seconds
# Epoch:   1/1, Batch: 4900/28892, Training Loss Error:  2.810, Training Time on 100 Batches: 26 seconds
# Epoch:   1/1, Batch: 5000/28892, Training Loss Error:  2.608, Training Time on 100 Batches: 26 seconds
# Epoch:   1/1, Batch: 5100/28892, Training Loss Error:  2.622, Training Time on 100 Batches: 27 seconds
# Epoch:   1/1, Batch: 5200/28892, Training Loss Error:  2.738, Training Time on 100 Batches: 31 seconds
# Epoch:   1/1, Batch: 5300/28892, Training Loss Error:  2.608, Training Time on 100 Batches: 35 seconds
# Epoch:   1/1, Batch: 5400/28892, Training Loss Error:  2.710, Training Time on 100 Batches: 27 seconds
# Epoch:   1/1, Batch: 5500/28892, Training Loss Error:  2.650, Training Time on 100 Batches: 41 seconds
# Epoch:   1/1, Batch: 5600/28892, Training Loss Error:  2.676, Training Time on 100 Batches: 38 seconds
# Epoch:   1/1, Batch: 5700/28892, Training Loss Error:  2.518, Training Time on 100 Batches: 62 seconds
# Epoch:   1/1, Batch: 5800/28892, Training Loss Error:  2.572, Training Time on 100 Batches: 41 seconds
# Epoch:   1/1, Batch: 5900/28892, Training Loss Error:  2.651, Training Time on 100 Batches: 21 seconds
# Epoch:   1/1, Batch: 6000/28892, Training Loss Error:  2.726, Training Time on 100 Batches: 45 seconds
# Epoch:   1/1, Batch: 6100/28892, Training Loss Error:  2.658, Training Time on 100 Batches: 26 seconds
# Epoch:   1/1, Batch: 6200/28892, Training Loss Error:  2.646, Training Time on 100 Batches: 23 seconds
# Epoch:   1/1, Batch: 6300/28892, Training Loss Error:  2.496, Training Time on 100 Batches: 46 seconds
# Epoch:   1/1, Batch: 6400/28892, Training Loss Error:  2.626, Training Time on 100 Batches: 20 seconds
# Epoch:   1/1, Batch: 6500/28892, Training Loss Error:  2.416, Training Time on 100 Batches: 33 seconds
# Epoch:   1/1, Batch: 6600/28892, Training Loss Error:  2.612, Training Time on 100 Batches: 21 seconds
# Epoch:   1/1, Batch: 6700/28892, Training Loss Error:  2.685, Training Time on 100 Batches: 25 seconds
# Epoch:   1/1, Batch: 6800/28892, Training Loss Error:  2.512, Training Time on 100 Batches: 29 seconds
# Epoch:   1/1, Batch: 6900/28892, Training Loss Error:  2.556, Training Time on 100 Batches: 40 seconds
# Epoch:   1/1, Batch: 7000/28892, Training Loss Error:  2.573, Training Time on 100 Batches: 20 seconds
# Epoch:   1/1, Batch: 7100/28892, Training Loss Error:  2.579, Training Time on 100 Batches: 33 seconds
# Epoch:   1/1, Batch: 7200/28892, Training Loss Error:  2.707, Training Time on 100 Batches: 29 seconds
# Epoch:   1/1, Batch: 7300/28892, Training Loss Error:  2.665, Training Time on 100 Batches: 29 seconds
# Epoch:   1/1, Batch: 7400/28892, Training Loss Error:  2.628, Training Time on 100 Batches: 24 seconds
# Epoch:   1/1, Batch: 7500/28892, Training Loss Error:  2.594, Training Time on 100 Batches: 22 seconds
# Epoch:   1/1, Batch: 7600/28892, Training Loss Error:  2.706, Training Time on 100 Batches: 30 seconds
# Epoch:   1/1, Batch: 7700/28892, Training Loss Error:  2.528, Training Time on 100 Batches: 38 seconds
# Epoch:   1/1, Batch: 7800/28892, Training Loss Error:  2.676, Training Time on 100 Batches: 22 seconds
# Epoch:   1/1, Batch: 7900/28892, Training Loss Error:  2.557, Training Time on 100 Batches: 29 seconds
# Epoch:   1/1, Batch: 8000/28892, Training Loss Error:  2.628, Training Time on 100 Batches: 21 seconds
# Epoch:   1/1, Batch: 8100/28892, Training Loss Error:  2.531, Training Time on 100 Batches: 31 seconds
# Epoch:   1/1, Batch: 8200/28892, Training Loss Error:  2.656, Training Time on 100 Batches: 23 seconds
# Epoch:   1/1, Batch: 8300/28892, Training Loss Error:  2.655, Training Time on 100 Batches: 44 seconds
# Epoch:   1/1, Batch: 8400/28892, Training Loss Error:  2.676, Training Time on 100 Batches: 26 seconds
# Epoch:   1/1, Batch: 8500/28892, Training Loss Error:  2.521, Training Time on 100 Batches: 38 seconds
# Epoch:   1/1, Batch: 8600/28892, Training Loss Error:  2.655, Training Time on 100 Batches: 21 seconds
# Epoch:   1/1, Batch: 8700/28892, Training Loss Error:  2.636, Training Time on 100 Batches: 62 seconds
# Epoch:   1/1, Batch: 8800/28892, Training Loss Error:  2.460, Training Time on 100 Batches: 55 seconds
# Epoch:   1/1, Batch: 8900/28892, Training Loss Error:  2.514, Training Time on 100 Batches: 34 seconds
# Epoch:   1/1, Batch: 9000/28892, Training Loss Error:  2.602, Training Time on 100 Batches: 79 seconds
# Epoch:   1/1, Batch: 9100/28892, Training Loss Error:  2.571, Training Time on 100 Batches: 45 seconds
# Epoch:   1/1, Batch: 9200/28892, Training Loss Error:  2.549, Training Time on 100 Batches: 31 seconds
# Epoch:   1/1, Batch: 9300/28892, Training Loss Error:  2.761, Training Time on 100 Batches: 38 seconds
# Epoch:   1/1, Batch: 9400/28892, Training Loss Error:  2.495, Training Time on 100 Batches: 50 seconds
# Epoch:   1/1, Batch: 9500/28892, Training Loss Error:  2.609, Training Time on 100 Batches: 34 seconds
# Epoch:   1/1, Batch: 9600/28892, Training Loss Error:  2.503, Training Time on 100 Batches: 40 seconds
# Epoch:   1/1, Batch: 9700/28892, Training Loss Error:  2.545, Training Time on 100 Batches: 26 seconds
# Epoch:   1/1, Batch: 9800/28892, Training Loss Error:  2.536, Training Time on 100 Batches: 26 seconds
# Epoch:   1/1, Batch: 9900/28892, Training Loss Error:  2.677, Training Time on 100 Batches: 58 seconds
# Epoch:   1/1, Batch: 10000/28892, Training Loss Error:  2.629, Training Time on 100 Batches: 35 seconds
# Epoch:   1/1, Batch: 10100/28892, Training Loss Error:  2.521, Training Time on 100 Batches: 22 seconds
# Epoch:   1/1, Batch: 10200/28892, Training Loss Error:  2.535, Training Time on 100 Batches: 35 seconds
# Epoch:   1/1, Batch: 10300/28892, Training Loss Error:  2.672, Training Time on 100 Batches: 63 seconds
# Epoch:   1/1, Batch: 10400/28892, Training Loss Error:  2.472, Training Time on 100 Batches: 26 seconds
# Epoch:   1/1, Batch: 10500/28892, Training Loss Error:  2.622, Training Time on 100 Batches: 44 seconds
# Epoch:   1/1, Batch: 10600/28892, Training Loss Error:  2.515, Training Time on 100 Batches: 42 seconds
# Epoch:   1/1, Batch: 10700/28892, Training Loss Error:  2.694, Training Time on 100 Batches: 34 seconds
# Epoch:   1/1, Batch: 10800/28892, Training Loss Error:  2.578, Training Time on 100 Batches: 33 seconds
# Epoch:   1/1, Batch: 10900/28892, Training Loss Error:  2.599, Training Time on 100 Batches: 32 seconds
# Epoch:   1/1, Batch: 11000/28892, Training Loss Error:  2.444, Training Time on 100 Batches: 36 seconds
# Epoch:   1/1, Batch: 11100/28892, Training Loss Error:  2.658, Training Time on 100 Batches: 37 seconds
# Epoch:   1/1, Batch: 11200/28892, Training Loss Error:  2.578, Training Time on 100 Batches: 36 seconds
# Epoch:   1/1, Batch: 11300/28892, Training Loss Error:  2.662, Training Time on 100 Batches: 35 seconds
# Epoch:   1/1, Batch: 11400/28892, Training Loss Error:  2.572, Training Time on 100 Batches: 26 seconds
# Epoch:   1/1, Batch: 11500/28892, Training Loss Error:  2.618, Training Time on 100 Batches: 31 seconds
# Epoch:   1/1, Batch: 11600/28892, Training Loss Error:  2.629, Training Time on 100 Batches: 23 seconds
# Epoch:   1/1, Batch: 11700/28892, Training Loss Error:  2.595, Training Time on 100 Batches: 28 seconds
# Epoch:   1/1, Batch: 11800/28892, Training Loss Error:  2.577, Training Time on 100 Batches: 29 seconds
# Epoch:   1/1, Batch: 11900/28892, Training Loss Error:  2.587, Training Time on 100 Batches: 38 seconds
# Epoch:   1/1, Batch: 12000/28892, Training Loss Error:  2.444, Training Time on 100 Batches: 41 seconds
# Epoch:   1/1, Batch: 12100/28892, Training Loss Error:  2.689, Training Time on 100 Batches: 42 seconds
# Epoch:   1/1, Batch: 12200/28892, Training Loss Error:  2.627, Training Time on 100 Batches: 30 seconds
# Epoch:   1/1, Batch: 12300/28892, Training Loss Error:  2.503, Training Time on 100 Batches: 38 seconds
# Epoch:   1/1, Batch: 12400/28892, Training Loss Error:  2.500, Training Time on 100 Batches: 53 seconds
# Epoch:   1/1, Batch: 12500/28892, Training Loss Error:  2.511, Training Time on 100 Batches: 44 seconds
# Epoch:   1/1, Batch: 12600/28892, Training Loss Error:  2.659, Training Time on 100 Batches: 45 seconds
# Epoch:   1/1, Batch: 12700/28892, Training Loss Error:  2.516, Training Time on 100 Batches: 27 seconds
# Epoch:   1/1, Batch: 12800/28892, Training Loss Error:  2.510, Training Time on 100 Batches: 30 seconds
# Epoch:   1/1, Batch: 12900/28892, Training Loss Error:  2.606, Training Time on 100 Batches: 32 seconds
# Epoch:   1/1, Batch: 13000/28892, Training Loss Error:  2.568, Training Time on 100 Batches: 34 seconds
# Epoch:   1/1, Batch: 13100/28892, Training Loss Error:  2.550, Training Time on 100 Batches: 55 seconds
# Epoch:   1/1, Batch: 13200/28892, Training Loss Error:  2.540, Training Time on 100 Batches: 38 seconds
# Epoch:   1/1, Batch: 13300/28892, Training Loss Error:  2.482, Training Time on 100 Batches: 40 seconds
# Epoch:   1/1, Batch: 13400/28892, Training Loss Error:  2.610, Training Time on 100 Batches: 30 seconds
# Epoch:   1/1, Batch: 13500/28892, Training Loss Error:  2.520, Training Time on 100 Batches: 28 seconds
# Epoch:   1/1, Batch: 13600/28892, Training Loss Error:  2.517, Training Time on 100 Batches: 36 seconds
# Epoch:   1/1, Batch: 13700/28892, Training Loss Error:  2.640, Training Time on 100 Batches: 57 seconds
# Epoch:   1/1, Batch: 13800/28892, Training Loss Error:  2.670, Training Time on 100 Batches: 31 seconds
# Epoch:   1/1, Batch: 13900/28892, Training Loss Error:  2.426, Training Time on 100 Batches: 34 seconds
# Epoch:   1/1, Batch: 14000/28892, Training Loss Error:  2.628, Training Time on 100 Batches: 36 seconds
# Epoch:   1/1, Batch: 14100/28892, Training Loss Error:  2.417, Training Time on 100 Batches: 45 seconds
# Epoch:   1/1, Batch: 14200/28892, Training Loss Error:  2.584, Training Time on 100 Batches: 25 seconds
# Epoch:   1/1, Batch: 14300/28892, Training Loss Error:  2.603, Training Time on 100 Batches: 34 seconds
# Epoch:   1/1, Batch: 14400/28892, Training Loss Error:  2.635, Training Time on 100 Batches: 45 seconds
# Validation Loss Error:  2.739, Batch Validation Time: 424 seconds
# I speak better now!!
# Epoch:   1/1, Batch: 14500/28892, Training Loss Error:  2.535, Training Time on 100 Batches: 31 seconds
# Epoch:   1/1, Batch: 14600/28892, Training Loss Error:  2.480, Training Time on 100 Batches: 46 seconds
# Epoch:   1/1, Batch: 14700/28892, Training Loss Error:  2.356, Training Time on 100 Batches: 38 seconds
# Epoch:   1/1, Batch: 14800/28892, Training Loss Error:  2.642, Training Time on 100 Batches: 32 seconds
# Epoch:   1/1, Batch: 14900/28892, Training Loss Error:  2.420, Training Time on 100 Batches: 39 seconds
# Epoch:   1/1, Batch: 15000/28892, Training Loss Error:  2.508, Training Time on 100 Batches: 31 seconds
# Epoch:   1/1, Batch: 15100/28892, Training Loss Error:  2.507, Training Time on 100 Batches: 58 seconds
# Epoch:   1/1, Batch: 15200/28892, Training Loss Error:  2.627, Training Time on 100 Batches: 30 seconds
# Epoch:   1/1, Batch: 15300/28892, Training Loss Error:  2.506, Training Time on 100 Batches: 61 seconds
# Epoch:   1/1, Batch: 15400/28892, Training Loss Error:  2.470, Training Time on 100 Batches: 50 seconds
# Epoch:   1/1, Batch: 15500/28892, Training Loss Error:  2.499, Training Time on 100 Batches: 90 seconds
# Epoch:   1/1, Batch: 15600/28892, Training Loss Error:  2.525, Training Time on 100 Batches: 62 seconds
# Epoch:   1/1, Batch: 15700/28892, Training Loss Error:  2.471, Training Time on 100 Batches: 40 seconds
# Epoch:   1/1, Batch: 15800/28892, Training Loss Error:  2.675, Training Time on 100 Batches: 114 seconds
# Epoch:   1/1, Batch: 15900/28892, Training Loss Error:  2.547, Training Time on 100 Batches: 34 seconds
# Epoch:   1/1, Batch: 16000/28892, Training Loss Error:  2.556, Training Time on 100 Batches: 55 seconds
# Epoch:   1/1, Batch: 16100/28892, Training Loss Error:  3.492, Training Time on 100 Batches: 28 seconds
# Epoch:   1/1, Batch: 16200/28892, Training Loss Error: 25.454, Training Time on 100 Batches: 58 seconds
# Epoch:   1/1, Batch: 16300/28892, Training Loss Error:  4.196, Training Time on 100 Batches: 53 seconds
# Epoch:   1/1, Batch: 16400/28892, Training Loss Error:  3.746, Training Time on 100 Batches: 65 seconds
# Epoch:   1/1, Batch: 16500/28892, Training Loss Error:  3.760, Training Time on 100 Batches: 37 seconds
# Epoch:   1/1, Batch: 16600/28892, Training Loss Error:  3.383, Training Time on 100 Batches: 56 seconds
# Epoch:   1/1, Batch: 16700/28892, Training Loss Error:  3.326, Training Time on 100 Batches: 44 seconds
# Epoch:   1/1, Batch: 16800/28892, Training Loss Error:  3.266, Training Time on 100 Batches: 48 seconds
# Epoch:   1/1, Batch: 16900/28892, Training Loss Error:  3.162, Training Time on 100 Batches: 45 seconds
# Epoch:   1/1, Batch: 17000/28892, Training Loss Error:  3.121, Training Time on 100 Batches: 30 seconds
# Epoch:   1/1, Batch: 17100/28892, Training Loss Error:  3.140, Training Time on 100 Batches: 60 seconds
# Epoch:   1/1, Batch: 17200/28892, Training Loss Error:  3.089, Training Time on 100 Batches: 59 seconds
# Epoch:   1/1, Batch: 17300/28892, Training Loss Error:  3.085, Training Time on 100 Batches: 31 seconds
# Epoch:   1/1, Batch: 17400/28892, Training Loss Error:  3.048, Training Time on 100 Batches: 51 seconds
# Epoch:   1/1, Batch: 17500/28892, Training Loss Error:  3.005, Training Time on 100 Batches: 69 seconds
# Epoch:   1/1, Batch: 17600/28892, Training Loss Error:  3.043, Training Time on 100 Batches: 50 seconds
# Epoch:   1/1, Batch: 17700/28892, Training Loss Error:  2.965, Training Time on 100 Batches: 38 seconds
# Epoch:   1/1, Batch: 17800/28892, Training Loss Error:  2.956, Training Time on 100 Batches: 38 seconds
# Epoch:   1/1, Batch: 17900/28892, Training Loss Error:  2.796, Training Time on 100 Batches: 34 seconds
# Epoch:   1/1, Batch: 18000/28892, Training Loss Error:  2.922, Training Time on 100 Batches: 70 seconds
# Epoch:   1/1, Batch: 18100/28892, Training Loss Error:  2.936, Training Time on 100 Batches: 39 seconds
# Epoch:   1/1, Batch: 18200/28892, Training Loss Error:  2.814, Training Time on 100 Batches: 39 seconds
# Epoch:   1/1, Batch: 18300/28892, Training Loss Error:  2.829, Training Time on 100 Batches: 41 seconds
# Epoch:   1/1, Batch: 18400/28892, Training Loss Error:  2.974, Training Time on 100 Batches: 32 seconds
# Epoch:   1/1, Batch: 18500/28892, Training Loss Error:  2.822, Training Time on 100 Batches: 65 seconds
# Epoch:   1/1, Batch: 18600/28892, Training Loss Error:  2.739, Training Time on 100 Batches: 51 seconds
# Epoch:   1/1, Batch: 18700/28892, Training Loss Error:  2.819, Training Time on 100 Batches: 59 seconds
# Epoch:   1/1, Batch: 18800/28892, Training Loss Error:  2.909, Training Time on 100 Batches: 27 seconds
# Epoch:   1/1, Batch: 18900/28892, Training Loss Error:  2.856, Training Time on 100 Batches: 59 seconds
# Epoch:   1/1, Batch: 19000/28892, Training Loss Error:  2.865, Training Time on 100 Batches: 31 seconds
# Epoch:   1/1, Batch: 19100/28892, Training Loss Error:  2.803, Training Time on 100 Batches: 47 seconds
# Epoch:   1/1, Batch: 19200/28892, Training Loss Error:  2.935, Training Time on 100 Batches: 36 seconds
# Epoch:   1/1, Batch: 19300/28892, Training Loss Error:  2.790, Training Time on 100 Batches: 49 seconds
# Epoch:   1/1, Batch: 19400/28892, Training Loss Error:  2.856, Training Time on 100 Batches: 44 seconds
# Epoch:   1/1, Batch: 19500/28892, Training Loss Error:  2.789, Training Time on 100 Batches: 50 seconds
# Epoch:   1/1, Batch: 19600/28892, Training Loss Error:  2.981, Training Time on 100 Batches: 63 seconds
# Epoch:   1/1, Batch: 19700/28892, Training Loss Error:  2.748, Training Time on 100 Batches: 39 seconds
# Epoch:   1/1, Batch: 19800/28892, Training Loss Error:  2.808, Training Time on 100 Batches: 63 seconds
# Epoch:   1/1, Batch: 19900/28892, Training Loss Error:  2.699, Training Time on 100 Batches: 32 seconds
# Epoch:   1/1, Batch: 20000/28892, Training Loss Error:  2.875, Training Time on 100 Batches: 31 seconds
# Epoch:   1/1, Batch: 20100/28892, Training Loss Error:  2.712, Training Time on 100 Batches: 42 seconds
# Epoch:   1/1, Batch: 20200/28892, Training Loss Error:  2.650, Training Time on 100 Batches: 41 seconds
# Epoch:   1/1, Batch: 20300/28892, Training Loss Error:  2.746, Training Time on 100 Batches: 69 seconds
# Epoch:   1/1, Batch: 20400/28892, Training Loss Error:  2.716, Training Time on 100 Batches: 32 seconds
# Epoch:   1/1, Batch: 20500/28892, Training Loss Error:  2.632, Training Time on 100 Batches: 42 seconds
# Epoch:   1/1, Batch: 20600/28892, Training Loss Error:  2.818, Training Time on 100 Batches: 83 seconds
# Epoch:   1/1, Batch: 20700/28892, Training Loss Error:  2.739, Training Time on 100 Batches: 54 seconds
# Epoch:   1/1, Batch: 20800/28892, Training Loss Error:  2.940, Training Time on 100 Batches: 51 seconds
# Epoch:   1/1, Batch: 20900/28892, Training Loss Error:  2.613, Training Time on 100 Batches: 80 seconds
# Epoch:   1/1, Batch: 21000/28892, Training Loss Error:  2.639, Training Time on 100 Batches: 50 seconds
# Epoch:   1/1, Batch: 21100/28892, Training Loss Error:  2.799, Training Time on 100 Batches: 31 seconds
# Epoch:   1/1, Batch: 21200/28892, Training Loss Error:  2.684, Training Time on 100 Batches: 49 seconds
# Epoch:   1/1, Batch: 21300/28892, Training Loss Error:  2.584, Training Time on 100 Batches: 80 seconds
# Epoch:   1/1, Batch: 21400/28892, Training Loss Error:  2.684, Training Time on 100 Batches: 82 seconds
# Epoch:   1/1, Batch: 21500/28892, Training Loss Error:  2.637, Training Time on 100 Batches: 63 seconds
# Epoch:   1/1, Batch: 21600/28892, Training Loss Error:  2.858, Training Time on 100 Batches: 53 seconds
# Epoch:   1/1, Batch: 21700/28892, Training Loss Error:  2.711, Training Time on 100 Batches: 34 seconds
# Epoch:   1/1, Batch: 21800/28892, Training Loss Error:  2.600, Training Time on 100 Batches: 65 seconds
# Epoch:   1/1, Batch: 21900/28892, Training Loss Error:  2.697, Training Time on 100 Batches: 62 seconds
# Epoch:   1/1, Batch: 22000/28892, Training Loss Error:  2.725, Training Time on 100 Batches: 44 seconds
# Epoch:   1/1, Batch: 22100/28892, Training Loss Error:  2.664, Training Time on 100 Batches: 55 seconds
# Epoch:   1/1, Batch: 22200/28892, Training Loss Error:  2.724, Training Time on 100 Batches: 37 seconds
# Epoch:   1/1, Batch: 22300/28892, Training Loss Error:  2.850, Training Time on 100 Batches: 63 seconds
# Epoch:   1/1, Batch: 22400/28892, Training Loss Error:  2.759, Training Time on 100 Batches: 44 seconds
# Epoch:   1/1, Batch: 22500/28892, Training Loss Error:  2.725, Training Time on 100 Batches: 55 seconds
# Epoch:   1/1, Batch: 22600/28892, Training Loss Error:  2.717, Training Time on 100 Batches: 29 seconds
# Epoch:   1/1, Batch: 22700/28892, Training Loss Error:  2.620, Training Time on 100 Batches: 33 seconds
# Epoch:   1/1, Batch: 22800/28892, Training Loss Error:  2.645, Training Time on 100 Batches: 109 seconds
# Epoch:   1/1, Batch: 22900/28892, Training Loss Error:  2.608, Training Time on 100 Batches: 44 seconds
# Epoch:   1/1, Batch: 23000/28892, Training Loss Error:  2.589, Training Time on 100 Batches: 41 seconds
# Epoch:   1/1, Batch: 23100/28892, Training Loss Error:  2.679, Training Time on 100 Batches: 29 seconds
# Epoch:   1/1, Batch: 23200/28892, Training Loss Error:  2.653, Training Time on 100 Batches: 38 seconds
# Epoch:   1/1, Batch: 23300/28892, Training Loss Error:  2.777, Training Time on 100 Batches: 69 seconds
# Epoch:   1/1, Batch: 23400/28892, Training Loss Error:  2.773, Training Time on 100 Batches: 36 seconds
# Epoch:   1/1, Batch: 23500/28892, Training Loss Error:  2.688, Training Time on 100 Batches: 52 seconds
# Epoch:   1/1, Batch: 23600/28892, Training Loss Error:  2.634, Training Time on 100 Batches: 38 seconds
# Epoch:   1/1, Batch: 23700/28892, Training Loss Error:  2.525, Training Time on 100 Batches: 114 seconds
# Epoch:   1/1, Batch: 23800/28892, Training Loss Error:  2.600, Training Time on 100 Batches: 37 seconds
# Epoch:   1/1, Batch: 23900/28892, Training Loss Error:  2.677, Training Time on 100 Batches: 37 seconds
# Epoch:   1/1, Batch: 24000/28892, Training Loss Error:  2.645, Training Time on 100 Batches: 36 seconds
# Epoch:   1/1, Batch: 24100/28892, Training Loss Error:  2.652, Training Time on 100 Batches: 97 seconds
# Epoch:   1/1, Batch: 24200/28892, Training Loss Error:  2.843, Training Time on 100 Batches: 33 seconds
# Epoch:   1/1, Batch: 24300/28892, Training Loss Error:  2.814, Training Time on 100 Batches: 40 seconds
# Epoch:   1/1, Batch: 24400/28892, Training Loss Error:  2.627, Training Time on 100 Batches: 60 seconds
# Epoch:   1/1, Batch: 24500/28892, Training Loss Error:  2.642, Training Time on 100 Batches: 41 seconds
# Epoch:   1/1, Batch: 24600/28892, Training Loss Error:  2.566, Training Time on 100 Batches: 55 seconds
# Epoch:   1/1, Batch: 24700/28892, Training Loss Error:  2.625, Training Time on 100 Batches: 34 seconds
# Epoch:   1/1, Batch: 24800/28892, Training Loss Error:  2.592, Training Time on 100 Batches: 62 seconds
# Epoch:   1/1, Batch: 24900/28892, Training Loss Error:  2.555, Training Time on 100 Batches: 78 seconds
# Epoch:   1/1, Batch: 25000/28892, Training Loss Error:  2.677, Training Time on 100 Batches: 55 seconds
# Epoch:   1/1, Batch: 25100/28892, Training Loss Error:  2.697, Training Time on 100 Batches: 37 seconds
# Epoch:   1/1, Batch: 25200/28892, Training Loss Error:  2.705, Training Time on 100 Batches: 56 seconds
# Epoch:   1/1, Batch: 25300/28892, Training Loss Error:  2.652, Training Time on 100 Batches: 41 seconds
# Epoch:   1/1, Batch: 25400/28892, Training Loss Error:  2.655, Training Time on 100 Batches: 67 seconds
# Epoch:   1/1, Batch: 25500/28892, Training Loss Error:  2.622, Training Time on 100 Batches: 42 seconds
# Epoch:   1/1, Batch: 25600/28892, Training Loss Error:  2.691, Training Time on 100 Batches: 29 seconds
# Epoch:   1/1, Batch: 25700/28892, Training Loss Error:  2.585, Training Time on 100 Batches: 61 seconds
# Epoch:   1/1, Batch: 25800/28892, Training Loss Error:  2.642, Training Time on 100 Batches: 36 seconds
# Epoch:   1/1, Batch: 25900/28892, Training Loss Error:  2.505, Training Time on 100 Batches: 40 seconds
# Epoch:   1/1, Batch: 26000/28892, Training Loss Error:  2.557, Training Time on 100 Batches: 29 seconds
# Epoch:   1/1, Batch: 26100/28892, Training Loss Error:  2.604, Training Time on 100 Batches: 47 seconds
# Epoch:   1/1, Batch: 26200/28892, Training Loss Error:  2.694, Training Time on 100 Batches: 37 seconds
# Epoch:   1/1, Batch: 26300/28892, Training Loss Error:  2.557, Training Time on 100 Batches: 49 seconds
# Epoch:   1/1, Batch: 26400/28892, Training Loss Error:  2.543, Training Time on 100 Batches: 34 seconds
# Epoch:   1/1, Batch: 26500/28892, Training Loss Error:  2.666, Training Time on 100 Batches: 43 seconds
# Epoch:   1/1, Batch: 26600/28892, Training Loss Error:  2.589, Training Time on 100 Batches: 41 seconds
# Epoch:   1/1, Batch: 26700/28892, Training Loss Error:  2.608, Training Time on 100 Batches: 39 seconds
# Epoch:   1/1, Batch: 26800/28892, Training Loss Error:  2.640, Training Time on 100 Batches: 52 seconds
# Epoch:   1/1, Batch: 26900/28892, Training Loss Error:  2.665, Training Time on 100 Batches: 30 seconds
# Epoch:   1/1, Batch: 27000/28892, Training Loss Error:  2.560, Training Time on 100 Batches: 32 seconds
# Epoch:   1/1, Batch: 27100/28892, Training Loss Error:  2.636, Training Time on 100 Batches: 37 seconds
# Epoch:   1/1, Batch: 27200/28892, Training Loss Error:  2.549, Training Time on 100 Batches: 40 seconds
# Epoch:   1/1, Batch: 27300/28892, Training Loss Error:  2.707, Training Time on 100 Batches: 35 seconds
# Epoch:   1/1, Batch: 27400/28892, Training Loss Error:  2.731, Training Time on 100 Batches: 31 seconds
# Epoch:   1/1, Batch: 27500/28892, Training Loss Error:  2.620, Training Time on 100 Batches: 51 seconds
# Epoch:   1/1, Batch: 27600/28892, Training Loss Error:  2.539, Training Time on 100 Batches: 48 seconds
# Epoch:   1/1, Batch: 27700/28892, Training Loss Error:  2.596, Training Time on 100 Batches: 45 seconds
# Epoch:   1/1, Batch: 27800/28892, Training Loss Error:  2.635, Training Time on 100 Batches: 48 seconds
# Epoch:   1/1, Batch: 27900/28892, Training Loss Error:  2.609, Training Time on 100 Batches: 47 seconds
# Epoch:   1/1, Batch: 28000/28892, Training Loss Error:  2.553, Training Time on 100 Batches: 54 seconds
# Epoch:   1/1, Batch: 28100/28892, Training Loss Error:  2.644, Training Time on 100 Batches: 86 seconds
# Epoch:   1/1, Batch: 28200/28892, Training Loss Error:  2.566, Training Time on 100 Batches: 35 seconds
# Epoch:   1/1, Batch: 28300/28892, Training Loss Error:  2.637, Training Time on 100 Batches: 43 seconds
# Epoch:   1/1, Batch: 28400/28892, Training Loss Error:  2.525, Training Time on 100 Batches: 37 seconds
# Epoch:   1/1, Batch: 28500/28892, Training Loss Error:  2.611, Training Time on 100 Batches: 37 seconds
# Epoch:   1/1, Batch: 28600/28892, Training Loss Error:  2.620, Training Time on 100 Batches: 45 seconds
# Epoch:   1/1, Batch: 28700/28892, Training Loss Error:  2.554, Training Time on 100 Batches: 43 seconds
# Epoch:   1/1, Batch: 28800/28892, Training Loss Error:  2.650, Training Time on 100 Batches: 38 seconds
# Validation Loss Error:  2.522, Batch Validation Time: 416 seconds
# I speak better now!!
# Game Over

# %%
checkpoint = "E:\Data\cornell movie-dialogs corpus/chatbot_weights.ckpt"
session = tf.InteractiveSession()
session.run(tf.global_variables_initializer())
saver = tf.train.Saver()
saver.restore(session, checkpoint)

# %%
def convert_string2int(question, word2int):
    question = clean_text(question)
    return [word2int.get(word, word2int['<OUT>']) for word in question.split()]

# %%
while(True):
    question = input("You: ")
    if question == 'Goodbye':
        break
    question = convert_string2int(question, questionswords2int)
    question = question + [questionswords2int['<PAD>']] * (25 - len(question))
    fake_batch = np.zeros((batch_size, 25))
    fake_batch[0] = question
    predicted_answer = session.run(test_predictions, {inputs: fake_batch, keep_prob: 0.5})[0]
    answer = ''
    for i in np.argmax(predicted_answer, 1):
        if answersints2word[i] == 'i':
            token = ' I'
        elif answersints2word[i] == '<EOS>':
            token = '.'
        elif answersints2word[i] == '<OUT>':
            token = 'out'
        else:
            token = ' ' + answersints2word[i]
        answer += token
        if token == '.':
            break
    print('ChatBot: ' + answer)
# Out:
# You: hii
# ChatBot:  mechanical cue cue cue cue lie! addressed addressed addressed addressed addressed addressed patience patience patience patience addressed addressed addressed addressed addressed patience patience patience patience
